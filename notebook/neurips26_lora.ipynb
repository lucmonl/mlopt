# %%
#general
from plot_functions import plot_figures_opts_attr
from main import graphs

lr, dataset_name, loss_name, opt_name, momentum, weight_decay, batch_size, epochs = 0.001, "20newsgroups", 'CrossEntropyLoss', "federated", 0.0, 0.0, 128, 2000
model_name= "gpt2"
client_opt, client_lr, client_momentum, client_weight_decay, client_num, client_epoch, sketch_size, non_iid_alpha, client_round  ="sgd", 0.1, 0.9, 0.0, 5, 1, -1, 1.0, 0

model_params = {}
model_params["fr_1e-2"] = {"non_iid": non_iid_alpha, "lora_rank": 16, "lora_alpha": 16,  "fedlora_avg": "fr",  'server_opt': 'sgd', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, "client_weight_decay": client_weight_decay, "client_num": client_num, 'client_epoch': client_epoch, 'client_round': client_round, "sketch_size": sketch_size}
model_params["fr_1e-3"] = {"non_iid": non_iid_alpha, "lora_rank": 16, "lora_alpha": 16,  "fedlora_avg": "fr",  'server_opt': 'sgd', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, "client_weight_decay": client_weight_decay, "client_num": client_num, 'client_epoch': client_epoch,  "sketch_size": sketch_size}

model_params["muon_v1"] = {"non_iid": non_iid_alpha, "lora_rank": 16, "lora_alpha": 16, "fedlora_avg": "muonlora_v1",   'server_opt': 'sgd', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, "client_weight_decay": client_weight_decay, "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": sketch_size}
model_params["muon_v2"] = {"non_iid": non_iid_alpha, "lora_rank": 16, "lora_alpha": 16, "fedlora_avg": "muonlora_v2",   'server_opt': 'sgd', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, "client_weight_decay": client_weight_decay, "client_num": client_num, 'client_epoch': client_epoch, 'client_round': client_round, "sketch_size": sketch_size}

opt_params = {}
opt_params["fr_1e-2"] = {'lr': 0.01, 'dataset_name':dataset_name, 'loss': loss_name, 'opt':opt_name, 'model_name':model_name, 'momentum':momentum, 'weight_decay':weight_decay, 'batch_size':batch_size, 'epochs':epochs}
opt_params["fr_1e-3"] = {'lr': 0.001, 'dataset_name':dataset_name, 'loss': loss_name, 'opt':opt_name, 'model_name':model_name, 'momentum':momentum, 'weight_decay':weight_decay, 'batch_size':batch_size, 'epochs':epochs}
opt_params["muon_v1"] = {'lr': lr, 'dataset_name':dataset_name, 'loss': loss_name, 'opt':opt_name, 'model_name':model_name, 'momentum':momentum, 'weight_decay':weight_decay, 'batch_size':batch_size, 'epochs':epochs}
opt_params["muon_v2"] = {'lr': lr, 'dataset_name':dataset_name, 'loss': loss_name, 'opt':opt_name, 'model_name':model_name, 'momentum':momentum, 'weight_decay':weight_decay, 'batch_size':batch_size, 'epochs':epochs}

#plot_figures_opts_attr([["lora_avg", "lora_flora", "lora_ffa", "lora_fedex",  "lora_flasc", "lora_svd"]], model_params, opt_params, ["test_acc"], start=4, end=20, alpha=1.0, linewidth=1.0, titles=[""], legends=[["FedIT", "FLoRA", "FFA", "FedEX", "FLASC", "TFLoRA"]], save_dir=None, return_last=False) #"../plots/iclr25workshop/cifar_acc.pdf"
plot_figures_opts_attr([["fr_1e-2", "fr_1e-3", "muon_v1", "muon_v2"]], model_params, opt_params, ["test_loss"], start=0, end=-1, alpha=1.0, linewidth=1.0, titles=[""], legends=[["FR_1e-2", "FR_1e-3", "Muon_v1", "Muon_v2"]], save_dir=None, yaxis=[""], return_last=False)
# Out:
# /projects/illinois/eng/cs/arindamb/lucmon/mlopt/results/20newsgroups/CrossEntropyLoss/federated/gpt2/non_iid_1.0/lora_rank_16/lora_alpha_16/fedlora_avg_fr/server_opt_sgd/client_opt_sgd/client_lr_0.1/client_momentum_0.9/client_weight_decay_0.0/client_num_5/client_epoch_1/client_round_0/sketch_size_-1/lr_0.01/moment_0.0/wd_0.0/batch_size_128/epoch_2000/run_0/
# /projects/illinois/eng/cs/arindamb/lucmon/mlopt/results/20newsgroups/CrossEntropyLoss/federated/gpt2/non_iid_1.0/lora_rank_16/lora_alpha_16/fedlora_avg_fr/server_opt_sgd/client_opt_sgd/client_lr_0.1/client_momentum_0.9/client_weight_decay_0.0/client_num_5/client_epoch_1/sketch_size_-1/lr_0.001/moment_0.0/wd_0.0/batch_size_128/epoch_2000/run_0/
# ...

# %%
#general
from plot_functions import plot_figures_opts_attr
from main import graphs

lr, dataset_name, loss_name, opt_name, momentum, weight_decay, batch_size, epochs = 0.001, "20newsgroups", 'CrossEntropyLoss', "federated", 0.0, 0.0, 128, 2000
model_name= "gpt2"
client_opt, client_lr, client_momentum, client_weight_decay, client_num, client_epoch, sketch_size, non_iid_alpha, client_round  ="sgd", 0.1, 0.9, 0.0, 5, 1, -1, 1.0, 0

model_params = {}
model_params["fr_1e-2"] = {"non_iid": non_iid_alpha, "lora_rank": 16, "lora_alpha": 16,  "fedlora_avg": "fr",  'server_opt': 'sgd', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, "client_weight_decay": client_weight_decay, "client_num": client_num, 'client_epoch': client_epoch, 'client_round': client_round, "sketch_size": sketch_size}
model_params["fr_1e-3"] = {"non_iid": non_iid_alpha, "lora_rank": 16, "lora_alpha": 16,  "fedlora_avg": "fr",  'server_opt': 'sgd', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, "client_weight_decay": client_weight_decay, "client_num": client_num, 'client_epoch': client_epoch,  "sketch_size": sketch_size}

model_params["muon_v1"] = {"non_iid": non_iid_alpha, "lora_rank": 16, "lora_alpha": 16, "fedlora_avg": "muonlora_v1",   'server_opt': 'sgd', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, "client_weight_decay": client_weight_decay, "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": sketch_size}
model_params["muon_v2"] = {"non_iid": non_iid_alpha, "lora_rank": 16, "lora_alpha": 16, "fedlora_avg": "muonlora_v2",   'server_opt': 'sgd', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, "client_weight_decay": client_weight_decay, "client_num": client_num, 'client_epoch': client_epoch, 'client_round': client_round, "sketch_size": sketch_size}

opt_params = {}
opt_params["fr_1e-2"] = {'lr': 0.01, 'dataset_name':dataset_name, 'loss': loss_name, 'opt':opt_name, 'model_name':model_name, 'momentum':momentum, 'weight_decay':weight_decay, 'batch_size':batch_size, 'epochs':epochs}
opt_params["fr_1e-3"] = {'lr': 0.001, 'dataset_name':dataset_name, 'loss': loss_name, 'opt':opt_name, 'model_name':model_name, 'momentum':momentum, 'weight_decay':weight_decay, 'batch_size':batch_size, 'epochs':epochs}
opt_params["muon_v1"] = {'lr': lr, 'dataset_name':dataset_name, 'loss': loss_name, 'opt':opt_name, 'model_name':model_name, 'momentum':momentum, 'weight_decay':weight_decay, 'batch_size':batch_size, 'epochs':epochs}
opt_params["muon_v2"] = {'lr': 0.0011, 'dataset_name':dataset_name, 'loss': loss_name, 'opt':opt_name, 'model_name':model_name, 'momentum':momentum, 'weight_decay':weight_decay, 'batch_size':batch_size, 'epochs':epochs}

#plot_figures_opts_attr([["lora_avg", "lora_flora", "lora_ffa", "lora_fedex",  "lora_flasc", "lora_svd"]], model_params, opt_params, ["test_acc"], start=4, end=20, alpha=1.0, linewidth=1.0, titles=[""], legends=[["FedIT", "FLoRA", "FFA", "FedEX", "FLASC", "TFLoRA"]], save_dir=None, return_last=False) #"../plots/iclr25workshop/cifar_acc.pdf"
plot_figures_opts_attr([["fr_1e-2", "fr_1e-3", "muon_v1", "muon_v2"]], model_params, opt_params, ["test_loss"], start=0, end=-1, alpha=1.0, linewidth=1.0, titles=[""], legends=[["FR_1e-2", "FR_1e-3", "Muon_v1", "Muon_v2"]], save_dir=None, yaxis=[""], return_last=False)
# Out:
# /u/lucmon/mlopt/results/20newsgroups/CrossEntropyLoss/federated/gpt2/non_iid_1.0/lora_rank_16/lora_alpha_16/fedlora_avg_fr/server_opt_sgd/client_opt_sgd/client_lr_0.1/client_momentum_0.9/client_weight_decay_0.0/client_num_5/client_epoch_1/client_round_0/sketch_size_-1/lr_0.01/moment_0.0/wd_0.0/batch_size_128/epoch_2000/run_0/
# /u/lucmon/mlopt/results/20newsgroups/CrossEntropyLoss/federated/gpt2/non_iid_1.0/lora_rank_16/lora_alpha_16/fedlora_avg_fr/server_opt_sgd/client_opt_sgd/client_lr_0.1/client_momentum_0.9/client_weight_decay_0.0/client_num_5/client_epoch_1/sketch_size_-1/lr_0.001/moment_0.0/wd_0.0/batch_size_128/epoch_2000/run_0/
# /u/lucmon/mlopt/results/20newsgroups/CrossEntropyLoss/federated/gpt2/non_iid_1.0/lora_rank_16/lora_alpha_16/fedlora_avg_muonlora_v1/server_opt_sgd/client_opt_sgd/client_lr_0.1/client_momentum_0.9/client_weight_decay_0.0/client_num_5/client_epoch_1/sketch_size_-1/lr_0.001/moment_0.0/wd_0.0/batch_size_128/epoch_2000/run_0/
# ...

# %%
#general
from plot_functions import plot_figures_opts_attr
from main import graphs

lr, dataset_name, loss_name, opt_name, momentum, weight_decay, batch_size, epochs = 0.01, "20newsgroups", 'CrossEntropyLoss', "federated", 0.0, 0.0, 128, 2000
model_name= "gpt2"
client_opt, client_lr, client_momentum, client_weight_decay, client_num, client_epoch, sketch_size, non_iid_alpha, client_round  ="sgd", 0.1, 0.9, 0.0, 5, 1, -1, 1.0, 0

model_params = {}
model_params["fr"] = {"non_iid": non_iid_alpha, "lora_rank": 16, "lora_alpha": 16,  "fedlora_avg": "fr",  'server_opt': 'sgd', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, "client_weight_decay": client_weight_decay, "client_num": client_num, 'client_epoch': client_epoch, 'client_round': client_round, "sketch_size": sketch_size}
model_params["muon"] = {"non_iid": non_iid_alpha, "lora_rank": 16, "lora_alpha": 16, "fedlora_avg": "muonlora_v1",   'server_opt': 'sgd', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, "client_weight_decay": client_weight_decay, "client_num": client_num, 'client_epoch': client_epoch, 'client_round': client_round, "sketch_size": sketch_size}

opt_params = {}
opt_params["fr"] = {'lr': lr, 'dataset_name':dataset_name, 'loss': loss_name, 'opt':opt_name, 'model_name':model_name, 'momentum':momentum, 'weight_decay':weight_decay, 'batch_size':batch_size, 'epochs':epochs}
opt_params["muon"] = {'lr': lr, 'dataset_name':dataset_name, 'loss': loss_name, 'opt':opt_name, 'model_name':model_name, 'momentum':momentum, 'weight_decay':weight_decay, 'batch_size':batch_size, 'epochs':epochs}

#plot_figures_opts_attr([["lora_avg", "lora_flora", "lora_ffa", "lora_fedex",  "lora_flasc", "lora_svd"]], model_params, opt_params, ["test_acc"], start=4, end=20, alpha=1.0, linewidth=1.0, titles=[""], legends=[["FedIT", "FLoRA", "FFA", "FedEX", "FLASC", "TFLoRA"]], save_dir=None, return_last=False) #"../plots/iclr25workshop/cifar_acc.pdf"
plot_figures_opts_attr([["fr", "muon"]], model_params, opt_params, ["test_loss"], start=10, end=-1, alpha=1.0, linewidth=1.0, titles=[""], legends=[["FR", "Muon"]], save_dir=None, return_last=False)
# Out:
# /projects/illinois/eng/cs/arindamb/lucmon/mlopt/results/20newsgroups/CrossEntropyLoss/federated/gpt2/non_iid_1.0/lora_rank_16/lora_alpha_16/fedlora_avg_fr/server_opt_sgd/client_opt_sgd/client_lr_0.1/client_momentum_0.9/client_weight_decay_0.0/client_num_5/client_epoch_1/client_round_0/sketch_size_-1/lr_0.01/moment_0.0/wd_0.0/batch_size_128/epoch_2000/run_0/
# /projects/illinois/eng/cs/arindamb/lucmon/mlopt/results/20newsgroups/CrossEntropyLoss/federated/gpt2/non_iid_1.0/lora_rank_16/lora_alpha_16/fedlora_avg_muonlora_v1/server_opt_sgd/client_opt_sgd/client_lr_0.1/client_momentum_0.9/client_weight_decay_0.0/client_num_5/client_epoch_1/client_round_0/sketch_size_-1/lr_0.01/moment_0.0/wd_0.0/batch_size_128/epoch_2000/run_0/

# %%
/projects/illinois/eng/cs/arindamb/lucmon/mlopt/results/20newsgroups/CrossEntropyLoss/federated/gpt2/non_iid_1.0/lora_rank_16/lora_alpha_16/fedlora_avg_muonlora_v1/server_opt_sgd/client_opt_sgd/client_lr_0.1/client_momentum_0.9/client_weight_decay_0.0/client_num_5/client_epoch_1/sketch_size_-1/lr_0.001/moment_0.0/wd_0.0/batch_size_128/epoch_2000/run_0/

/projects/illinois/eng/cs/arindamb/lucmon/mlopt/results/20newsgroups/CrossEntropyLoss/federated/gpt2/non_iid_1.0/lora_rank_16/lora_alpha_16/server_opt_sgd/client_opt_sgd/client_lr_0.1/client_momentum_0.9/client_weight_decay_0.0/client_num_5/client_epoch_1/sketch_size_-1/lr_0.001/moment_0.0/wd_0.0/batch_size_128/epoch_2000/run_0/train_graphs.pk

/projects/illinois/eng/cs/arindamb/lucmon/mlopt/results/20newsgroups/CrossEntropyLoss/federated/gpt2/non_iid_1.0/lora_rank_16/lora_alpha_16/fedlora_avg_fr/server_opt_sgd/client_opt_sgd/client_lr_0.1/client_momentum_0.9/client_weight_decay_0.0/client_num_5/client_epoch_1/sketch_size_-1/lr_0.001/moment_0.0/wd_0.0/batch_size_128/epoch_2000/run_0/

# %%
/projects/illinois/eng/cs/arindamb/lucmon/mlopt/results/fedllm_bench/HF_CrossEntropy/federated/meta-llama/Llama-3.1-8B-Instruct/task_name_ChatbotIT/lora_rank_16/lora_alpha_16/fedlora_avg_muonlora_v1/server_opt_sgd/client_opt_sgd/client_lr_0.1/client_momentum_0.9/client_weight_decay_0.0/client_num_236/client_epoch_1/client_round_0/sketch_size_-1/lr_0.001/moment_0.0/wd_0.0/batch_size_2/epoch_2000/run_0/

/projects/illinois/eng/cs/arindamb/lucmon/mlopt/results/fedllm_bench/HF_CrossEntropy/federated/meta-llama/Llama-3.1-8B-Instruct/task_name_ChatbotIT/lora_rank_16/lora_alpha_16/fedlora_avg_fr/server_opt_sgd/client_opt_sgd/client_lr_0.1/client_momentum_0.9/client_weight_decay_0.0/client_num_5/client_epoch_1/sketch_size_-1/lr_0.001/moment_0.0/wd_0.0/batch_size_128/epoch_2000/run_0/

# %%
#general
from plot_functions import plot_figures_opts_attr
from main import graphs

lr, dataset_name, task_name, loss_name, opt_name, momentum, weight_decay, batch_size, epochs = 0.001, "fedllm_bench", "ChatbotIT", 'HF_CrossEntropy', "federated", 0.0, 0.0, 2, 2000
model_name= "meta-llama/Llama-3.1-8B-Instruct"
client_opt, client_lr, client_momentum, client_weight_decay, client_num, client_epoch, sketch_size, non_iid_alpha, client_round  ="sgd", 0.1, 0.9, 0.0, 236, 1, -1, 1.0, 0

model_params = {}
model_params["fr"] = {"task_name": task_name, "lora_rank": 16, "lora_alpha": 16,  "fedlora_avg": "fr",  'server_opt': 'sgd', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, "client_weight_decay": client_weight_decay, "client_num": client_num, 'client_epoch': client_epoch, 'client_round': client_round, "sketch_size": sketch_size}
model_params["muon_v1"] = {"task_name": task_name, "lora_rank": 16, "lora_alpha": 16, "fedlora_avg": "muonlora_v1",   'server_opt': 'sgd', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, "client_weight_decay": client_weight_decay, "client_num": client_num, 'client_epoch': client_epoch, 'client_round': client_round, "sketch_size": sketch_size}
model_params["muon_v2"] = {"task_name": task_name, "lora_rank": 16, "lora_alpha": 16, "fedlora_avg": "muonlora_v2",   'server_opt': 'sgd', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, "client_weight_decay": client_weight_decay, "client_num": client_num, 'client_epoch': client_epoch, 'client_round': client_round, "sketch_size": sketch_size}

opt_params = {}
opt_params["fr"] = {'lr': lr, 'dataset_name':dataset_name, 'loss': loss_name, 'opt':opt_name, 'model_name':model_name, 'momentum':momentum, 'weight_decay':weight_decay, 'batch_size':batch_size, 'epochs':epochs}
opt_params["muon_v1"] = {'lr': lr, 'dataset_name':dataset_name, 'loss': loss_name, 'opt':opt_name, 'model_name':model_name, 'momentum':momentum, 'weight_decay':weight_decay, 'batch_size':batch_size, 'epochs':epochs}
opt_params["muon_v2"] = {'lr': lr, 'dataset_name':dataset_name, 'loss': loss_name, 'opt':opt_name, 'model_name':model_name, 'momentum':momentum, 'weight_decay':weight_decay, 'batch_size':batch_size, 'epochs':epochs}

#plot_figures_opts_attr([["lora_avg", "lora_flora", "lora_ffa", "lora_fedex",  "lora_flasc", "lora_svd"]], model_params, opt_params, ["test_acc"], start=4, end=20, alpha=1.0, linewidth=1.0, titles=[""], legends=[["FedIT", "FLoRA", "FFA", "FedEX", "FLASC", "TFLoRA"]], save_dir=None, return_last=False) #"../plots/iclr25workshop/cifar_acc.pdf"
plot_figures_opts_attr([["fr", "muon_v1", "muon_v2"]], model_params, opt_params, ["test_loss"], start=0, end=-5, alpha=1.0, linewidth=1.0, titles=[""], legends=[["FR", "Muon_v1", "Muon_v2"]], save_dir=None, yaxis=[""], return_last=False)
# Out:
# /u/lucmon/mlopt/results/fedllm_bench/HF_CrossEntropy/federated/meta-llama/Llama-3.1-8B-Instruct/task_name_ChatbotIT/lora_rank_16/lora_alpha_16/fedlora_avg_fr/server_opt_sgd/client_opt_sgd/client_lr_0.1/client_momentum_0.9/client_weight_decay_0.0/client_num_236/client_epoch_1/client_round_0/sketch_size_-1/lr_0.001/moment_0.0/wd_0.0/batch_size_2/epoch_2000/run_0/
# /u/lucmon/mlopt/results/fedllm_bench/HF_CrossEntropy/federated/meta-llama/Llama-3.1-8B-Instruct/task_name_ChatbotIT/lora_rank_16/lora_alpha_16/fedlora_avg_muonlora_v1/server_opt_sgd/client_opt_sgd/client_lr_0.1/client_momentum_0.9/client_weight_decay_0.0/client_num_236/client_epoch_1/client_round_0/sketch_size_-1/lr_0.001/moment_0.0/wd_0.0/batch_size_2/epoch_2000/run_0/
# ...

# %%
#general
from plot_functions import plot_figures_opts_attr
from main import graphs

lr, dataset_name, task_name, loss_name, opt_name, momentum, weight_decay, batch_size, epochs = 0.001, "fedllm_bench", "ChatbotIT", 'HF_CrossEntropy', "federated", 0.0, 0.0, 2, 10000
model_name= "meta-llama/Llama-3.1-8B-Instruct"
client_opt, client_lr, client_momentum, client_weight_decay, client_num, client_epoch, sketch_size, client_partial, non_iid_alpha, client_round  ="sgd", 0.1, 0.9, 0.0, 236, 1, -1, 0.04, 1.0, 0

model_params = {}
model_params["fr"] = {"task_name": task_name, "lora_rank": 16, "lora_alpha": 16,  "fedlora_avg": "fr",  'server_opt': 'sgd', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, "client_weight_decay": client_weight_decay, "client_num": client_num, 'client_epoch': client_epoch, 'client_round': client_round, "sketch_size": sketch_size, "client_partial": client_partial}
model_params["muon_v1"] = {"task_name": task_name, "lora_rank": 16, "lora_alpha": 16, "fedlora_avg": "muonlora_v1",   'server_opt': 'sgd', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, "client_weight_decay": client_weight_decay, "client_num": client_num, 'client_epoch': client_epoch, 'client_round': client_round, "sketch_size": sketch_size,  "client_partial": client_partial}
model_params["muon_v2"] = {"task_name": task_name, "lora_rank": 16, "lora_alpha": 16, "fedlora_avg": "muonlora_v2",   'server_opt': 'sgd', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, "client_weight_decay": client_weight_decay, "client_num": client_num, 'client_epoch': client_epoch, 'client_round': client_round, "sketch_size": sketch_size}

opt_params = {}
opt_params["fr"] = {'lr': lr, 'dataset_name':dataset_name, 'loss': loss_name, 'opt':opt_name, 'model_name':model_name, 'momentum':momentum, 'weight_decay':weight_decay, 'batch_size':batch_size, 'epochs':epochs}
opt_params["muon_v1"] = {'lr': lr, 'dataset_name':dataset_name, 'loss': loss_name, 'opt':opt_name, 'model_name':model_name, 'momentum':momentum, 'weight_decay':weight_decay, 'batch_size':batch_size, 'epochs':epochs}
opt_params["muon_v2"] = {'lr': lr, 'dataset_name':dataset_name, 'loss': loss_name, 'opt':opt_name, 'model_name':model_name, 'momentum':momentum, 'weight_decay':weight_decay, 'batch_size':batch_size, 'epochs':2000}

#plot_figures_opts_attr([["lora_avg", "lora_flora", "lora_ffa", "lora_fedex",  "lora_flasc", "lora_svd"]], model_params, opt_params, ["test_acc"], start=4, end=20, alpha=1.0, linewidth=1.0, titles=[""], legends=[["FedIT", "FLoRA", "FFA", "FedEX", "FLASC", "TFLoRA"]], save_dir=None, return_last=False) #"../plots/iclr25workshop/cifar_acc.pdf"
plot_figures_opts_attr([["fr", "muon_v1", "muon_v2"]], model_params, opt_params, ["test_loss"], start=0, end=30, alpha=1.0, linewidth=1.0, titles=[""], legends=[["FR", "Muon_v1", "Muon_v2"]], save_dir=None, yaxis=[""], return_last=False)
# Out:
# /u/lucmon/mlopt/results/fedllm_bench/HF_CrossEntropy/federated/meta-llama/Llama-3.1-8B-Instruct/task_name_ChatbotIT/lora_rank_16/lora_alpha_16/fedlora_avg_fr/server_opt_sgd/client_opt_sgd/client_lr_0.1/client_momentum_0.9/client_weight_decay_0.0/client_num_236/client_epoch_1/client_round_0/sketch_size_-1/client_partial_0.04/lr_0.001/moment_0.0/wd_0.0/batch_size_2/epoch_10000/run_0/
# /u/lucmon/mlopt/results/fedllm_bench/HF_CrossEntropy/federated/meta-llama/Llama-3.1-8B-Instruct/task_name_ChatbotIT/lora_rank_16/lora_alpha_16/fedlora_avg_muonlora_v1/server_opt_sgd/client_opt_sgd/client_lr_0.1/client_momentum_0.9/client_weight_decay_0.0/client_num_236/client_epoch_1/client_round_0/sketch_size_-1/client_partial_0.04/lr_0.001/moment_0.0/wd_0.0/batch_size_2/epoch_10000/run_0/
# ...

# %%
#/u/lucmon/mlopt/results/fedllm_bench/HF_CrossEntropy/federated/meta-llama/Llama-3.1-8B-Instruct/task_name_ChatbotIT/lora_rank_16/lora_alpha_16/fedlora_avg_fr/server_opt_sgd/client_opt_sgd/client_lr_0.1/client_momentum_0.9/client_weight_decay_0.0/client_num_64/client_epoch_1/client_round_0/sketch_size_-1/lr_0.001/moment_0.0/wd_0.0/batch_size_2/epoch_10000/run_0/

#general
from plot_functions import plot_figures_opts_attr
from main import graphs

lr, dataset_name, task_name, loss_name, opt_name, momentum, weight_decay, batch_size, epochs = 0.001, "fedllm_bench", "ChatbotIT", 'HF_CrossEntropy', "federated", 0.0, 0.0, 2, 10000
model_name= "meta-llama/Llama-3.1-8B-Instruct"
client_opt, client_lr, client_momentum, client_weight_decay, client_num, client_epoch, sketch_size, non_iid_alpha, client_round  ="sgd", 0.1, 0.9, 0.0, 64, 1, -1, 1.0, 0

model_params = {}
model_params["fr"] = {"task_name": task_name, "lora_rank": 16, "lora_alpha": 16,  "fedlora_avg": "fr",  'server_opt': 'sgd', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, "client_weight_decay": client_weight_decay, "client_num": client_num, 'client_epoch': client_epoch, 'client_round': client_round, "sketch_size": sketch_size}
model_params["muon_v1"] = {"task_name": task_name, "lora_rank": 16, "lora_alpha": 16, "fedlora_avg": "muonlora_v1",   'server_opt': 'sgd', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, "client_weight_decay": client_weight_decay, "client_num": client_num, 'client_epoch': client_epoch, 'client_round': client_round, "sketch_size": sketch_size}
model_params["muon_v2"] = {"task_name": task_name, "lora_rank": 16, "lora_alpha": 16, "fedlora_avg": "muonlora_v2",   'server_opt': 'sgd', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, "client_weight_decay": client_weight_decay, "client_num": client_num, 'client_epoch': client_epoch, 'client_round': client_round, "sketch_size": sketch_size}
model_params["muon_v3"] = {"task_name": task_name, "lora_rank": 16, "lora_alpha": 16, "fedlora_avg": "muonlora_v3",   'server_opt': 'sgd', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, "client_weight_decay": client_weight_decay, "client_num": client_num, 'client_epoch': client_epoch, 'client_round': client_round, "sketch_size": sketch_size}

opt_params = {}
opt_params["fr"] = {'lr': 0.001, 'dataset_name':dataset_name, 'loss': loss_name, 'opt':opt_name, 'model_name':model_name, 'momentum':momentum, 'weight_decay':weight_decay, 'batch_size':batch_size, 'epochs':epochs}
opt_params["muon_v1"] = {'lr': 0.001, 'dataset_name':dataset_name, 'loss': loss_name, 'opt':opt_name, 'model_name':model_name, 'momentum':momentum, 'weight_decay':weight_decay, 'batch_size':batch_size, 'epochs':epochs}
opt_params["muon_v2"] = {'lr': lr, 'dataset_name':dataset_name, 'loss': loss_name, 'opt':opt_name, 'model_name':model_name, 'momentum':momentum, 'weight_decay':weight_decay, 'batch_size':batch_size, 'epochs':2000}
opt_params["muon_v3"] = {'lr': lr, 'dataset_name':dataset_name, 'loss': loss_name, 'opt':opt_name, 'model_name':model_name, 'momentum':momentum, 'weight_decay':weight_decay, 'batch_size':batch_size, 'epochs':epochs}

#plot_figures_opts_attr([["lora_avg", "lora_flora", "lora_ffa", "lora_fedex",  "lora_flasc", "lora_svd"]], model_params, opt_params, ["test_acc"], start=4, end=20, alpha=1.0, linewidth=1.0, titles=[""], legends=[["FedIT", "FLoRA", "FFA", "FedEX", "FLASC", "TFLoRA"]], save_dir=None, return_last=False) #"../plots/iclr25workshop/cifar_acc.pdf"
plot_figures_opts_attr([["fr", "muon_v1"]], model_params, opt_params, ["test_loss"], start=0, end=-1, alpha=1.0, linewidth=1.0, titles=[""], legends=[["FR", "Muon_v1", "Muon_v3"]], save_dir=None, yaxis=[""], return_last=False)
# Out:
# /u/lucmon/mlopt/results/fedllm_bench/HF_CrossEntropy/federated/meta-llama/Llama-3.1-8B-Instruct/task_name_ChatbotIT/lora_rank_16/lora_alpha_16/fedlora_avg_fr/server_opt_sgd/client_opt_sgd/client_lr_0.1/client_momentum_0.9/client_weight_decay_0.0/client_num_64/client_epoch_1/client_round_0/sketch_size_-1/lr_0.001/moment_0.0/wd_0.0/batch_size_2/epoch_10000/run_0/
# /u/lucmon/mlopt/results/fedllm_bench/HF_CrossEntropy/federated/meta-llama/Llama-3.1-8B-Instruct/task_name_ChatbotIT/lora_rank_16/lora_alpha_16/fedlora_avg_muonlora_v1/server_opt_sgd/client_opt_sgd/client_lr_0.1/client_momentum_0.9/client_weight_decay_0.0/client_num_64/client_epoch_1/client_round_0/sketch_size_-1/lr_0.001/moment_0.0/wd_0.0/batch_size_2/epoch_10000/run_0/

# %%
#/u/lucmon/mlopt/results/fedllm_bench/HF_CrossEntropy/federated/meta-llama/Llama-3.1-8B-Instruct/task_name_ChatbotIT/lora_rank_16/lora_alpha_16/fedlora_avg_fr/server_opt_sgd/client_opt_sgd/client_lr_0.1/client_momentum_0.9/client_weight_decay_0.0/client_num_64/client_epoch_1/client_round_0/sketch_size_-1/lr_0.001/moment_0.0/wd_0.0/batch_size_2/epoch_10000/run_0/

#general
from plot_functions import plot_figures_opts_attr
from main import graphs

lr, dataset_name, task_name, loss_name, opt_name, momentum, weight_decay, batch_size, epochs = 0.001, "fedllm_bench", "ChatbotIT", 'HF_CrossEntropy', "federated", 0.0, 0.0, 2, 10000
model_name= "meta-llama/Llama-3.1-8B-Instruct"
client_opt, client_lr, client_momentum, client_weight_decay, client_num, client_epoch, sketch_size, non_iid_alpha, client_round  ="sgd", 0.1, 0.9, 0.0, 5, 1, -1, 1.0, 0

model_params = {}
model_params["fr"] = {"task_name": task_name, "lora_rank": 16, "lora_alpha": 16,  "fedlora_avg": "fr",  'server_opt': 'sgd', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, "client_weight_decay": client_weight_decay, "client_num": client_num, 'client_epoch': client_epoch, 'client_round': client_round, "sketch_size": sketch_size}
model_params["muon_v1"] = {"task_name": task_name, "lora_rank": 16, "lora_alpha": 16, "fedlora_avg": "muonlora_v1",   'server_opt': 'sgd', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, "client_weight_decay": client_weight_decay, "client_num": client_num, 'client_epoch': client_epoch, 'client_round': client_round, "sketch_size": sketch_size}
model_params["muon_v2"] = {"task_name": task_name, "lora_rank": 16, "lora_alpha": 16, "fedlora_avg": "muonlora_v2",   'server_opt': 'sgd', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, "client_weight_decay": client_weight_decay, "client_num": client_num, 'client_epoch': client_epoch, 'client_round': client_round, "sketch_size": sketch_size}
model_params["muon_v3"] = {"task_name": task_name, "lora_rank": 16, "lora_alpha": 16, "fedlora_avg": "muonlora_v3",   'server_opt': 'sgd', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, "client_weight_decay": client_weight_decay, "client_num": client_num, 'client_epoch': client_epoch, 'client_round': client_round, "sketch_size": sketch_size}

opt_params = {}
opt_params["fr"] = {'lr': 0.01, 'dataset_name':dataset_name, 'loss': loss_name, 'opt':opt_name, 'model_name':model_name, 'momentum':momentum, 'weight_decay':weight_decay, 'batch_size':batch_size, 'epochs':epochs}
opt_params["muon_v1"] = {'lr': 0.001, 'dataset_name':dataset_name, 'loss': loss_name, 'opt':opt_name, 'model_name':model_name, 'momentum':momentum, 'weight_decay':weight_decay, 'batch_size':batch_size, 'epochs':epochs}
opt_params["muon_v2"] = {'lr': lr, 'dataset_name':dataset_name, 'loss': loss_name, 'opt':opt_name, 'model_name':model_name, 'momentum':momentum, 'weight_decay':weight_decay, 'batch_size':batch_size, 'epochs':epochs}
opt_params["muon_v3"] = {'lr': lr, 'dataset_name':dataset_name, 'loss': loss_name, 'opt':opt_name, 'model_name':model_name, 'momentum':momentum, 'weight_decay':weight_decay, 'batch_size':batch_size, 'epochs':epochs}

#plot_figures_opts_attr([["lora_avg", "lora_flora", "lora_ffa", "lora_fedex",  "lora_flasc", "lora_svd"]], model_params, opt_params, ["test_acc"], start=4, end=20, alpha=1.0, linewidth=1.0, titles=[""], legends=[["FedIT", "FLoRA", "FFA", "FedEX", "FLASC", "TFLoRA"]], save_dir=None, return_last=False) #"../plots/iclr25workshop/cifar_acc.pdf"
plot_figures_opts_attr([["fr", "muon_v2"]], model_params, opt_params, [ "test_loss"], start=0, end=None, alpha=1.0, linewidth=1.0, titles=[""], legends=[["FR", "Muon_v1", "Muon_v3"]], save_dir=None, yaxis=[""], return_last=False)
# Out:
# /u/lucmon/mlopt/results/fedllm_bench/HF_CrossEntropy/federated/meta-llama/Llama-3.1-8B-Instruct/task_name_ChatbotIT/lora_rank_16/lora_alpha_16/fedlora_avg_fr/server_opt_sgd/client_opt_sgd/client_lr_0.1/client_momentum_0.9/client_weight_decay_0.0/client_num_5/client_epoch_1/client_round_0/sketch_size_-1/lr_0.01/moment_0.0/wd_0.0/batch_size_2/epoch_10000/run_0/
# /u/lucmon/mlopt/results/fedllm_bench/HF_CrossEntropy/federated/meta-llama/Llama-3.1-8B-Instruct/task_name_ChatbotIT/lora_rank_16/lora_alpha_16/fedlora_avg_muonlora_v2/server_opt_sgd/client_opt_sgd/client_lr_0.1/client_momentum_0.9/client_weight_decay_0.0/client_num_5/client_epoch_1/client_round_0/sketch_size_-1/lr_0.001/moment_0.0/wd_0.0/batch_size_2/epoch_10000/run_0/

# %%
#/u/lucmon/mlopt/results/fedllm_bench/HF_CrossEntropy/federated/meta-llama/Llama-3.1-8B-Instruct/task_name_ChatbotIT/lora_rank_16/lora_alpha_16/fedlora_avg_fr/server_opt_sgd/client_opt_sgd/client_lr_0.1/client_momentum_0.9/client_weight_decay_0.0/client_num_64/client_epoch_1/client_round_0/sketch_size_-1/lr_0.001/moment_0.0/wd_0.0/batch_size_2/epoch_10000/run_0/

#general
from plot_functions import plot_figures_opts_attr
from main import graphs

lr, dataset_name, task_name, loss_name, opt_name, momentum, weight_decay, batch_size, epochs = 0.001, "fedllm_bench", "ChatbotIT", 'HF_CrossEntropy', "federated", 0.0, 0.0, 2, 10000
model_name= "meta-llama/Llama-3.1-8B-Instruct"
client_opt, client_lr, client_momentum, client_weight_decay, client_num, client_epoch, sketch_size, non_iid_alpha, client_round  ="sgd", 0.1, 0.9, 0.0, 5, 1, -1, 1.0, 0

model_params = {}
model_params["fr"] = {"task_name": task_name, "lora_rank": 16, "lora_alpha": 16,  "fedlora_avg": "fr",  'server_opt': 'sgd', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, "client_weight_decay": client_weight_decay, "client_num": client_num, 'client_epoch': client_epoch, 'client_round': client_round, "sketch_size": sketch_size}
model_params["muon_v1"] = {"task_name": task_name, "lora_rank": 16, "lora_alpha": 16, "fedlora_avg": "muonlora_v1",   'server_opt': 'sgd', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, "client_weight_decay": client_weight_decay, "client_num": client_num, 'client_epoch': client_epoch, 'client_round': client_round, "sketch_size": sketch_size}
model_params["muon_v2-0.001"] = {"task_name": task_name, "lora_rank": 16, "lora_alpha": 16, "fedlora_avg": "muonlora_v2",   'server_opt': 'sgd', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, "client_weight_decay": client_weight_decay, "client_num": client_num, 'client_epoch': client_epoch, 'client_round': client_round, "sketch_size": sketch_size}
model_params["muon_v2-0.01"] = {"task_name": task_name, "lora_rank": 16, "lora_alpha": 16, "fedlora_avg": "muonlora_v2",   'server_opt': 'sgd', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, "client_weight_decay": client_weight_decay, "client_num": client_num, 'client_epoch': client_epoch, 'client_round': client_round, "sketch_size": sketch_size}
model_params["muon_v3"] = {"task_name": task_name, "lora_rank": 16, "lora_alpha": 16, "fedlora_avg": "muonlora_v3",   'server_opt': 'sgd', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, "client_weight_decay": client_weight_decay, "client_num": client_num, 'client_epoch': client_epoch, 'client_round': client_round, "sketch_size": sketch_size}

opt_params = {}
opt_params["fr"] = {'lr': 0.1, 'dataset_name':dataset_name, 'loss': loss_name, 'opt':opt_name, 'model_name':model_name, 'momentum':momentum, 'weight_decay':weight_decay, 'batch_size':batch_size, 'epochs':epochs}
opt_params["muon_v1"] = {'lr': lr, 'dataset_name':dataset_name, 'loss': loss_name, 'opt':opt_name, 'model_name':model_name, 'momentum':momentum, 'weight_decay':weight_decay, 'batch_size':batch_size, 'epochs':epochs}
opt_params["muon_v2-0.001"] = {'lr': 0.001, 'dataset_name':dataset_name, 'loss': loss_name, 'opt':opt_name, 'model_name':model_name, 'momentum':momentum, 'weight_decay':weight_decay, 'batch_size':batch_size, 'epochs':epochs}
opt_params["muon_v2-0.01"] = {'lr': 0.01, 'dataset_name':dataset_name, 'loss': loss_name, 'opt':opt_name, 'model_name':model_name, 'momentum':momentum, 'weight_decay':weight_decay, 'batch_size':batch_size, 'epochs':epochs}
opt_params["muon_v3"] = {'lr': lr, 'dataset_name':dataset_name, 'loss': loss_name, 'opt':opt_name, 'model_name':model_name, 'momentum':momentum, 'weight_decay':weight_decay, 'batch_size':batch_size, 'epochs':epochs}

#plot_figures_opts_attr([["lora_avg", "lora_flora", "lora_ffa", "lora_fedex",  "lora_flasc", "lora_svd"]], model_params, opt_params, ["test_acc"], start=4, end=20, alpha=1.0, linewidth=1.0, titles=[""], legends=[["FedIT", "FLoRA", "FFA", "FedEX", "FLASC", "TFLoRA"]], save_dir=None, return_last=False) #"../plots/iclr25workshop/cifar_acc.pdf"
plot_figures_opts_attr([["fr", "muon_v2-0.001", "muon_v2-0.01"]], model_params, opt_params, ["test_loss"], start=0, end=100, alpha=1.0, linewidth=1.0, titles=[""], legends=[["FR-0.1", "Muon_v2-0.001", "Muon_v2-0.01"]], save_dir=None, yaxis=[""], return_last=False)
# Out:
# /u/lucmon/mlopt/results/fedllm_bench/HF_CrossEntropy/federated/meta-llama/Llama-3.1-8B-Instruct/task_name_ChatbotIT/lora_rank_16/lora_alpha_16/fedlora_avg_fr/server_opt_sgd/client_opt_sgd/client_lr_0.1/client_momentum_0.9/client_weight_decay_0.0/client_num_5/client_epoch_1/client_round_0/sketch_size_-1/lr_0.1/moment_0.0/wd_0.0/batch_size_2/epoch_10000/run_0/
# /u/lucmon/mlopt/results/fedllm_bench/HF_CrossEntropy/federated/meta-llama/Llama-3.1-8B-Instruct/task_name_ChatbotIT/lora_rank_16/lora_alpha_16/fedlora_avg_muonlora_v2/server_opt_sgd/client_opt_sgd/client_lr_0.1/client_momentum_0.9/client_weight_decay_0.0/client_num_5/client_epoch_1/client_round_0/sketch_size_-1/lr_0.001/moment_0.0/wd_0.0/batch_size_2/epoch_10000/run_0/
# ...

# %%
#/u/lucmon/mlopt/results/fedllm_bench/HF_CrossEntropy/federated/meta-llama/Llama-3.1-8B-Instruct/task_name_ChatbotIT/lora_rank_16/lora_alpha_16/fedlora_avg_fr/server_opt_sgd/client_opt_sgd/client_lr_0.1/client_momentum_0.9/client_weight_decay_0.0/client_num_64/client_epoch_1/client_round_0/sketch_size_-1/lr_0.001/moment_0.0/wd_0.0/batch_size_2/epoch_10000/run_0/

#general
from plot_functions import plot_figures_opts_attr
from main import graphs

lr, dataset_name, task_name, loss_name, opt_name, momentum, weight_decay, batch_size, epochs = 0.001, "fedllm_bench", "ChatbotIT", 'HF_CrossEntropy', "federated", 0.0, 0.0, 2, 10000
model_name= "meta-llama/Llama-3.1-8B-Instruct"
client_opt, client_lr, client_momentum, client_weight_decay, client_num, client_epoch, sketch_size, non_iid_alpha, client_round  ="sgd", 0.1, 0.9, 0.0, 5, 1, -1, 1.0, 0

model_params = {}
model_params["fr"] = {"task_name": task_name, "lora_rank": 16, "lora_alpha": 16,  "fedlora_avg": "fr",  'server_opt': 'sgd', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, "client_weight_decay": client_weight_decay, "client_num": client_num, 'client_epoch': client_epoch, 'client_round': client_round, "sketch_size": sketch_size}
model_params["muon_v1"] = {"task_name": task_name, "lora_rank": 16, "lora_alpha": 16, "fedlora_avg": "muonlora_v1",   'server_opt': 'sgd', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, "client_weight_decay": client_weight_decay, "client_num": client_num, 'client_epoch': client_epoch, 'client_round': client_round, "sketch_size": sketch_size}
model_params["muon_v2-0.002"] = {"task_name": task_name, "lora_rank": 16, "lora_alpha": 16, "fedlora_avg": "muonlora_v2",   'server_opt': 'sgd', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, "client_weight_decay": client_weight_decay, "client_num": client_num, 'client_epoch': client_epoch, 'client_round': client_round, "sketch_size": sketch_size, "scheduler": "cosine", "lr_min": 1e-5}
model_params["muon_v2-0.001"] = {"task_name": task_name, "lora_rank": 16, "lora_alpha": 16, "fedlora_avg": "muonlora_v2",   'server_opt': 'sgd', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, "client_weight_decay": client_weight_decay, "client_num": client_num, 'client_epoch': client_epoch, 'client_round': client_round, "sketch_size": sketch_size}
model_params["muon_v2-0.01"] = {"task_name": task_name, "lora_rank": 16, "lora_alpha": 16, "fedlora_avg": "muonlora_v2",   'server_opt': 'sgd', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, "client_weight_decay": client_weight_decay, "client_num": client_num, 'client_epoch': client_epoch, 'client_round': client_round, "sketch_size": sketch_size, "scheduler": "cosine", "lr_min": 1e-5}
model_params["muon_v3"] = {"task_name": task_name, "lora_rank": 16, "lora_alpha": 16, "fedlora_avg": "muonlora_v3",   'server_opt': 'sgd', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, "client_weight_decay": client_weight_decay, "client_num": client_num, 'client_epoch': client_epoch, 'client_round': client_round, "sketch_size": sketch_size}

opt_params = {}
opt_params["fr"] = {'lr': 0.1, 'dataset_name':dataset_name, 'loss': loss_name, 'opt':opt_name, 'model_name':model_name, 'momentum':momentum, 'weight_decay':weight_decay, 'batch_size':batch_size, 'epochs':epochs}
opt_params["muon_v1"] = {'lr': lr, 'dataset_name':dataset_name, 'loss': loss_name, 'opt':opt_name, 'model_name':model_name, 'momentum':momentum, 'weight_decay':weight_decay, 'batch_size':batch_size, 'epochs':epochs}
opt_params["muon_v2-0.002"] = {'lr': 0.005, 'dataset_name':dataset_name, 'loss': loss_name, 'opt':opt_name, 'model_name':model_name, 'momentum':momentum, 'weight_decay':weight_decay, 'batch_size':batch_size, 'epochs':500}
opt_params["muon_v2-0.001"] = {'lr': 0.001, 'dataset_name':dataset_name, 'loss': loss_name, 'opt':opt_name, 'model_name':model_name, 'momentum':momentum, 'weight_decay':weight_decay, 'batch_size':batch_size, 'epochs':epochs}
opt_params["muon_v2-0.01"] = {'lr': 0.01, 'dataset_name':dataset_name, 'loss': loss_name, 'opt':opt_name, 'model_name':model_name, 'momentum':momentum, 'weight_decay':weight_decay, 'batch_size':batch_size, 'epochs':800}
opt_params["muon_v3"] = {'lr': lr, 'dataset_name':dataset_name, 'loss': loss_name, 'opt':opt_name, 'model_name':model_name, 'momentum':momentum, 'weight_decay':weight_decay, 'batch_size':batch_size, 'epochs':epochs}

#plot_figures_opts_attr([["lora_avg", "lora_flora", "lora_ffa", "lora_fedex",  "lora_flasc", "lora_svd"]], model_params, opt_params, ["test_acc"], start=4, end=20, alpha=1.0, linewidth=1.0, titles=[""], legends=[["FedIT", "FLoRA", "FFA", "FedEX", "FLASC", "TFLoRA"]], save_dir=None, return_last=False) #"../plots/iclr25workshop/cifar_acc.pdf"
plot_figures_opts_attr([["fr", "muon_v2-0.002", "muon_v2-0.01"]], model_params, opt_params, ["loss"], start=0, end=80, alpha=1.0, linewidth=1.0, titles=[""], legends=[["FR-0.1", "Muon_v2-0.001", "Muon_v2-0.01"]], save_dir=None, yaxis=[""], return_last=False)
plot_figures_opts_attr([["fr", "muon_v2-0.002", "muon_v2-0.01"]], model_params, opt_params, ["test_loss"], start=0, end=80, alpha=1.0, linewidth=1.0, titles=[""], legends=[["FR-0.1", "Muon_v2-0.001", "Muon_v2-0.01"]], save_dir=None, yaxis=[""], return_last=False)
# Out:
# /u/lucmon/mlopt/results/fedllm_bench/HF_CrossEntropy/federated/meta-llama/Llama-3.1-8B-Instruct/task_name_ChatbotIT/lora_rank_16/lora_alpha_16/fedlora_avg_fr/server_opt_sgd/client_opt_sgd/client_lr_0.1/client_momentum_0.9/client_weight_decay_0.0/client_num_5/client_epoch_1/client_round_0/sketch_size_-1/lr_0.1/moment_0.0/wd_0.0/batch_size_2/epoch_10000/run_0/
# /u/lucmon/mlopt/results/fedllm_bench/HF_CrossEntropy/federated/meta-llama/Llama-3.1-8B-Instruct/task_name_ChatbotIT/lora_rank_16/lora_alpha_16/fedlora_avg_muonlora_v2/server_opt_sgd/client_opt_sgd/client_lr_0.1/client_momentum_0.9/client_weight_decay_0.0/client_num_5/client_epoch_1/client_round_0/sketch_size_-1/scheduler_cosine/lr_min_1e-05/lr_0.005/moment_0.0/wd_0.0/batch_size_2/epoch_500/run_0/
# ...

# %%
/u/lucmon/mlopt/results/fedllm_bench/HF_CrossEntropy/federated/meta-llama/Llama-3.1-8B-Instruct/task_name_ChatbotIT/lora_rank_16/lora_alpha_16/fedlora_avg_muonlora_v2/server_opt_sgd/client_opt_sgd/client_lr_0.1/client_momentum_0.9/client_weight_decay_0.0/client_num_5/client_epoch_1/client_round_0/sketch_size_-1/scheduler_cosine/lr_min_1e-05/lr_0.01/moment_0.0/wd_0.0/batch_size_2/epoch_2000/run_0/

# %%
#/u/lucmon/mlopt/results/fedllm_bench/HF_CrossEntropy/federated/meta-llama/Llama-3.1-8B-Instruct/task_name_ChatbotIT/lora_rank_16/lora_alpha_16/fedlora_avg_fr/server_opt_sgd/client_opt_sgd/client_lr_0.1/client_momentum_0.9/client_weight_decay_0.0/client_num_64/client_epoch_1/client_round_0/sketch_size_-1/lr_0.001/moment_0.0/wd_0.0/batch_size_2/epoch_10000/run_0/

#general
from plot_functions import plot_figures_opts_attr
from main import graphs

lr, dataset_name, task_name, loss_name, opt_name, momentum, weight_decay, batch_size, epochs = 0.001, "fedllm_bench", "ChatbotIT", 'HF_CrossEntropy', "federated", 0.0, 0.0, 2, 10000
model_name= "meta-llama/Llama-3.1-8B-Instruct"
client_opt, client_lr, client_momentum, client_weight_decay, client_num, client_epoch, sketch_size, non_iid_alpha, client_round  ="sgd", 1.0, 0.0, 0.0, 5, 1, -1, 1.0, 0

model_params = {}
model_params["fr-0.01"] = { "task_name": task_name, "lora_rank": 16, "lora_alpha": 16,  "fedlora_avg": "fr",  'server_opt': 'sgd', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, "client_weight_decay": client_weight_decay, "client_num": client_num, 'client_epoch': client_epoch, 'client_round': client_round, "sketch_size": sketch_size}
model_params["muon_v1"] = {"task_name": task_name, "init": "weights", "lora_rank": 16, "lora_alpha": 16, "fedlora_avg": "muonlora_v1",   'server_opt': 'sgd', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, "client_weight_decay": client_weight_decay, "client_num": client_num, 'client_epoch': client_epoch, 'client_round': client_round, "sketch_size": sketch_size}
model_params["muon_v2-0.002"] = {"task_name": task_name, "init": "weights", "lora_rank": 16, "lora_alpha": 16, "fedlora_avg": "muonlora_v2",   'server_opt': 'sgd', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, "client_weight_decay": client_weight_decay, "client_num": client_num, 'client_epoch': client_epoch, 'client_round': client_round, "sketch_size": sketch_size, "scheduler": "cosine", "lr_min": 1e-5}
model_params["muon_v2-0.001"] = {"task_name": task_name, "init": "weights", "lora_rank": 16, "lora_alpha": 16, "fedlora_avg": "muonlora_v2",   'server_opt': 'sgd', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, "client_weight_decay": client_weight_decay, "client_num": client_num, 'client_epoch': client_epoch, 'client_round': client_round, "sketch_size": sketch_size, "scheduler": "cosine", "lr_min": 1e-5}
model_params["muon_v2-0.01"] = {"task_name": task_name, "init": "weights", "lora_rank": 16, "lora_alpha": 16, "fedlora_avg": "muonlora_v2",   'server_opt': 'sgd', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, "client_weight_decay": client_weight_decay, "client_num": client_num, 'client_epoch': client_epoch, 'client_round': client_round, "sketch_size": sketch_size, "scheduler": "cosine", "lr_min": 1e-5}
model_params["muon_v3"] = {"task_name": task_name, "init": "weights", "lora_rank": 16, "lora_alpha": 16, "fedlora_avg": "muonlora_v3",   'server_opt': 'sgd', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, "client_weight_decay": client_weight_decay, "client_num": client_num, 'client_epoch': client_epoch, 'client_round': client_round, "sketch_size": sketch_size}

opt_params = {}
opt_params["fr-0.01"] = {'lr': 0.01, 'dataset_name':dataset_name, 'loss': loss_name, 'opt':opt_name, 'model_name':model_name, 'momentum':momentum, 'weight_decay':weight_decay, 'batch_size':batch_size, 'epochs':epochs}
opt_params["muon_v1"] = {'lr': lr, 'dataset_name':dataset_name, 'loss': loss_name, 'opt':opt_name, 'model_name':model_name, 'momentum':momentum, 'weight_decay':weight_decay, 'batch_size':batch_size, 'epochs':epochs}
opt_params["muon_v2-0.002"] = {'lr': 0.002, 'dataset_name':dataset_name, 'loss': loss_name, 'opt':opt_name, 'model_name':model_name, 'momentum':momentum, 'weight_decay':weight_decay, 'batch_size':batch_size, 'epochs':500}
opt_params["muon_v2-0.001"] = {'lr': 0.001, 'dataset_name':dataset_name, 'loss': loss_name, 'opt':opt_name, 'model_name':model_name, 'momentum':momentum, 'weight_decay':weight_decay, 'batch_size':batch_size, 'epochs':2000}
opt_params["muon_v2-0.01"] = {'lr': 0.01, 'dataset_name':dataset_name, 'loss': loss_name, 'opt':opt_name, 'model_name':model_name, 'momentum':momentum, 'weight_decay':weight_decay, 'batch_size':batch_size, 'epochs':800}
opt_params["muon_v3"] = {'lr': lr, 'dataset_name':dataset_name, 'loss': loss_name, 'opt':opt_name, 'model_name':model_name, 'momentum':momentum, 'weight_decay':weight_decay, 'batch_size':batch_size, 'epochs':epochs}

#plot_figures_opts_attr([["lora_avg", "lora_flora", "lora_ffa", "lora_fedex",  "lora_flasc", "lora_svd"]], model_params, opt_params, ["test_acc"], start=4, end=20, alpha=1.0, linewidth=1.0, titles=[""], legends=[["FedIT", "FLoRA", "FFA", "FedEX", "FLASC", "TFLoRA"]], save_dir=None, return_last=False) #"../plots/iclr25workshop/cifar_acc.pdf"
plot_figures_opts_attr([["fr-0.01", "muon_v2-0.001"]], model_params, opt_params, ["loss"], start=0, end=-1, alpha=1.0, linewidth=1.0, titles=[""], legends=[["FR-0.01", "Muon_v2-0.001", "Muon_v2-0.01"]], save_dir=None, yaxis=[""], return_last=False)
plot_figures_opts_attr([["fr-0.01", "muon_v2-0.001"]], model_params, opt_params, ["test_loss"], start=0, end=-1, alpha=1.0, linewidth=1.0, titles=[""], legends=[["FR-0.01", "Muon_v2-0.001", "Muon_v2-0.01"]], save_dir=None, yaxis=[""], return_last=False)
# Out:
# /u/lucmon/mlopt/results/fedllm_bench/HF_CrossEntropy/federated/meta-llama/Llama-3.1-8B-Instruct/task_name_ChatbotIT/lora_rank_16/lora_alpha_16/fedlora_avg_fr/server_opt_sgd/client_opt_sgd/client_lr_1.0/client_momentum_0.0/client_weight_decay_0.0/client_num_5/client_epoch_1/client_round_0/sketch_size_-1/lr_0.01/moment_0.0/wd_0.0/batch_size_2/epoch_10000/run_0/
# /u/lucmon/mlopt/results/fedllm_bench/HF_CrossEntropy/federated/meta-llama/Llama-3.1-8B-Instruct/task_name_ChatbotIT/init_weights/lora_rank_16/lora_alpha_16/fedlora_avg_muonlora_v2/server_opt_sgd/client_opt_sgd/client_lr_1.0/client_momentum_0.0/client_weight_decay_0.0/client_num_5/client_epoch_1/client_round_0/sketch_size_-1/scheduler_cosine/lr_min_1e-05/lr_0.001/moment_0.0/wd_0.0/batch_size_2/epoch_2000/run_0/
# ...

# %%
#/u/lucmon/mlopt/results/fedllm_bench/HF_CrossEntropy/federated/meta-llama/Llama-3.1-8B-Instruct/task_name_ChatbotIT/lora_rank_16/lora_alpha_16/fedlora_avg_fr/server_opt_sgd/client_opt_sgd/client_lr_0.1/client_momentum_0.9/client_weight_decay_0.0/client_num_64/client_epoch_1/client_round_0/sketch_size_-1/lr_0.001/moment_0.0/wd_0.0/batch_size_2/epoch_10000/run_0/

#general
from plot_functions import plot_figures_opts_attr
from main import graphs

lr, dataset_name, task_name, loss_name, opt_name, momentum, weight_decay, batch_size, epochs = 0.001, "fedllm_bench", "ChatbotIT", 'HF_CrossEntropy', "federated", 0.0, 0.0, 2, 10000
model_name= "meta-llama/Llama-3.1-8B-Instruct"
client_opt, client_lr, client_momentum, client_weight_decay, client_num, client_epoch, sketch_size, non_iid_alpha, client_round  ="sgd", 1.0, 0.0, 0.0, 5, 1, -1, 1.0, 0

model_params = {}
model_params["fr-0.01"] = { "task_name": task_name, "lora_rank": 16, "lora_alpha": 16,  "fedlora_avg": "fr",  'server_opt': 'sgd', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, "client_weight_decay": client_weight_decay, "client_num": client_num, 'client_epoch': client_epoch, 'client_round': client_round, "sketch_size": sketch_size}
model_params["muon_v1"] = {"task_name": task_name, "init": "weights", "lora_rank": 16, "lora_alpha": 16, "fedlora_avg": "muonlora_v1",   'server_opt': 'sgd', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, "client_weight_decay": client_weight_decay, "client_num": client_num, 'client_epoch': client_epoch, 'client_round': client_round, "sketch_size": sketch_size}
model_params["muon_v2-0.002"] = {"task_name": task_name, "init": "weights", "lora_rank": 16, "lora_alpha": 16, "fedlora_avg": "muonlora_v2",   'server_opt': 'sgd', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, "client_weight_decay": client_weight_decay, "client_num": client_num, 'client_epoch': client_epoch, 'client_round': client_round, "sketch_size": sketch_size, "scheduler": "cosine", "lr_min": 1e-5}
model_params["muon_v2-0.001"] = {"task_name": task_name, "lora_rank": 16, "lora_alpha": 16, "fedlora_avg": "muonlora_v2",   'server_opt': 'sgd', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, "client_weight_decay": client_weight_decay, "client_num": client_num, 'client_epoch': client_epoch, 'client_round': client_round, "sketch_size": sketch_size, "scheduler": "cosine", "lr_min": 1e-5}
model_params["muon_v2-0.01"] = {"task_name": task_name, "init": "weights", "lora_rank": 16, "lora_alpha": 16, "fedlora_avg": "muonlora_v2",   'server_opt': 'sgd', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, "client_weight_decay": client_weight_decay, "client_num": client_num, 'client_epoch': client_epoch, 'client_round': client_round, "sketch_size": sketch_size, "scheduler": "cosine", "lr_min": 1e-5}
model_params["muon_v3"] = {"task_name": task_name, "init": "weights", "lora_rank": 16, "lora_alpha": 16, "fedlora_avg": "muonlora_v3",   'server_opt': 'sgd', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, "client_weight_decay": client_weight_decay, "client_num": client_num, 'client_epoch': client_epoch, 'client_round': client_round, "sketch_size": sketch_size}

opt_params = {}
opt_params["fr-0.01"] = {'lr': 0.01, 'dataset_name':dataset_name, 'loss': loss_name, 'opt':opt_name, 'model_name':model_name, 'momentum':momentum, 'weight_decay':weight_decay, 'batch_size':batch_size, 'epochs':epochs}
opt_params["muon_v1"] = {'lr': lr, 'dataset_name':dataset_name, 'loss': loss_name, 'opt':opt_name, 'model_name':model_name, 'momentum':momentum, 'weight_decay':weight_decay, 'batch_size':batch_size, 'epochs':epochs}
opt_params["muon_v2-0.002"] = {'lr': 0.002, 'dataset_name':dataset_name, 'loss': loss_name, 'opt':opt_name, 'model_name':model_name, 'momentum':momentum, 'weight_decay':weight_decay, 'batch_size':batch_size, 'epochs':500}
opt_params["muon_v2-0.001"] = {'lr': 0.001, 'dataset_name':dataset_name, 'loss': loss_name, 'opt':opt_name, 'model_name':model_name, 'momentum':momentum, 'weight_decay':weight_decay, 'batch_size':batch_size, 'epochs':2000}
opt_params["muon_v2-0.01"] = {'lr': 0.01, 'dataset_name':dataset_name, 'loss': loss_name, 'opt':opt_name, 'model_name':model_name, 'momentum':momentum, 'weight_decay':weight_decay, 'batch_size':batch_size, 'epochs':800}
opt_params["muon_v3"] = {'lr': lr, 'dataset_name':dataset_name, 'loss': loss_name, 'opt':opt_name, 'model_name':model_name, 'momentum':momentum, 'weight_decay':weight_decay, 'batch_size':batch_size, 'epochs':epochs}

#plot_figures_opts_attr([["lora_avg", "lora_flora", "lora_ffa", "lora_fedex",  "lora_flasc", "lora_svd"]], model_params, opt_params, ["test_acc"], start=4, end=20, alpha=1.0, linewidth=1.0, titles=[""], legends=[["FedIT", "FLoRA", "FFA", "FedEX", "FLASC", "TFLoRA"]], save_dir=None, return_last=False) #"../plots/iclr25workshop/cifar_acc.pdf"
plot_figures_opts_attr([["fr-0.01", "muon_v2-0.001"]], model_params, opt_params, ["loss"], start=0, end=-1, alpha=1.0, linewidth=1.0, titles=[""], legends=[["FR-0.01", "Muon_v2-0.001", "Muon_v2-0.01"]], save_dir=None, yaxis=[""], return_last=False)
plot_figures_opts_attr([["fr-0.01", "muon_v2-0.001"]], model_params, opt_params, ["test_loss"], start=0, end=-1, alpha=1.0, linewidth=1.0, titles=[""], legends=[["FR-0.01", "Muon_v2-0.001", "Muon_v2-0.01"]], save_dir=None, yaxis=[""], return_last=False)
# Out:
# /u/lucmon/mlopt/results/fedllm_bench/HF_CrossEntropy/federated/meta-llama/Llama-3.1-8B-Instruct/task_name_ChatbotIT/lora_rank_16/lora_alpha_16/fedlora_avg_fr/server_opt_sgd/client_opt_sgd/client_lr_1.0/client_momentum_0.0/client_weight_decay_0.0/client_num_5/client_epoch_1/client_round_0/sketch_size_-1/lr_0.01/moment_0.0/wd_0.0/batch_size_2/epoch_10000/run_0/
# /u/lucmon/mlopt/results/fedllm_bench/HF_CrossEntropy/federated/meta-llama/Llama-3.1-8B-Instruct/task_name_ChatbotIT/lora_rank_16/lora_alpha_16/fedlora_avg_muonlora_v2/server_opt_sgd/client_opt_sgd/client_lr_1.0/client_momentum_0.0/client_weight_decay_0.0/client_num_5/client_epoch_1/client_round_0/sketch_size_-1/scheduler_cosine/lr_min_1e-05/lr_0.001/moment_0.0/wd_0.0/batch_size_2/epoch_2000/run_0/
# ...

# %%
/u/lucmon/mlopt/results/fedllm_bench/HF_CrossEntropy/federated/meta-llama/Llama-3.1-8B-Instruct/task_name_ChatbotIT/lora_rank_16/lora_alpha_16/fedlora_avg_fr/server_opt_sgd/client_opt_sgd/client_lr_0.1/client_momentum_0.9/client_weight_decay_0.0/client_num_5/client_epoch_1/client_round_0/sketch_size_-1/lr_0.1/moment_0.0/wd_0.0/batch_size_2/epoch_10000/run_0/


/u/lucmon/mlopt/results/fedllm_bench/HF_CrossEntropy/federated/meta-llama/Llama-3.1-8B-Instruct/task_name_ChatbotIT/lora_rank_16/lora_alpha_16/fedlora_avg_fr/server_opt_sgd/client_opt_sgd/client_lr_1.0/client_momentum_0.0/client_weight_decay_0.0/client_num_5/client_epoch_1/client_round_0/sketch_size_-1/lr_0.01/moment_0.0/wd_0.0/batch_size_2/epoch_10000/run_0/

# %%
"/u/lucmon/mlopt/results/fedllm_bench/HF_CrossEntropy/federated/meta-llama/Llama-3.1-8B-Instruct/task_name_ChatbotIT/lora_rank_16/lora_alpha_16/fedlora_avg_fr/server_opt_sgd/client_opt_sgd/client_lr_0.1/client_momentum_0.0/client_weight_decay_0.0/client_num_5/client_epoch_1/client_round_0/sketch_size_-1/lr_0.1/moment_0.0/wd_0.0/batch_size_2/epoch_10000/run_0/" =="/u/lucmon/mlopt/results/fedllm_bench/HF_CrossEntropy/federated/meta-llama/Llama-3.1-8B-Instruct/task_name_ChatbotIT/lora_rank_16/lora_alpha_16/fedlora_avg_fr/server_opt_sgd/client_opt_sgd/client_lr_0.1/client_momentum_0.0/client_weight_decay_0.0/client_num_5/client_epoch_1/client_round_0/sketch_size_-1/lr_0.1/moment_0.0/wd_0.0/batch_size_2/epoch_10000/run_0/"
# Out:
# True

# %%
#/u/lucmon/mlopt/results/fedllm_bench/HF_CrossEntropy/federated/meta-llama/Llama-3.1-8B-Instruct/task_name_ChatbotIT/lora_rank_16/lora_alpha_16/fedlora_avg_fr/server_opt_sgd/client_opt_sgd/client_lr_0.1/client_momentum_0.9/client_weight_decay_0.0/client_num_64/client_epoch_1/client_round_0/sketch_size_-1/lr_0.001/moment_0.0/wd_0.0/batch_size_2/epoch_10000/run_0/

#general
from plot_functions import plot_figures_opts_attr
from main import graphs

lr, dataset_name, task_name, loss_name, opt_name, momentum, weight_decay, batch_size, epochs = 0.001, "fedllm_bench", "ChatbotIT", 'HF_CrossEntropy', "federated", 0.0, 0.0, 2, 10000
model_name= "meta-llama/Llama-3.1-8B-Instruct"
client_opt, client_lr, client_momentum, client_weight_decay, client_num, client_epoch, sketch_size, non_iid_alpha, client_round  ="sgd", 1.0, 0.0, 0.0, 64, 1, -1, 1.0, 0

model_params = {}
model_params["fr-0.1"] = { "task_name": task_name, "lora_rank": 16, "lora_alpha": 16,  "fedlora_avg": "fr",  'server_opt': 'sgd', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, "client_weight_decay": client_weight_decay, "client_num": client_num, 'client_epoch': client_epoch, 'client_round': client_round, "sketch_size": sketch_size}
model_params["fr-0.01"] = { "task_name": task_name, "lora_rank": 16, "lora_alpha": 16,  "fedlora_avg": "fr",  'server_opt': 'sgd', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, "client_weight_decay": client_weight_decay, "client_num": client_num, 'client_epoch': client_epoch, 'client_round': client_round, "sketch_size": sketch_size}
model_params["muon_v1"] = {"task_name": task_name, "init": "weights", "lora_rank": 16, "lora_alpha": 16, "fedlora_avg": "muonlora_v1",   'server_opt': 'sgd', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, "client_weight_decay": client_weight_decay, "client_num": client_num, 'client_epoch': client_epoch, 'client_round': client_round, "sketch_size": sketch_size}
model_params["muon_v2-0.002"] = {"task_name": task_name, "init": "weights", "lora_rank": 16, "lora_alpha": 16, "fedlora_avg": "muonlora_v2",   'server_opt': 'sgd', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, "client_weight_decay": client_weight_decay, "client_num": client_num, 'client_epoch': client_epoch, 'client_round': client_round, "sketch_size": sketch_size, "scheduler": "cosine", "lr_min": 1e-5}
model_params["muon_v2-0.001"] = {"task_name": task_name, "lora_rank": 16, "lora_alpha": 16, "fedlora_avg": "muonlora_v2",   'server_opt': 'sgd', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, "client_weight_decay": client_weight_decay, "client_num": client_num, 'client_epoch': client_epoch, 'client_round': client_round, "sketch_size": sketch_size, "scheduler": "cosine", "lr_min": 1e-5}
model_params["muon_v2-0.01"] = {"task_name": task_name, "lora_rank": 16, "lora_alpha": 16, "fedlora_avg": "muonlora_v2",   'server_opt': 'sgd', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, "client_weight_decay": client_weight_decay, "client_num": client_num, 'client_epoch': client_epoch, 'client_round': client_round, "sketch_size": sketch_size, "scheduler": "cosine", "lr_min": 1e-5}
model_params["muon_v3"] = {"task_name": task_name, "init": "weights", "lora_rank": 16, "lora_alpha": 16, "fedlora_avg": "muonlora_v3",   'server_opt': 'sgd', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, "client_weight_decay": client_weight_decay, "client_num": client_num, 'client_epoch': client_epoch, 'client_round': client_round, "sketch_size": sketch_size}

opt_params = {}
opt_params["fr-0.1"] = {'lr': 0.1, 'dataset_name':dataset_name, 'loss': loss_name, 'opt':opt_name, 'model_name':model_name, 'momentum':momentum, 'weight_decay':weight_decay, 'batch_size':batch_size, 'epochs':epochs}
opt_params["fr-0.01"] = {'lr': 0.01, 'dataset_name':dataset_name, 'loss': loss_name, 'opt':opt_name, 'model_name':model_name, 'momentum':momentum, 'weight_decay':weight_decay, 'batch_size':batch_size, 'epochs':epochs}
opt_params["muon_v1"] = {'lr': lr, 'dataset_name':dataset_name, 'loss': loss_name, 'opt':opt_name, 'model_name':model_name, 'momentum':momentum, 'weight_decay':weight_decay, 'batch_size':batch_size, 'epochs':epochs}
opt_params["muon_v2-0.002"] = {'lr': 0.002, 'dataset_name':dataset_name, 'loss': loss_name, 'opt':opt_name, 'model_name':model_name, 'momentum':momentum, 'weight_decay':weight_decay, 'batch_size':batch_size, 'epochs':500}
opt_params["muon_v2-0.001"] = {'lr': 0.001, 'dataset_name':dataset_name, 'loss': loss_name, 'opt':opt_name, 'model_name':model_name, 'momentum':momentum, 'weight_decay':weight_decay, 'batch_size':batch_size, 'epochs':2000}
opt_params["muon_v2-0.01"] = {'lr': 0.01, 'dataset_name':dataset_name, 'loss': loss_name, 'opt':opt_name, 'model_name':model_name, 'momentum':momentum, 'weight_decay':weight_decay, 'batch_size':batch_size, 'epochs':2000}
opt_params["muon_v3"] = {'lr': lr, 'dataset_name':dataset_name, 'loss': loss_name, 'opt':opt_name, 'model_name':model_name, 'momentum':momentum, 'weight_decay':weight_decay, 'batch_size':batch_size, 'epochs':epochs}

#plot_figures_opts_attr([["lora_avg", "lora_flora", "lora_ffa", "lora_fedex",  "lora_flasc", "lora_svd"]], model_params, opt_params, ["test_acc"], start=4, end=20, alpha=1.0, linewidth=1.0, titles=[""], legends=[["FedIT", "FLoRA", "FFA", "FedEX", "FLASC", "TFLoRA"]], save_dir=None, return_last=False) #"../plots/iclr25workshop/cifar_acc.pdf"
plot_figures_opts_attr([["fr-0.01", "muon_v2-0.01"]], model_params, opt_params, ["loss"], start=0, end=-1, alpha=1.0, linewidth=1.0, titles=[""], legends=[["FR-0.01", "Muon_v2-0.001", "Muon_v2-0.01"]], save_dir=None, yaxis=[""], return_last=False)
plot_figures_opts_attr([["fr-0.01", "muon_v2-0.001", "muon_v2-0.01"]], model_params, opt_params, ["test_loss"], start=0, end=None, alpha=1.0, linewidth=1.0, titles=[""], legends=[["FR-0.01", "Muon_v2-0.001", "Muon_v2-0.01"]], save_dir=None, yaxis=[""], return_last=False)
# Out:
# /u/lucmon/mlopt/results/fedllm_bench/HF_CrossEntropy/federated/meta-llama/Llama-3.1-8B-Instruct/task_name_ChatbotIT/lora_rank_16/lora_alpha_16/fedlora_avg_fr/server_opt_sgd/client_opt_sgd/client_lr_1.0/client_momentum_0.0/client_weight_decay_0.0/client_num_64/client_epoch_1/client_round_0/sketch_size_-1/lr_0.01/moment_0.0/wd_0.0/batch_size_2/epoch_10000/run_0/
# /u/lucmon/mlopt/results/fedllm_bench/HF_CrossEntropy/federated/meta-llama/Llama-3.1-8B-Instruct/task_name_ChatbotIT/lora_rank_16/lora_alpha_16/fedlora_avg_muonlora_v2/server_opt_sgd/client_opt_sgd/client_lr_1.0/client_momentum_0.0/client_weight_decay_0.0/client_num_64/client_epoch_1/client_round_0/sketch_size_-1/scheduler_cosine/lr_min_1e-05/lr_0.01/moment_0.0/wd_0.0/batch_size_2/epoch_2000/run_0/
# ...

# %%
#/u/lucmon/mlopt/results/fedllm_bench/HF_CrossEntropy/federated/meta-llama/Llama-3.1-8B-Instruct/task_name_ChatbotIT/lora_rank_16/lora_alpha_16/fedlora_avg_fr/server_opt_sgd/client_opt_sgd/client_lr_0.1/client_momentum_0.9/client_weight_decay_0.0/client_num_64/client_epoch_1/client_round_0/sketch_size_-1/lr_0.001/moment_0.0/wd_0.0/batch_size_2/epoch_10000/run_0/

#general
from plot_functions import plot_figures_opts_attr
from main import graphs

lr, dataset_name, task_name, loss_name, opt_name, momentum, weight_decay, batch_size, epochs = 0.001, "fedllm_bench", "ChatbotIT", 'HF_CrossEntropy', "federated", 0.0, 0.0, 2, 10000
model_name= "meta-llama/Llama-3.1-8B-Instruct"
client_opt, client_lr, client_momentum, client_weight_decay, client_num, client_epoch, sketch_size, non_iid_alpha, client_round  ="sgd", 1.0, 0.0, 0.0, 64, 1, -1, 1.0, 0

model_params = {}
model_params["fr-0.01-bf"] = { "task_name": task_name, "lora_rank": 16, "lora_alpha": 16,  "fedlora_avg": "fr",  'server_opt': 'sgd', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, "client_weight_decay": client_weight_decay, "client_num": client_num, 'client_epoch': client_epoch, 'client_round': client_round, "sketch_size": sketch_size}
model_params["fr-0.01-f"] = { "task_name": task_name, "lora_rank": 16, "lora_alpha": 16,  "fedlora_avg": "fr",  'server_opt': 'sgd', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': 0.9, "client_weight_decay": client_weight_decay, "client_num": client_num, 'client_epoch': client_epoch, 'client_round': client_round, "sketch_size": sketch_size}

model_params["muon_v2-0.001-f"] = {"task_name": task_name, "lora_rank": 16, "lora_alpha": 16, "fedlora_avg": "muonlora_v2",   'server_opt': 'sgd', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': 0.9, "client_weight_decay": client_weight_decay, "client_num": client_num, 'client_epoch': client_epoch, 'client_round': client_round, "sketch_size": sketch_size, "scheduler": "cosine", "lr_min": 1e-5}
model_params["muon_v2-0.001-bf"] = {"task_name": task_name, "lora_rank": 16, "lora_alpha": 16, "fedlora_avg": "muonlora_v2",   'server_opt': 'sgd', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, "client_weight_decay": client_weight_decay, "client_num": client_num, 'client_epoch': client_epoch, 'client_round': client_round, "sketch_size": sketch_size, "scheduler": "cosine", "lr_min": 1e-5}

opt_params = {}
opt_params["fr-0.01-bf"] = {'lr': 0.01, 'dataset_name':dataset_name, 'loss': loss_name, 'opt':opt_name, 'model_name':model_name, 'momentum':momentum, 'weight_decay':weight_decay, 'batch_size':batch_size, 'epochs':epochs}
opt_params["fr-0.01-f"] = {'lr': 0.01, 'dataset_name':dataset_name, 'loss': loss_name, 'opt':opt_name, 'model_name':model_name, 'momentum':momentum, 'weight_decay':weight_decay, 'batch_size':batch_size, 'epochs':epochs}
opt_params["muon_v2-0.001-f"] = {'lr': 0.01, 'dataset_name':dataset_name, 'loss': loss_name, 'opt':opt_name, 'model_name':model_name, 'momentum':momentum, 'weight_decay':weight_decay, 'batch_size':batch_size, 'epochs':2000}
opt_params["muon_v2-0.001-bf"] = {'lr': 0.01, 'dataset_name':dataset_name, 'loss': loss_name, 'opt':opt_name, 'model_name':model_name, 'momentum':momentum, 'weight_decay':weight_decay, 'batch_size':batch_size, 'epochs':2000}

#plot_figures_opts_attr([["lora_avg", "lora_flora", "lora_ffa", "lora_fedex",  "lora_flasc", "lora_svd"]], model_params, opt_params, ["test_acc"], start=4, end=20, alpha=1.0, linewidth=1.0, titles=[""], legends=[["FedIT", "FLoRA", "FFA", "FedEX", "FLASC", "TFLoRA"]], save_dir=None, return_last=False) #"../plots/iclr25workshop/cifar_acc.pdf"
plot_figures_opts_attr([["fr-0.01-f", "fr-0.01-bf", "muon_v2-0.001-f", "muon_v2-0.001-bf"]], model_params, opt_params, ["loss"], start=0, end=None, alpha=1.0, linewidth=1.0, titles=[""], legends=[["FR-f", "FR-bf", "Muon_v2-f", "Muon_v2-bf"]], save_dir=None, yaxis=[""], return_last=False)
plot_figures_opts_attr([["fr-0.01-f", "fr-0.01-bf", "muon_v2-0.001-f", "muon_v2-0.001-bf"]], model_params, opt_params, ["test_loss"], start=0, end=None, alpha=1.0, linewidth=1.0, titles=[""], legends=[["FR-f", "FR-bf", "Muon_v2-f", "Muon_v2-bf"]], save_dir=None, yaxis=[""], return_last=False)
# Out:
# /u/lucmon/mlopt/results/fedllm_bench/HF_CrossEntropy/federated/meta-llama/Llama-3.1-8B-Instruct/task_name_ChatbotIT/lora_rank_16/lora_alpha_16/fedlora_avg_fr/server_opt_sgd/client_opt_sgd/client_lr_1.0/client_momentum_0.9/client_weight_decay_0.0/client_num_64/client_epoch_1/client_round_0/sketch_size_-1/lr_0.01/moment_0.0/wd_0.0/batch_size_2/epoch_10000/run_0/
# /u/lucmon/mlopt/results/fedllm_bench/HF_CrossEntropy/federated/meta-llama/Llama-3.1-8B-Instruct/task_name_ChatbotIT/lora_rank_16/lora_alpha_16/fedlora_avg_fr/server_opt_sgd/client_opt_sgd/client_lr_1.0/client_momentum_0.0/client_weight_decay_0.0/client_num_64/client_epoch_1/client_round_0/sketch_size_-1/lr_0.01/moment_0.0/wd_0.0/batch_size_2/epoch_10000/run_0/
# ...

# %%
/u/lucmon/mlopt/results/fedllm_bench/HF_CrossEntropy/federated/meta-llama/Llama-3.1-8B-Instruct/task_name_ChatbotIT/lora_rank_16/lora_alpha_16/fedlora_avg_muonlora_v2/server_opt_sgd/client_opt_sgd/client_lr_1.0/client_momentum_0.0/client_weight_decay_0.0/client_num_64/client_epoch_1/client_round_0/sketch_size_-1/scheduler_cosine/lr_min_1e-05/lr_0.01/moment_0.0/wd_0.0/batch_size_2/epoch_2000/run_0/

/u/lucmon/mlopt/results/fedllm_bench/HF_CrossEntropy/federated/meta-llama/Llama-3.1-8B-Instruct/task_name_ChatbotIT/lora_rank_16/lora_alpha_16/fedlora_avg_muonlora_v2/server_opt_sgd/client_opt_sgd/client_lr_1.0/client_momentum_0.0/client_weight_decay_0.0/client_num_64/client_epoch_1/client_round_0/sketch_size_-1/scheduler_cosine/lr_min_1e-05/lr_0.01/moment_0.0/wd_0.0/batch_size_2/epoch_2000/run_0/

# %%
## pretrain
#/u/lucmon/mlopt/results/fedllm_bench/HF_CrossEntropy/federated/meta-llama/Llama-3.1-8B-Instruct/task_name_ChatbotIT/lora_rank_16/lora_alpha_16/fedlora_avg_fr/server_opt_sgd/client_opt_sgd/client_lr_0.1/client_momentum_0.9/client_weight_decay_0.0/client_num_64/client_epoch_1/client_round_0/sketch_size_-1/lr_0.001/moment_0.0/wd_0.0/batch_size_2/epoch_10000/run_0/

#general
from plot_functions import plot_figures_opts_attr
from main import graphs

lr, dataset_name, task_name, loss_name, opt_name, momentum, weight_decay, batch_size, epochs = 0.001, "fedllm_bench", "ChatbotIT", 'HF_CrossEntropy', "federated", 0.0, 0.0, 2, 10000
model_name= "meta-llama/Llama-3.1-8B-Instruct"
client_opt, client_lr, client_momentum, client_weight_decay, client_num, client_epoch, sketch_size, non_iid_alpha, client_round  ="sgd", 1.0, 0.0, 0.0, 5, 1, -1, 1.0, 0

model_params = {}
model_params["fr-0.01"] = { "task_name": task_name, "init": "weights", "lora_rank": 16, "lora_alpha": 16,  "fedlora_avg": "fr",  'server_opt': 'sgd', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, "client_weight_decay": client_weight_decay, "client_num": client_num, 'client_epoch': client_epoch, 'client_round': client_round, "sketch_size": sketch_size}
model_params["muon_v1"] = {"task_name": task_name, "init": "weights", "lora_rank": 16, "lora_alpha": 16, "fedlora_avg": "muonlora_v1",   'server_opt': 'sgd', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, "client_weight_decay": client_weight_decay, "client_num": client_num, 'client_epoch': client_epoch, 'client_round': client_round, "sketch_size": sketch_size}
model_params["muon_v2-0.002"] = {"task_name": task_name, "init": "weights", "lora_rank": 16, "lora_alpha": 16, "fedlora_avg": "muonlora_v2",   'server_opt': 'sgd', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, "client_weight_decay": client_weight_decay, "client_num": client_num, 'client_epoch': client_epoch, 'client_round': client_round, "sketch_size": sketch_size, "scheduler": "cosine", "lr_min": 1e-5}
model_params["muon_v2-0.001"] = {"task_name": task_name, "init": "weights", "lora_rank": 16, "lora_alpha": 16, "fedlora_avg": "muonlora_v2",   'server_opt': 'sgd', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, "client_weight_decay": client_weight_decay, "client_num": client_num, 'client_epoch': client_epoch, 'client_round': client_round, "sketch_size": sketch_size, "scheduler": "cosine", "lr_min": 1e-5}
model_params["muon_v2-0.01"] = {"task_name": task_name, "init": "weights", "lora_rank": 16, "lora_alpha": 16, "fedlora_avg": "muonlora_v2",   'server_opt': 'sgd', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, "client_weight_decay": client_weight_decay, "client_num": client_num, 'client_epoch': client_epoch, 'client_round': client_round, "sketch_size": sketch_size, "scheduler": "cosine", "lr_min": 1e-5}
model_params["muon_v3"] = {"task_name": task_name, "init": "weights", "lora_rank": 16, "lora_alpha": 16, "fedlora_avg": "muonlora_v3",   'server_opt': 'sgd', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, "client_weight_decay": client_weight_decay, "client_num": client_num, 'client_epoch': client_epoch, 'client_round': client_round, "sketch_size": sketch_size}

opt_params = {}
opt_params["fr-0.01"] = {'lr': 5.0, 'dataset_name':dataset_name, 'loss': loss_name, 'opt':opt_name, 'model_name':model_name, 'momentum':momentum, 'weight_decay':weight_decay, 'batch_size':batch_size, 'epochs':epochs}
opt_params["muon_v1"] = {'lr': lr, 'dataset_name':dataset_name, 'loss': loss_name, 'opt':opt_name, 'model_name':model_name, 'momentum':momentum, 'weight_decay':weight_decay, 'batch_size':batch_size, 'epochs':epochs}
opt_params["muon_v2-0.002"] = {'lr': 0.002, 'dataset_name':dataset_name, 'loss': loss_name, 'opt':opt_name, 'model_name':model_name, 'momentum':momentum, 'weight_decay':weight_decay, 'batch_size':batch_size, 'epochs':500}
opt_params["muon_v2-0.001"] = {'lr': 0.05, 'dataset_name':dataset_name, 'loss': loss_name, 'opt':opt_name, 'model_name':model_name, 'momentum':momentum, 'weight_decay':weight_decay, 'batch_size':batch_size, 'epochs':epochs}
opt_params["muon_v2-0.01"] = {'lr': 0.01, 'dataset_name':dataset_name, 'loss': loss_name, 'opt':opt_name, 'model_name':model_name, 'momentum':momentum, 'weight_decay':weight_decay, 'batch_size':batch_size, 'epochs':800}
opt_params["muon_v3"] = {'lr': lr, 'dataset_name':dataset_name, 'loss': loss_name, 'opt':opt_name, 'model_name':model_name, 'momentum':momentum, 'weight_decay':weight_decay, 'batch_size':batch_size, 'epochs':epochs}

#plot_figures_opts_attr([["lora_avg", "lora_flora", "lora_ffa", "lora_fedex",  "lora_flasc", "lora_svd"]], model_params, opt_params, ["test_acc"], start=4, end=20, alpha=1.0, linewidth=1.0, titles=[""], legends=[["FedIT", "FLoRA", "FFA", "FedEX", "FLASC", "TFLoRA"]], save_dir=None, return_last=False) #"../plots/iclr25workshop/cifar_acc.pdf"
plot_figures_opts_attr([["fr-0.01", "muon_v2-0.001"]], model_params, opt_params, ["loss"], start=20, end=None, alpha=1.0, linewidth=1.0, titles=[""], legends=[["FR-0.01", "Muon_v2-0.001", "Muon_v2-0.01"]], save_dir=None, yaxis=[""], return_last=False)
plot_figures_opts_attr([["fr-0.01", "muon_v2-0.001"]], model_params, opt_params, ["test_loss"], start=20, end=None, alpha=1.0, linewidth=1.0, titles=[""], legends=[["FR-0.01", "Muon_v2-0.001", "Muon_v2-0.01"]], save_dir=None, yaxis=[""], return_last=False)
# Out:
# /u/lucmon/mlopt/results/fedllm_bench/HF_CrossEntropy/federated/meta-llama/Llama-3.1-8B-Instruct/task_name_ChatbotIT/init_weights/lora_rank_16/lora_alpha_16/fedlora_avg_fr/server_opt_sgd/client_opt_sgd/client_lr_1.0/client_momentum_0.0/client_weight_decay_0.0/client_num_5/client_epoch_1/client_round_0/sketch_size_-1/lr_5.0/moment_0.0/wd_0.0/batch_size_2/epoch_10000/run_0/
# /u/lucmon/mlopt/results/fedllm_bench/HF_CrossEntropy/federated/meta-llama/Llama-3.1-8B-Instruct/task_name_ChatbotIT/init_weights/lora_rank_16/lora_alpha_16/fedlora_avg_muonlora_v2/server_opt_sgd/client_opt_sgd/client_lr_1.0/client_momentum_0.0/client_weight_decay_0.0/client_num_5/client_epoch_1/client_round_0/sketch_size_-1/scheduler_cosine/lr_min_1e-05/lr_0.05/moment_0.0/wd_0.0/batch_size_2/epoch_10000/run_0/
# ...

# %%
/u/lucmon/mlopt/results/fedllm_bench/HF_CrossEntropy/federated/meta-llama/Llama-3.1-8B-Instruct/task_name_ChatbotIT/init_weights/lora_rank_16/lora_alpha_16/fedlora_avg_muonlora_v2/server_opt_sgd/client_opt_sgd/client_lr_1.0/client_momentum_0.0/client_weight_decay_0.0/client_num_5/client_epoch_1/client_round_0/sketch_size_-1/scheduler_cosine/lr_min_1e-05/lr_0.001/moment_0.0/wd_0.0/batch_size_2/epoch_10000/run_0/
