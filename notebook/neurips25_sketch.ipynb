# %%
from plot_functions import plot_figures_opts, plot_attr_figure, plot_figures_opts_attrs, plot_figures_opts_attr
from main import graphs

lr, dataset_name, loss_name, momentum, weight_decay, batch_size, epochs = 0.1, "cifar", 'CrossEntropyLoss', 0.9, 1e-4, 128, 100
model_name, depth = "resnet_gn", 101
client_opt, client_lr, client_momentum, client_num, client_epoch, sketch_size, scheduler, lr_min  ="sgd", 0.1, 0.0, 5, 1, 80000, "cosine", 1e-5
model_params = {}
model_params["f-adam-4e4"] = {"depth": depth, "smooth": 0.1, 'server_opt': 'adam', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": 40000, "scheduler": scheduler, "lr_min": lr_min}
model_params["f-adam-4e3"] = {"depth": depth, "smooth": 0.1, 'server_opt': 'adam', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, "client_weight_decay": 0.0, "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": 4000, "scheduler": scheduler, "lr_min": lr_min}
model_params["f-adam-4e2"] = {"depth": depth, "smooth": 0.1, 'server_opt': 'adam', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, "client_weight_decay": 0.0, "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": 400, "scheduler": scheduler, "lr_min": lr_min}
model_params["f-adam"] = {"depth": depth, "smooth": 0.1, 'server_opt': 'adam', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": -1, "scheduler": scheduler, "lr_min": lr_min}
model_params["f-adam-1e6"] = {"depth": depth, "smooth": 0.1, 'server_opt': 'adam', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": 1000001, "scheduler": scheduler, "lr_min": lr_min}
model_params["f-sgd-4e5"] = {"depth": depth, "smooth": 0.1, 'server_opt': 'sgd', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": 400000, "scheduler": scheduler, "lr_min": lr_min}
model_params["f-adam-4e5"] = {"depth": depth, "smooth": 0.1, 'server_opt': 'adam', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": 400000, "scheduler": scheduler, "lr_min": lr_min}
model_params["f-sgdm-4e4"] = {"depth": depth, "smooth": 0.1, 'server_opt': 'sgd', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, "client_weight_decay": 0.0, "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": 40000, "scheduler": scheduler, "lr_min": lr_min}
model_params["f-sgdm-4e5"] = {"depth": depth, "smooth": 0.1, 'server_opt': 'sgd', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, "client_weight_decay": 0.0, "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": 400000, "scheduler": scheduler, "lr_min": lr_min}
model_params["f-fetchsgd-4e4"] = {"depth": depth, "smooth": 0.1, 'server_opt': 'fetchsgd', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, "client_weight_decay": 0.0,  "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": 40000, "scheduler": scheduler, "lr_min": lr_min}
model_params["f-fetchsgd-4e5"] = {"depth": depth, "smooth": 0.1, 'server_opt': 'fetchsgd', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, "client_weight_decay": 0.0,  "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": 400000, "scheduler": scheduler, "lr_min": lr_min}
model_params["f-fetchsgd-4e6"] = {"depth": depth, "smooth": 0.1, 'server_opt': 'fetchsgd', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, "client_weight_decay": 0.0,  "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": 4000000, "scheduler": scheduler, "lr_min": lr_min}

model_params["f-sgd-4e6"] = {"depth": depth, "smooth": 0.1, 'server_opt': 'sgd', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": 4000000, "scheduler": scheduler, "lr_min": lr_min}
model_params["f-adam-4e6"] = {"depth": depth, "smooth": 0.1, 'server_opt': 'adam', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, 'client_weight_decay': 0.0, "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": 4000000, "clip": 0.5, "scheduler": scheduler, "lr_min": lr_min}
model_params["f-sgdm-4e6"] = {"depth": depth, "smooth": 0.1, 'server_opt': 'sgd', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": 4000000, "scheduler": scheduler, "lr_min": lr_min}
model_params["f-adam-4e5-500"] = {"depth": depth, "smooth": 0.1, 'server_opt': 'adam', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, 'client_weight_decay': 0.0, "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": 400000, 'clip': 0.5, "scheduler": scheduler, "lr_min": lr_min}
model_params["f-1bit-adam"] = {"depth": depth, "smooth": 0.1, 'server_opt': 'onebit', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, "client_weight_decay": 0.0,  "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": 4000000, "switch_epoch": 10, "scheduler": scheduler, "lr_min": lr_min}
model_params["f-marina-4e4"] = {"depth": depth, "smooth": 0.1, 'server_opt': 'marina', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': 0.0, 'client_weight_decay': 0.0, "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": 40000, "base_opt": "adam", "full_prob": 0.1, "scheduler": scheduler, "lr_min": lr_min}
model_params["f-marina-4e5"] = {"depth": depth, "smooth": 0.1, 'server_opt': 'marina', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': 0.9, 'client_weight_decay': 0.0, "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": 400001, "base_opt": "sgd", "full_prob": 0.1, "scheduler": scheduler, "lr_min": lr_min}
model_params["f-marina-4e6"] = {"depth": depth, "smooth": 0.1, 'server_opt': 'marina', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': 0.9, 'client_weight_decay': 0.0, "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": 4000001, "base_opt": "sgd", "full_prob": 0.1, "scheduler": scheduler, "lr_min": lr_min}
model_params["f-cdadam-4e4"] = {"depth": depth, "smooth": 0.1, 'server_opt': 'cdadam', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, 'client_weight_decay': 0.0, "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": 40000, "scheduler": scheduler, "lr_min": lr_min}
model_params["f-cdadam-4e5"] = {"depth": depth, "smooth": 0.1, 'server_opt': 'cdadam', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, 'client_weight_decay': 0.0, "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": 400000, "scheduler": scheduler, "lr_min": lr_min}
model_params["f-cdadam-4e6"] = {"depth": depth, "smooth": 0.1, 'server_opt': 'cdadam', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, 'client_weight_decay': 0.0, "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": 4000000, "scheduler": scheduler, "lr_min": lr_min}
model_params["f-cocktail-4e4"] = {"depth": depth, "smooth": 0.1, 'server_opt': 'cocktailsgd2', 'client_opt': client_opt, 'client_lr': 0.001, 'client_momentum': 0.9, "client_weight_decay": 0.0,  "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": 40000, "scheduler": scheduler, "lr_min": 0.001}
#model_params["f-cocktail-4e5"] = {"depth": depth, "smooth": 0.1, 'server_opt': 'cocktailsgd2', 'client_opt': client_opt, 'client_lr': 0.04, 'client_momentum': 0.9, "client_weight_decay": 0.0,  "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": 400000, "scheduler": scheduler, "lr_min": lr_min}
model_params["f-cocktail-4e5"] = {"depth": depth, "smooth": 0.1, 'server_opt': 'cocktailsgd2', 'client_opt': client_opt, 'client_lr': 0.1, 'client_momentum': 0.9, "client_weight_decay": 0.0,  "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": 400000, "scheduler": scheduler, "lr_min": lr_min}
model_params["f-cocktail-4e6"] = {"depth": depth, "smooth": 0.1, 'server_opt': 'cocktailsgd2', 'client_opt': client_opt, 'client_lr': 0.1, 'client_momentum': 0.9, "client_weight_decay": 0.0,  "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": 4000000, "scheduler": scheduler, "lr_min": 0.1}
model_params["f-cams-4e4"] = {"depth": depth, "smooth": 0.1, 'server_opt': 'cams', 'client_opt': client_opt, 'client_lr': 0.1, 'client_momentum': 0.9, "client_weight_decay": 0.0,  "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": 40000, "base_opt":"adam", "scheduler": scheduler, "lr_min": 1e-5}
model_params["f-cams-4e5"] = {"depth": depth, "smooth": 0.1, 'server_opt': 'cams', 'client_opt': client_opt, 'client_lr': 0.1, 'client_momentum': 0.9, "client_weight_decay": 0.0,  "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": 400000, "base_opt":"adam", "scheduler": scheduler, "lr_min": 1e-5}
model_params["f-cams-4e6"] = {"depth": depth, "smooth": 0.1, 'server_opt': 'cams', 'client_opt': client_opt, 'client_lr': 0.1, 'client_momentum': 0.9, "client_weight_decay": 0.0,  "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": 4000000, "base_opt":"adam", "scheduler": scheduler, "lr_min": 1e-5}
model_params["f-paq-4e5"] = {"depth": depth, "smooth": 0.1, 'server_opt': 'paq', 'client_opt': client_opt, 'client_lr': 0.1, 'client_momentum': 0.9, "client_weight_decay": 0.0,  "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": 400000, "base_opt":"adam", "scheduler": scheduler, "lr_min": 1e-5}


model_params["f-adam-4e4"] = {"depth": depth, "smooth": 0.1, 'server_opt': 'adam', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, 'client_weight_decay': 0.0, "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": 40000,  'clip': 0.5, "scheduler": scheduler, "lr_min": lr_min}
model_params["f-adam-4e3"] = {"depth": depth, "smooth": 0.1, 'server_opt': 'adam', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, 'client_weight_decay': 0.0, "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": 4000,  'clip': 0.5, "scheduler": scheduler, "lr_min": lr_min}
model_params["f-adam"] = {"depth": depth, "smooth": 0.1, 'server_opt': 'adam', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, 'client_weight_decay': 0.0, "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": -1,  'clip': 0.1, "scheduler": scheduler, "lr_min": lr_min}
model_params["f-sketch-adam"] = {"depth": depth, "smooth": 0.1, 'server_opt': 'sketch_adam', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': 0.9, 'client_weight_decay': 0.0, "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": 200000, 'clip': 0.5,  "scheduler": scheduler, "lr_min": lr_min}
model_params["f-sketch-adam"] = {"depth": depth, "smooth": 0.1, 'server_opt': 'sketch_adam', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': 0.0, 'client_weight_decay': 0.0, "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": 200000, 'clip': 0.5,  "scheduler": scheduler, "lr_min": lr_min}
model_params["f-sketch-adam-2e6"] = {"depth": depth, "smooth": 0.1, 'server_opt': 'sketch_adam', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': 0.0, 'client_weight_decay': 0.0, "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": 2000000, 'clip': 0.5,  "scheduler": scheduler, "lr_min": lr_min}
model_params["f-amsgrad-4e4"] = {"depth": depth, "smooth": 0.1, 'server_opt': 'amsgrad', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, 'client_weight_decay': 0.0, "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": 40000,  'clip': 0.5, "scheduler": scheduler, "lr_min": lr_min}


opt_params = {}
opt_params['f-adam'] = {'lr': 0.01, 'dataset_name':dataset_name, 'loss': loss_name, 'opt':'federated', 'model_name':model_name, 'momentum':momentum, 'weight_decay':weight_decay, 'batch_size':batch_size, 'epochs':epochs}
opt_params['f-adam-4e4'] = {'lr': 0.01, 'dataset_name':dataset_name, 'loss': loss_name, 'opt':'federated', 'model_name':model_name, 'momentum':momentum, 'weight_decay':weight_decay, 'batch_size':batch_size, 'epochs':epochs}
opt_params['f-adam-4e3'] = {'lr': 0.01, 'dataset_name':dataset_name, 'loss': loss_name, 'opt':'federated', 'model_name':model_name, 'momentum':momentum, 'weight_decay':weight_decay, 'batch_size':batch_size, 'epochs':epochs}
opt_params['f-adam-4e2'] = {'lr': 0.01, 'dataset_name':dataset_name, 'loss': loss_name, 'opt':'federated', 'model_name':model_name, 'momentum':momentum, 'weight_decay':weight_decay, 'batch_size':batch_size, 'epochs':epochs}
opt_params['f-adam-1e6'] = {'lr': 0.01, 'dataset_name':dataset_name, 'loss': loss_name, 'opt':'federated', 'model_name':model_name, 'momentum':momentum, 'weight_decay':weight_decay, 'batch_size':batch_size, 'epochs':epochs}

opt_params['f-adam-4e5'] = {'lr': 0.01, 'dataset_name':dataset_name, 'loss': loss_name, 'opt':'federated', 'model_name':model_name, 'momentum':momentum, 'weight_decay':weight_decay, 'batch_size':batch_size, 'epochs':epochs}

opt_params['f-sgdm-4e4'] = {'lr': 1.0, 'dataset_name':dataset_name, 'loss': loss_name, 'opt':'federated', 'model_name':model_name, 'momentum':momentum, 'weight_decay':weight_decay, 'batch_size':batch_size, 'epochs':500}
opt_params['f-sgdm-4e5'] = {'lr': 1.0, 'dataset_name':dataset_name, 'loss': loss_name, 'opt':'federated', 'model_name':model_name, 'momentum':momentum, 'weight_decay':weight_decay, 'batch_size':batch_size, 'epochs':500}
opt_params['f-sgd-4e5'] = {'lr': 1.0, 'dataset_name':dataset_name, 'loss': loss_name, 'opt':'federated', 'model_name':model_name, 'momentum':0.0, 'weight_decay':weight_decay, 'batch_size':batch_size, 'epochs':epochs}
opt_params['f-fetchsgd-4e4'] = {'lr': 2.0, 'dataset_name':dataset_name, 'loss': loss_name, 'opt':'federated', 'model_name':model_name, 'momentum':momentum, 'weight_decay':weight_decay, 'batch_size':batch_size, 'epochs':500}
opt_params['f-fetchsgd-4e5'] = {'lr': 1.0, 'dataset_name':dataset_name, 'loss': loss_name, 'opt':'federated', 'model_name':model_name, 'momentum':momentum, 'weight_decay':weight_decay, 'batch_size':batch_size, 'epochs':500}
opt_params['f-fetchsgd-4e6'] = {'lr': 0.5, 'dataset_name':dataset_name, 'loss': loss_name, 'opt':'federated', 'model_name':model_name, 'momentum':momentum, 'weight_decay':weight_decay, 'batch_size':batch_size, 'epochs':500}

opt_params['f-adam-4e6'] = {'lr': 0.01, 'dataset_name':dataset_name, 'loss': loss_name, 'opt':'federated', 'model_name':model_name, 'momentum':momentum, 'weight_decay':weight_decay, 'batch_size':batch_size, 'epochs':500}
opt_params['f-sgdm-4e6'] = {'lr': 1.0, 'dataset_name':dataset_name, 'loss': loss_name, 'opt':'federated', 'model_name':model_name, 'momentum':momentum, 'weight_decay':weight_decay, 'batch_size':batch_size, 'epochs':500}
opt_params['f-sgd-4e6'] = {'lr': 1.0, 'dataset_name':dataset_name, 'loss': loss_name, 'opt':'federated', 'model_name':model_name, 'momentum':0.0, 'weight_decay':weight_decay, 'batch_size':batch_size, 'epochs':epochs}

opt_params['f-adam-4e5-500'] = {'lr': 0.04, 'dataset_name':dataset_name, 'loss': loss_name, 'opt':'federated', 'model_name':model_name, 'momentum':momentum, 'weight_decay':weight_decay, 'batch_size':batch_size, 'epochs':500}
opt_params['f-1bit-adam'] = {'lr': 0.0001, 'dataset_name':dataset_name, 'loss': loss_name, 'opt':'federated', 'model_name':model_name, 'momentum':momentum, 'weight_decay':weight_decay, 'batch_size':batch_size, 'epochs':500}
opt_params['f-cdadam-4e4'] = {'lr': 0.01, 'dataset_name':dataset_name, 'loss': loss_name, 'opt':'federated', 'model_name':model_name, 'momentum':momentum, 'weight_decay':weight_decay, 'batch_size':batch_size, 'epochs':500}
opt_params['f-cdadam-4e5'] = {'lr': 0.01, 'dataset_name':dataset_name, 'loss': loss_name, 'opt':'federated', 'model_name':model_name, 'momentum':momentum, 'weight_decay':weight_decay, 'batch_size':batch_size, 'epochs':500}
opt_params['f-cdadam-4e6'] = {'lr': 0.01, 'dataset_name':dataset_name, 'loss': loss_name, 'opt':'federated', 'model_name':model_name, 'momentum':momentum, 'weight_decay':weight_decay, 'batch_size':batch_size, 'epochs':500}
opt_params['f-marina-4e4'] = {'lr': 0.01, 'dataset_name':dataset_name, 'loss': loss_name, 'opt':'federated', 'model_name':model_name, 'momentum':momentum, 'weight_decay':weight_decay, 'batch_size':batch_size, 'epochs':500}
opt_params['f-marina-4e5'] = {'lr': 0.1, 'dataset_name':dataset_name, 'loss': loss_name, 'opt':'federated', 'model_name':model_name, 'momentum':momentum, 'weight_decay':weight_decay, 'batch_size':batch_size, 'epochs':500}
opt_params['f-marina-4e6'] = {'lr': 0.1, 'dataset_name':dataset_name, 'loss': loss_name, 'opt':'federated', 'model_name':model_name, 'momentum':momentum, 'weight_decay':weight_decay, 'batch_size':batch_size, 'epochs':500}
#opt_params['f-cocktail-4e5'] = {'lr': 1.0, 'dataset_name':dataset_name, 'loss': loss_name, 'opt':'federated', 'model_name':model_name, 'momentum':momentum, 'weight_decay':weight_decay, 'batch_size':batch_size, 'epochs':500}
opt_params['f-cocktail-4e4'] = {'lr': 2.0, 'dataset_name':dataset_name, 'loss': loss_name, 'opt':'federated', 'model_name':model_name, 'momentum':momentum, 'weight_decay':weight_decay, 'batch_size':batch_size, 'epochs':500}
opt_params['f-cocktail-4e5'] = {'lr': 2.0, 'dataset_name':dataset_name, 'loss': loss_name, 'opt':'federated', 'model_name':model_name, 'momentum':momentum, 'weight_decay':weight_decay, 'batch_size':batch_size, 'epochs':500}
opt_params['f-cocktail-4e6'] = {'lr': 2.0, 'dataset_name':dataset_name, 'loss': loss_name, 'opt':'federated', 'model_name':model_name, 'momentum':momentum, 'weight_decay':weight_decay, 'batch_size':batch_size, 'epochs':500}
opt_params['f-cams-4e4'] = {'lr': 0.01, 'dataset_name':dataset_name, 'loss': loss_name, 'opt':'federated', 'model_name':model_name, 'momentum':momentum, 'weight_decay':weight_decay, 'batch_size':batch_size, 'epochs':500}
opt_params['f-cams-4e5'] = {'lr': 0.01, 'dataset_name':dataset_name, 'loss': loss_name, 'opt':'federated', 'model_name':model_name, 'momentum':momentum, 'weight_decay':weight_decay, 'batch_size':batch_size, 'epochs':500}
opt_params['f-cams-4e6'] = {'lr': 0.01, 'dataset_name':dataset_name, 'loss': loss_name, 'opt':'federated', 'model_name':model_name, 'momentum':momentum, 'weight_decay':weight_decay, 'batch_size':batch_size, 'epochs':500}
opt_params['f-paq-4e5'] = {'lr': 0.01, 'dataset_name':dataset_name, 'loss': loss_name, 'opt':'federated', 'model_name':model_name, 'momentum':momentum, 'weight_decay':weight_decay, 'batch_size':batch_size, 'epochs':500}

opt_params['f-adam-4e5'] = {'lr': 0.01, 'dataset_name':dataset_name, 'loss': loss_name, 'opt':'federated', 'model_name':model_name, 'momentum':momentum, 'weight_decay':weight_decay, 'batch_size':batch_size, 'epochs':500}
opt_params['f-adam-4e3'] = opt_params['f-adam-4e4'] = opt_params['f-adam'] = opt_params['f-adam-4e5']
opt_params['f-amsgrad-4e4'] =  opt_params['f-adam-4e5']
opt_params['f-sketch-adam'] = {'lr': 0.05, 'dataset_name':dataset_name, 'loss': loss_name, 'opt':'federated', 'model_name':model_name, 'momentum':momentum, 'weight_decay':weight_decay, 'batch_size':batch_size, 'epochs':500}
opt_params['f-sketch-adam-2e6'] = {'lr': 0.01, 'dataset_name':dataset_name, 'loss': loss_name, 'opt':'federated', 'model_name':model_name, 'momentum':momentum, 'weight_decay':weight_decay, 'batch_size':batch_size, 'epochs':500}

#opt_params['norm-sgd'] = {"adv_eta":0.05, 'lr': lr, 'dataset_name':dataset_name, 'loss': loss_name, 'opt':'norm-sgd', 'model_name':model_name, 'momentum':momentum, 'weight_decay':weight_decay, 'batch_size':batch_size, 'epochs':5000}
#opt_params['norm-sgd-0.1'] = {"adv_eta":0.01, 'lr': lr, 'dataset_name':dataset_name, 'loss': loss_name, 'opt':'norm-sgd', 'model_name':model_name, 'momentum':momentum, 'weight_decay':weight_decay, 'batch_size':batch_size, 'epochs':epochs}

#plot_figures_opts(["sgd-0.01", "sgd-0.05"], model_params, opt_params)
#plot_figures_opts_attrs(['f-adam-4e2','f-adam-4e3', 'f-adam-4e4', 'f-adam-4e5'], model_params, opt_params, attrs=["loss", "accuracy", "test_err"], start=10)
#plot_figures_opts_attrs(['f-sgd-4e5', 'f-sgdm-4e5', 'f-adam-4e5', 'f-fetchsgd-4e5'], model_params, opt_params, attrs=["loss", "accuracy", "test_err"], start=10)
#plot_figures_opts_attrs(['f-sgd-4e6', 'f-sgdm-4e6', 'f-adam-4e6', 'f-fetchsgd-4e6'], model_params, opt_params, attrs=["loss", "accuracy", "test_err"], start=10)
"""
plot_figures_opts_attr([['f-sgd-4e5', 'f-sgdm-4e5', 'f-adam-4e5', 'f-fetchsgd-4e5'],
                        ['f-sgd-4e6', 'f-sgdm-4e6', 'f-adam-4e6', 'f-fetchsgd-4e6'],
                        ['f-adam-4e2','f-adam-4e3', 'f-adam-4e4', 'f-adam-4e5']], model_params, opt_params, attr="test_err", start=10, 
                        legends = [['sgd', 'sgdm', 'adam', 'fetchsgd'], ['sgd', 'sgdm', 'adam', 'fetchsgd'], ['4e2', '4e3', '4e4', '4e5']],
                        titles = [r"b=4e5",r'b=4e6',''], save_dir="../plots/neurips24/cifar_sketch_fetchsgd.pdf")
"""
plot_figures_opts_attr([['f-adam-4e4', 'f-cdadam-4e4',  'f-fetchsgd-4e4', 'f-marina-4e4', 'f-cocktail-4e4'],
                        ['f-adam-4e5-500',  'f-cdadam-4e5', 'f-fetchsgd-4e5', 'f-marina-4e5', 'f-cocktail-4e5', 'f-cams-4e5', 'f-1bit-adam', 'f-paq-4e5'],
                        #['f-adam-4e6', 'f-cdadam-4e6', 'f-fetchsgd-4e6', 'f-marina-4e6', 'f-cocktail-4e6', 'f-cams-4e6'], #'f-sketch-adam-2e6'
                        ['f-adam-4e3', 'f-adam-4e4', 'f-adam-4e5-500', 'f-adam-4e6','f-adam'],
                        ['f-adam-4e3', 'f-adam-4e4', 'f-adam-4e5-500', 'f-adam-4e6']
                        ], model_params, opt_params, 
                        attrs=["test_err", "test_err", "test_err", "train_err"], start=10, 
                        legends = [['SADL', 'CDAdam', 'FetchSGD', 'MARINA','CocktailSGD', 'CAMS'], ['SADL', 'CDAdam', 'FetchSGD', 'MARINA', 'CocktailSGD', 'CAMS', '1bit-Adam', 'PAQ'],
                                    [r'$1.6 \times 10^4$',r'$1.6 \times 10^5$',r'$1.6 \times 10^6$', r'$1.6 \times 10^7$',r'$1.6 \times 10^8$'], [r'$1.6 \times 10^4$',r'$1.6 \times 10^5$',r'$1.6 \times 10^6$', r'$1.6 \times 10^7$']],
                        yaxis = ["Validation Error", "Validation Error", "Validation Error", "Train Error"], legend_fontsize=8,
                        titles = [r"$1.6 \times 10^5$ Bytes/epoch",r'$1.6 \times 10^6$ Bytes/epoch','', ''], save_dir=None) # "../plots/nips25sketch/cifar_sketch_full.pdf"
# Out:
# /u/lucmon/lucmon/anaconda3/envs/mlopt/lib/python3.11/site-packages/torch/cuda/__init__.py:716: UserWarning: Can't initialize NVML
#   warnings.warn("Can't initialize NVML")
# Available GPU Count:  0
# /projects/illinois/eng/cs/arindamb/lucmon/mlopt/results/cifar/CrossEntropyLoss/federated/resnet_gn/depth_101/smooth_0.1/server_opt_adam/client_opt_sgd/client_lr_0.1/client_momentum_0.0/client_weight_decay_0.0/client_num_5/client_epoch_1/sketch_size_40000/clip_0.5/scheduler_cosine/lr_min_1e-05/lr_0.01/moment_0.9/wd_0.0001/batch_size_128/epoch_500/run_0/
# /projects/illinois/eng/cs/arindamb/lucmon/mlopt/results/cifar/CrossEntropyLoss/federated/resnet_gn/depth_101/smooth_0.1/server_opt_cdadam/client_opt_sgd/client_lr_0.1/client_momentum_0.0/client_weight_decay_0.0/client_num_5/client_epoch_1/sketch_size_40000/scheduler_cosine/lr_min_1e-05/lr_0.01/moment_0.9/wd_0.0001/batch_size_128/epoch_500/run_0/
# ...

# %%
/projects/illinois/eng/cs/arindamb/lucmon/mlopt/results/cifar/CrossEntropyLoss/federated/resnet_gn/depth_101/smooth_0.1/server_opt_marina/client_opt_sgd/client_lr_0.1/client_momentum_0.9/client_weight_decay_0.0/client_num_5/client_epoch_1/sketch_size_40000/base_opt_adam/full_prob_0.1/scheduler_cosine/lr_min_1e-05/lr_0.01/moment_0.9/wd_0.0001/batch_size_128/epoch_500/run_0/

/projects/illinois/eng/cs/arindamb/lucmon/mlopt/results/cifar/CrossEntropyLoss/federated/resnet_gn/depth_101/smooth_0.1/server_opt_marina/client_opt_sgd/client_lr_0.1/client_momentum_0.0/client_weight_decay_0.0/client_num_5/client_epoch_1/sketch_size_40000/base_opt_adam/full_prob_0.1/scheduler_cosine/lr_min_1e-05/lr_0.01/moment_0.9/wd_0.0001/batch_size_128/epoch_500/run_0/

# %%
from plot_functions import get_attr
opt_name = "f-adam-4e4"
attr = "test_accuracy"
for opt_name in ["f-adam-4e4", "f-adam-4e5-500", "f-amsgrad-4e4", 'f-cams-4e4', 'f-cocktail-4e4', 'f-marina-4e4', 'f-fetchsgd-4e4']:
    attr_list = get_attr(opt_name, model_params, opt_params, attr, eval_graph=False, return_x =False)
    print(opt_name, [1 - run[-1] for run in attr_list])
# Out:
# /projects/illinois/eng/cs/arindamb/lucmon/mlopt/results/cifar/CrossEntropyLoss/federated/resnet_gn/depth_101/smooth_0.1/server_opt_adam/client_opt_sgd/client_lr_0.1/client_momentum_0.0/client_weight_decay_0.0/client_num_5/client_epoch_1/sketch_size_40000/clip_0.5/scheduler_cosine/lr_min_1e-05/lr_0.01/moment_0.9/wd_0.0001/batch_size_128/epoch_500/
# f-adam-4e4 [0.17020000000000002, 0.18620000000000003, 0.17800000000000005]
# /projects/illinois/eng/cs/arindamb/lucmon/mlopt/results/cifar/CrossEntropyLoss/federated/resnet_gn/depth_101/smooth_0.1/server_opt_adam/client_opt_sgd/client_lr_0.1/client_momentum_0.0/client_weight_decay_0.0/client_num_5/client_epoch_1/sketch_size_400000/clip_0.5/scheduler_cosine/lr_min_1e-05/lr_0.04/moment_0.9/wd_0.0001/batch_size_128/epoch_500/
# f-adam-4e5-500 [0.16659999999999997, 0.1724, 0.16759999999999997]
# ...

# %%
/projects/illinois/eng/cs/arindamb/lucmon/mlopt/results/cifar/CrossEntropyLoss/federated/resnet_gn/depth_101/smooth_0.1/server_opt_fetchsgd/client_opt_sgd/client_lr_0.1/client_momentum_0.0/client_weight_decay_0.0/client_num_5/client_epoch_1/sketch_size_40000/scheduler_cosine/lr_min_1e-05/lr_2.0/moment_0.9/wd_0.0001/batch_size_128/epoch_500/run_1

/projects/illinois/eng/cs/arindamb/lucmon/mlopt/results/cifar/CrossEntropyLoss/federated/resnet_gn/depth_101/smooth_0.1/server_opt_fetchsgd/client_opt_sgd/client_lr_0.1/client_momentum_0.0/client_weight_decay_0.0/client_num_5/client_epoch_1/sketch_size_40000/scheduler_cosine/lr_min_1e-05/lr_2.0/moment_0.9/wd_0.0001/batch_size_128/epoch_500/run_0/

# %%
/projects/illinois/eng/cs/arindamb/lucmon/mlopt/results/cifar/CrossEntropyLoss/federated/resnet_gn/depth_101/smooth_0.1/server_opt_amsgrad/client_opt_sgd/client_lr_0.1/client_momentum_0.0/client_weight_decay_0.0/client_num_5/client_epoch_1/sketch_size_40000/clip_0.5/scheduler_cosine/lr_min_1e-05/lr_0.01/moment_0.9/wd_0.0001/batch_size_128/epoch_100/
/projects/illinois/eng/cs/arindamb/lucmon/mlopt/results/cifar/CrossEntropyLoss/federated/resnet_gn/depth_101/smooth_0.1/server_opt_amsgrad/client_opt_sgd/client_lr_0.1/client_momentum_0.0/client_weight_decay_0.0/client_num_5/client_epoch_1/sketch_size_40000/clip_0.5/scheduler_cosine/lr_min_1e-05/lr_0.01/moment_0.9/wd_0.0001/batch_size_128/epoch_500/run_0/

# %%
## ViT-Base
from plot_functions import plot_figures_opts, plot_attr_figure, plot_figures_opts_attr
from main import graphs

lr, dataset_name, loss_name, momentum, weight_decay, batch_size, epochs = 0.001, "cifar", 'CrossEntropyLoss', 0.9, 0.0005, 128, 100
model_name, depth, patch_size = "google/vit-base-patch16-224-in21k", 50, 8
client_opt, client_lr, client_momentum, client_weight_decay, client_num, client_epoch, sketch_size, scheduler, lr_min  ="sgd", 0.01, 0.9, 0.0, 5, 1, 80000, "cosine", 1e-5
model_params = {}
model_params["f-sgdm-8e5"] = {'server_opt': 'sgd', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': 0.0, "client_weight_decay": client_weight_decay, "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": 800000, "scheduler": scheduler, "lr_min": lr_min}
#model_params["f-adam-8e5"] = {'server_opt': 'adamw', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, "client_weight_decay": client_weight_decay, "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": 800000, "scheduler": scheduler, "lr_min": lr_min}
model_params["f-sgdm-8e6"] = {'server_opt': 'sgd', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': 0.0, "client_weight_decay": client_weight_decay, "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": 8000000, "scheduler": scheduler, "lr_min": lr_min}
model_params["f-adam-8e6"] = {'server_opt': 'adamw', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': 0.9, "client_weight_decay": client_weight_decay, "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": 8000000, "scheduler": scheduler, "lr_min": lr_min}
model_params["f-sgdm-8e4"] = {'server_opt': 'sgd', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': 0.0, "client_weight_decay": client_weight_decay, "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": sketch_size, "scheduler": scheduler, "lr_min": lr_min}
model_params["f-adam-8e4"] = {'server_opt': 'adamw', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, "client_weight_decay": client_weight_decay, "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": sketch_size, 'clip': 0.5, "scheduler": scheduler, "lr_min": lr_min}
model_params["f-onebit"] = {'clip': 0.5, 'switch_epoch': 5, 'server_opt': 'onebit', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, "client_weight_decay": client_weight_decay, "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": 800000, "scheduler": scheduler, "lr_min": 1e-7}
model_params["f-adam-8e5"] = {'clip': 0.5, 'server_opt': 'adamw', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, "client_weight_decay": client_weight_decay, "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": 800000, "scheduler": scheduler, "lr_min": lr_min}
model_params["f-fetchsgd-8e5"] = {'server_opt': 'fetchsgd', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, "client_weight_decay": client_weight_decay, "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": 800000, "scheduler": scheduler, "lr_min": lr_min}
model_params["f-fetchsgd-8e4"] = {'server_opt': 'fetchsgd', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, "client_weight_decay": client_weight_decay, "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": 80000, "scheduler": scheduler, "lr_min": lr_min}
model_params["f-fetchsgd-8e6"] = {'server_opt': 'fetchsgd', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, "client_weight_decay": client_weight_decay, "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": 8000000, "scheduler": scheduler, "lr_min": lr_min}
model_params["f-cocktail-8e4"] = {'server_opt': 'cocktailsgd2', 'client_opt': client_opt, 'client_lr': 0.01, 'client_momentum': 0.9, "client_weight_decay": client_weight_decay, "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": 80000, "scheduler": scheduler, "lr_min": 0.01}
model_params["f-cocktail-8e5"] = {'server_opt': 'cocktailsgd2', 'client_opt': client_opt, 'client_lr': 0.01, 'client_momentum': 0.9, "client_weight_decay": client_weight_decay, "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": 800000, "scheduler": scheduler, "lr_min": 0.01}
model_params["f-cocktail-8e6"] = {'server_opt': 'cocktailsgd2', 'client_opt': client_opt, 'client_lr': 0.01, 'client_momentum': 0.9, "client_weight_decay": client_weight_decay, "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": 8000000, "scheduler": scheduler, "lr_min": 0.01}
model_params["f-cdadam-8e4"] = {'server_opt': 'cdadam', 'client_opt': client_opt, 'client_lr':client_lr, 'client_momentum': client_momentum, "client_weight_decay": client_weight_decay, "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": 80001, "scheduler": scheduler, "lr_min": lr_min}
model_params["f-cdadam-8e5"] = {'server_opt': 'cdadam', 'client_opt': client_opt, 'client_lr':client_lr, 'client_momentum': client_momentum, "client_weight_decay": client_weight_decay, "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": 800000, "scheduler": scheduler, "lr_min": lr_min}
model_params["f-cdadam-8e6"] = {'server_opt': 'cdadam', 'client_opt': client_opt, 'client_lr':client_lr, 'client_momentum': client_momentum, "client_weight_decay": client_weight_decay, "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": 8000000, "scheduler": scheduler, "lr_min": lr_min}
model_params["f-marina-8e4"] = {'server_opt': 'marina', 'client_opt': client_opt, 'client_lr':client_lr, 'client_momentum': 0.0, "client_weight_decay": client_weight_decay, "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": 80000,  "base_opt": "sgd", "full_prob": 0.1, "scheduler": scheduler, "lr_min": lr_min}
model_params["f-marina-8e5"] = {'server_opt': 'marina', 'client_opt': client_opt, 'client_lr':client_lr, 'client_momentum': 0.0, "client_weight_decay": client_weight_decay, "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": 800000,  "base_opt": "sgd", "full_prob": 0.1, "scheduler": scheduler, "lr_min": lr_min}
model_params["f-marina-8e6"] = {'server_opt': 'marina', 'client_opt': client_opt, 'client_lr':client_lr, 'client_momentum': 0.0, "client_weight_decay": client_weight_decay, "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": 8000000,  "base_opt": "sgd", "full_prob": 0.1, "scheduler": scheduler, "lr_min": lr_min}
model_params["f-cams-8e4"] = {'server_opt': 'cams', 'client_opt': client_opt, 'client_lr':client_lr, 'client_momentum': client_momentum, "client_weight_decay": client_weight_decay, "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": 80000,  "base_opt": "adam", "scheduler": scheduler, "lr_min": lr_min}
model_params["f-cams-8e5"] = {'server_opt': 'cams', 'client_opt': client_opt, 'client_lr':client_lr, 'client_momentum': client_momentum, "client_weight_decay": client_weight_decay, "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": 800000,  "base_opt": "adam", "scheduler": scheduler, "lr_min": lr_min}
model_params["f-cams-8e6"] = {'server_opt': 'cams', 'client_opt': client_opt, 'client_lr':client_lr, 'client_momentum': client_momentum, "client_weight_decay": client_weight_decay, "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": 8000000,  "base_opt": "adam", "scheduler": scheduler, "lr_min": lr_min}
model_params["f-paq-8e5"] = {'server_opt': 'paq', 'client_opt': client_opt, 'client_lr':client_lr, 'client_momentum': client_momentum, "client_weight_decay": client_weight_decay, "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": 800000,  "base_opt": "adam", "scheduler": scheduler, "lr_min": lr_min}

model_params["sketch-adam-8e4"] = {'server_opt': 'sketch_adam', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, "client_weight_decay": client_weight_decay, "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": sketch_size, 'clip': 0.5, "scheduler": scheduler, "lr_min": lr_min}


opt_params = {}
opt_params['f-onebit'] = {'lr': 0.0005, 'dataset_name':dataset_name, 'loss': loss_name, 'opt':'federated', 'model_name':model_name, 'momentum':momentum, 'weight_decay':5e-3, 'batch_size':batch_size, 'epochs':epochs}
opt_params['f-onebit'] = {'lr': 0.0001, 'dataset_name':dataset_name, 'loss': loss_name, 'opt':'federated', 'model_name':model_name, 'momentum':momentum, 'weight_decay':5e-3, 'batch_size':batch_size, 'epochs':40}


opt_params['f-adam-8e5'] = {'lr': 0.005, 'dataset_name':dataset_name, 'loss': loss_name, 'opt':'federated', 'model_name':model_name, 'momentum':momentum, 'weight_decay':5e-3, 'batch_size':batch_size, 'epochs':40}
opt_params['f-sgdm-8e5'] = {'lr': 1.0, 'dataset_name':dataset_name, 'loss': loss_name, 'opt':'federated', 'model_name':model_name, 'momentum':momentum, 'weight_decay':weight_decay, 'batch_size':batch_size, 'epochs':epochs}
opt_params['f-adam-8e6'] = {'lr': 0.001, 'dataset_name':dataset_name, 'loss': loss_name, 'opt':'federated', 'model_name':model_name, 'momentum':momentum, 'weight_decay':5e-3, 'batch_size':batch_size, 'epochs':epochs}
opt_params['f-sgdm-8e6'] = {'lr': 1.0, 'dataset_name':dataset_name, 'loss': loss_name, 'opt':'federated', 'model_name':model_name, 'momentum':momentum, 'weight_decay':weight_decay, 'batch_size':batch_size, 'epochs':epochs}
opt_params['f-adam-8e4'] = {'lr': 0.005, 'dataset_name':dataset_name, 'loss': loss_name, 'opt':'federated', 'model_name':model_name, 'momentum':momentum, 'weight_decay':5e-3, 'batch_size':batch_size, 'epochs':40}
opt_params['f-sgdm-8e4'] = {'lr': 0.5, 'dataset_name':dataset_name, 'loss': loss_name, 'opt':'federated', 'model_name':model_name, 'momentum':momentum, 'weight_decay':weight_decay, 'batch_size':batch_size, 'epochs':epochs}

opt_params['f-fetchsgd-8e4'] = {'lr': 0.5, 'dataset_name':dataset_name, 'loss': loss_name, 'opt':'federated', 'model_name':model_name, 'momentum':momentum, 'weight_decay':5e-3, 'batch_size':batch_size, 'epochs':40}
opt_params['f-fetchsgd-8e5'] = {'lr': 0.5, 'dataset_name':dataset_name, 'loss': loss_name, 'opt':'federated', 'model_name':model_name, 'momentum':momentum, 'weight_decay':5e-3, 'batch_size':batch_size, 'epochs':40}
opt_params['f-fetchsgd-8e6'] = {'lr': 0.5, 'dataset_name':dataset_name, 'loss': loss_name, 'opt':'federated', 'model_name':model_name, 'momentum':momentum, 'weight_decay':5e-3, 'batch_size':batch_size, 'epochs':40}
opt_params['f-cocktail-8e4'] = {'lr': 1.0, 'dataset_name':dataset_name, 'loss': loss_name, 'opt':'federated', 'model_name':model_name, 'momentum':momentum, 'weight_decay':5e-3, 'batch_size':batch_size, 'epochs':40}
opt_params['f-cocktail-8e5'] = {'lr': 1.0, 'dataset_name':dataset_name, 'loss': loss_name, 'opt':'federated', 'model_name':model_name, 'momentum':momentum, 'weight_decay':5e-3, 'batch_size':batch_size, 'epochs':40}
opt_params['f-cocktail-8e6'] = {'lr': 1.0, 'dataset_name':dataset_name, 'loss': loss_name, 'opt':'federated', 'model_name':model_name, 'momentum':momentum, 'weight_decay':5e-3, 'batch_size':batch_size, 'epochs':40}
opt_params['f-cdadam-8e4'] = {'lr': 0.0005, 'dataset_name':dataset_name, 'loss': loss_name, 'opt':'federated', 'model_name':model_name, 'momentum':momentum, 'weight_decay':5e-3, 'batch_size':batch_size, 'epochs':40}
opt_params['f-cdadam-8e5'] = {'lr': 0.001, 'dataset_name':dataset_name, 'loss': loss_name, 'opt':'federated', 'model_name':model_name, 'momentum':momentum, 'weight_decay':5e-3, 'batch_size':batch_size, 'epochs':40}
opt_params['f-cdadam-8e6'] = {'lr': 0.001, 'dataset_name':dataset_name, 'loss': loss_name, 'opt':'federated', 'model_name':model_name, 'momentum':momentum, 'weight_decay':5e-3, 'batch_size':batch_size, 'epochs':40}
opt_params['f-marina-8e4'] = {'lr': 1.0, 'dataset_name':dataset_name, 'loss': loss_name, 'opt':'federated', 'model_name':model_name, 'momentum':0.9, 'weight_decay':5e-3, 'batch_size':batch_size, 'epochs':40}
opt_params['f-marina-8e5'] = {'lr': 1.0, 'dataset_name':dataset_name, 'loss': loss_name, 'opt':'federated', 'model_name':model_name, 'momentum':0.9, 'weight_decay':5e-3, 'batch_size':batch_size, 'epochs':40}
opt_params['f-marina-8e6'] = {'lr': 1.0, 'dataset_name':dataset_name, 'loss': loss_name, 'opt':'federated', 'model_name':model_name, 'momentum':0.9, 'weight_decay':5e-3, 'batch_size':batch_size, 'epochs':40}
opt_params['f-cams-8e4'] = {'lr': 0.01, 'dataset_name':dataset_name, 'loss': loss_name, 'opt':'federated', 'model_name':model_name, 'momentum':momentum, 'weight_decay':5e-3, 'batch_size':batch_size, 'epochs':40}
opt_params['f-cams-8e6'] = {'lr': 0.001, 'dataset_name':dataset_name, 'loss': loss_name, 'opt':'federated', 'model_name':model_name, 'momentum':momentum, 'weight_decay':5e-3, 'batch_size':batch_size, 'epochs':40}
opt_params['f-cams-8e5'] = {'lr': 0.001, 'dataset_name':dataset_name, 'loss': loss_name, 'opt':'federated', 'model_name':model_name, 'momentum':momentum, 'weight_decay':5e-3, 'batch_size':batch_size, 'epochs':40}
opt_params['f-paq-8e5'] = {'lr': 0.001, 'dataset_name':dataset_name, 'loss': loss_name, 'opt':'federated', 'model_name':model_name, 'momentum':momentum, 'weight_decay':5e-3, 'batch_size':batch_size, 'epochs':40}

opt_params['sketch-adam-8e4'] = {'lr': 0.05, 'dataset_name':dataset_name, 'loss': loss_name, 'opt':'federated', 'model_name':model_name, 'momentum':momentum, 'weight_decay':1e-4, 'batch_size':batch_size, 'epochs':40}


plot_figures_opts_attr([
                        ['f-adam-8e4', 'f-cdadam-8e4', 'f-fetchsgd-8e4',  'f-marina-8e4',  "f-cocktail-8e4", 'f-cams-8e4'], #'f-cdadam-8e4'
                        ['f-adam-8e5',  'f-cdadam-8e5', 'f-fetchsgd-8e5', 'f-marina-8e5', "f-onebit", "f-cocktail-8e5", 'f-cams-8e5', 'f-paq-8e5'],
                        ['f-adam-8e6',  'f-cdadam-8e6', 'f-fetchsgd-8e6',  'f-marina-8e6', "f-cocktail-8e6", "f-cams-8e6"],], model_params, opt_params, attrs="test_err", start=8, end=40, 
                        legends = [['SADL', 'CDAdam', 'FetchSGD', 'MARINA', 'CocktailSGD', 'CAMS'], ['SADL', 'CDAdam', 'FetchSGD', 'MARINA', '1bit-Adam','CocktailSGD', 'CAMS', 'PAQ'], ['SADL', 'CDAdam', 'FetchSGD', 'MARINA', 'CocktailSGD', 'CAMS']],
                        titles = [r'$3 \times 10^5$ Bytes/epoch',r'$3 \times 10^6$  Bytes/epoch', r'$3 \times 10^7$ Bytes/epoch'], linewidth=1.0, yaxis="Validation Error", legend_fontsize=8, save_dir=None) #"../plots/nips25sketch/vit_sketch_full.pdf"
# Out:
# /projects/illinois/eng/cs/arindamb/lucmon/mlopt/results/cifar/CrossEntropyLoss/federated/google/vit-base-patch16-224-in21k/server_opt_adamw/client_opt_sgd/client_lr_0.01/client_momentum_0.9/client_weight_decay_0.0/client_num_5/client_epoch_1/sketch_size_80000/clip_0.5/scheduler_cosine/lr_min_1e-05/lr_0.005/moment_0.9/wd_0.005/batch_size_128/epoch_40/run_0/
# /projects/illinois/eng/cs/arindamb/lucmon/mlopt/results/cifar/CrossEntropyLoss/federated/google/vit-base-patch16-224-in21k/server_opt_cdadam/client_opt_sgd/client_lr_0.01/client_momentum_0.9/client_weight_decay_0.0/client_num_5/client_epoch_1/sketch_size_80001/scheduler_cosine/lr_min_1e-05/lr_0.0005/moment_0.9/wd_0.005/batch_size_128/epoch_40/run_0/
# ...

# %%
from plot_functions import get_attr
attr = "test_accuracy"
for opt_name in ["f-adam-8e4", "f-cdadam-8e4"]:
    attr_list = get_attr(opt_name, model_params, opt_params, attr, eval_graph=False, return_x =False)
    print(opt_name, [1 - run[-1] for run in attr_list])
# Out:
# /projects/illinois/eng/cs/arindamb/lucmon/mlopt/results/cifar/CrossEntropyLoss/federated/google/vit-base-patch16-224-in21k/server_opt_adamw/client_opt_sgd/client_lr_0.01/client_momentum_0.9/client_weight_decay_0.0/client_num_5/client_epoch_1/sketch_size_80000/clip_0.5/scheduler_cosine/lr_min_1e-05/lr_0.005/moment_0.9/wd_0.005/batch_size_128/epoch_40/
# f-adam-8e4 [0.02080000000000004, 0.020399999999999974]
# /projects/illinois/eng/cs/arindamb/lucmon/mlopt/results/cifar/CrossEntropyLoss/federated/google/vit-base-patch16-224-in21k/server_opt_cdadam/client_opt_sgd/client_lr_0.01/client_momentum_0.9/client_weight_decay_0.0/client_num_5/client_epoch_1/sketch_size_80001/scheduler_cosine/lr_min_1e-05/lr_0.0005/moment_0.9/wd_0.005/batch_size_128/epoch_40/
# f-cdadam-8e4 [0.02980000000000005, 0.027200000000000002, 0.03080000000000005]

# %%
/projects/illinois/eng/cs/arindamb/lucmon/mlopt/results/cifar/CrossEntropyLoss/federated/google/vit-base-patch16-224-in21k/server_opt_adamw/client_opt_sgd/client_lr_0.01/client_momentum_0.9/client_weight_decay_0.0/client_num_5/client_epoch_1/sketch_size_80000/clip_0.5/scheduler_cosine/lr_min_1e-05/lr_0.005/moment_0.9/wd_0.005/batch_size_128/epoch_40/run_0/

/projects/illinois/eng/cs/arindamb/lucmon/mlopt/results/cifar/CrossEntropyLoss/federated/google/vit-base-patch16-224-in21k/clip_0.5/server_opt_adamw/client_opt_sgd/client_lr_0.01/client_momentum_0.9/client_weight_decay_0.0/client_num_5/client_epoch_1/sketch_size_80000/scheduler_cosine/lr_min_1e-05/lr_0.005/moment_0.9/wd_0.005/batch_size_128/epoch_40/run_0/
