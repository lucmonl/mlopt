# %%
#nips25
from plot_functions import plot_figures_opts, plot_attr_figure, plot_figures_opts_attrs, plot_figures_opts_attr
from main import graphs

lr, dataset_name, loss_name, momentum, weight_decay, batch_size, epochs = 0.1, "emnist", 'CrossEntropyLoss', 0.9, 1e-4, 64, 100
model_name, depth = "resnet_gn", 101
client_opt, client_lr, client_momentum, client_num, client_epoch, sketch_size, scheduler, lr_min  ="sgd", 0.01, 0.0, 625, 1, 80000, "cosine", 1e-5
model_params = {}

model_params["fetch-8e6-n0.8"] = {"depth": depth, "smooth": 0.1, 'server_opt': 'fetchsgd', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, "client_weight_decay": 0.0, "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": 8000000, "client_partial": 0.0064, "privacy_clip": 1.0, "privacy_noise": 0.8, "scheduler": scheduler, "lr_min": lr_min}
model_params["fetch-8e6-n1"] = {"depth": depth, "smooth": 0.1, 'server_opt': 'fetchsgd', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, "client_weight_decay": 0.0, "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": 8000000, "client_partial": 0.0064, "privacy_clip": 1.0, "privacy_noise": 1.0, "scheduler": scheduler, "lr_min": lr_min}
model_params["fetch-8e6-n2"] = {"depth": depth, "smooth": 0.1, 'server_opt': 'fetchsgd', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, "client_weight_decay": 0.0, "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": 8000000, "client_partial": 0.0064, "privacy_clip": 1.0, "privacy_noise": 2.0, "scheduler": scheduler, "lr_min": lr_min}
model_params["fetch-8e6-n4"] = {"depth": depth, "smooth": 0.1, 'server_opt': 'fetchsgd', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, "client_weight_decay": 0.0, "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": 8000000, "client_partial": 0.0064, "privacy_clip": 1.0, "privacy_noise": 4.0, "scheduler": scheduler, "lr_min": lr_min}
model_params["fetch-4e5-n0.8"] = {"depth": depth, "smooth": 0.1, 'server_opt': 'fetchsgd', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, "client_weight_decay": 0.0, "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": 400000, "client_partial": 0.0064, "privacy_clip": 1.0, "privacy_noise": 0.0883, "scheduler": scheduler, "lr_min": lr_min}
model_params["fetch-4e5-n1"] = {"depth": depth, "smooth": 0.1, 'server_opt': 'fetchsgd', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, "client_weight_decay": 0.0, "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": 400000, "client_partial": 0.0064, "privacy_clip": 1.0, "privacy_noise": 0.1013, "scheduler": scheduler, "lr_min": lr_min}
model_params["fetch-4e5-n2"] = {"depth": depth, "smooth": 0.1, 'server_opt': 'fetchsgd', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, "client_weight_decay": 0.0, "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": 400000, "client_partial": 0.0064, "privacy_clip": 1.0, "privacy_noise": 0.1588, "scheduler": scheduler, "lr_min": lr_min}
model_params["fetch-4e5-n4"] = {"depth": depth, "smooth": 0.1, 'server_opt': 'fetchsgd', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, "client_weight_decay": 0.0, "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": 400000, "client_partial": 0.0064, "privacy_clip": 1.0, "privacy_noise": 0.2265, "scheduler": scheduler, "lr_min": lr_min}

model_params["sgdm-4e5-n0.8"] = {"depth": depth, "smooth": 0.1, 'server_opt': 'sgd', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, "client_weight_decay": 0.0, "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": 400000, "client_partial": 0.0064, "privacy_clip": 1.0, "privacy_noise": 0.0883, "scheduler": scheduler, "lr_min": lr_min}
model_params["adam-4e5-n0.8"] = {"depth": depth, "smooth": 0.1, 'server_opt': 'adam', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum,"client_weight_decay": 0.0,  "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": 400000, "client_partial": 0.0064, "privacy_clip": 1.0, "privacy_noise": 0.0883, "scheduler": scheduler, "lr_min": lr_min}
model_params["sgdm-no-n0.8"] = {"depth": depth, "smooth": 0.1, 'server_opt': 'sgd', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, "client_weight_decay": 0.0, "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": -1, "client_partial": 0.0064, "privacy_clip": 1.0, "privacy_noise": 0.8, "scheduler": scheduler, "lr_min": lr_min}
model_params["adam-no-n0.8"] = {"depth": depth, "smooth": 0.1, 'server_opt': 'adam', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum,"client_weight_decay": 0.0,  "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": -1, "client_partial": 0.0064, "privacy_clip": 1.0, "privacy_noise": 0.8, "scheduler": scheduler, "lr_min": lr_min}
model_params["sgdm-4e5-n1.0"] = {"depth": depth, "smooth": 0.1, 'server_opt': 'sgd', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, "client_weight_decay": 0.0, "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": 400000, "client_partial": 0.0064, "privacy_clip": 1.0, "privacy_noise": 0.1013, "scheduler": scheduler, "lr_min": lr_min}
model_params["adam-4e5-n1.0"] = {"depth": depth, "smooth": 0.1, 'server_opt': 'adam', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum,"client_weight_decay": 0.0,  "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": 400000, "client_partial": 0.0064, "privacy_clip": 1.0, "privacy_noise": 0.1013, "scheduler": scheduler, "lr_min": lr_min}
model_params["sgdm-no-n1.0"] = {"depth": depth, "smooth": 0.1, 'server_opt': 'sgd', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, "client_weight_decay": 0.0, "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": -1, "client_partial": 0.0064, "privacy_clip": 1.0, "privacy_noise": 1.0, "scheduler": scheduler, "lr_min": lr_min}
model_params["adam-no-n1.0"] = {"depth": depth, "smooth": 0.1, 'server_opt': 'adam', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum,"client_weight_decay": 0.0,  "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": -1, "client_partial": 0.0064, "privacy_clip": 1.0, "privacy_noise": 1.0, "scheduler": scheduler, "lr_min": lr_min}


model_params["sgdm-4e5-n2"] = {"depth": depth, "smooth": 0.1, 'server_opt': 'sgd', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, "client_weight_decay": 0.0, "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": 400000, "client_partial": 0.0064, "privacy_clip": 1.0, "privacy_noise": 0.1588, "scheduler": scheduler, "lr_min": lr_min}
model_params["adam-4e5-n2"] = {"depth": depth, "smooth": 0.1, 'server_opt': 'adam', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum,"client_weight_decay": 0.0,  "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": 400000, "client_partial": 0.0064, "privacy_clip": 1.0, "privacy_noise": 0.1588, "scheduler": scheduler, "lr_min": lr_min}
model_params["sgdm-no-n2"] = {"depth": depth, "smooth": 0.1, 'server_opt': 'sgd', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, "client_weight_decay": 0.0, "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": -1, "client_partial": 0.0064, "privacy_clip": 1.0, "privacy_noise": 2.0, "scheduler": scheduler, "lr_min": lr_min}
model_params["adam-no-n2"] = {"depth": depth, "smooth": 0.1, 'server_opt': 'adam', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum,"client_weight_decay": 0.0,  "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": -1, "client_partial": 0.0064, "privacy_clip": 1.0, "privacy_noise": 2.0, "scheduler": scheduler, "lr_min": lr_min}
model_params["sgdm-4e5-n4"] = {"depth": depth, "smooth": 0.1, 'server_opt': 'sgd', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, "client_weight_decay": 0.0, "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": 400000, "client_partial": 0.0064, "privacy_clip": 1.0, "privacy_noise": 0.2265, "scheduler": scheduler, "lr_min": lr_min}
model_params["adam-4e5-n4"] = {"depth": depth, "smooth": 0.1, 'server_opt': 'adam', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum,"client_weight_decay": 0.0,  "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": 400000, "client_partial": 0.0064, "privacy_clip": 1.0, "privacy_noise": 0.2265, "scheduler": scheduler, "lr_min": lr_min}
model_params["sgdm-no-n4"] = {"depth": depth, "smooth": 0.1, 'server_opt': 'sgd', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, "client_weight_decay": 0.0, "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": -1, "client_partial": 0.0064, "privacy_clip": 1.0, "privacy_noise": 4.0, "scheduler": scheduler, "lr_min": lr_min}
model_params["adam-no-n4"] = {"depth": depth, "smooth": 0.1, 'server_opt': 'adam', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum,"client_weight_decay": 0.0,  "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": -1, "client_partial": 0.0064, "privacy_clip": 1.0, "privacy_noise": 4.0, "scheduler": scheduler, "lr_min": lr_min}
model_params["sgdm-4e5-n6"] = {"depth": depth, "smooth": 0.1, 'server_opt': 'sgd', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, "client_weight_decay": 0.0, "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": 400000, "client_partial": 0.0064, "privacy_clip": 1.0, "privacy_noise": 6.0, "scheduler": scheduler, "lr_min": lr_min}
model_params["adam-4e5-n6"] = {"depth": depth, "smooth": 0.1, 'server_opt': 'adam', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum,"client_weight_decay": 0.0,  "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": 400000, "client_partial": 0.0064, "privacy_clip": 1.0, "privacy_noise": 6.0, "scheduler": scheduler, "lr_min": lr_min}
model_params["sgdm-no-n6"] = {"depth": depth, "smooth": 0.1, 'server_opt': 'sgd', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, "client_weight_decay": 0.0, "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": -1, "client_partial": 0.0064, "privacy_clip": 1.0, "privacy_noise": 6.0, "scheduler": scheduler, "lr_min": lr_min}
model_params["adam-no-n6"] = {"depth": depth, "smooth": 0.1, 'server_opt': 'adam', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum,"client_weight_decay": 0.0,  "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": -1, "client_partial": 0.0064, "privacy_clip": 1.0, "privacy_noise": 6.0, "scheduler": scheduler, "lr_min": lr_min}
model_params["sgdm-4e5-n8"] = {"depth": depth, "smooth": 0.1, 'server_opt': 'sgd', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, "client_weight_decay": 0.0, "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": 400000, "client_partial": 0.0064, "privacy_clip": 1.0, "privacy_noise": 8.0, "scheduler": scheduler, "lr_min": lr_min}
model_params["adam-4e5-n8"] = {"depth": depth, "smooth": 0.1, 'server_opt': 'adam', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum,"client_weight_decay": 0.0,  "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": 400000, "client_partial": 0.0064, "privacy_clip": 1.0, "privacy_noise": 8.0, "scheduler": scheduler, "lr_min": lr_min}
model_params["sgdm-no-n8"] = {"depth": depth, "smooth": 0.1, 'server_opt': 'sgd', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, "client_weight_decay": 0.0, "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": -1, "client_partial": 0.0064, "privacy_clip": 1.0, "privacy_noise": 8.0, "scheduler": scheduler, "lr_min": lr_min}
model_params["adam-no-n8"] = {"depth": depth, "smooth": 0.1, 'server_opt': 'adam', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum,"client_weight_decay": 0.0,  "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": -1, "client_partial": 0.0064, "privacy_clip": 1.0, "privacy_noise": 8.0, "scheduler": scheduler, "lr_min": lr_min}

opt_params = {}
opt_params["fetch-4e5-n0.8"] = {'lr': 0.5, 'dataset_name':dataset_name, 'loss': loss_name, 'opt':'federated', 'model_name':model_name, 'momentum':momentum, 'weight_decay':weight_decay, 'batch_size':batch_size, 'epochs':500}
opt_params["fetch-8e6-n0.8"] = {'lr': 0.5, 'dataset_name':dataset_name, 'loss': loss_name, 'opt':'federated', 'model_name':model_name, 'momentum':momentum, 'weight_decay':weight_decay, 'batch_size':batch_size, 'epochs':500}
opt_params["sgdm-4e5-n2"] = {'lr': 0.01, 'dataset_name':dataset_name, 'loss': loss_name, 'opt':'federated', 'model_name':model_name, 'momentum':momentum, 'weight_decay':weight_decay, 'batch_size':batch_size, 'epochs':500}
opt_params["adam-4e5-n2"] = {'lr': 0.01, 'dataset_name':dataset_name, 'loss': loss_name, 'opt':'federated', 'model_name':model_name, 'momentum':momentum, 'weight_decay':weight_decay, 'batch_size':batch_size, 'epochs':500}
opt_params["sgdm-no-n2"] = {'lr': 0.01, 'dataset_name':dataset_name, 'loss': loss_name, 'opt':'federated', 'model_name':model_name, 'momentum':momentum, 'weight_decay':weight_decay, 'batch_size':batch_size, 'epochs':500}
opt_params["adam-no-n2"] = {'lr': 0.01, 'dataset_name':dataset_name, 'loss': loss_name, 'opt':'federated', 'model_name':model_name, 'momentum':momentum, 'weight_decay':weight_decay, 'batch_size':batch_size, 'epochs':500}
opt_params["sgdm-4e5-n0.8"] = opt_params["sgdm-4e5-n1.0"] =opt_params["sgdm-4e5-n8"] = opt_params["sgdm-4e5-n6"] = opt_params["sgdm-4e5-n4"] = opt_params["sgdm-4e5-n2"]
opt_params["adam-4e5-n0.8"] = opt_params["adam-4e5-n1.0"] = opt_params["adam-4e5-n8"] = opt_params["adam-4e5-n6"] = opt_params["adam-4e5-n4"] = opt_params["adam-4e5-n2"]
opt_params["adam-no-n0.8"] = opt_params["adam-no-n1.0"] = opt_params["adam-no-n8"] = opt_params["adam-no-n6"] = opt_params["adam-no-n4"] = opt_params["adam-no-n2"]
opt_params["sgdm-no-n0.8"] = opt_params["sgdm-no-n1.0"] = opt_params["sgdm-no-n8"] = opt_params["sgdm-no-n6"] = opt_params["sgdm-no-n4"] = opt_params["sgdm-no-n2"]
opt_params["fetch-8e6-n4"] = opt_params["fetch-8e6-n2"] = opt_params["fetch-8e6-n1"]= opt_params["fetch-8e6-n0.8"]
opt_params["fetch-4e5-n4"] = opt_params["fetch-4e5-n2"] = opt_params["fetch-4e5-n1"]= opt_params["fetch-4e5-n0.8"]

max_vals = {}
max_vals[0.8] = plot_figures_opts_attr([["sgdm-4e5-n0.8", "sgdm-no-n0.8", "adam-4e5-n0.8", "adam-no-n0.8", "fetch-4e5-n0.8"]], model_params, opt_params, ["test_acc"], start=10, end=None, alpha=1.0, linewidth=1.0, ylabel = "Test Accuracy", titles=[""], legends=[["sgd-4e5", "sgd-no", "adam-4e5", "adam-no", "DiffSketch"]], save_dir=None, return_last=False, return_max=True) #"../plots/iclr25workshop/cifar_client_2.pdf"
max_vals[1.0] = plot_figures_opts_attr([["sgdm-4e5-n1.0", "sgdm-no-n1.0", "adam-4e5-n1.0", "adam-no-n1.0", "fetch-4e5-n1"]], model_params, opt_params, ["test_acc"], start=10, end=None, alpha=1.0, linewidth=1.0, ylabel = "Test Accuracy",titles=[""], legends=[["sgd-4e5", "sgd-no", "adam-4e5", "adam-no",  "DiffSketch"]], save_dir=None, return_last=False, return_max=True) #"../plots/iclr25workshop/cifar_client_2.pdf"
max_vals[2.0] = plot_figures_opts_attr([["sgdm-4e5-n2", "sgdm-no-n2", "adam-4e5-n2", "adam-no-n2", "fetch-4e5-n2"]], model_params, opt_params, ["test_acc"], start=10, end=None, alpha=1.0, linewidth=1.0, ylabel = "Test Accuracy",titles=[""], legends=[["sgd-4e5", "sgd-no", "adam-4e5", "adam-no", "DiffSketch"]], save_dir=None, return_last=False, return_max=True) #"../plots/iclr25workshop/cifar_client_2.pdf"
max_vals[4.0] = plot_figures_opts_attr([["sgdm-4e5-n4", "sgdm-no-n4", "adam-4e5-n4", "adam-no-n4", "fetch-4e5-n4"]], model_params, opt_params, ["test_acc"], start=10, end=None, alpha=1.0, linewidth=1.0, ylabel = "Test Accuracy",titles=[""], legends=[["sgd-4e5", "sgd-no", "adam-4e5", "adam-no","DiffSketch"]], save_dir=None, return_last=False, return_max=True) #"../plots/iclr25workshop/cifar_client_2.pdf"

max_vals_train = {}
max_vals_train[0.8] = plot_figures_opts_attr([["sgdm-4e5-n0.8", "sgdm-no-n0.8", "adam-4e5-n0.8", "adam-no-n0.8", "fetch-4e5-n0.8"]], model_params, opt_params, ["acc"], start=10, end=None, alpha=1.0, linewidth=1.0, ylabel = "Train Accuracy", titles=[""], legends=[["sgd-4e5", "sgd-no", "adam-4e5", "adam-no", "DiffSketch"]], save_dir=None, return_last=False, return_max=True) #"../plots/iclr25workshop/cifar_client_2.pdf"
max_vals_train[1] = plot_figures_opts_attr([["sgdm-4e5-n1.0", "sgdm-no-n1.0", "adam-4e5-n1.0", "adam-no-n1.0", "fetch-4e5-n1"]], model_params, opt_params, ["acc"], start=10, end=None, alpha=1.0, linewidth=1.0, ylabel = "Train Accuracy",titles=[""], legends=[["sgd-4e5", "sgd-no", "adam-4e5", "adam-no",  "DiffSketch"]], save_dir=None, return_last=False, return_max=True) #"../plots/iclr25workshop/cifar_client_2.pdf"
max_vals_train[2] = plot_figures_opts_attr([["sgdm-4e5-n2", "sgdm-no-n2", "adam-4e5-n2", "adam-no-n2", "fetch-4e5-n2"]], model_params, opt_params, ["acc"], start=10, end=None, alpha=1.0, linewidth=1.0, ylabel = "Train Accuracy",titles=[""], legends=[["sgd-4e5", "sgd-no", "adam-4e5", "adam-no", "DiffSketch"]], save_dir=None, return_last=False, return_max=True) #"../plots/iclr25workshop/cifar_client_2.pdf"
max_vals_train[4] = plot_figures_opts_attr([["sgdm-4e5-n4", "sgdm-no-n4", "adam-4e5-n4", "adam-no-n4", "fetch-4e5-n4"]], model_params, opt_params, ["acc"], start=10, end=None, alpha=1.0, linewidth=1.0, ylabel = "Train Accuracy",titles=[""], legends=[["sgd-4e5", "sgd-no", "adam-4e5", "adam-no", "DiffSketch"]], save_dir=None, return_last=False, return_max=True)
# Out:
# /projects/illinois/eng/cs/arindamb/lucmon/mlopt/results/emnist/CrossEntropyLoss/federated/resnet_gn/depth_101/smooth_0.1/server_opt_sgd/client_opt_sgd/client_lr_0.01/client_momentum_0.0/client_weight_decay_0.0/client_num_625/client_epoch_1/sketch_size_400000/client_partial_0.0064/privacy_clip_1.0/privacy_noise_0.0883/scheduler_cosine/lr_min_1e-05/lr_0.01/moment_0.9/wd_0.0001/batch_size_64/epoch_500/run_0/
# /projects/illinois/eng/cs/arindamb/lucmon/mlopt/results/emnist/CrossEntropyLoss/federated/resnet_gn/depth_101/smooth_0.1/server_opt_sgd/client_opt_sgd/client_lr_0.01/client_momentum_0.0/client_weight_decay_0.0/client_num_625/client_epoch_1/sketch_size_-1/client_partial_0.0064/privacy_clip_1.0/privacy_noise_0.8/scheduler_cosine/lr_min_1e-05/lr_0.01/moment_0.9/wd_0.0001/batch_size_64/epoch_500/run_0/
# ...

# %%
from plot_functions import get_attr
import numpy as np
attr = "test_accuracy"
for opt_name in ["sgdm-4e5-n1.0", "sgdm-no-n1.0", "adam-4e5-n1.0", "adam-no-n1.0",]:
    attr_list = get_attr(opt_name, model_params, opt_params, attr, eval_graph=False, return_x =False)
    last_value = [1 - run[-1] for run in attr_list]
    print(opt_name, last_value, np.mean(last_value), np.std(last_value))
# Out:
# /projects/illinois/eng/cs/arindamb/lucmon/mlopt/results/emnist/CrossEntropyLoss/federated/resnet_gn/depth_101/smooth_0.1/server_opt_sgd/client_opt_sgd/client_lr_0.01/client_momentum_0.0/client_weight_decay_0.0/client_num_625/client_epoch_1/sketch_size_400000/client_partial_0.0064/privacy_clip_1.0/privacy_noise_0.1013/scheduler_cosine/lr_min_1e-05/lr_0.01/moment_0.9/wd_0.0001/batch_size_64/epoch_500/
# sgdm-4e5-n1.0 [0.3741, 0.36960000000000004, 0.3668] 0.3701666666666667 0.00300702880302503
# /projects/illinois/eng/cs/arindamb/lucmon/mlopt/results/emnist/CrossEntropyLoss/federated/resnet_gn/depth_101/smooth_0.1/server_opt_sgd/client_opt_sgd/client_lr_0.01/client_momentum_0.0/client_weight_decay_0.0/client_num_625/client_epoch_1/sketch_size_-1/client_partial_0.0064/privacy_clip_1.0/privacy_noise_1.0/scheduler_cosine/lr_min_1e-05/lr_0.01/moment_0.9/wd_0.0001/batch_size_64/epoch_500/
# sgdm-no-n1.0 [0.37529999999999997, 0.3627, 0.3618] 0.36660000000000004 0.006162791575252218
# ...

# %%
#nips25
from plot_functions import plot_figures_opts, plot_attr_figure, plot_figures_opts_attrs, plot_figures_opts_attr
from main import graphs

lr, dataset_name, loss_name, momentum, weight_decay, batch_size, epochs = 0.1, "emnist", 'CrossEntropyLoss', 0.9, 1e-4, 64, 100
model_name, depth = "resnet_gn", 101
client_opt, client_lr, client_momentum, client_num, client_epoch, sketch_size, scheduler, lr_min  ="sgd", 0.01, 0.0, 625, 1, 80000, "cosine", 1e-5
model_params = {}

model_params["sgdm-4e5-n1.0"] = {"depth": depth, "smooth": 0.1, 'server_opt': 'sgd', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, "client_weight_decay": 0.0, "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": 400000, "client_partial": 0.0064, "privacy_clip": 1.0, "privacy_noise": 0.1013, "scheduler": scheduler, "lr_min": lr_min}
model_params["adam-4e5-n1.0"] = {"depth": depth, "smooth": 0.1, 'server_opt': 'adam', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum,"client_weight_decay": 0.0,  "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": 400000, "client_partial": 0.0064, "privacy_clip": 1.0, "privacy_noise": 0.1013, "scheduler": scheduler, "lr_min": lr_min}
model_params["amsgrad-4e5-n1.0"] = {"depth": depth, "smooth": 0.1, 'server_opt': 'amsgrad', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum,"client_weight_decay": 0.0,  "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": 400000, "client_partial": 0.0064, "privacy_clip": 1.0, "privacy_noise": 0.1013, "scheduler": scheduler, "lr_min": lr_min}

model_params["sgdm-no-n1.0"] = {"depth": depth, "smooth": 0.1, 'server_opt': 'sgd', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, "client_weight_decay": 0.0, "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": -1, "client_partial": 0.0064, "privacy_clip": 1.0, "privacy_noise": 1.0, "scheduler": scheduler, "lr_min": lr_min}
model_params["adam-no-n1.0"] = {"depth": depth, "smooth": 0.1, 'server_opt': 'adam', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum,"client_weight_decay": 0.0,  "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": -1, "client_partial": 0.0064, "privacy_clip": 1.0, "privacy_noise": 1.0, "scheduler": scheduler, "lr_min": lr_min}
model_params["amsgrad-no-n1.0"] = {"depth": depth, "smooth": 0.1, 'server_opt': 'amsgrad', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum,"client_weight_decay": 0.0,  "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": -1, "client_partial": 0.0064, "privacy_clip": 1.0, "privacy_noise": 1.0, "scheduler": scheduler, "lr_min": lr_min}

model_params["sgdm-4e5-clip-0.5"] = {"depth": depth, "smooth": 0.1, 'server_opt': 'sgd', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, "client_weight_decay": 0.0, "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": 400000, "client_partial": 0.0064, "privacy_clip": 0.5, "privacy_noise": 0.1013, "scheduler": scheduler, "lr_min": lr_min}
model_params["adam-4e5-clip-0.5"] = {"depth": depth, "smooth": 0.1, 'server_opt': 'adam', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum,"client_weight_decay": 0.0,  "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": 400000, "client_partial": 0.0064, "privacy_clip": 0.5, "privacy_noise": 0.1013, "scheduler": scheduler, "lr_min": lr_min}
model_params["sgdm-no-clip-0.5"] = {"depth": depth, "smooth": 0.1, 'server_opt': 'sgd', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, "client_weight_decay": 0.0, "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": -1, "client_partial": 0.0064, "privacy_clip": 0.5, "privacy_noise": 1.0, "scheduler": scheduler, "lr_min": lr_min}
model_params["adam-no-clip-0.5"] = {"depth": depth, "smooth": 0.1, 'server_opt': 'adam', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum,"client_weight_decay": 0.0,  "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": -1, "client_partial": 0.0064, "privacy_clip": 0.5, "privacy_noise": 1.0, "scheduler": scheduler, "lr_min": lr_min}

model_params["fetch-4e5-n0.8"] = {"depth": depth, "smooth": 0.1, 'server_opt': 'fetchsgd', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, "client_weight_decay": 0.0, "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": 400000, "client_partial": 0.0064, "privacy_clip": 1.0, "privacy_noise": 0.0883, "scheduler": scheduler, "lr_min": lr_min}
model_params["fetch-4e5-n1"] = {"depth": depth, "smooth": 0.1, 'server_opt': 'fetchsgd', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, "client_weight_decay": 0.0, "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": 400000, "client_partial": 0.0064, "privacy_clip": 1.0, "privacy_noise": 0.1013, "scheduler": scheduler, "lr_min": lr_min}
model_params["fetch-4e5-n2"] = {"depth": depth, "smooth": 0.1, 'server_opt': 'fetchsgd', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, "client_weight_decay": 0.0, "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": 400000, "client_partial": 0.0064, "privacy_clip": 1.0, "privacy_noise": 0.1588, "scheduler": scheduler, "lr_min": lr_min}
model_params["fetch-4e5-n4"] = {"depth": depth, "smooth": 0.1, 'server_opt': 'fetchsgd', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, "client_weight_decay": 0.0, "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": 400000, "client_partial": 0.0064, "privacy_clip": 1.0, "privacy_noise": 0.2265, "scheduler": scheduler, "lr_min": lr_min}


model_params["sgdm-4e5-clip-2.0"] = {"depth": depth, "smooth": 0.1, 'server_opt': 'sgd', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, "client_weight_decay": 0.0, "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": 400000, "client_partial": 0.0064, "privacy_clip": 2.0, "privacy_noise": 0.1013, "scheduler": scheduler, "lr_min": lr_min}
model_params["adam-4e5-clip-2.0"] = {"depth": depth, "smooth": 0.1, 'server_opt': 'adam', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum,"client_weight_decay": 0.0,  "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": 400000, "client_partial": 0.0064, "privacy_clip": 2.0, "privacy_noise": 0.1013, "scheduler": scheduler, "lr_min": lr_min}
model_params["sgdm-no-clip-2.0"] = {"depth": depth, "smooth": 0.1, 'server_opt': 'sgd', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, "client_weight_decay": 0.0, "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": -1, "client_partial": 0.0064, "privacy_clip": 2.0, "privacy_noise": 1.0, "scheduler": scheduler, "lr_min": lr_min}
model_params["adam-no-clip-2.0"] = {"depth": depth, "smooth": 0.1, 'server_opt': 'adam', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum,"client_weight_decay": 0.0,  "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": -1, "client_partial": 0.0064, "privacy_clip": 2.0, "privacy_noise": 1.0, "scheduler": scheduler, "lr_min": lr_min}


opt_params = {}
opt_params["fetch-4e5-n0.8"] = {'lr': 0.5, 'dataset_name':dataset_name, 'loss': loss_name, 'opt':'federated', 'model_name':model_name, 'momentum':momentum, 'weight_decay':weight_decay, 'batch_size':batch_size, 'epochs':500}
opt_params["fetch-8e6-n0.8"] = {'lr': 0.5, 'dataset_name':dataset_name, 'loss': loss_name, 'opt':'federated', 'model_name':model_name, 'momentum':momentum, 'weight_decay':weight_decay, 'batch_size':batch_size, 'epochs':500}
opt_params["sgdm-4e5-n2"] = {'lr': 0.01, 'dataset_name':dataset_name, 'loss': loss_name, 'opt':'federated', 'model_name':model_name, 'momentum':momentum, 'weight_decay':weight_decay, 'batch_size':batch_size, 'epochs':500}
opt_params["adam-4e5-n2"] = {'lr': 0.01, 'dataset_name':dataset_name, 'loss': loss_name, 'opt':'federated', 'model_name':model_name, 'momentum':momentum, 'weight_decay':weight_decay, 'batch_size':batch_size, 'epochs':500}
opt_params["sgdm-no-n2"] = {'lr': 0.01, 'dataset_name':dataset_name, 'loss': loss_name, 'opt':'federated', 'model_name':model_name, 'momentum':momentum, 'weight_decay':weight_decay, 'batch_size':batch_size, 'epochs':500}
opt_params["adam-no-n2"] = {'lr': 0.01, 'dataset_name':dataset_name, 'loss': loss_name, 'opt':'federated', 'model_name':model_name, 'momentum':momentum, 'weight_decay':weight_decay, 'batch_size':batch_size, 'epochs':500}
opt_params["sgdm-4e5-clip-0.5"] = opt_params["sgdm-4e5-clip-2.0"]  = opt_params["sgdm-4e5-n0.8"] = opt_params["sgdm-4e5-n1.0"] =opt_params["sgdm-4e5-n8"] = opt_params["sgdm-4e5-n6"] = opt_params["sgdm-4e5-n4"] = opt_params["sgdm-4e5-n2"]
opt_params["amsgrad-4e5-n1.0"] = opt_params["adam-4e5-clip-0.5"] = opt_params["adam-4e5-clip-2.0"] = opt_params["adam-4e5-n0.8"] = opt_params["adam-4e5-n1.0"] = opt_params["adam-4e5-n8"] = opt_params["adam-4e5-n6"] = opt_params["adam-4e5-n4"] = opt_params["adam-4e5-n2"]
opt_params["amsgrad-no-n1.0"] = opt_params["adam-no-clip-0.5"] = opt_params["adam-no-clip-2.0"] = opt_params["adam-no-n0.8"] = opt_params["adam-no-n1.0"] = opt_params["adam-no-n8"] = opt_params["adam-no-n6"] = opt_params["adam-no-n4"] = opt_params["adam-no-n2"]
opt_params["sgdm-no-clip-0.5"] = opt_params["sgdm-no-clip-2.0"] = opt_params["sgdm-no-n0.8"] = opt_params["sgdm-no-n1.0"] = opt_params["sgdm-no-n8"] = opt_params["sgdm-no-n6"] = opt_params["sgdm-no-n4"] = opt_params["sgdm-no-n2"]
opt_params["fetch-8e6-n4"] = opt_params["fetch-8e6-n2"] = opt_params["fetch-8e6-n1"]= opt_params["fetch-8e6-n0.8"]
opt_params["fetch-4e5-n4"] = opt_params["fetch-4e5-n2"] = opt_params["fetch-4e5-n1"]= opt_params["fetch-4e5-n0.8"]
# Out:
# Available GPU Count:  0
# /u/lucmon/lucmon/anaconda3/envs/mlopt/lib/python3.11/site-packages/torch/cuda/__init__.py:716: UserWarning: Can't initialize NVML
#   warnings.warn("Can't initialize NVML")

# %%
from plot_functions import get_attr
import numpy as np
attr = "test_accuracy"
for opt_name in ["sgdm-4e5", "sgdm-no", "adam-4e5", "adam-no",]:
    for attr_name in ["-clip-0.5", "-n1.0",  "-clip-2.0"]:
        concat_opt_name = opt_name + attr_name
        attr_list = get_attr(concat_opt_name, model_params, opt_params, attr, eval_graph=False, return_x =False)
        last_value = [1 - run[-1] for run in attr_list]
        print(concat_opt_name, last_value, np.std(last_value))
# Out:
# /projects/illinois/eng/cs/arindamb/lucmon/mlopt/results/emnist/CrossEntropyLoss/federated/resnet_gn/depth_101/smooth_0.1/server_opt_sgd/client_opt_sgd/client_lr_0.01/client_momentum_0.0/client_weight_decay_0.0/client_num_625/client_epoch_1/sketch_size_400000/client_partial_0.0064/privacy_clip_0.5/privacy_noise_0.1013/scheduler_cosine/lr_min_1e-05/lr_0.01/moment_0.9/wd_0.0001/batch_size_64/epoch_500/
# sgdm-4e5-clip-0.5 [0.3709] 0.0
# /projects/illinois/eng/cs/arindamb/lucmon/mlopt/results/emnist/CrossEntropyLoss/federated/resnet_gn/depth_101/smooth_0.1/server_opt_sgd/client_opt_sgd/client_lr_0.01/client_momentum_0.0/client_weight_decay_0.0/client_num_625/client_epoch_1/sketch_size_400000/client_partial_0.0064/privacy_clip_1.0/privacy_noise_0.1013/scheduler_cosine/lr_min_1e-05/lr_0.01/moment_0.9/wd_0.0001/batch_size_64/epoch_500/
# sgdm-4e5-n1.0 [0.3741, 0.36960000000000004, 0.3668] 0.00300702880302503
# ...

# %%
from plot_functions import get_attr
import numpy as np
attr = "test_accuracy"
for opt_name in ["sgdm-4e5", "sgdm-no", "adam-4e5", "adam-no",]:
    for attr_name in ["-n1.0"]:
        concat_opt_name = opt_name + attr_name
        attr_list = get_attr(concat_opt_name, model_params, opt_params, attr, eval_graph=False, return_x =False)
        last_value = [1 - run[-1] for run in attr_list]
        print(concat_opt_name, last_value[0])
# Out:
# /projects/illinois/eng/cs/arindamb/lucmon/mlopt/results/emnist/CrossEntropyLoss/federated/resnet_gn/depth_101/smooth_0.1/server_opt_sgd/client_opt_sgd/client_lr_0.01/client_momentum_0.0/client_weight_decay_0.0/client_num_625/client_epoch_1/sketch_size_400000/client_partial_0.0064/privacy_clip_1.0/privacy_noise_0.1013/scheduler_cosine/lr_min_1e-05/lr_0.01/moment_0.9/wd_0.0001/batch_size_64/epoch_500/
# sgdm-4e5-n1.0 0.6629
# /projects/illinois/eng/cs/arindamb/lucmon/mlopt/results/emnist/CrossEntropyLoss/federated/resnet_gn/depth_101/smooth_0.1/server_opt_sgd/client_opt_sgd/client_lr_0.01/client_momentum_0.0/client_weight_decay_0.0/client_num_625/client_epoch_1/sketch_size_-1/client_partial_0.0064/privacy_clip_1.0/privacy_noise_1.0/scheduler_cosine/lr_min_1e-05/lr_0.01/moment_0.9/wd_0.0001/batch_size_64/epoch_500/
# sgdm-no-n1.0 0.6469
# ...

# %%
from plot_functions import get_attr
import numpy as np
attr = "test_accuracy"
for opt_name in ["sgdm-4e5", "sgdm-no", "adam-4e5", "adam-no",]:
    for attr_name in ["-n1.0", "-k2", "-k4"]:
        concat_opt_name = opt_name + attr_name
        try:
            attr_list = get_attr(concat_opt_name, model_params, opt_params, attr, eval_graph=False, return_x =False)
            last_value = [1 - run[-1] for run in attr_list]
            print(concat_opt_name, last_value, np.std(last_value))
        except:
            print(concat_opt_name)
# Out:
# /projects/illinois/eng/cs/arindamb/lucmon/mlopt/results/emnist/CrossEntropyLoss/federated/resnet_gn/depth_101/smooth_0.1/server_opt_sgd/client_opt_sgd/client_lr_0.01/client_momentum_0.0/client_weight_decay_0.0/client_num_625/client_epoch_1/sketch_size_400000/client_partial_0.0064/privacy_clip_1.0/privacy_noise_0.1013/scheduler_cosine/lr_min_1e-05/lr_0.01/moment_0.9/wd_0.0001/batch_size_64/epoch_500/
# sgdm-4e5-n1.0 [0.3741, 0.36960000000000004, 0.3668] 0.00300702880302503
# /projects/illinois/eng/cs/arindamb/lucmon/mlopt/results/emnist/CrossEntropyLoss/federated/resnet_gn/depth_101/smooth_0.1/server_opt_sgd/client_opt_sgd/client_lr_0.01/client_momentum_0.0/client_weight_decay_0.0/client_num_625/client_epoch_2/sketch_size_400000/client_partial_0.0064/privacy_clip_1.0/privacy_noise_0.1013/scheduler_cosine/lr_min_1e-05/lr_0.01/moment_0.9/wd_0.0001/batch_size_64/epoch_500/
# sgdm-4e5-k2 [0.28190000000000004] 0.0
# ...

# %%
from plot_functions import get_attr
import numpy as np
attr = "test_accuracy"
for opt_name in ["fetch-4e5-n0.8", "fetch-4e5-n1", "fetch-4e5-n2", "fetch-4e5-n4",]:
    for attr_name in [""]:
        concat_opt_name = opt_name + attr_name
        try:
            attr_list = get_attr(concat_opt_name, model_params, opt_params, attr, eval_graph=False, return_x =False)
            last_value = [1 - run[-1] for run in attr_list]
            print(concat_opt_name, last_value, np.std(last_value))
        except:
            print(concat_opt_name)
# Out:
# /projects/illinois/eng/cs/arindamb/lucmon/mlopt/results/emnist/CrossEntropyLoss/federated/resnet_gn/depth_101/smooth_0.1/server_opt_fetchsgd/client_opt_sgd/client_lr_0.01/client_momentum_0.0/client_weight_decay_0.0/client_num_625/client_epoch_1/sketch_size_400000/client_partial_0.0064/privacy_clip_1.0/privacy_noise_0.0883/scheduler_cosine/lr_min_1e-05/lr_0.5/moment_0.9/wd_0.0001/batch_size_64/epoch_500/
# fetch-4e5-n0.8 [0.2934] 0.0
# /projects/illinois/eng/cs/arindamb/lucmon/mlopt/results/emnist/CrossEntropyLoss/federated/resnet_gn/depth_101/smooth_0.1/server_opt_fetchsgd/client_opt_sgd/client_lr_0.01/client_momentum_0.0/client_weight_decay_0.0/client_num_625/client_epoch_1/sketch_size_400000/client_partial_0.0064/privacy_clip_1.0/privacy_noise_0.1013/scheduler_cosine/lr_min_1e-05/lr_0.5/moment_0.9/wd_0.0001/batch_size_64/epoch_500/
# fetch-4e5-n1 [0.29869999999999997] 0.0
# ...

# %%
from plot_functions import get_attr
import numpy as np
attr = "test_accuracy"
for opt_name in ["amsgrad-4e5-n1.0", "adam-4e5-n1.0", "amsgrad-no-n1.0", "adam-no-n1.0"]:
    for attr_name in [""]:
        concat_opt_name = opt_name + attr_name
        try:
            attr_list = get_attr(concat_opt_name, model_params, opt_params, attr, eval_graph=False, return_x =False)
            last_value = [1 - run[-1] for run in attr_list]
            print(concat_opt_name, last_value, np.std(last_value))
        except:
            print(concat_opt_name)
# Out:
# /projects/illinois/eng/cs/arindamb/lucmon/mlopt/results/emnist/CrossEntropyLoss/federated/resnet_gn/depth_101/smooth_0.1/server_opt_amsgrad/client_opt_sgd/client_lr_0.01/client_momentum_0.0/client_weight_decay_0.0/client_num_625/client_epoch_1/sketch_size_400000/client_partial_0.0064/privacy_clip_1.0/privacy_noise_0.1013/scheduler_cosine/lr_min_1e-05/lr_0.01/moment_0.9/wd_0.0001/batch_size_64/epoch_500/
# amsgrad-4e5-n1.0 [0.1492] 0.0
# /projects/illinois/eng/cs/arindamb/lucmon/mlopt/results/emnist/CrossEntropyLoss/federated/resnet_gn/depth_101/smooth_0.1/server_opt_adam/client_opt_sgd/client_lr_0.01/client_momentum_0.0/client_weight_decay_0.0/client_num_625/client_epoch_1/sketch_size_400000/client_partial_0.0064/privacy_clip_1.0/privacy_noise_0.1013/scheduler_cosine/lr_min_1e-05/lr_0.01/moment_0.9/wd_0.0001/batch_size_64/epoch_500/
# adam-4e5-n1.0 [0.14749999999999996, 0.1473, 0.15239999999999998] 0.002358436393507832
# ...

# %%
#nips25
from plot_functions import plot_figures_opts, plot_attr_figure, plot_figures_opts_attrs, plot_figures_opts_attr
from main import graphs

lr, dataset_name, loss_name, momentum, weight_decay, batch_size, epochs = 0.1, "mnist", 'CrossEntropyLoss', 0.9, 1e-4, 4, 100
model_name, depth = "resnet_gn", 50
client_opt, client_lr, client_momentum, client_num, client_epoch, sketch_size, scheduler, lr_min  ="sgd", 0.01, 0.0, 625, 1, 80000, "cosine", 1e-5
model_params = {}

model_params["fetch-8e6-n0.8"] = {"depth": depth, "smooth": 0.1, 'server_opt': 'fetchsgd', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, "client_weight_decay": 0.0, "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": 8000000, "client_partial": 0.0064, "privacy_clip": 1.0, "privacy_noise": 0.8, "scheduler": scheduler, "lr_min": lr_min}
model_params["fetch-8e6-n1"] = {"depth": depth, "smooth": 0.1, 'server_opt': 'fetchsgd', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, "client_weight_decay": 0.0, "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": 8000000, "client_partial": 0.0064, "privacy_clip": 1.0, "privacy_noise": 1.0, "scheduler": scheduler, "lr_min": lr_min}
model_params["fetch-8e6-n2"] = {"depth": depth, "smooth": 0.1, 'server_opt': 'fetchsgd', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, "client_weight_decay": 0.0, "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": 8000000, "client_partial": 0.0064, "privacy_clip": 1.0, "privacy_noise": 2.0, "scheduler": scheduler, "lr_min": lr_min}
model_params["fetch-8e6-n4"] = {"depth": depth, "smooth": 0.1, 'server_opt': 'fetchsgd', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, "client_weight_decay": 0.0, "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": 8000000, "client_partial": 0.0064, "privacy_clip": 1.0, "privacy_noise": 4.0, "scheduler": scheduler, "lr_min": lr_min}
model_params["fetch-4e5-n0.8"] = {"depth": depth, "smooth": 0.1, 'server_opt': 'fetchsgd', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, "client_weight_decay": 0.0, "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": 400000, "client_partial": 0.0064, "privacy_clip": 1.0, "privacy_noise": 0.0883, "scheduler": scheduler, "lr_min": lr_min}
model_params["fetch-4e5-n1"] = {"depth": depth, "smooth": 0.1, 'server_opt': 'fetchsgd', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, "client_weight_decay": 0.0, "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": 400000, "client_partial": 0.0064, "privacy_clip": 1.0, "privacy_noise": 0.1013, "scheduler": scheduler, "lr_min": lr_min}
model_params["fetch-4e5-n2"] = {"depth": depth, "smooth": 0.1, 'server_opt': 'fetchsgd', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, "client_weight_decay": 0.0, "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": 400000, "client_partial": 0.0064, "privacy_clip": 1.0, "privacy_noise": 0.1588, "scheduler": scheduler, "lr_min": lr_min}
model_params["fetch-4e5-n4"] = {"depth": depth, "smooth": 0.1, 'server_opt': 'fetchsgd', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, "client_weight_decay": 0.0, "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": 400000, "client_partial": 0.0064, "privacy_clip": 1.0, "privacy_noise": 0.2265, "scheduler": scheduler, "lr_min": lr_min}

model_params["sgdm-4e5-n0.8"] = {"depth": depth, "smooth": 0.1, 'server_opt': 'sgd', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, "client_weight_decay": 0.0, "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": 200000, "client_partial": 0.0064, "privacy_clip": 1.0, "privacy_noise": 0.0883, "scheduler": scheduler, "lr_min": lr_min}
model_params["adam-4e5-n0.8"] = {"depth": depth, "smooth": 0.1, 'server_opt': 'adam', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum,"client_weight_decay": 0.0,  "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": 200000, "client_partial": 0.0064, "privacy_clip": 1.0, "privacy_noise": 0.0883, "scheduler": scheduler, "lr_min": lr_min}
model_params["sgdm-no-n0.8"] = {"depth": depth, "smooth": 0.1, 'server_opt': 'sgd', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, "client_weight_decay": 0.0, "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": -1, "client_partial": 0.0064, "privacy_clip": 1.0, "privacy_noise": 0.8, "scheduler": scheduler, "lr_min": lr_min}
model_params["adam-no-n0.8"] = {"depth": depth, "smooth": 0.1, 'server_opt': 'adam', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum,"client_weight_decay": 0.0,  "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": -1, "client_partial": 0.0064, "privacy_clip": 1.0, "privacy_noise": 0.8, "scheduler": scheduler, "lr_min": lr_min}
model_params["sgdm-4e5-n1.0"] = {"depth": depth, "smooth": 0.1, 'server_opt': 'sgd', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, "client_weight_decay": 0.0, "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": 200000, "client_partial": 0.0064, "privacy_clip": 1.0, "privacy_noise": 0.1013, "scheduler": scheduler, "lr_min": lr_min}
model_params["adam-4e5-n1.0"] = {"depth": depth, "smooth": 0.1, 'server_opt': 'adam', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum,"client_weight_decay": 0.0,  "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": 200000, "client_partial": 0.0064, "privacy_clip": 1.0, "privacy_noise": 0.1013, "scheduler": scheduler, "lr_min": lr_min}
model_params["sgdm-no-n1.0"] = {"depth": depth, "smooth": 0.1, 'server_opt': 'sgd', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, "client_weight_decay": 0.0, "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": -1, "client_partial": 0.0064, "privacy_clip": 1.0, "privacy_noise": 1.0, "scheduler": scheduler, "lr_min": lr_min}
model_params["adam-no-n1.0"] = {"depth": depth, "smooth": 0.1, 'server_opt': 'adam', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum,"client_weight_decay": 0.0,  "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": -1, "client_partial": 0.0064, "privacy_clip": 1.0, "privacy_noise": 1.0, "scheduler": scheduler, "lr_min": lr_min}


model_params["sgdm-4e5-n2"] = {"depth": depth, "smooth": 0.1, 'server_opt': 'sgd', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, "client_weight_decay": 0.0, "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": 200000, "client_partial": 0.0064, "privacy_clip": 1.0, "privacy_noise": 0.1588, "scheduler": scheduler, "lr_min": lr_min}
model_params["adam-4e5-n2"] = {"depth": depth, "smooth": 0.1, 'server_opt': 'adam', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum,"client_weight_decay": 0.0,  "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": 200000, "client_partial": 0.0064, "privacy_clip": 1.0, "privacy_noise": 0.1588, "scheduler": scheduler, "lr_min": lr_min}
model_params["sgdm-no-n2"] = {"depth": depth, "smooth": 0.1, 'server_opt': 'sgd', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, "client_weight_decay": 0.0, "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": -1, "client_partial": 0.0064, "privacy_clip": 1.0, "privacy_noise": 2.0, "scheduler": scheduler, "lr_min": lr_min}
model_params["adam-no-n2"] = {"depth": depth, "smooth": 0.1, 'server_opt': 'adam', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum,"client_weight_decay": 0.0,  "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": -1, "client_partial": 0.0064, "privacy_clip": 1.0, "privacy_noise": 2.0, "scheduler": scheduler, "lr_min": lr_min}
model_params["sgdm-4e5-n4"] = {"depth": depth, "smooth": 0.1, 'server_opt': 'sgd', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, "client_weight_decay": 0.0, "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": 200000, "client_partial": 0.0064, "privacy_clip": 1.0, "privacy_noise": 0.2265, "scheduler": scheduler, "lr_min": lr_min}
model_params["adam-4e5-n4"] = {"depth": depth, "smooth": 0.1, 'server_opt': 'adam', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum,"client_weight_decay": 0.0,  "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": 200000, "client_partial": 0.0064, "privacy_clip": 1.0, "privacy_noise": 0.2265, "scheduler": scheduler, "lr_min": lr_min}
model_params["sgdm-no-n4"] = {"depth": depth, "smooth": 0.1, 'server_opt': 'sgd', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, "client_weight_decay": 0.0, "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": -1, "client_partial": 0.0064, "privacy_clip": 1.0, "privacy_noise": 4.0, "scheduler": scheduler, "lr_min": lr_min}
model_params["adam-no-n4"] = {"depth": depth, "smooth": 0.1, 'server_opt': 'adam', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum,"client_weight_decay": 0.0,  "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": -1, "client_partial": 0.0064, "privacy_clip": 1.0, "privacy_noise": 4.0, "scheduler": scheduler, "lr_min": lr_min}
model_params["sgdm-4e5-n6"] = {"depth": depth, "smooth": 0.1, 'server_opt': 'sgd', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, "client_weight_decay": 0.0, "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": 200000, "client_partial": 0.0064, "privacy_clip": 1.0, "privacy_noise": 6.0, "scheduler": scheduler, "lr_min": lr_min}
model_params["adam-4e5-n6"] = {"depth": depth, "smooth": 0.1, 'server_opt': 'adam', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum,"client_weight_decay": 0.0,  "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": 200000, "client_partial": 0.0064, "privacy_clip": 1.0, "privacy_noise": 6.0, "scheduler": scheduler, "lr_min": lr_min}
model_params["sgdm-no-n6"] = {"depth": depth, "smooth": 0.1, 'server_opt': 'sgd', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, "client_weight_decay": 0.0, "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": -1, "client_partial": 0.0064, "privacy_clip": 1.0, "privacy_noise": 6.0, "scheduler": scheduler, "lr_min": lr_min}
model_params["adam-no-n6"] = {"depth": depth, "smooth": 0.1, 'server_opt': 'adam', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum,"client_weight_decay": 0.0,  "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": -1, "client_partial": 0.0064, "privacy_clip": 1.0, "privacy_noise": 6.0, "scheduler": scheduler, "lr_min": lr_min}
model_params["sgdm-4e5-n8"] = {"depth": depth, "smooth": 0.1, 'server_opt': 'sgd', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, "client_weight_decay": 0.0, "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": 200000, "client_partial": 0.0064, "privacy_clip": 1.0, "privacy_noise": 8.0, "scheduler": scheduler, "lr_min": lr_min}
model_params["adam-4e5-n8"] = {"depth": depth, "smooth": 0.1, 'server_opt': 'adam', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum,"client_weight_decay": 0.0,  "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": 200000, "client_partial": 0.0064, "privacy_clip": 1.0, "privacy_noise": 8.0, "scheduler": scheduler, "lr_min": lr_min}
model_params["sgdm-no-n8"] = {"depth": depth, "smooth": 0.1, 'server_opt': 'sgd', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, "client_weight_decay": 0.0, "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": -1, "client_partial": 0.0064, "privacy_clip": 1.0, "privacy_noise": 8.0, "scheduler": scheduler, "lr_min": lr_min}
model_params["adam-no-n8"] = {"depth": depth, "smooth": 0.1, 'server_opt': 'adam', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum,"client_weight_decay": 0.0,  "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": -1, "client_partial": 0.0064, "privacy_clip": 1.0, "privacy_noise": 8.0, "scheduler": scheduler, "lr_min": lr_min}

opt_params = {}
opt_params["fetch-4e5-n0.8"] = {'lr': 0.5, 'dataset_name':dataset_name, 'loss': loss_name, 'opt':'federated', 'model_name':model_name, 'momentum':momentum, 'weight_decay':weight_decay, 'batch_size':batch_size, 'epochs':500}
opt_params["fetch-8e6-n0.8"] = {'lr': 0.5, 'dataset_name':dataset_name, 'loss': loss_name, 'opt':'federated', 'model_name':model_name, 'momentum':momentum, 'weight_decay':weight_decay, 'batch_size':batch_size, 'epochs':500}
opt_params["sgdm-4e5-n2"] = {'lr': 0.5, 'dataset_name':dataset_name, 'loss': loss_name, 'opt':'federated', 'model_name':model_name, 'momentum':momentum, 'weight_decay':weight_decay, 'batch_size':batch_size, 'epochs':500}
opt_params["adam-4e5-n2"] = {'lr': 0.01, 'dataset_name':dataset_name, 'loss': loss_name, 'opt':'federated', 'model_name':model_name, 'momentum':momentum, 'weight_decay':weight_decay, 'batch_size':batch_size, 'epochs':500}
opt_params["sgdm-no-n2"] = {'lr': 0.5, 'dataset_name':dataset_name, 'loss': loss_name, 'opt':'federated', 'model_name':model_name, 'momentum':momentum, 'weight_decay':weight_decay, 'batch_size':batch_size, 'epochs':500}
opt_params["adam-no-n2"] = {'lr': 0.01, 'dataset_name':dataset_name, 'loss': loss_name, 'opt':'federated', 'model_name':model_name, 'momentum':momentum, 'weight_decay':weight_decay, 'batch_size':batch_size, 'epochs':500}
opt_params["sgdm-4e5-n0.8"] = opt_params["sgdm-4e5-n1.0"] =opt_params["sgdm-4e5-n8"] = opt_params["sgdm-4e5-n6"] = opt_params["sgdm-4e5-n4"] = opt_params["sgdm-4e5-n2"]
opt_params["adam-4e5-n0.8"] = opt_params["adam-4e5-n1.0"] = opt_params["adam-4e5-n8"] = opt_params["adam-4e5-n6"] = opt_params["adam-4e5-n4"] = opt_params["adam-4e5-n2"]
opt_params["adam-no-n0.8"] = opt_params["adam-no-n1.0"] = opt_params["adam-no-n8"] = opt_params["adam-no-n6"] = opt_params["adam-no-n4"] = opt_params["adam-no-n2"]
opt_params["sgdm-no-n0.8"] = opt_params["sgdm-no-n1.0"] = opt_params["sgdm-no-n8"] = opt_params["sgdm-no-n6"] = opt_params["sgdm-no-n4"] = opt_params["sgdm-no-n2"]
opt_params["fetch-8e6-n4"] = opt_params["fetch-8e6-n2"] = opt_params["fetch-8e6-n1"]= opt_params["fetch-8e6-n0.8"]
opt_params["fetch-4e5-n4"] = opt_params["fetch-4e5-n2"] = opt_params["fetch-4e5-n1"]= opt_params["fetch-4e5-n0.8"]

max_vals = {}
max_vals[0.8] = plot_figures_opts_attr([["sgdm-4e5-n0.8", "sgdm-no-n0.8", "adam-4e5-n0.8", "adam-no-n0.8"]], model_params, opt_params, ["test_acc"], start=10, end=None, alpha=1.0, linewidth=1.0, ylabel = "Test Accuracy", titles=[""], legends=[["sgd-4e5", "sgd-no", "adam-4e5", "adam-no", "DiffSketch"]], save_dir=None, return_last=False, return_max=True) #"../plots/iclr25workshop/cifar_client_2.pdf"
max_vals[1.0] = plot_figures_opts_attr([["sgdm-4e5-n1.0", "sgdm-no-n1.0", "adam-4e5-n1.0", "adam-no-n1.0"]], model_params, opt_params, ["test_acc"], start=10, end=None, alpha=1.0, linewidth=1.0, ylabel = "Test Accuracy",titles=[""], legends=[["sgd-4e5", "sgd-no", "adam-4e5", "adam-no",  "DiffSketch"]], save_dir=None, return_last=False, return_max=True) #"../plots/iclr25workshop/cifar_client_2.pdf"
max_vals[2.0] = plot_figures_opts_attr([["sgdm-4e5-n2", "sgdm-no-n2", "adam-4e5-n2", "adam-no-n2"]], model_params, opt_params, ["test_acc"], start=10, end=None, alpha=1.0, linewidth=1.0, ylabel = "Test Accuracy",titles=[""], legends=[["sgd-4e5", "sgd-no", "adam-4e5", "adam-no", "DiffSketch"]], save_dir=None, return_last=False, return_max=True) #"../plots/iclr25workshop/cifar_client_2.pdf"
max_vals[4.0] = plot_figures_opts_attr([["sgdm-4e5-n4", "sgdm-no-n4", "adam-4e5-n4", "adam-no-n4"]], model_params, opt_params, ["test_acc"], start=10, end=None, alpha=1.0, linewidth=1.0, ylabel = "Test Accuracy",titles=[""], legends=[["sgd-4e5", "sgd-no", "adam-4e5", "adam-no","DiffSketch"]], save_dir=None, return_last=False, return_max=True) #"../plots/iclr25workshop/cifar_client_2.pdf"
"""
max_vals_train = {}
max_vals_train[0.8] = plot_figures_opts_attr([["sgdm-4e5-n0.8", "sgdm-no-n0.8", "adam-4e5-n0.8", "adam-no-n0.8", "fetch-4e5-n0.8"]], model_params, opt_params, ["acc"], start=10, end=None, alpha=1.0, linewidth=1.0, ylabel = "Train Accuracy", titles=[""], legends=[["sgd-4e5", "sgd-no", "adam-4e5", "adam-no", "DiffSketch"]], save_dir=None, return_last=False, return_max=True) #"../plots/iclr25workshop/cifar_client_2.pdf"
max_vals_train[1] = plot_figures_opts_attr([["sgdm-4e5-n1.0", "sgdm-no-n1.0", "adam-4e5-n1.0", "adam-no-n1.0", "fetch-4e5-n1"]], model_params, opt_params, ["acc"], start=10, end=None, alpha=1.0, linewidth=1.0, ylabel = "Train Accuracy",titles=[""], legends=[["sgd-4e5", "sgd-no", "adam-4e5", "adam-no",  "DiffSketch"]], save_dir=None, return_last=False, return_max=True) #"../plots/iclr25workshop/cifar_client_2.pdf"
max_vals_train[2] = plot_figures_opts_attr([["sgdm-4e5-n2", "sgdm-no-n2", "adam-4e5-n2", "adam-no-n2", "fetch-4e5-n2"]], model_params, opt_params, ["acc"], start=10, end=None, alpha=1.0, linewidth=1.0, ylabel = "Train Accuracy",titles=[""], legends=[["sgd-4e5", "sgd-no", "adam-4e5", "adam-no", "DiffSketch"]], save_dir=None, return_last=False, return_max=True) #"../plots/iclr25workshop/cifar_client_2.pdf"
max_vals_train[4] = plot_figures_opts_attr([["sgdm-4e5-n4", "sgdm-no-n4", "adam-4e5-n4", "adam-no-n4", "fetch-4e5-n4"]], model_params, opt_params, ["acc"], start=10, end=None, alpha=1.0, linewidth=1.0, ylabel = "Train Accuracy",titles=[""], legends=[["sgd-4e5", "sgd-no", "adam-4e5", "adam-no", "DiffSketch"]], save_dir=None, return_last=False, return_max=True) 
"""
# Out:
# /projects/illinois/eng/cs/arindamb/lucmon/mlopt/results/mnist/CrossEntropyLoss/federated/resnet_gn/depth_50/smooth_0.1/server_opt_sgd/client_opt_sgd/client_lr_0.01/client_momentum_0.0/client_weight_decay_0.0/client_num_625/client_epoch_1/sketch_size_200000/client_partial_0.0064/privacy_clip_1.0/privacy_noise_0.0883/scheduler_cosine/lr_min_1e-05/lr_0.5/moment_0.9/wd_0.0001/batch_size_4/epoch_500/run_0/
# /projects/illinois/eng/cs/arindamb/lucmon/mlopt/results/mnist/CrossEntropyLoss/federated/resnet_gn/depth_50/smooth_0.1/server_opt_sgd/client_opt_sgd/client_lr_0.01/client_momentum_0.0/client_weight_decay_0.0/client_num_625/client_epoch_1/sketch_size_-1/client_partial_0.0064/privacy_clip_1.0/privacy_noise_0.8/scheduler_cosine/lr_min_1e-05/lr_0.5/moment_0.9/wd_0.0001/batch_size_4/epoch_500/run_0/
# ...

# %%
from plot_functions import get_attr
import numpy as np
attr = "test_accuracy"
for opt_name in [, "adam-no"]:
    for attr_name in ["-n0.8", "-n1.0", "-n2", "-n4"]:
        concat_opt_name = opt_name + attr_name
        try:
            attr_list = get_attr(concat_opt_name, model_params, opt_params, attr, eval_graph=False, return_x =False)
            last_value = [1 - run[-1] for run in attr_list]
            print(concat_opt_name, last_value, np.std(last_value))
        except:
            print(concat_opt_name)
# Out:
# /projects/illinois/eng/cs/arindamb/lucmon/mlopt/results/mnist/CrossEntropyLoss/federated/resnet_gn/depth_50/smooth_0.1/server_opt_sgd/client_opt_sgd/client_lr_0.01/client_momentum_0.0/client_weight_decay_0.0/client_num_625/client_epoch_1/sketch_size_200000/client_partial_0.0064/privacy_clip_1.0/privacy_noise_0.0883/scheduler_cosine/lr_min_1e-05/lr_0.5/moment_0.9/wd_0.0001/batch_size_4/epoch_500/
# sgdm-4e5-n0.8 [0.013000000000000012] 0.0
# /projects/illinois/eng/cs/arindamb/lucmon/mlopt/results/mnist/CrossEntropyLoss/federated/resnet_gn/depth_50/smooth_0.1/server_opt_sgd/client_opt_sgd/client_lr_0.01/client_momentum_0.0/client_weight_decay_0.0/client_num_625/client_epoch_1/sketch_size_200000/client_partial_0.0064/privacy_clip_1.0/privacy_noise_0.1013/scheduler_cosine/lr_min_1e-05/lr_0.5/moment_0.9/wd_0.0001/batch_size_4/epoch_500/
# sgdm-4e5-n1.0 [0.014399999999999968] 0.0
# ...

# %%
/projects/illinois/eng/cs/arindamb/lucmon/mlopt/results/mnist/CrossEntropyLoss/federated/resnet_gn/depth_101/smooth_0.1/server_opt_sgd/client_opt_sgd/client_lr_0.01/client_momentum_0.0/client_weight_decay_0.0/client_num_625/client_epoch_1/sketch_size_400000/client_partial_0.0064/privacy_clip_1.0/privacy_noise_0.0883/scheduler_cosine/lr_min_1e-05/lr_0.01/moment_0.9/wd_0.0001/batch_size_64/epoch_500/run_0/train_graphs.pk
