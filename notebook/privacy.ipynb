# %%
from plot_functions import plot_figures_opts, plot_attr_figure, plot_figures_opts_attrs, plot_figures_opts_attr
from main import graphs

lr, dataset_name, loss_name, momentum, weight_decay, batch_size, epochs = 0.1, "cifar", 'CrossEntropyLoss', 0.9, 1e-4, 128, 100
model_name, depth = "resnet_gn", 101
client_opt, client_lr, client_momentum, client_num, client_epoch, sketch_size, scheduler, lr_min  ="sgd", 0.1, 0.9, 5, 1, 80000, "cosine", 1e-5
model_params = {}
model_params["f-adam-4e4"] = {"depth": depth, "smooth": 0.1, 'server_opt': 'adam', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": 40000, "scheduler": scheduler, "lr_min": lr_min}
model_params["f-adam-4e3"] = {"depth": depth, "smooth": 0.1, 'server_opt': 'adam', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, "client_weight_decay": 0.0, "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": 4000, "scheduler": scheduler, "lr_min": lr_min}
model_params["f-adam-4e2"] = {"depth": depth, "smooth": 0.1, 'server_opt': 'adam', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, "client_weight_decay": 0.0, "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": 400, "scheduler": scheduler, "lr_min": lr_min}
model_params["f-adam"] = {"depth": depth, "smooth": 0.1, 'server_opt': 'adam', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": -1, "scheduler": scheduler, "lr_min": lr_min}
model_params["f-adam-1e6"] = {"depth": depth, "smooth": 0.1, 'server_opt': 'adam', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": 1000001, "scheduler": scheduler, "lr_min": lr_min}

model_params["f-sgd-4e5"] = {"depth": depth, "smooth": 0.1, 'server_opt': 'sgd', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": 400000, "scheduler": scheduler, "lr_min": lr_min}
model_params["f-adam-4e5"] = {"depth": depth, "smooth": 0.1, 'server_opt': 'adam', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum,"client_weight_decay": 0.0,  "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": 400001, "privacy_clip": 0.1, "privacy_noise": 1.0, "scheduler": scheduler, "lr_min": lr_min}
model_params["f-sgdm-4e5"] = {"depth": depth, "smooth": 0.1, 'server_opt': 'sgd', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, "client_weight_decay": 0.0, "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": 400000, "privacy_clip": 0.1, "privacy_noise": 1.0, "scheduler": scheduler, "lr_min": lr_min}

model_params["f-sgd-4e6"] = {"depth": depth, "smooth": 0.1, 'server_opt': 'sgd', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": 4000000, "scheduler": scheduler, "lr_min": lr_min}
model_params["f-adam-4e6"] = {"depth": depth, "smooth": 0.1, 'server_opt': 'adam', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, 'client_weight_decay': 0.0, "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": 4000000, "clip": 0.5, "scheduler": scheduler, "lr_min": lr_min}
model_params["f-sgdm-4e6"] = {"depth": depth, "smooth": 0.1, 'server_opt': 'sgd', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, 'client_weight_decay': 0.0, "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": 4000000, "scheduler": scheduler, "lr_min": lr_min}
model_params["f-adam-4e5-500"] = {"depth": depth, "smooth": 0.1, 'clip': 0.5, 'server_opt': 'adam', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, 'client_weight_decay': 0.0, "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": 400000, "scheduler": scheduler, "lr_min": lr_min}

model_params["f-adam-4e4"] = {"depth": depth, "smooth": 0.1, 'server_opt': 'adam', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, 'client_weight_decay': 0.0, "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": 40000,  'clip': 0.5, "scheduler": scheduler, "lr_min": lr_min}
model_params["f-adam-4e3"] = {"depth": depth, "smooth": 0.1, 'server_opt': 'adam', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, 'client_weight_decay': 0.0, "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": 4000,  'clip': 0.5, "scheduler": scheduler, "lr_min": lr_min}
model_params["f-adam"] = {"depth": depth, "smooth": 0.1, 'server_opt': 'adam', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, 'client_weight_decay': 0.0, "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": -1,  'clip': 0.1, "scheduler": scheduler, "lr_min": lr_min}


opt_params = {}
opt_params['f-adam'] = {'lr': 0.01, 'dataset_name':dataset_name, 'loss': loss_name, 'opt':'federated', 'model_name':model_name, 'momentum':momentum, 'weight_decay':weight_decay, 'batch_size':batch_size, 'epochs':epochs}
opt_params['f-adam-4e4'] = {'lr': 0.01, 'dataset_name':dataset_name, 'loss': loss_name, 'opt':'federated', 'model_name':model_name, 'momentum':momentum, 'weight_decay':weight_decay, 'batch_size':batch_size, 'epochs':epochs}
opt_params['f-adam-4e3'] = {'lr': 0.01, 'dataset_name':dataset_name, 'loss': loss_name, 'opt':'federated', 'model_name':model_name, 'momentum':momentum, 'weight_decay':weight_decay, 'batch_size':batch_size, 'epochs':epochs}
opt_params['f-adam-4e2'] = {'lr': 0.01, 'dataset_name':dataset_name, 'loss': loss_name, 'opt':'federated', 'model_name':model_name, 'momentum':momentum, 'weight_decay':weight_decay, 'batch_size':batch_size, 'epochs':epochs}
opt_params['f-adam-1e6'] = {'lr': 0.01, 'dataset_name':dataset_name, 'loss': loss_name, 'opt':'federated', 'model_name':model_name, 'momentum':momentum, 'weight_decay':weight_decay, 'batch_size':batch_size, 'epochs':epochs}

opt_params['f-adam-4e5'] = {'lr': 0.01, 'dataset_name':dataset_name, 'loss': loss_name, 'opt':'federated', 'model_name':model_name, 'momentum':momentum, 'weight_decay':weight_decay, 'batch_size':batch_size, 'epochs':500}
opt_params['f-sgdm-4e5'] = {'lr': 0.1, 'dataset_name':dataset_name, 'loss': loss_name, 'opt':'federated', 'model_name':model_name, 'momentum':momentum, 'weight_decay':weight_decay, 'batch_size':batch_size, 'epochs':500}
opt_params['f-sgd-4e5'] = {'lr': 1.0, 'dataset_name':dataset_name, 'loss': loss_name, 'opt':'federated', 'model_name':model_name, 'momentum':0.0, 'weight_decay':weight_decay, 'batch_size':batch_size, 'epochs':epochs}
opt_params['f-fetchsgd-4e5'] = {'lr': 1.0, 'dataset_name':dataset_name, 'loss': loss_name, 'opt':'federated', 'model_name':model_name, 'momentum':momentum, 'weight_decay':weight_decay, 'batch_size':batch_size, 'epochs':500}
opt_params['f-fetchsgd-4e6'] = {'lr': 0.5, 'dataset_name':dataset_name, 'loss': loss_name, 'opt':'federated', 'model_name':model_name, 'momentum':momentum, 'weight_decay':weight_decay, 'batch_size':batch_size, 'epochs':500}

opt_params['f-adam-4e6'] = {'lr': 0.01, 'dataset_name':dataset_name, 'loss': loss_name, 'opt':'federated', 'model_name':model_name, 'momentum':momentum, 'weight_decay':weight_decay, 'batch_size':batch_size, 'epochs':500}
opt_params['f-sgdm-4e6'] = {'lr': 1.0, 'dataset_name':dataset_name, 'loss': loss_name, 'opt':'federated', 'model_name':model_name, 'momentum':momentum, 'weight_decay':weight_decay, 'batch_size':batch_size, 'epochs':epochs}
opt_params['f-sgd-4e6'] = {'lr': 1.0, 'dataset_name':dataset_name, 'loss': loss_name, 'opt':'federated', 'model_name':model_name, 'momentum':0.0, 'weight_decay':weight_decay, 'batch_size':batch_size, 'epochs':epochs}

opt_params['f-adam-4e5-500'] = {'lr': 0.04, 'dataset_name':dataset_name, 'loss': loss_name, 'opt':'federated', 'model_name':model_name, 'momentum':momentum, 'weight_decay':weight_decay, 'batch_size':batch_size, 'epochs':500}

opt_params['f-adam-4e5'] = {'lr': 0.01, 'dataset_name':dataset_name, 'loss': loss_name, 'opt':'federated', 'model_name':model_name, 'momentum':momentum, 'weight_decay':weight_decay, 'batch_size':batch_size, 'epochs':500}
opt_params['f-adam-4e3'] = opt_params['f-adam-4e4'] = opt_params['f-adam'] = opt_params['f-adam-4e5']

plot_figures_opts_attrs(['f-sgdm-4e5', 'f-adam-4e5'], model_params, opt_params, attrs=["loss", "accuracy", "test_err"], start=10)
# Out:
# /projects/illinois/eng/cs/arindamb/lucmon/mlopt/results/cifar/CrossEntropyLoss/federated/resnet_gn/depth_101/smooth_0.1/server_opt_sgd/client_opt_sgd/client_lr_0.1/client_momentum_0.9/client_weight_decay_0.0/client_num_5/client_epoch_1/sketch_size_400000/privacy_clip_0.1/privacy_noise_1.0/scheduler_cosine/lr_min_1e-05/lr_0.1/moment_0.9/wd_0.0001/batch_size_128/epoch_500/
# 1
# 1
# 1
# /projects/illinois/eng/cs/arindamb/lucmon/mlopt/results/cifar/CrossEntropyLoss/federated/resnet_gn/depth_101/smooth_0.1/server_opt_adam/client_opt_sgd/client_lr_0.1/client_momentum_0.9/client_weight_decay_0.0/client_num_5/client_epoch_1/sketch_size_400001/privacy_clip_0.1/privacy_noise_1.0/scheduler_cosine/lr_min_1e-05/lr_0.01/moment_0.9/wd_0.0001/batch_size_128/epoch_500/
# 1
# 1
# 1

# %%
/projects/illinois/eng/cs/arindamb/lucmon/mlopt/results/cifar/CrossEntropyLoss/federated/resnet_gn/depth_101/smooth_0.1/server_opt_sgd/client_opt_sgd/client_lr_0.1/client_momentum_0.0/client_weight_decay_0.0/client_num_5/client_epoch_1/sketch_size_400000/privacy_clip_0.1/privacy_noise_1.0/scheduler_cosine/lr_min_1e-05/lr_0.1/moment_0.9/wd_0.0001/batch_size_128/epoch_500/
/projects/illinois/eng/cs/arindamb/lucmon/mlopt/results/cifar/CrossEntropyLoss/federated/resnet_gn/depth_101/smooth_0.1/server_opt_sgd/client_opt_sgd/client_lr_0.1/client_momentum_0.9/client_weight_decay_0.0/client_num_5/client_epoch_1/sketch_size_400000/privacy_clip_0.1/privacy_noise_1.0/scheduler_cosine/lr_min_1e-05/lr_0.1/moment_0.9/wd_0.0001/batch_size_128/epoch_500/run_0/

# %%
from plot_functions import plot_figures_opts, plot_attr_figure, plot_figures_opts_attrs, plot_figures_opts_attr
from main import graphs

lr, dataset_name, loss_name, momentum, weight_decay, batch_size, epochs = 0.1, "cifar", 'CrossEntropyLoss', 0.9, 1e-4, 128, 100
model_name, depth = "resnet_gn", 101
client_opt, client_lr, client_momentum, client_num, client_epoch, sketch_size, scheduler, lr_min  ="sgd", 0.1, 0.0, 5, 1, 80000, "cosine", 1e-5
model_params = {}
model_params["f-adam-4e4"] = {"depth": depth, "smooth": 0.1, 'server_opt': 'adam', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": 40000, "scheduler": scheduler, "lr_min": lr_min}
model_params["f-adam-4e3"] = {"depth": depth, "smooth": 0.1, 'server_opt': 'adam', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, "client_weight_decay": 0.0, "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": 4000, "scheduler": scheduler, "lr_min": lr_min}
model_params["f-adam-4e2"] = {"depth": depth, "smooth": 0.1, 'server_opt': 'adam', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, "client_weight_decay": 0.0, "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": 400, "scheduler": scheduler, "lr_min": lr_min}
model_params["f-adam"] = {"depth": depth, "smooth": 0.1, 'server_opt': 'adam', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": -1, "scheduler": scheduler, "lr_min": lr_min}
model_params["f-adam-1e6"] = {"depth": depth, "smooth": 0.1, 'server_opt': 'adam', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": 1000001, "scheduler": scheduler, "lr_min": lr_min}

model_params["f-sgd-4e5"] = {"depth": depth, "smooth": 0.1, 'server_opt': 'sgd', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": 400000, "scheduler": scheduler, "lr_min": lr_min}
model_params["f-adam-4e5"] = {"depth": depth, "smooth": 0.1, 'server_opt': 'adam', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum,"client_weight_decay": 0.0,  "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": 400000, "privacy_clip": 0.1, "privacy_noise": 0.1, "scheduler": scheduler, "lr_min": lr_min}
model_params["f-sgdm-4e5"] = {"depth": depth, "smooth": 0.1, 'server_opt': 'sgd', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, "client_weight_decay": 0.0, "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": 400000, "privacy_clip": 0.1, "privacy_noise": 0.1, "scheduler": scheduler, "lr_min": lr_min}

model_params["f-sgd-4e6"] = {"depth": depth, "smooth": 0.1, 'server_opt': 'sgd', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": 4000000, "scheduler": scheduler, "lr_min": lr_min}
model_params["f-adam-4e6"] = {"depth": depth, "smooth": 0.1, 'server_opt': 'adam', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, 'client_weight_decay': 0.0, "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": 4000000, "clip": 0.5, "scheduler": scheduler, "lr_min": lr_min}
model_params["f-sgdm-4e6"] = {"depth": depth, "smooth": 0.1, 'server_opt': 'sgd', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, 'client_weight_decay': 0.0, "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": 4000000, "scheduler": scheduler, "lr_min": lr_min}
model_params["f-adam-4e5-500"] = {"depth": depth, "smooth": 0.1, 'clip': 0.5, 'server_opt': 'adam', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, 'client_weight_decay': 0.0, "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": 400000, "scheduler": scheduler, "lr_min": lr_min}

model_params["f-adam-4e4"] = {"depth": depth, "smooth": 0.1, 'server_opt': 'adam', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, 'client_weight_decay': 0.0, "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": 40000,  'clip': 0.5, "scheduler": scheduler, "lr_min": lr_min}
model_params["f-adam-4e3"] = {"depth": depth, "smooth": 0.1, 'server_opt': 'adam', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, 'client_weight_decay': 0.0, "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": 4000,  'clip': 0.5, "scheduler": scheduler, "lr_min": lr_min}
model_params["f-adam"] = {"depth": depth, "smooth": 0.1, 'server_opt': 'adam', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, 'client_weight_decay': 0.0, "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": -1,  'clip': 0.1, "scheduler": scheduler, "lr_min": lr_min}


opt_params = {}
opt_params['f-adam'] = {'lr': 0.01, 'dataset_name':dataset_name, 'loss': loss_name, 'opt':'federated', 'model_name':model_name, 'momentum':momentum, 'weight_decay':weight_decay, 'batch_size':batch_size, 'epochs':epochs}
opt_params['f-adam-4e4'] = {'lr': 0.01, 'dataset_name':dataset_name, 'loss': loss_name, 'opt':'federated', 'model_name':model_name, 'momentum':momentum, 'weight_decay':weight_decay, 'batch_size':batch_size, 'epochs':epochs}
opt_params['f-adam-4e3'] = {'lr': 0.01, 'dataset_name':dataset_name, 'loss': loss_name, 'opt':'federated', 'model_name':model_name, 'momentum':momentum, 'weight_decay':weight_decay, 'batch_size':batch_size, 'epochs':epochs}
opt_params['f-adam-4e2'] = {'lr': 0.01, 'dataset_name':dataset_name, 'loss': loss_name, 'opt':'federated', 'model_name':model_name, 'momentum':momentum, 'weight_decay':weight_decay, 'batch_size':batch_size, 'epochs':epochs}
opt_params['f-adam-1e6'] = {'lr': 0.01, 'dataset_name':dataset_name, 'loss': loss_name, 'opt':'federated', 'model_name':model_name, 'momentum':momentum, 'weight_decay':weight_decay, 'batch_size':batch_size, 'epochs':epochs}

opt_params['f-adam-4e5'] = {'lr': 0.01, 'dataset_name':dataset_name, 'loss': loss_name, 'opt':'federated', 'model_name':model_name, 'momentum':momentum, 'weight_decay':weight_decay, 'batch_size':batch_size, 'epochs':500}
opt_params['f-sgdm-4e5'] = {'lr': 0.1, 'dataset_name':dataset_name, 'loss': loss_name, 'opt':'federated', 'model_name':model_name, 'momentum':momentum, 'weight_decay':weight_decay, 'batch_size':batch_size, 'epochs':500}
opt_params['f-sgd-4e5'] = {'lr': 1.0, 'dataset_name':dataset_name, 'loss': loss_name, 'opt':'federated', 'model_name':model_name, 'momentum':0.0, 'weight_decay':weight_decay, 'batch_size':batch_size, 'epochs':epochs}
opt_params['f-fetchsgd-4e5'] = {'lr': 1.0, 'dataset_name':dataset_name, 'loss': loss_name, 'opt':'federated', 'model_name':model_name, 'momentum':momentum, 'weight_decay':weight_decay, 'batch_size':batch_size, 'epochs':500}
opt_params['f-fetchsgd-4e6'] = {'lr': 0.5, 'dataset_name':dataset_name, 'loss': loss_name, 'opt':'federated', 'model_name':model_name, 'momentum':momentum, 'weight_decay':weight_decay, 'batch_size':batch_size, 'epochs':500}

opt_params['f-adam-4e6'] = {'lr': 0.01, 'dataset_name':dataset_name, 'loss': loss_name, 'opt':'federated', 'model_name':model_name, 'momentum':momentum, 'weight_decay':weight_decay, 'batch_size':batch_size, 'epochs':500}
opt_params['f-sgdm-4e6'] = {'lr': 1.0, 'dataset_name':dataset_name, 'loss': loss_name, 'opt':'federated', 'model_name':model_name, 'momentum':momentum, 'weight_decay':weight_decay, 'batch_size':batch_size, 'epochs':epochs}
opt_params['f-sgd-4e6'] = {'lr': 1.0, 'dataset_name':dataset_name, 'loss': loss_name, 'opt':'federated', 'model_name':model_name, 'momentum':0.0, 'weight_decay':weight_decay, 'batch_size':batch_size, 'epochs':epochs}

opt_params['f-adam-4e5-500'] = {'lr': 0.04, 'dataset_name':dataset_name, 'loss': loss_name, 'opt':'federated', 'model_name':model_name, 'momentum':momentum, 'weight_decay':weight_decay, 'batch_size':batch_size, 'epochs':500}

opt_params['f-adam-4e5'] = {'lr': 0.01, 'dataset_name':dataset_name, 'loss': loss_name, 'opt':'federated', 'model_name':model_name, 'momentum':momentum, 'weight_decay':weight_decay, 'batch_size':batch_size, 'epochs':500}
opt_params['f-adam-4e3'] = opt_params['f-adam-4e4'] = opt_params['f-adam'] = opt_params['f-adam-4e5']

plot_figures_opts_attrs(['f-sgdm-4e5', 'f-adam-4e5'], model_params, opt_params, attrs=["loss", "accuracy", "test_err"], start=10)
# Out:
# /u/lucmon/lucmon/anaconda3/envs/mlopt/lib/python3.11/site-packages/torch/cuda/__init__.py:716: UserWarning: Can't initialize NVML
#   warnings.warn("Can't initialize NVML")
# Available GPU Count:  0
# /projects/illinois/eng/cs/arindamb/lucmon/mlopt/results/cifar/CrossEntropyLoss/federated/resnet_gn/depth_101/smooth_0.1/server_opt_sgd/client_opt_sgd/client_lr_0.1/client_momentum_0.0/client_weight_decay_0.0/client_num_5/client_epoch_1/sketch_size_400000/privacy_clip_0.1/privacy_noise_0.1/scheduler_cosine/lr_min_1e-05/lr_0.1/moment_0.9/wd_0.0001/batch_size_128/epoch_500/
# 1
# 1
# 1
# /projects/illinois/eng/cs/arindamb/lucmon/mlopt/results/cifar/CrossEntropyLoss/federated/resnet_gn/depth_101/smooth_0.1/server_opt_adam/client_opt_sgd/client_lr_0.1/client_momentum_0.0/client_weight_decay_0.0/client_num_5/client_epoch_1/sketch_size_400000/privacy_clip_0.1/privacy_noise_0.1/scheduler_cosine/lr_min_1e-05/lr_0.01/moment_0.9/wd_0.0001/batch_size_128/epoch_500/
# 1
# 1
# 1

# %%
from plot_functions import plot_figures_opts, plot_attr_figure, plot_figures_opts_attrs, plot_figures_opts_attr
from main import graphs

lr, dataset_name, loss_name, momentum, weight_decay, batch_size, epochs = 0.1, "cifar", 'CrossEntropyLoss', 0.9, 1e-4, 128, 100
model_name, depth = "resnet_gn", 101
client_opt, client_lr, client_momentum, client_num, client_epoch, sketch_size, scheduler, lr_min  ="sgd", 0.1, 0.0, 5, 1, 80000, "cosine", 1e-5
model_params = {}
model_params["f-adam-4e4"] = {"depth": depth, "smooth": 0.1, 'server_opt': 'adam', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": 40000, "scheduler": scheduler, "lr_min": lr_min}
model_params["f-adam-4e3"] = {"depth": depth, "smooth": 0.1, 'server_opt': 'adam', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, "client_weight_decay": 0.0, "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": 4000, "scheduler": scheduler, "lr_min": lr_min}
model_params["f-adam-4e2"] = {"depth": depth, "smooth": 0.1, 'server_opt': 'adam', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, "client_weight_decay": 0.0, "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": 400, "scheduler": scheduler, "lr_min": lr_min}
model_params["f-adam"] = {"depth": depth, "smooth": 0.1, 'server_opt': 'adam', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": -1, "scheduler": scheduler, "lr_min": lr_min}
model_params["f-adam-1e6"] = {"depth": depth, "smooth": 0.1, 'server_opt': 'adam', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": 1000001, "scheduler": scheduler, "lr_min": lr_min}

model_params["f-sgd-4e5"] = {"depth": depth, "smooth": 0.1, 'server_opt': 'sgd', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": 400000, "scheduler": scheduler, "lr_min": lr_min}
model_params["f-adam-4e5"] = {"depth": depth, "smooth": 0.1, 'server_opt': 'adam', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum,"client_weight_decay": 0.0,  "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": 400000, "privacy_clip": 0.1, "privacy_noise": 0.5, "scheduler": scheduler, "lr_min": lr_min}
model_params["f-sgdm-4e5"] = {"depth": depth, "smooth": 0.1, 'server_opt': 'sgd', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, "client_weight_decay": 0.0, "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": 400000, "privacy_clip": 0.1, "privacy_noise": 0.5, "scheduler": scheduler, "lr_min": lr_min}

model_params["f-sgd-4e6"] = {"depth": depth, "smooth": 0.1, 'server_opt': 'sgd', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": 4000000, "scheduler": scheduler, "lr_min": lr_min}
model_params["f-adam-4e6"] = {"depth": depth, "smooth": 0.1, 'server_opt': 'adam', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, 'client_weight_decay': 0.0, "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": 4000000, "clip": 0.5, "scheduler": scheduler, "lr_min": lr_min}
model_params["f-sgdm-4e6"] = {"depth": depth, "smooth": 0.1, 'server_opt': 'sgd', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, 'client_weight_decay': 0.0, "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": 4000000, "scheduler": scheduler, "lr_min": lr_min}
model_params["f-adam-4e5-500"] = {"depth": depth, "smooth": 0.1, 'clip': 0.5, 'server_opt': 'adam', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, 'client_weight_decay': 0.0, "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": 400000, "scheduler": scheduler, "lr_min": lr_min}

model_params["f-adam-4e4"] = {"depth": depth, "smooth": 0.1, 'server_opt': 'adam', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, 'client_weight_decay': 0.0, "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": 40000,  'clip': 0.5, "scheduler": scheduler, "lr_min": lr_min}
model_params["f-adam-4e3"] = {"depth": depth, "smooth": 0.1, 'server_opt': 'adam', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, 'client_weight_decay': 0.0, "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": 4000,  'clip': 0.5, "scheduler": scheduler, "lr_min": lr_min}
model_params["f-adam"] = {"depth": depth, "smooth": 0.1, 'server_opt': 'adam', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, 'client_weight_decay': 0.0, "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": -1,  'clip': 0.1, "scheduler": scheduler, "lr_min": lr_min}


opt_params = {}
opt_params['f-adam'] = {'lr': 0.01, 'dataset_name':dataset_name, 'loss': loss_name, 'opt':'federated', 'model_name':model_name, 'momentum':momentum, 'weight_decay':weight_decay, 'batch_size':batch_size, 'epochs':epochs}
opt_params['f-adam-4e4'] = {'lr': 0.01, 'dataset_name':dataset_name, 'loss': loss_name, 'opt':'federated', 'model_name':model_name, 'momentum':momentum, 'weight_decay':weight_decay, 'batch_size':batch_size, 'epochs':epochs}
opt_params['f-adam-4e3'] = {'lr': 0.01, 'dataset_name':dataset_name, 'loss': loss_name, 'opt':'federated', 'model_name':model_name, 'momentum':momentum, 'weight_decay':weight_decay, 'batch_size':batch_size, 'epochs':epochs}
opt_params['f-adam-4e2'] = {'lr': 0.01, 'dataset_name':dataset_name, 'loss': loss_name, 'opt':'federated', 'model_name':model_name, 'momentum':momentum, 'weight_decay':weight_decay, 'batch_size':batch_size, 'epochs':epochs}
opt_params['f-adam-1e6'] = {'lr': 0.01, 'dataset_name':dataset_name, 'loss': loss_name, 'opt':'federated', 'model_name':model_name, 'momentum':momentum, 'weight_decay':weight_decay, 'batch_size':batch_size, 'epochs':epochs}

opt_params['f-adam-4e5'] = {'lr': 0.01, 'dataset_name':dataset_name, 'loss': loss_name, 'opt':'federated', 'model_name':model_name, 'momentum':momentum, 'weight_decay':weight_decay, 'batch_size':batch_size, 'epochs':500}
opt_params['f-sgdm-4e5'] = {'lr': 0.1, 'dataset_name':dataset_name, 'loss': loss_name, 'opt':'federated', 'model_name':model_name, 'momentum':momentum, 'weight_decay':weight_decay, 'batch_size':batch_size, 'epochs':500}
opt_params['f-sgd-4e5'] = {'lr': 1.0, 'dataset_name':dataset_name, 'loss': loss_name, 'opt':'federated', 'model_name':model_name, 'momentum':0.0, 'weight_decay':weight_decay, 'batch_size':batch_size, 'epochs':epochs}
opt_params['f-fetchsgd-4e5'] = {'lr': 1.0, 'dataset_name':dataset_name, 'loss': loss_name, 'opt':'federated', 'model_name':model_name, 'momentum':momentum, 'weight_decay':weight_decay, 'batch_size':batch_size, 'epochs':500}
opt_params['f-fetchsgd-4e6'] = {'lr': 0.5, 'dataset_name':dataset_name, 'loss': loss_name, 'opt':'federated', 'model_name':model_name, 'momentum':momentum, 'weight_decay':weight_decay, 'batch_size':batch_size, 'epochs':500}

opt_params['f-adam-4e6'] = {'lr': 0.01, 'dataset_name':dataset_name, 'loss': loss_name, 'opt':'federated', 'model_name':model_name, 'momentum':momentum, 'weight_decay':weight_decay, 'batch_size':batch_size, 'epochs':500}
opt_params['f-sgdm-4e6'] = {'lr': 1.0, 'dataset_name':dataset_name, 'loss': loss_name, 'opt':'federated', 'model_name':model_name, 'momentum':momentum, 'weight_decay':weight_decay, 'batch_size':batch_size, 'epochs':epochs}
opt_params['f-sgd-4e6'] = {'lr': 1.0, 'dataset_name':dataset_name, 'loss': loss_name, 'opt':'federated', 'model_name':model_name, 'momentum':0.0, 'weight_decay':weight_decay, 'batch_size':batch_size, 'epochs':epochs}

opt_params['f-adam-4e5-500'] = {'lr': 0.04, 'dataset_name':dataset_name, 'loss': loss_name, 'opt':'federated', 'model_name':model_name, 'momentum':momentum, 'weight_decay':weight_decay, 'batch_size':batch_size, 'epochs':500}

opt_params['f-adam-4e5'] = {'lr': 0.01, 'dataset_name':dataset_name, 'loss': loss_name, 'opt':'federated', 'model_name':model_name, 'momentum':momentum, 'weight_decay':weight_decay, 'batch_size':batch_size, 'epochs':500}
opt_params['f-adam-4e3'] = opt_params['f-adam-4e4'] = opt_params['f-adam'] = opt_params['f-adam-4e5']

plot_figures_opts_attrs(['f-sgdm-4e5', 'f-adam-4e5'], model_params, opt_params, attrs=["loss", "accuracy", "test_err"], start=10)
# Out:
# /projects/illinois/eng/cs/arindamb/lucmon/mlopt/results/cifar/CrossEntropyLoss/federated/resnet_gn/depth_101/smooth_0.1/server_opt_sgd/client_opt_sgd/client_lr_0.1/client_momentum_0.0/client_weight_decay_0.0/client_num_5/client_epoch_1/sketch_size_400000/privacy_clip_0.1/privacy_noise_0.5/scheduler_cosine/lr_min_1e-05/lr_0.1/moment_0.9/wd_0.0001/batch_size_128/epoch_500/
# 1
# 1
# 1
# /projects/illinois/eng/cs/arindamb/lucmon/mlopt/results/cifar/CrossEntropyLoss/federated/resnet_gn/depth_101/smooth_0.1/server_opt_adam/client_opt_sgd/client_lr_0.1/client_momentum_0.0/client_weight_decay_0.0/client_num_5/client_epoch_1/sketch_size_400000/privacy_clip_0.1/privacy_noise_0.5/scheduler_cosine/lr_min_1e-05/lr_0.01/moment_0.9/wd_0.0001/batch_size_128/epoch_500/
# 1
# 1
# 1

# %%
/projects/illinois/eng/cs/arindamb/lucmon/mlopt/results/cifar/CrossEntropyLoss/federated/resnet_gn/depth_101/smooth_0.1/server_opt_adam/client_opt_sgd/client_lr_0.1/client_momentum_0.9/client_weight_decay_0.0/client_num_5/client_epoch_1/sketch_size_400000/privacy_clip_0.1/privacy_noise_0.1/scheduler_cosine/lr_min_1e-05/lr_0.01/moment_0.9/wd_0.0001/batch_size_128/epoch_500/

/projects/illinois/eng/cs/arindamb/lucmon/mlopt/results/cifar/CrossEntropyLoss/federated/resnet_gn/depth_101/smooth_0.1/server_opt_adam/client_opt_sgd/client_lr_0.1/client_momentum_0.0/client_weight_decay_0.0/client_num_5/client_epoch_1/sketch_size_400000/privacy_clip_0.1/privacy_noise_0.1/scheduler_cosine/lr_min_1e-05/lr_0.01/moment_0.9/wd_0.0001/batch_size_128/epoch_500/run_0/

# %%
/projects/illinois/eng/cs/arindamb/lucmon/mlopt/results/emnist/CrossEntropyLoss/federated/resnet_gn/depth_101/smooth_0.1/server_opt_sgd/client_opt_sgd/client_lr_0.01/client_momentum_0.0/client_weight_decay_0.0/client_num_625/client_epoch_1/sketch_size_4000000/client_partial_0.0064/privacy_clip_1.0/privacy_noise_4.0/scheduler_cosine/lr_min_1e-05/lr_0.01/moment_0.0/wd_0.0001/batch_size_64/epoch_500/run_0/


/projects/illinois/eng/cs/arindamb/lucmon/mlopt/results/emnist/CrossEntropyLoss/federated/resnet_gn/depth_101/smooth_0.1/server_opt_sgd/client_opt_sgd/client_lr_0.01/client_momentum_0.0/client_weight_decay_0.0/client_num_625/client_epoch_1/sketch_size_400000/client_partial_0.0064/privacy_clip_1.0/privacy_noise_0.8/scheduler_cosine/lr_min_1e-05/lr_0.01/moment_0.9/wd_0.0001/batch_size_64/epoch_500/

# %%
from plot_functions import plot_figures_opts, plot_attr_figure, plot_figures_opts_attrs, plot_figures_opts_attr
from main import graphs

lr, dataset_name, loss_name, momentum, weight_decay, batch_size, epochs = 0.1, "emnist", 'CrossEntropyLoss', 0.9, 1e-4, 64, 100
model_name, depth = "resnet_gn", 101
client_opt, client_lr, client_momentum, client_num, client_epoch, sketch_size, scheduler, lr_min  ="sgd", 0.01, 0.0, 625, 1, 80000, "cosine", 1e-5
model_params = {}

model_params["fetch-8e6-n0.8"] = {"depth": depth, "smooth": 0.1, 'server_opt': 'fetchsgd', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, "client_weight_decay": 0.0, "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": 8000000, "client_partial": 0.0064, "privacy_clip": 1.0, "privacy_noise": 0.8, "scheduler": scheduler, "lr_min": lr_min}
model_params["fetch-8e6-n1"] = {"depth": depth, "smooth": 0.1, 'server_opt': 'fetchsgd', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, "client_weight_decay": 0.0, "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": 8000000, "client_partial": 0.0064, "privacy_clip": 1.0, "privacy_noise": 1.0, "scheduler": scheduler, "lr_min": lr_min}
model_params["fetch-8e6-n2"] = {"depth": depth, "smooth": 0.1, 'server_opt': 'fetchsgd', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, "client_weight_decay": 0.0, "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": 8000000, "client_partial": 0.0064, "privacy_clip": 1.0, "privacy_noise": 2.0, "scheduler": scheduler, "lr_min": lr_min}
model_params["fetch-8e6-n4"] = {"depth": depth, "smooth": 0.1, 'server_opt': 'fetchsgd', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, "client_weight_decay": 0.0, "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": 8000000, "client_partial": 0.0064, "privacy_clip": 1.0, "privacy_noise": 4.0, "scheduler": scheduler, "lr_min": lr_min}

model_params["sgdm-4e5-n0.8"] = {"depth": depth, "smooth": 0.1, 'server_opt': 'sgd', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, "client_weight_decay": 0.0, "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": 400000, "client_partial": 0.0064, "privacy_clip": 1.0, "privacy_noise": 0.8, "scheduler": scheduler, "lr_min": lr_min}
model_params["adam-4e5-n0.8"] = {"depth": depth, "smooth": 0.1, 'server_opt': 'adam', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum,"client_weight_decay": 0.0,  "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": 400000, "client_partial": 0.0064, "privacy_clip": 1.0, "privacy_noise": 0.8, "scheduler": scheduler, "lr_min": lr_min}
model_params["sgdm-no-n0.8"] = {"depth": depth, "smooth": 0.1, 'server_opt': 'sgd', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, "client_weight_decay": 0.0, "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": -1, "client_partial": 0.0064, "privacy_clip": 1.0, "privacy_noise": 0.8, "scheduler": scheduler, "lr_min": lr_min}
model_params["adam-no-n0.8"] = {"depth": depth, "smooth": 0.1, 'server_opt': 'adam', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum,"client_weight_decay": 0.0,  "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": -1, "client_partial": 0.0064, "privacy_clip": 1.0, "privacy_noise": 0.8, "scheduler": scheduler, "lr_min": lr_min}
model_params["sgdm-4e5-n1.0"] = {"depth": depth, "smooth": 0.1, 'server_opt': 'sgd', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, "client_weight_decay": 0.0, "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": 400000, "client_partial": 0.0064, "privacy_clip": 1.0, "privacy_noise": 1.0, "scheduler": scheduler, "lr_min": lr_min}
model_params["adam-4e5-n1.0"] = {"depth": depth, "smooth": 0.1, 'server_opt': 'adam', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum,"client_weight_decay": 0.0,  "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": 400000, "client_partial": 0.0064, "privacy_clip": 1.0, "privacy_noise": 1.0, "scheduler": scheduler, "lr_min": lr_min}
model_params["sgdm-no-n1.0"] = {"depth": depth, "smooth": 0.1, 'server_opt': 'sgd', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, "client_weight_decay": 0.0, "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": -1, "client_partial": 0.0064, "privacy_clip": 1.0, "privacy_noise": 1.0, "scheduler": scheduler, "lr_min": lr_min}
model_params["adam-no-n1.0"] = {"depth": depth, "smooth": 0.1, 'server_opt': 'adam', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum,"client_weight_decay": 0.0,  "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": -1, "client_partial": 0.0064, "privacy_clip": 1.0, "privacy_noise": 1.0, "scheduler": scheduler, "lr_min": lr_min}


model_params["sgdm-4e5-n2"] = {"depth": depth, "smooth": 0.1, 'server_opt': 'sgd', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, "client_weight_decay": 0.0, "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": 400000, "client_partial": 0.0064, "privacy_clip": 1.0, "privacy_noise": 2.0, "scheduler": scheduler, "lr_min": lr_min}
model_params["adam-4e5-n2"] = {"depth": depth, "smooth": 0.1, 'server_opt': 'adam', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum,"client_weight_decay": 0.0,  "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": 400000, "client_partial": 0.0064, "privacy_clip": 1.0, "privacy_noise": 2.0, "scheduler": scheduler, "lr_min": lr_min}
model_params["sgdm-no-n2"] = {"depth": depth, "smooth": 0.1, 'server_opt': 'sgd', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, "client_weight_decay": 0.0, "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": -1, "client_partial": 0.0064, "privacy_clip": 1.0, "privacy_noise": 2.0, "scheduler": scheduler, "lr_min": lr_min}
model_params["adam-no-n2"] = {"depth": depth, "smooth": 0.1, 'server_opt': 'adam', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum,"client_weight_decay": 0.0,  "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": -1, "client_partial": 0.0064, "privacy_clip": 1.0, "privacy_noise": 2.0, "scheduler": scheduler, "lr_min": lr_min}
model_params["sgdm-4e5-n4"] = {"depth": depth, "smooth": 0.1, 'server_opt': 'sgd', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, "client_weight_decay": 0.0, "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": 400000, "client_partial": 0.0064, "privacy_clip": 1.0, "privacy_noise": 4.0, "scheduler": scheduler, "lr_min": lr_min}
model_params["adam-4e5-n4"] = {"depth": depth, "smooth": 0.1, 'server_opt': 'adam', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum,"client_weight_decay": 0.0,  "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": 400000, "client_partial": 0.0064, "privacy_clip": 1.0, "privacy_noise": 4.0, "scheduler": scheduler, "lr_min": lr_min}
model_params["sgdm-no-n4"] = {"depth": depth, "smooth": 0.1, 'server_opt': 'sgd', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, "client_weight_decay": 0.0, "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": -1, "client_partial": 0.0064, "privacy_clip": 1.0, "privacy_noise": 4.0, "scheduler": scheduler, "lr_min": lr_min}
model_params["adam-no-n4"] = {"depth": depth, "smooth": 0.1, 'server_opt': 'adam', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum,"client_weight_decay": 0.0,  "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": -1, "client_partial": 0.0064, "privacy_clip": 1.0, "privacy_noise": 4.0, "scheduler": scheduler, "lr_min": lr_min}
model_params["sgdm-4e5-n6"] = {"depth": depth, "smooth": 0.1, 'server_opt': 'sgd', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, "client_weight_decay": 0.0, "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": 400000, "client_partial": 0.0064, "privacy_clip": 1.0, "privacy_noise": 6.0, "scheduler": scheduler, "lr_min": lr_min}
model_params["adam-4e5-n6"] = {"depth": depth, "smooth": 0.1, 'server_opt': 'adam', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum,"client_weight_decay": 0.0,  "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": 400000, "client_partial": 0.0064, "privacy_clip": 1.0, "privacy_noise": 6.0, "scheduler": scheduler, "lr_min": lr_min}
model_params["sgdm-no-n6"] = {"depth": depth, "smooth": 0.1, 'server_opt': 'sgd', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, "client_weight_decay": 0.0, "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": -1, "client_partial": 0.0064, "privacy_clip": 1.0, "privacy_noise": 6.0, "scheduler": scheduler, "lr_min": lr_min}
model_params["adam-no-n6"] = {"depth": depth, "smooth": 0.1, 'server_opt': 'adam', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum,"client_weight_decay": 0.0,  "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": -1, "client_partial": 0.0064, "privacy_clip": 1.0, "privacy_noise": 6.0, "scheduler": scheduler, "lr_min": lr_min}
model_params["sgdm-4e5-n8"] = {"depth": depth, "smooth": 0.1, 'server_opt': 'sgd', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, "client_weight_decay": 0.0, "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": 400000, "client_partial": 0.0064, "privacy_clip": 1.0, "privacy_noise": 8.0, "scheduler": scheduler, "lr_min": lr_min}
model_params["adam-4e5-n8"] = {"depth": depth, "smooth": 0.1, 'server_opt': 'adam', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum,"client_weight_decay": 0.0,  "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": 400000, "client_partial": 0.0064, "privacy_clip": 1.0, "privacy_noise": 8.0, "scheduler": scheduler, "lr_min": lr_min}
model_params["sgdm-no-n8"] = {"depth": depth, "smooth": 0.1, 'server_opt': 'sgd', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, "client_weight_decay": 0.0, "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": -1, "client_partial": 0.0064, "privacy_clip": 1.0, "privacy_noise": 8.0, "scheduler": scheduler, "lr_min": lr_min}
model_params["adam-no-n8"] = {"depth": depth, "smooth": 0.1, 'server_opt': 'adam', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum,"client_weight_decay": 0.0,  "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": -1, "client_partial": 0.0064, "privacy_clip": 1.0, "privacy_noise": 8.0, "scheduler": scheduler, "lr_min": lr_min}

opt_params = {}
opt_params["fetch-8e6-n0.8"] = {'lr': 0.5, 'dataset_name':dataset_name, 'loss': loss_name, 'opt':'federated', 'model_name':model_name, 'momentum':momentum, 'weight_decay':weight_decay, 'batch_size':batch_size, 'epochs':500}
opt_params["sgdm-4e5-n2"] = {'lr': 0.01, 'dataset_name':dataset_name, 'loss': loss_name, 'opt':'federated', 'model_name':model_name, 'momentum':momentum, 'weight_decay':weight_decay, 'batch_size':batch_size, 'epochs':500}
opt_params["adam-4e5-n2"] = {'lr': 0.01, 'dataset_name':dataset_name, 'loss': loss_name, 'opt':'federated', 'model_name':model_name, 'momentum':momentum, 'weight_decay':weight_decay, 'batch_size':batch_size, 'epochs':500}
opt_params["sgdm-no-n2"] = {'lr': 0.01, 'dataset_name':dataset_name, 'loss': loss_name, 'opt':'federated', 'model_name':model_name, 'momentum':momentum, 'weight_decay':weight_decay, 'batch_size':batch_size, 'epochs':500}
opt_params["adam-no-n2"] = {'lr': 0.01, 'dataset_name':dataset_name, 'loss': loss_name, 'opt':'federated', 'model_name':model_name, 'momentum':momentum, 'weight_decay':weight_decay, 'batch_size':batch_size, 'epochs':500}
opt_params["sgdm-4e5-n0.8"] = opt_params["sgdm-4e5-n1.0"] =opt_params["sgdm-4e5-n8"] = opt_params["sgdm-4e5-n6"] = opt_params["sgdm-4e5-n4"] = opt_params["sgdm-4e5-n2"]
opt_params["adam-4e5-n0.8"] = opt_params["adam-4e5-n1.0"] = opt_params["adam-4e5-n8"] = opt_params["adam-4e5-n6"] = opt_params["adam-4e5-n4"] = opt_params["adam-4e5-n2"]
opt_params["adam-no-n0.8"] = opt_params["adam-no-n1.0"] = opt_params["adam-no-n8"] = opt_params["adam-no-n6"] = opt_params["adam-no-n4"] = opt_params["adam-no-n2"]
opt_params["sgdm-no-n0.8"] = opt_params["sgdm-no-n1.0"] = opt_params["sgdm-no-n8"] = opt_params["sgdm-no-n6"] = opt_params["sgdm-no-n4"] = opt_params["sgdm-no-n2"]
opt_params["fetch-8e6-n4"] = opt_params["fetch-8e6-n2"] = opt_params["fetch-8e6-n1"]= opt_params["fetch-8e6-n0.8"]

max_vals = {}
max_vals[0.8] = plot_figures_opts_attr([["sgdm-4e5-n0.8", "sgdm-no-n0.8", "adam-4e5-n0.8", "adam-no-n0.8", "fetch-8e6-n0.8"]], model_params, opt_params, ["test_acc"], start=10, end=None, alpha=1.0, linewidth=1.0, ylabel = "Test Accuracy", titles=[""], legends=[["sgd-4e5", "sgd-no", "adam-4e5", "adam-no", "fetch-8e6"]], save_dir=None, return_last=False, return_max=True) #"../plots/iclr25workshop/cifar_client_2.pdf"
max_vals[1.0] = plot_figures_opts_attr([["sgdm-4e5-n1.0", "sgdm-no-n1.0", "adam-4e5-n1.0", "adam-no-n1.0", "fetch-8e6-n1"]], model_params, opt_params, ["test_acc"], start=10, end=None, alpha=1.0, linewidth=1.0, ylabel = "Test Accuracy",titles=[""], legends=[["sgd-4e5", "sgd-no", "adam-4e5", "adam-no",  "fetch-8e6"]], save_dir=None, return_last=False, return_max=True) #"../plots/iclr25workshop/cifar_client_2.pdf"
max_vals[2.0] = plot_figures_opts_attr([["sgdm-4e5-n2", "sgdm-no-n2", "adam-4e5-n2", "adam-no-n2", "fetch-8e6-n2"]], model_params, opt_params, ["test_acc"], start=10, end=None, alpha=1.0, linewidth=1.0, ylabel = "Test Accuracy",titles=[""], legends=[["sgd-4e5", "sgd-no", "adam-4e5", "adam-no", "fetch-8e6"]], save_dir=None, return_last=False, return_max=True) #"../plots/iclr25workshop/cifar_client_2.pdf"
max_vals[4.0] = plot_figures_opts_attr([["sgdm-4e5-n4", "sgdm-no-n4", "adam-4e5-n4", "adam-no-n4", "fetch-8e6-n4"]], model_params, opt_params, ["test_acc"], start=10, end=None, alpha=1.0, linewidth=1.0, ylabel = "Test Accuracy",titles=[""], legends=[["sgd-4e5", "sgd-no", "adam-4e5", "adam-no", "fetch-8e6"]], save_dir=None, return_last=False, return_max=True) #"../plots/iclr25workshop/cifar_client_2.pdf"
# Out:
# /projects/illinois/eng/cs/arindamb/lucmon/mlopt/results/emnist/CrossEntropyLoss/federated/resnet_gn/depth_101/smooth_0.1/server_opt_sgd/client_opt_sgd/client_lr_0.01/client_momentum_0.0/client_weight_decay_0.0/client_num_625/client_epoch_1/sketch_size_400000/client_partial_0.0064/privacy_clip_1.0/privacy_noise_0.8/scheduler_cosine/lr_min_1e-05/lr_0.01/moment_0.9/wd_0.0001/batch_size_64/epoch_500/run_0/
# /projects/illinois/eng/cs/arindamb/lucmon/mlopt/results/emnist/CrossEntropyLoss/federated/resnet_gn/depth_101/smooth_0.1/server_opt_sgd/client_opt_sgd/client_lr_0.01/client_momentum_0.0/client_weight_decay_0.0/client_num_625/client_epoch_1/sketch_size_-1/client_partial_0.0064/privacy_clip_1.0/privacy_noise_0.8/scheduler_cosine/lr_min_1e-05/lr_0.01/moment_0.9/wd_0.0001/batch_size_64/epoch_500/run_0/
# ...

# %%
#nips25
from plot_functions import plot_figures_opts, plot_attr_figure, plot_figures_opts_attrs, plot_figures_opts_attr
from main import graphs

lr, dataset_name, loss_name, momentum, weight_decay, batch_size, epochs = 0.1, "emnist", 'CrossEntropyLoss', 0.9, 1e-4, 64, 100
model_name, depth = "resnet_gn", 101
client_opt, client_lr, client_momentum, client_num, client_epoch, sketch_size, scheduler, lr_min  ="sgd", 0.01, 0.0, 625, 1, 80000, "cosine", 1e-5
model_params = {}

model_params["fetch-8e6-n0.8"] = {"depth": depth, "smooth": 0.1, 'server_opt': 'fetchsgd', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, "client_weight_decay": 0.0, "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": 8000000, "client_partial": 0.0064, "privacy_clip": 1.0, "privacy_noise": 0.8, "scheduler": scheduler, "lr_min": lr_min}
model_params["fetch-8e6-n1"] = {"depth": depth, "smooth": 0.1, 'server_opt': 'fetchsgd', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, "client_weight_decay": 0.0, "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": 8000000, "client_partial": 0.0064, "privacy_clip": 1.0, "privacy_noise": 1.0, "scheduler": scheduler, "lr_min": lr_min}
model_params["fetch-8e6-n2"] = {"depth": depth, "smooth": 0.1, 'server_opt': 'fetchsgd', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, "client_weight_decay": 0.0, "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": 8000000, "client_partial": 0.0064, "privacy_clip": 1.0, "privacy_noise": 2.0, "scheduler": scheduler, "lr_min": lr_min}
model_params["fetch-8e6-n4"] = {"depth": depth, "smooth": 0.1, 'server_opt': 'fetchsgd', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, "client_weight_decay": 0.0, "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": 8000000, "client_partial": 0.0064, "privacy_clip": 1.0, "privacy_noise": 4.0, "scheduler": scheduler, "lr_min": lr_min}
model_params["fetch-4e5-n0.8"] = {"depth": depth, "smooth": 0.1, 'server_opt': 'fetchsgd', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, "client_weight_decay": 0.0, "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": 400000, "client_partial": 0.0064, "privacy_clip": 1.0, "privacy_noise": 0.0883, "scheduler": scheduler, "lr_min": lr_min}
model_params["fetch-4e5-n1"] = {"depth": depth, "smooth": 0.1, 'server_opt': 'fetchsgd', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, "client_weight_decay": 0.0, "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": 400000, "client_partial": 0.0064, "privacy_clip": 1.0, "privacy_noise": 0.1013, "scheduler": scheduler, "lr_min": lr_min}
model_params["fetch-4e5-n2"] = {"depth": depth, "smooth": 0.1, 'server_opt': 'fetchsgd', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, "client_weight_decay": 0.0, "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": 400000, "client_partial": 0.0064, "privacy_clip": 1.0, "privacy_noise": 0.1588, "scheduler": scheduler, "lr_min": lr_min}
model_params["fetch-4e5-n4"] = {"depth": depth, "smooth": 0.1, 'server_opt': 'fetchsgd', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, "client_weight_decay": 0.0, "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": 400000, "client_partial": 0.0064, "privacy_clip": 1.0, "privacy_noise": 0.2265, "scheduler": scheduler, "lr_min": lr_min}

model_params["sgdm-4e5-n0.8"] = {"depth": depth, "smooth": 0.1, 'server_opt': 'sgd', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, "client_weight_decay": 0.0, "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": 400000, "client_partial": 0.0064, "privacy_clip": 1.0, "privacy_noise": 0.0883, "scheduler": scheduler, "lr_min": lr_min}
model_params["adam-4e5-n0.8"] = {"depth": depth, "smooth": 0.1, 'server_opt': 'adam', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum,"client_weight_decay": 0.0,  "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": 400000, "client_partial": 0.0064, "privacy_clip": 1.0, "privacy_noise": 0.0883, "scheduler": scheduler, "lr_min": lr_min}
model_params["sgdm-no-n0.8"] = {"depth": depth, "smooth": 0.1, 'server_opt': 'sgd', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, "client_weight_decay": 0.0, "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": -1, "client_partial": 0.0064, "privacy_clip": 1.0, "privacy_noise": 0.8, "scheduler": scheduler, "lr_min": lr_min}
model_params["adam-no-n0.8"] = {"depth": depth, "smooth": 0.1, 'server_opt': 'adam', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum,"client_weight_decay": 0.0,  "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": -1, "client_partial": 0.0064, "privacy_clip": 1.0, "privacy_noise": 0.8, "scheduler": scheduler, "lr_min": lr_min}
model_params["sgdm-4e5-n1.0"] = {"depth": depth, "smooth": 0.1, 'server_opt': 'sgd', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, "client_weight_decay": 0.0, "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": 400000, "client_partial": 0.0064, "privacy_clip": 1.0, "privacy_noise": 1.0, "scheduler": scheduler, "lr_min": lr_min}
model_params["adam-4e5-n1.0"] = {"depth": depth, "smooth": 0.1, 'server_opt': 'adam', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum,"client_weight_decay": 0.0,  "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": 400000, "client_partial": 0.0064, "privacy_clip": 1.0, "privacy_noise": 0.1013, "scheduler": scheduler, "lr_min": lr_min}
model_params["sgdm-no-n1.0"] = {"depth": depth, "smooth": 0.1, 'server_opt': 'sgd', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, "client_weight_decay": 0.0, "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": -1, "client_partial": 0.0064, "privacy_clip": 1.0, "privacy_noise": 1.0, "scheduler": scheduler, "lr_min": lr_min}
model_params["adam-no-n1.0"] = {"depth": depth, "smooth": 0.1, 'server_opt': 'adam', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum,"client_weight_decay": 0.0,  "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": -1, "client_partial": 0.0064, "privacy_clip": 1.0, "privacy_noise": 1.0, "scheduler": scheduler, "lr_min": lr_min}


model_params["sgdm-4e5-n2"] = {"depth": depth, "smooth": 0.1, 'server_opt': 'sgd', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, "client_weight_decay": 0.0, "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": 400000, "client_partial": 0.0064, "privacy_clip": 1.0, "privacy_noise": 0.1588, "scheduler": scheduler, "lr_min": lr_min}
model_params["adam-4e5-n2"] = {"depth": depth, "smooth": 0.1, 'server_opt': 'adam', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum,"client_weight_decay": 0.0,  "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": 400000, "client_partial": 0.0064, "privacy_clip": 1.0, "privacy_noise": 0.1588, "scheduler": scheduler, "lr_min": lr_min}
model_params["sgdm-no-n2"] = {"depth": depth, "smooth": 0.1, 'server_opt': 'sgd', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, "client_weight_decay": 0.0, "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": -1, "client_partial": 0.0064, "privacy_clip": 1.0, "privacy_noise": 2.0, "scheduler": scheduler, "lr_min": lr_min}
model_params["adam-no-n2"] = {"depth": depth, "smooth": 0.1, 'server_opt': 'adam', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum,"client_weight_decay": 0.0,  "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": -1, "client_partial": 0.0064, "privacy_clip": 1.0, "privacy_noise": 2.0, "scheduler": scheduler, "lr_min": lr_min}
model_params["sgdm-4e5-n4"] = {"depth": depth, "smooth": 0.1, 'server_opt': 'sgd', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, "client_weight_decay": 0.0, "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": 400000, "client_partial": 0.0064, "privacy_clip": 1.0, "privacy_noise": 0.2265, "scheduler": scheduler, "lr_min": lr_min}
model_params["adam-4e5-n4"] = {"depth": depth, "smooth": 0.1, 'server_opt': 'adam', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum,"client_weight_decay": 0.0,  "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": 400000, "client_partial": 0.0064, "privacy_clip": 1.0, "privacy_noise": 0.2265, "scheduler": scheduler, "lr_min": lr_min}
model_params["sgdm-no-n4"] = {"depth": depth, "smooth": 0.1, 'server_opt': 'sgd', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, "client_weight_decay": 0.0, "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": -1, "client_partial": 0.0064, "privacy_clip": 1.0, "privacy_noise": 4.0, "scheduler": scheduler, "lr_min": lr_min}
model_params["adam-no-n4"] = {"depth": depth, "smooth": 0.1, 'server_opt': 'adam', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum,"client_weight_decay": 0.0,  "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": -1, "client_partial": 0.0064, "privacy_clip": 1.0, "privacy_noise": 4.0, "scheduler": scheduler, "lr_min": lr_min}
model_params["sgdm-4e5-n6"] = {"depth": depth, "smooth": 0.1, 'server_opt': 'sgd', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, "client_weight_decay": 0.0, "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": 400000, "client_partial": 0.0064, "privacy_clip": 1.0, "privacy_noise": 6.0, "scheduler": scheduler, "lr_min": lr_min}
model_params["adam-4e5-n6"] = {"depth": depth, "smooth": 0.1, 'server_opt': 'adam', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum,"client_weight_decay": 0.0,  "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": 400000, "client_partial": 0.0064, "privacy_clip": 1.0, "privacy_noise": 6.0, "scheduler": scheduler, "lr_min": lr_min}
model_params["sgdm-no-n6"] = {"depth": depth, "smooth": 0.1, 'server_opt': 'sgd', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, "client_weight_decay": 0.0, "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": -1, "client_partial": 0.0064, "privacy_clip": 1.0, "privacy_noise": 6.0, "scheduler": scheduler, "lr_min": lr_min}
model_params["adam-no-n6"] = {"depth": depth, "smooth": 0.1, 'server_opt': 'adam', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum,"client_weight_decay": 0.0,  "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": -1, "client_partial": 0.0064, "privacy_clip": 1.0, "privacy_noise": 6.0, "scheduler": scheduler, "lr_min": lr_min}
model_params["sgdm-4e5-n8"] = {"depth": depth, "smooth": 0.1, 'server_opt': 'sgd', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, "client_weight_decay": 0.0, "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": 400000, "client_partial": 0.0064, "privacy_clip": 1.0, "privacy_noise": 8.0, "scheduler": scheduler, "lr_min": lr_min}
model_params["adam-4e5-n8"] = {"depth": depth, "smooth": 0.1, 'server_opt': 'adam', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum,"client_weight_decay": 0.0,  "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": 400000, "client_partial": 0.0064, "privacy_clip": 1.0, "privacy_noise": 8.0, "scheduler": scheduler, "lr_min": lr_min}
model_params["sgdm-no-n8"] = {"depth": depth, "smooth": 0.1, 'server_opt': 'sgd', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, "client_weight_decay": 0.0, "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": -1, "client_partial": 0.0064, "privacy_clip": 1.0, "privacy_noise": 8.0, "scheduler": scheduler, "lr_min": lr_min}
model_params["adam-no-n8"] = {"depth": depth, "smooth": 0.1, 'server_opt': 'adam', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum,"client_weight_decay": 0.0,  "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": -1, "client_partial": 0.0064, "privacy_clip": 1.0, "privacy_noise": 8.0, "scheduler": scheduler, "lr_min": lr_min}

opt_params = {}
opt_params["fetch-4e5-n0.8"] = {'lr': 0.5, 'dataset_name':dataset_name, 'loss': loss_name, 'opt':'federated', 'model_name':model_name, 'momentum':momentum, 'weight_decay':weight_decay, 'batch_size':batch_size, 'epochs':500}
opt_params["fetch-8e6-n0.8"] = {'lr': 0.5, 'dataset_name':dataset_name, 'loss': loss_name, 'opt':'federated', 'model_name':model_name, 'momentum':momentum, 'weight_decay':weight_decay, 'batch_size':batch_size, 'epochs':500}
opt_params["sgdm-4e5-n2"] = {'lr': 0.01, 'dataset_name':dataset_name, 'loss': loss_name, 'opt':'federated', 'model_name':model_name, 'momentum':momentum, 'weight_decay':weight_decay, 'batch_size':batch_size, 'epochs':500}
opt_params["adam-4e5-n2"] = {'lr': 0.01, 'dataset_name':dataset_name, 'loss': loss_name, 'opt':'federated', 'model_name':model_name, 'momentum':momentum, 'weight_decay':weight_decay, 'batch_size':batch_size, 'epochs':500}
opt_params["sgdm-no-n2"] = {'lr': 0.01, 'dataset_name':dataset_name, 'loss': loss_name, 'opt':'federated', 'model_name':model_name, 'momentum':momentum, 'weight_decay':weight_decay, 'batch_size':batch_size, 'epochs':500}
opt_params["adam-no-n2"] = {'lr': 0.01, 'dataset_name':dataset_name, 'loss': loss_name, 'opt':'federated', 'model_name':model_name, 'momentum':momentum, 'weight_decay':weight_decay, 'batch_size':batch_size, 'epochs':500}
opt_params["sgdm-4e5-n0.8"] = opt_params["sgdm-4e5-n1.0"] =opt_params["sgdm-4e5-n8"] = opt_params["sgdm-4e5-n6"] = opt_params["sgdm-4e5-n4"] = opt_params["sgdm-4e5-n2"]
opt_params["adam-4e5-n0.8"] = opt_params["adam-4e5-n1.0"] = opt_params["adam-4e5-n8"] = opt_params["adam-4e5-n6"] = opt_params["adam-4e5-n4"] = opt_params["adam-4e5-n2"]
opt_params["adam-no-n0.8"] = opt_params["adam-no-n1.0"] = opt_params["adam-no-n8"] = opt_params["adam-no-n6"] = opt_params["adam-no-n4"] = opt_params["adam-no-n2"]
opt_params["sgdm-no-n0.8"] = opt_params["sgdm-no-n1.0"] = opt_params["sgdm-no-n8"] = opt_params["sgdm-no-n6"] = opt_params["sgdm-no-n4"] = opt_params["sgdm-no-n2"]
opt_params["fetch-8e6-n4"] = opt_params["fetch-8e6-n2"] = opt_params["fetch-8e6-n1"]= opt_params["fetch-8e6-n0.8"]
opt_params["fetch-4e5-n4"] = opt_params["fetch-4e5-n2"] = opt_params["fetch-4e5-n1"]= opt_params["fetch-4e5-n0.8"]

max_vals = {}
max_vals[0.8] = plot_figures_opts_attr([["sgdm-4e5-n0.8", "sgdm-no-n0.8", "adam-4e5-n0.8", "adam-no-n0.8", "fetch-4e5-n0.8"]], model_params, opt_params, ["test_acc"], start=10, end=None, alpha=1.0, linewidth=1.0, ylabel = "Test Accuracy", titles=[""], legends=[["sgd-4e5", "sgd-no", "adam-4e5", "adam-no", "DiffSketch"]], save_dir="../plots/nips25privacy/emnist_0.8.pdf", return_last=False, return_max=True) #"../plots/iclr25workshop/cifar_client_2.pdf"
max_vals[1.0] = plot_figures_opts_attr([["sgdm-4e5-n1.0", "sgdm-no-n1.0", "adam-4e5-n1.0", "adam-no-n1.0", "fetch-4e5-n1"]], model_params, opt_params, ["test_acc"], start=10, end=None, alpha=1.0, linewidth=1.0, ylabel = "Test Accuracy",titles=[""], legends=[["sgd-4e5", "sgd-no", "adam-4e5", "adam-no",  "DiffSketch"]], save_dir="../plots/nips25privacy/emnist_1.pdf", return_last=False, return_max=True) #"../plots/iclr25workshop/cifar_client_2.pdf"
max_vals[2.0] = plot_figures_opts_attr([["sgdm-4e5-n2", "sgdm-no-n2", "adam-4e5-n2", "adam-no-n2", "fetch-4e5-n2"]], model_params, opt_params, ["test_acc"], start=10, end=None, alpha=1.0, linewidth=1.0, ylabel = "Test Accuracy",titles=[""], legends=[["sgd-4e5", "sgd-no", "adam-4e5", "adam-no", "DiffSketch"]], save_dir="../plots/nips25privacy/emnist_2.pdf", return_last=False, return_max=True) #"../plots/iclr25workshop/cifar_client_2.pdf"
max_vals[4.0] = plot_figures_opts_attr([["sgdm-4e5-n4", "sgdm-no-n4", "adam-4e5-n4", "adam-no-n4", "fetch-4e5-n4"]], model_params, opt_params, ["test_acc"], start=10, end=None, alpha=1.0, linewidth=1.0, ylabel = "Test Accuracy",titles=[""], legends=[["sgd-4e5", "sgd-no", "adam-4e5", "adam-no","DiffSketch"]], save_dir="../plots/nips25privacy/emnist_4.pdf", return_last=False, return_max=True) #"../plots/iclr25workshop/cifar_client_2.pdf"

max_vals_train = {}
max_vals_train[0.8] = plot_figures_opts_attr([["sgdm-4e5-n0.8", "sgdm-no-n0.8", "adam-4e5-n0.8", "adam-no-n0.8", "fetch-4e5-n0.8"]], model_params, opt_params, ["acc"], start=10, end=None, alpha=1.0, linewidth=1.0, ylabel = "Train Accuracy", titles=[""], legends=[["sgd-4e5", "sgd-no", "adam-4e5", "adam-no", "DiffSketch"]], save_dir="../plots/nips25privacy/emnist_0.8_train.pdf", return_last=False, return_max=True) #"../plots/iclr25workshop/cifar_client_2.pdf"
max_vals_train[1] = plot_figures_opts_attr([["sgdm-4e5-n1.0", "sgdm-no-n1.0", "adam-4e5-n1.0", "adam-no-n1.0", "fetch-4e5-n1"]], model_params, opt_params, ["acc"], start=10, end=None, alpha=1.0, linewidth=1.0, ylabel = "Train Accuracy",titles=[""], legends=[["sgd-4e5", "sgd-no", "adam-4e5", "adam-no",  "DiffSketch"]], save_dir="../plots/nips25privacy/emnist_1_train.pdf", return_last=False, return_max=True) #"../plots/iclr25workshop/cifar_client_2.pdf"
max_vals_train[2] = plot_figures_opts_attr([["sgdm-4e5-n2", "sgdm-no-n2", "adam-4e5-n2", "adam-no-n2", "fetch-4e5-n2"]], model_params, opt_params, ["acc"], start=10, end=None, alpha=1.0, linewidth=1.0, ylabel = "Train Accuracy",titles=[""], legends=[["sgd-4e5", "sgd-no", "adam-4e5", "adam-no", "DiffSketch"]], save_dir="../plots/nips25privacy/emnist_2_train.pdf", return_last=False, return_max=True) #"../plots/iclr25workshop/cifar_client_2.pdf"
max_vals_train[4] = plot_figures_opts_attr([["sgdm-4e5-n4", "sgdm-no-n4", "adam-4e5-n4", "adam-no-n4", "fetch-4e5-n4"]], model_params, opt_params, ["acc"], start=10, end=None, alpha=1.0, linewidth=1.0, ylabel = "Train Accuracy",titles=[""], legends=[["sgd-4e5", "sgd-no", "adam-4e5", "adam-no", "DiffSketch"]], save_dir="../plots/nips25privacy/emnist_4_train.pdf", return_last=False, return_max=True)
# Out:
# /projects/illinois/eng/cs/arindamb/lucmon/mlopt/results/emnist/CrossEntropyLoss/federated/resnet_gn/depth_101/smooth_0.1/server_opt_sgd/client_opt_sgd/client_lr_0.01/client_momentum_0.0/client_weight_decay_0.0/client_num_625/client_epoch_1/sketch_size_400000/client_partial_0.0064/privacy_clip_1.0/privacy_noise_0.0883/scheduler_cosine/lr_min_1e-05/lr_0.01/moment_0.9/wd_0.0001/batch_size_64/epoch_500/run_0/
# /projects/illinois/eng/cs/arindamb/lucmon/mlopt/results/emnist/CrossEntropyLoss/federated/resnet_gn/depth_101/smooth_0.1/server_opt_sgd/client_opt_sgd/client_lr_0.01/client_momentum_0.0/client_weight_decay_0.0/client_num_625/client_epoch_1/sketch_size_-1/client_partial_0.0064/privacy_clip_1.0/privacy_noise_0.8/scheduler_cosine/lr_min_1e-05/lr_0.01/moment_0.9/wd_0.0001/batch_size_64/epoch_500/run_0/
# ...

# %%
/projects/illinois/eng/cs/arindamb/lucmon/mlopt/results/emnist/CrossEntropyLoss/federated/resnet_gn/depth_101/smooth_0.1/server_opt_fetchsgd/client_opt_sgd/client_lr_0.01/client_momentum_0.0/client_weight_decay_0.0/client_num_625/client_epoch_1/sketch_size_8000000/client_partial_0.0064/privacy_clip_1.0/privacy_noise_0.1013/scheduler_cosine/lr_min_0.005/lr_0.5/moment_0.9/wd_0.0001/batch_size_64/epoch_500/run_0/

/projects/illinois/eng/cs/arindamb/lucmon/mlopt/results/emnist/CrossEntropyLoss/federated/resnet_gn/depth_101/smooth_0.1/server_opt_fetchsgd/client_opt_sgd/client_lr_0.01/client_momentum_0.0/client_weight_decay_0.0/client_num_625/client_epoch_1/sketch_size_400000/client_partial_0.0064/privacy_clip_1.0/privacy_noise_0.1013/scheduler_cosine/lr_min_0.005/lr_0.5/moment_0.9/wd_0.0001/batch_size_64/epoch_500/run_0/

# %%
import numpy as np

import matplotlib.pyplot as plt
noise = [0.8, 1, 2,4]
epsilon = [2.76, 1.60, 0.42, 0.18]
legends = ["sgd-4e5","sgd-no","adam-4e5","adam-no", "DiffSketch"]
for i in range(len(legends)):
    array = []
    for n in noise:
        array.append(max_vals[n][0][i])
    plt.plot(epsilon, array)

plt.legend(legends)
plt.ylabel("Test Accuracy")
plt.xlabel(r"$\epsilon$")
plt.savefig("../plots/nips25privacy/emnist_test_acc_trend.pdf")

# %%
import numpy as np

import matplotlib.pyplot as plt
noise = [0.8, 1, 2,4]
epsilon = [2.76, 1.60, 0.42, 0.18]
legends = ["sgd-4e5","sgd-no","adam-4e5","adam-no", "DiffSketch"]
for i in range(len(legends)):
    array = []
    for n in noise:
        array.append(max_vals_train[n][0][i])
    plt.plot(epsilon, array)

plt.legend(legends)
plt.ylabel("Test Accuracy")
plt.xlabel(r"$\epsilon$")
plt.savefig("../plots/nips25privacy/emnist_train_acc_trend.pdf")

# %%
max_vals
# Out:
# {0.8: [[0.6261, 0.6243, 0.8547, 0.7944, 0.7069]],
#  1.0: [[0.6261, 0.625, 0.8527, 0.7855, 0.7884]],
#  2.0: [[0.6256, 0.6295, 0.8466, 0.7372, 0.7855]],
#  4.0: [[0.626, 0.6158, 0.8353, 0.6729, 0.7851]]}

# %%
/projects/illinois/eng/cs/arindamb/lucmon/mlopt/results/emnist/CrossEntropyLoss/federated/resnet_gn/depth_101/smooth_0.1/server_opt_fetchsgd/client_opt_sgd/client_lr_0.01/client_momentum_0.0/client_weight_decay_0.0/client_num_625/client_epoch_1/sketch_size_8000000/client_partial_0.0064/privacy_clip_1.0/privacy_noise_0.8/scheduler_cosine/lr_min_1e-05/lr_0.5/moment_0.9/wd_0.0001/batch_size_64/epoch_500/run_0/

/projects/illinois/eng/cs/arindamb/lucmon/mlopt/results/emnist/CrossEntropyLoss/federated/resnet_gn/depth_101/smooth_0.1/server_opt_sgd/client_opt_sgd/client_lr_0.01/client_momentum_0.0/client_weight_decay_0.0/client_num_625/client_epoch_1/sketch_size_8000000/client_partial_0.0064/privacy_clip_1.0/privacy_noise_0.8/scheduler_cosine/lr_min_1e-05/lr_0.5/moment_0.9/wd_0.0001/batch_size_64/epoch_500/run_0/train_graphs.pk

# %%
from plot_functions import plot_figures_opts, plot_attr_figure, plot_figures_opts_attrs, plot_figures_opts_attr
from main import graphs

lr, dataset_name, loss_name, momentum, weight_decay, batch_size, epochs = 0.1, "emnist", 'CrossEntropyLoss', 0.9, 1e-4, 64, 100
model_name, depth = "resnet_gn", 101
client_opt, client_lr, client_momentum, client_num, client_epoch, sketch_size, scheduler, lr_min  ="sgd", 0.01, 0.0, 625, 1, 80000, "cosine", 1e-5
model_params = {}

model_params["sgdm-4e5-n0.8"] = {"depth": depth, "smooth": 0.1, 'server_opt': 'sgd', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, "client_weight_decay": 0.0, "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": 400000, "client_partial": 0.0064, "privacy_clip": 1.0, "privacy_noise": 0.8, "scheduler": scheduler, "lr_min": lr_min}
model_params["adam-4e5-n0.8"] = {"depth": depth, "smooth": 0.1, 'server_opt': 'adam', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum,"client_weight_decay": 0.0,  "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": 400000, "client_partial": 0.0064, "privacy_clip": 1.0, "privacy_noise": 0.8, "scheduler": scheduler, "lr_min": lr_min}
model_params["sgdm-no-n0.8"] = {"depth": depth, "smooth": 0.1, 'server_opt': 'sgd', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, "client_weight_decay": 0.0, "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": -1, "client_partial": 0.0064, "privacy_clip": 1.0, "privacy_noise": 0.8, "scheduler": scheduler, "lr_min": lr_min}
model_params["adam-no-n0.8"] = {"depth": depth, "smooth": 0.1, 'server_opt': 'adam', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum,"client_weight_decay": 0.0,  "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": -1, "client_partial": 0.0064, "privacy_clip": 1.0, "privacy_noise": 0.8, "scheduler": scheduler, "lr_min": lr_min}
model_params["sgdm-4e5-n1.0"] = {"depth": depth, "smooth": 0.1, 'server_opt': 'sgd', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, "client_weight_decay": 0.0, "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": 400000, "client_partial": 0.0064, "privacy_clip": 1.0, "privacy_noise": 1.0, "scheduler": scheduler, "lr_min": lr_min}
model_params["adam-4e5-n1.0"] = {"depth": depth, "smooth": 0.1, 'server_opt': 'adam', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum,"client_weight_decay": 0.0,  "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": 400000, "client_partial": 0.0064, "privacy_clip": 1.0, "privacy_noise": 1.0, "scheduler": scheduler, "lr_min": lr_min}
model_params["sgdm-no-n1.0"] = {"depth": depth, "smooth": 0.1, 'server_opt': 'sgd', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, "client_weight_decay": 0.0, "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": -1, "client_partial": 0.0064, "privacy_clip": 1.0, "privacy_noise": 1.0, "scheduler": scheduler, "lr_min": lr_min}
model_params["adam-no-n1.0"] = {"depth": depth, "smooth": 0.1, 'server_opt': 'adam', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum,"client_weight_decay": 0.0,  "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": -1, "client_partial": 0.0064, "privacy_clip": 1.0, "privacy_noise": 1.0, "scheduler": scheduler, "lr_min": lr_min}


model_params["sgdm-4e5-n2"] = {"depth": depth, "smooth": 0.1, 'server_opt': 'sgd', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, "client_weight_decay": 0.0, "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": 400000, "client_partial": 0.0064, "privacy_clip": 1.0, "privacy_noise": 2.0, "scheduler": scheduler, "lr_min": lr_min}
model_params["adam-4e5-n2"] = {"depth": depth, "smooth": 0.1, 'server_opt': 'adam', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum,"client_weight_decay": 0.0,  "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": 400000, "client_partial": 0.0064, "privacy_clip": 1.0, "privacy_noise": 2.0, "scheduler": scheduler, "lr_min": lr_min}
model_params["sgdm-no-n2"] = {"depth": depth, "smooth": 0.1, 'server_opt': 'sgd', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, "client_weight_decay": 0.0, "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": -1, "client_partial": 0.0064, "privacy_clip": 1.0, "privacy_noise": 2.0, "scheduler": scheduler, "lr_min": lr_min}
model_params["adam-no-n2"] = {"depth": depth, "smooth": 0.1, 'server_opt': 'adam', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum,"client_weight_decay": 0.0,  "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": -1, "client_partial": 0.0064, "privacy_clip": 1.0, "privacy_noise": 2.0, "scheduler": scheduler, "lr_min": lr_min}
model_params["sgdm-4e5-n4"] = {"depth": depth, "smooth": 0.1, 'server_opt': 'sgd', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, "client_weight_decay": 0.0, "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": 400000, "client_partial": 0.0064, "privacy_clip": 1.0, "privacy_noise": 4.0, "scheduler": scheduler, "lr_min": lr_min}
model_params["adam-4e5-n4"] = {"depth": depth, "smooth": 0.1, 'server_opt': 'adam', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum,"client_weight_decay": 0.0,  "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": 400000, "client_partial": 0.0064, "privacy_clip": 1.0, "privacy_noise": 4.0, "scheduler": scheduler, "lr_min": lr_min}
model_params["sgdm-no-n4"] = {"depth": depth, "smooth": 0.1, 'server_opt': 'sgd', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, "client_weight_decay": 0.0, "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": -1, "client_partial": 0.0064, "privacy_clip": 1.0, "privacy_noise": 4.0, "scheduler": scheduler, "lr_min": lr_min}
model_params["adam-no-n4"] = {"depth": depth, "smooth": 0.1, 'server_opt': 'adam', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum,"client_weight_decay": 0.0,  "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": -1, "client_partial": 0.0064, "privacy_clip": 1.0, "privacy_noise": 4.0, "scheduler": scheduler, "lr_min": lr_min}
model_params["sgdm-4e5-n6"] = {"depth": depth, "smooth": 0.1, 'server_opt': 'sgd', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, "client_weight_decay": 0.0, "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": 400000, "client_partial": 0.0064, "privacy_clip": 1.0, "privacy_noise": 6.0, "scheduler": scheduler, "lr_min": lr_min}
model_params["adam-4e5-n6"] = {"depth": depth, "smooth": 0.1, 'server_opt': 'adam', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum,"client_weight_decay": 0.0,  "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": 400000, "client_partial": 0.0064, "privacy_clip": 1.0, "privacy_noise": 6.0, "scheduler": scheduler, "lr_min": lr_min}
model_params["sgdm-no-n6"] = {"depth": depth, "smooth": 0.1, 'server_opt': 'sgd', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, "client_weight_decay": 0.0, "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": -1, "client_partial": 0.0064, "privacy_clip": 1.0, "privacy_noise": 6.0, "scheduler": scheduler, "lr_min": lr_min}
model_params["adam-no-n6"] = {"depth": depth, "smooth": 0.1, 'server_opt': 'adam', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum,"client_weight_decay": 0.0,  "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": -1, "client_partial": 0.0064, "privacy_clip": 1.0, "privacy_noise": 6.0, "scheduler": scheduler, "lr_min": lr_min}
model_params["sgdm-4e5-n8"] = {"depth": depth, "smooth": 0.1, 'server_opt': 'sgd', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, "client_weight_decay": 0.0, "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": 400000, "client_partial": 0.0064, "privacy_clip": 1.0, "privacy_noise": 8.0, "scheduler": scheduler, "lr_min": lr_min}
model_params["adam-4e5-n8"] = {"depth": depth, "smooth": 0.1, 'server_opt': 'adam', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum,"client_weight_decay": 0.0,  "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": 400000, "client_partial": 0.0064, "privacy_clip": 1.0, "privacy_noise": 8.0, "scheduler": scheduler, "lr_min": lr_min}
model_params["sgdm-no-n8"] = {"depth": depth, "smooth": 0.1, 'server_opt': 'sgd', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, "client_weight_decay": 0.0, "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": -1, "client_partial": 0.0064, "privacy_clip": 1.0, "privacy_noise": 8.0, "scheduler": scheduler, "lr_min": lr_min}
model_params["adam-no-n8"] = {"depth": depth, "smooth": 0.1, 'server_opt': 'adam', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum,"client_weight_decay": 0.0,  "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": -1, "client_partial": 0.0064, "privacy_clip": 1.0, "privacy_noise": 8.0, "scheduler": scheduler, "lr_min": lr_min}

opt_params = {}
opt_params["sgdm-4e5-n2"] = {'lr': 0.01, 'dataset_name':dataset_name, 'loss': loss_name, 'opt':'federated', 'model_name':model_name, 'momentum':momentum, 'weight_decay':weight_decay, 'batch_size':batch_size, 'epochs':500}
opt_params["adam-4e5-n2"] = {'lr': 0.01, 'dataset_name':dataset_name, 'loss': loss_name, 'opt':'federated', 'model_name':model_name, 'momentum':momentum, 'weight_decay':weight_decay, 'batch_size':batch_size, 'epochs':500}
opt_params["sgdm-no-n2"] = {'lr': 0.01, 'dataset_name':dataset_name, 'loss': loss_name, 'opt':'federated', 'model_name':model_name, 'momentum':momentum, 'weight_decay':weight_decay, 'batch_size':batch_size, 'epochs':500}
opt_params["adam-no-n2"] = {'lr': 0.01, 'dataset_name':dataset_name, 'loss': loss_name, 'opt':'federated', 'model_name':model_name, 'momentum':momentum, 'weight_decay':weight_decay, 'batch_size':batch_size, 'epochs':500}
opt_params["sgdm-4e5-n0.8"] = opt_params["sgdm-4e5-n1.0"] =opt_params["sgdm-4e5-n8"] = opt_params["sgdm-4e5-n6"] = opt_params["sgdm-4e5-n4"] = opt_params["sgdm-4e5-n2"]
opt_params["adam-4e5-n0.8"] = opt_params["adam-4e5-n1.0"] = opt_params["adam-4e5-n8"] = opt_params["adam-4e5-n6"] = opt_params["adam-4e5-n4"] = opt_params["adam-4e5-n2"]
opt_params["adam-no-n0.8"] = opt_params["adam-no-n1.0"] = opt_params["adam-no-n8"] = opt_params["adam-no-n6"] = opt_params["adam-no-n4"] = opt_params["adam-no-n2"]
opt_params["sgdm-no-n0.8"] = opt_params["sgdm-no-n1.0"] = opt_params["sgdm-no-n8"] = opt_params["sgdm-no-n6"] = opt_params["sgdm-no-n4"] = opt_params["sgdm-no-n2"]

plot_figures_opts_attr([["sgdm-4e5-n0.8", "sgdm-no-n0.8", "adam-4e5-n0.8", "adam-no-n0.8"]], model_params, opt_params, ["test_acc"], start=10, end=None, alpha=1.0, linewidth=1.0, ylabel = "Test Accuracy", titles=[""], legends=[["sgd-4e5", "sgd-no", "adam-4e5", "adam-no"]], save_dir="../plots/uai25/privacy_n0.8.pdf", return_last=False) #"../plots/iclr25workshop/cifar_client_2.pdf"
plot_figures_opts_attr([["sgdm-4e5-n1.0", "sgdm-no-n1.0", "adam-4e5-n1.0", "adam-no-n1.0"]], model_params, opt_params, ["test_acc"], start=10, end=None, alpha=1.0, linewidth=1.0, ylabel = "Test Accuracy",titles=[""], legends=[["sgd-4e5", "sgd-no", "adam-4e5", "adam-no"]], save_dir="../plots/uai25/privacy_n1.pdf", return_last=False) #"../plots/iclr25workshop/cifar_client_2.pdf"
plot_figures_opts_attr([["sgdm-4e5-n2", "sgdm-no-n2", "adam-4e5-n2", "adam-no-n2"]], model_params, opt_params, ["test_acc"], start=10, end=None, alpha=1.0, linewidth=1.0, ylabel = "Test Accuracy",titles=[""], legends=[["sgd-4e5", "sgd-no", "adam-4e5", "adam-no"]], save_dir="../plots/uai25/privacy_n2.pdf", return_last=False) #"../plots/iclr25workshop/cifar_client_2.pdf"
plot_figures_opts_attr([["sgdm-4e5-n4", "sgdm-no-n4", "adam-4e5-n4", "adam-no-n4"]], model_params, opt_params, ["test_acc"], start=10, end=None, alpha=1.0, linewidth=1.0, ylabel = "Test Accuracy",titles=[""], legends=[["sgd-4e5", "sgd-no", "adam-4e5", "adam-no"]], save_dir="../plots/uai25/privacy_n4.pdf", return_last=False) #"../plots/iclr25workshop/cifar_client_2.pdf"
plot_figures_opts_attr([["sgdm-4e5-n6", "sgdm-no-n6", "adam-4e5-n6", "adam-no-n6"]], model_params, opt_params, ["test_acc"], start=10, end=None, alpha=1.0, linewidth=1.0, ylabel = "Test Accuracy",titles=[""], legends=[["sgd-4e5", "sgd-no", "adam-4e5", "adam-no"]], save_dir="../plots/uai25/privacy_n6.pdf", return_last=False) #"../plots/iclr25workshop/cifar_client_2.pdf"
plot_figures_opts_attr([["sgdm-4e5-n8", "sgdm-no-n8", "adam-4e5-n8", "adam-no-n8"]], model_params, opt_params, ["test_acc"], start=10, end=None, alpha=1.0, linewidth=1.0, ylabel = "Test Accuracy",titles=[""], legends=[["sgd-4e5", "sgd-no", "adam-4e5", "adam-no"]], save_dir="../plots/uai25/privacy_n8.pdf", return_last=False) #"../plots/iclr25workshop/cifar_client_2.pdf"

plot_figures_opts_attr([["sgdm-4e5-n0.8", "sgdm-no-n0.8", "adam-4e5-n0.8", "adam-no-n0.8"]], model_params, opt_params, ["acc"], start=10, end=None, alpha=1.0, linewidth=1.0, ylabel = "Train Accuracy", titles=[""], legends=[["sgd-4e5", "sgd-no", "adam-4e5", "adam-no"]], save_dir="../plots/uai25/privacy_n0.8_train.pdf", return_last=False) #"../plots/iclr25workshop/cifar_client_2.pdf"
plot_figures_opts_attr([["sgdm-4e5-n1.0", "sgdm-no-n1.0", "adam-4e5-n1.0", "adam-no-n1.0"]], model_params, opt_params, ["acc"], start=10, end=None, alpha=1.0, linewidth=1.0, ylabel = "Train Accuracy",titles=[""], legends=[["sgd-4e5", "sgd-no", "adam-4e5", "adam-no"]], save_dir="../plots/uai25/privacy_n1_train.pdf", return_last=False) #"../plots/iclr25workshop/cifar_client_2.pdf"
plot_figures_opts_attr([["sgdm-4e5-n2", "sgdm-no-n2", "adam-4e5-n2", "adam-no-n2"]], model_params, opt_params, ["acc"], start=10, end=None, alpha=1.0, linewidth=1.0, ylabel = "Train Accuracy",titles=[""], legends=[["sgd-4e5", "sgd-no", "adam-4e5", "adam-no"]], save_dir="../plots/uai25/privacy_n2_train.pdf", return_last=False) #"../plots/iclr25workshop/cifar_client_2.pdf"
plot_figures_opts_attr([["sgdm-4e5-n4", "sgdm-no-n4", "adam-4e5-n4", "adam-no-n4"]], model_params, opt_params, ["acc"], start=10, end=None, alpha=1.0, linewidth=1.0, ylabel = "Train Accuracy",titles=[""], legends=[["sgd-4e5", "sgd-no", "adam-4e5", "adam-no"]], save_dir="../plots/uai25/privacy_n4_train.pdf", return_last=False) #"../plots/iclr25workshop/cifar_client_2.pdf"
plot_figures_opts_attr([["sgdm-4e5-n6", "sgdm-no-n6", "adam-4e5-n6", "adam-no-n6"]], model_params, opt_params, ["acc"], start=10, end=None, alpha=1.0, linewidth=1.0, ylabel = "Train Accuracy",titles=[""], legends=[["sgd-4e5", "sgd-no", "adam-4e5", "adam-no"]], save_dir="../plots/uai25/privacy_n6_train.pdf", return_last=False) #"../plots/iclr25workshop/cifar_client_2.pdf"
plot_figures_opts_attr([["sgdm-4e5-n8", "sgdm-no-n8", "adam-4e5-n8", "adam-no-n8"]], model_params, opt_params, ["acc"], start=10, end=None, alpha=1.0, linewidth=1.0, ylabel = "Train Accuracy",titles=[""], legends=[["sgd-4e5", "sgd-no", "adam-4e5", "adam-no"]], save_dir="../plots/uai25/privacy_n8_train.pdf", return_last=False) #"../plots/iclr25workshop/cifar_client_2.pdf"


"""
print(plot_figures_opts_attrs(["sgdm-4e5-n0.8", "sgdm-no-n0.8", "adam-4e5-n0.8", "adam-no-n0.8"], model_params, opt_params, attrs=["loss", "accuracy", "test_err"], start=10, return_last=True))
print(plot_figures_opts_attrs(["sgdm-4e5-n1.0", "sgdm-no-n1.0", "adam-4e5-n1.0", "adam-no-n1.0"], model_params, opt_params, attrs=["loss", "accuracy", "test_err"], start=10, return_last=True))
print(plot_figures_opts_attrs(["sgdm-4e5-n2", "sgdm-no-n2", "adam-4e5-n2", "adam-no-n2"], model_params, opt_params, attrs=["loss", "accuracy", "test_err"], start=10, return_last=True))
print(plot_figures_opts_attrs(["sgdm-4e5-n4", "sgdm-no-n4", "adam-4e5-n4", "adam-no-n4"], model_params, opt_params, attrs=["loss", "accuracy", "test_err"], start=10, return_last=True))
print(plot_figures_opts_attrs(["sgdm-4e5-n6", "sgdm-no-n6", "adam-4e5-n6", "adam-no-n6"], model_params, opt_params, attrs=["loss", "accuracy", "test_err"], start=10, return_last=True))
print(plot_figures_opts_attrs(["sgdm-4e5-n8", "sgdm-no-n8", "adam-4e5-n8", "adam-no-n8"], model_params, opt_params, attrs=["loss", "accuracy", "test_err"], start=10, return_last=True))
"""
# Out:
# /u/lucmon/lucmon/anaconda3/envs/mlopt/lib/python3.11/site-packages/torch/cuda/__init__.py:716: UserWarning: Can't initialize NVML
#   warnings.warn("Can't initialize NVML")
# Available GPU Count:  0
# /projects/illinois/eng/cs/arindamb/lucmon/mlopt/results/emnist/CrossEntropyLoss/federated/resnet_gn/depth_101/smooth_0.1/server_opt_sgd/client_opt_sgd/client_lr_0.01/client_momentum_0.0/client_weight_decay_0.0/client_num_625/client_epoch_1/sketch_size_400000/client_partial_0.0064/privacy_clip_1.0/privacy_noise_0.8/scheduler_cosine/lr_min_1e-05/lr_0.01/moment_0.9/wd_0.0001/batch_size_64/epoch_500/run_0/
# ...

# %%
[0.3741, 0.37529999999999997, 0.21230000000000004, 0.21489999999999998]

# %%
[0.3742, 0.3758, 0.19879999999999998, 0.2066]
import numpy as np
n = [0.8, 1, 2,4,6,8]
epsilon = [1.3766864791702054, 0.7969908257565782, 0.2124472080389102, 0.08998466881151074]
sgd_sketch = np.array([0.3742, 0.3741, 0.3698, 0.3779, 0.4013, 0.4405])
sgd_no = np.array([0.3758, 0.37529999999999997, 0.37070000000000003, 0.38439999999999996, 0.4041, 0.43100000000000005])
adam_sketch = np.array([0.19879999999999998, 0.21230000000000004, 0.2603, 0.33399999999999996, 0.3971, 0.43100000000000005])
adam_no = np.array([0.2066, 0.21489999999999998, 0.263, 0.32830000000000004, 0.38460000000000005, 0.4224])

import matplotlib.pyplot as plt
plt.plot(epsilon[:4], 1-sgd_sketch[:4])
plt.plot(epsilon[:4], 1-sgd_no[:4])
plt.plot(epsilon[:4], 1-adam_sketch[:4])
plt.plot(epsilon[:4], 1-adam_no[:4])
plt.legend(["sgd-4e5", "sgd-no", "adam-4e5", "adam-no"])
plt.ylabel("Test Accuracy")
plt.xlabel(r"$\epsilon$")
plt.savefig("../plots/uai25/test_acc_trend.pdf")

# %%
#nips25
from plot_functions import plot_figures_opts, plot_attr_figure, plot_figures_opts_attrs, plot_figures_opts_attr
from main import graphs

lr, dataset_name, loss_name, momentum, weight_decay, batch_size, epochs = 0.1, "emnist", 'CrossEntropyLoss', 0.9, 1e-4, 64, 100
model_name, depth = "resnet_gn", 101
client_opt, client_lr, client_momentum, client_num, client_epoch, sketch_size, scheduler, lr_min  ="sgd", 0.01, 0.0, 625, 1, 80000, "cosine", 1e-5
model_params = {}

model_params["adam-4e4-n2"] = {"depth": depth, "smooth": 0.1, 'server_opt': 'adam', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum,"client_weight_decay": 0.0,  "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": 40000, "client_partial": 0.0064, "privacy_clip": 1.0, "privacy_noise": 0.1793, "scheduler": scheduler, "lr_min": lr_min}
model_params["adam-4e5-n2"] = {"depth": depth, "smooth": 0.1, 'server_opt': 'adam', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum,"client_weight_decay": 0.0,  "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": 400000, "client_partial": 0.0064, "privacy_clip": 1.0, "privacy_noise": 0.1588, "scheduler": scheduler, "lr_min": lr_min}
model_params["adam-4e6-n2"] = {"depth": depth, "smooth": 0.1, 'server_opt': 'adam', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum,"client_weight_decay": 0.0,  "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": 4000000, "client_partial": 0.0064, "privacy_clip": 1.0, "privacy_noise": 0.05704, "scheduler": scheduler, "lr_min": lr_min}
model_params["adam-4e7-n2"] = {"depth": depth, "smooth": 0.1, 'server_opt': 'adam', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum,"client_weight_decay": 0.0,  "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": 40000000, "client_partial": 0.0064, "privacy_clip": 1.0, "privacy_noise": 0.03209, "scheduler": scheduler, "lr_min": lr_min}
model_params["adam-no-n2"] = {"depth": depth, "smooth": 0.1, 'server_opt': 'adam', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum,"client_weight_decay": 0.0,  "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": -1, "client_partial": 0.0064, "privacy_clip": 1.0, "privacy_noise": 2.0, "scheduler": scheduler, "lr_min": lr_min}

opt_params = {}
opt_params["adam-4e5-n2"] = {'lr': 0.01, 'dataset_name':dataset_name, 'loss': loss_name, 'opt':'federated', 'model_name':model_name, 'momentum':momentum, 'weight_decay':weight_decay, 'batch_size':batch_size, 'epochs':500}
opt_params["adam-no-n2"] = {'lr': 0.01, 'dataset_name':dataset_name, 'loss': loss_name, 'opt':'federated', 'model_name':model_name, 'momentum':momentum, 'weight_decay':weight_decay, 'batch_size':batch_size, 'epochs':500}
opt_params["adam-4e7-n2"] = opt_params["adam-4e6-n2"] = opt_params["adam-4e4-n2"] = opt_params["adam-4e5-n2"]
max_vals = {}
max_vals[2] = plot_figures_opts_attr([["adam-4e4-n2", "adam-4e5-n2", "adam-4e6-n2", "adam-4e7-n2"]], model_params, opt_params, ["test_acc"], start=50, end=None, alpha=1.0, linewidth=1.0, ylabel = "Test Accuracy", titles=[""], legends=[["4e4", "4e5", "4e6", "4e7"]], save_dir=None, return_last=False, return_max=True) #"../plots/iclr25workshop/cifar_client_2.pdf"
# Out:
# /projects/illinois/eng/cs/arindamb/lucmon/mlopt/results/emnist/CrossEntropyLoss/federated/resnet_gn/depth_101/smooth_0.1/server_opt_adam/client_opt_sgd/client_lr_0.01/client_momentum_0.0/client_weight_decay_0.0/client_num_625/client_epoch_1/sketch_size_40000/client_partial_0.0064/privacy_clip_1.0/privacy_noise_0.1793/scheduler_cosine/lr_min_1e-05/lr_0.01/moment_0.9/wd_0.0001/batch_size_64/epoch_500/run_0/
# /projects/illinois/eng/cs/arindamb/lucmon/mlopt/results/emnist/CrossEntropyLoss/federated/resnet_gn/depth_101/smooth_0.1/server_opt_adam/client_opt_sgd/client_lr_0.01/client_momentum_0.0/client_weight_decay_0.0/client_num_625/client_epoch_1/sketch_size_400000/client_partial_0.0064/privacy_clip_1.0/privacy_noise_0.1588/scheduler_cosine/lr_min_1e-05/lr_0.01/moment_0.9/wd_0.0001/batch_size_64/epoch_500/run_0/
# ...

# %%
/projects/illinois/eng/cs/arindamb/lucmon/mlopt/results/emnist/CrossEntropyLoss/federated/resnet_gn/depth_101/smooth_0.1/server_opt_adam/client_opt_sgd/client_lr_0.01/client_momentum_0.0/client_weight_decay_0.0/client_num_625/client_epoch_1/sketch_size_400000/client_partial_0.0064/privacy_clip_1.0/privacy_noise_0.1793/scheduler_cosine/lr_min_1e-05/lr_0.01/moment_0.9/wd_0.0001/batch_size_64/epoch_500/run_0/train_graphs.pk

/projects/illinois/eng/cs/arindamb/lucmon/mlopt/results/emnist/CrossEntropyLoss/federated/resnet_gn/depth_101/smooth_0.1/server_opt_adam/client_opt_sgd/client_lr_0.01/client_momentum_0.0/client_weight_decay_0.0/client_num_625/client_epoch_1/sketch_size_40000/client_partial_0.0064/privacy_clip_1.0/privacy_noise_0.1793/scheduler_cosine/lr_min_1e-05/lr_0.01/moment_0.9/wd_0.0001/batch_size_64/epoch_500/run_0/

# %%
[0.5703125, 0.640625, 0.6484375, 0.6328125]

import numpy as np
n = [0.8, 1, 2,4,6,8]
epsilon = [1.3766864791702054, 0.7969908257565782, 0.2124472080389102, 0.08998466881151074]
sgd_sketch = np.array([0.609375, 0.5859375,0.5859375, 0.5703125, 0.4013, 0.4405])
sgd_no = np.array([0.6328125, 0.640625, 0.640625,  0.640625, 0.4041, 0.43100000000000005])
adam_sketch = np.array([0.8515625, 0.828125,  0.78125,0.6484375, 0.3971, 0.43100000000000005])
adam_no = np.array([0.8125, 0.8125,0.7421875,  0.6328125, 0.38460000000000005, 0.4224])

import matplotlib.pyplot as plt
plt.plot(epsilon[:4], sgd_sketch[:4])
plt.plot(epsilon[:4], sgd_no[:4])
plt.plot(epsilon[:4], adam_sketch[:4])
plt.plot(epsilon[:4], adam_no[:4])
plt.legend(["sgd-4e5", "sgd-no", "adam-4e5", "adam-no"])
plt.ylabel("Train Accuracy")
plt.xlabel(r"$\epsilon$")
plt.savefig("../plots/uai25/train_acc_trend.pdf")

# %%
from plot_functions import plot_figures_opts, plot_attr_figure, plot_figures_opts_attrs, plot_figures_opts_attr
from main import graphs

lr, dataset_name, loss_name, momentum, weight_decay, batch_size, epochs = 0.1, "emnist", 'CrossEntropyLoss', 0.9, 1e-4, 64, 100
model_name, depth = "resnet_gn", 101
client_opt, client_lr, client_momentum, client_num, client_epoch, sketch_size, scheduler, lr_min  ="sgd", 0.01, 0.0, 625, 1, 80000, "cosine", 1e-5
model_params = {}
model_params["sgdm-4e5-n2"] = {"depth": depth, "smooth": 0.1, 'server_opt': 'sgd', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, "client_weight_decay": 0.0, "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": 4000000, "client_partial": 0.0064, "privacy_clip": 1.0, "privacy_noise": 2.0, "scheduler": scheduler, "lr_min": lr_min}
model_params["adam-4e5-n2"] = {"depth": depth, "smooth": 0.1, 'server_opt': 'adam', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum,"client_weight_decay": 0.0,  "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": 4000000, "client_partial": 0.0064, "privacy_clip": 1.0, "privacy_noise": 2.0, "scheduler": scheduler, "lr_min": lr_min}
model_params["sgdm-no-n2"] = {"depth": depth, "smooth": 0.1, 'server_opt': 'sgd', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, "client_weight_decay": 0.0, "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": -1, "client_partial": 0.0064, "privacy_clip": 1.0, "privacy_noise": 2.0, "scheduler": scheduler, "lr_min": lr_min}
model_params["adam-no-n2"] = {"depth": depth, "smooth": 0.1, 'server_opt': 'adam', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum,"client_weight_decay": 0.0,  "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": -1, "client_partial": 0.0064, "privacy_clip": 1.0, "privacy_noise": 2.0, "scheduler": scheduler, "lr_min": lr_min}
model_params["sgdm-4e5-n4"] = {"depth": depth, "smooth": 0.1, 'server_opt': 'sgd', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, "client_weight_decay": 0.0, "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": 4000000, "client_partial": 0.0064, "privacy_clip": 1.0, "privacy_noise": 4.0, "scheduler": scheduler, "lr_min": lr_min}
model_params["adam-4e5-n4"] = {"depth": depth, "smooth": 0.1, 'server_opt': 'adam', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum,"client_weight_decay": 0.0,  "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": 4000000, "client_partial": 0.0064, "privacy_clip": 1.0, "privacy_noise": 4.0, "scheduler": scheduler, "lr_min": lr_min}
model_params["sgdm-no-n4"] = {"depth": depth, "smooth": 0.1, 'server_opt': 'sgd', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, "client_weight_decay": 0.0, "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": -1, "client_partial": 0.0064, "privacy_clip": 1.0, "privacy_noise": 4.0, "scheduler": scheduler, "lr_min": lr_min}
model_params["adam-no-n4"] = {"depth": depth, "smooth": 0.1, 'server_opt': 'adam', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum,"client_weight_decay": 0.0,  "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": -1, "client_partial": 0.0064, "privacy_clip": 1.0, "privacy_noise": 4.0, "scheduler": scheduler, "lr_min": lr_min}
model_params["sgdm-4e5-n6"] = {"depth": depth, "smooth": 0.1, 'server_opt': 'sgd', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, "client_weight_decay": 0.0, "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": 4000000, "client_partial": 0.0064, "privacy_clip": 1.0, "privacy_noise": 6.0, "scheduler": scheduler, "lr_min": lr_min}
model_params["adam-4e5-n6"] = {"depth": depth, "smooth": 0.1, 'server_opt': 'adam', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum,"client_weight_decay": 0.0,  "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": 4000000, "client_partial": 0.0064, "privacy_clip": 1.0, "privacy_noise": 6.0, "scheduler": scheduler, "lr_min": lr_min}
model_params["sgdm-no-n6"] = {"depth": depth, "smooth": 0.1, 'server_opt': 'sgd', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, "client_weight_decay": 0.0, "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": -1, "client_partial": 0.0064, "privacy_clip": 1.0, "privacy_noise": 6.0, "scheduler": scheduler, "lr_min": lr_min}
model_params["adam-no-n6"] = {"depth": depth, "smooth": 0.1, 'server_opt': 'adam', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum,"client_weight_decay": 0.0,  "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": -1, "client_partial": 0.0064, "privacy_clip": 1.0, "privacy_noise": 6.0, "scheduler": scheduler, "lr_min": lr_min}
model_params["sgdm-4e5-n8"] = {"depth": depth, "smooth": 0.1, 'server_opt': 'sgd', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, "client_weight_decay": 0.0, "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": 4000000, "client_partial": 0.0064, "privacy_clip": 1.0, "privacy_noise": 8.0, "scheduler": scheduler, "lr_min": lr_min}
model_params["adam-4e5-n8"] = {"depth": depth, "smooth": 0.1, 'server_opt': 'adam', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum,"client_weight_decay": 0.0,  "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": 4000000, "client_partial": 0.0064, "privacy_clip": 1.0, "privacy_noise": 8.0, "scheduler": scheduler, "lr_min": lr_min}
model_params["sgdm-no-n8"] = {"depth": depth, "smooth": 0.1, 'server_opt': 'sgd', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, "client_weight_decay": 0.0, "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": -1, "client_partial": 0.0064, "privacy_clip": 1.0, "privacy_noise": 8.0, "scheduler": scheduler, "lr_min": lr_min}
model_params["adam-no-n8"] = {"depth": depth, "smooth": 0.1, 'server_opt': 'adam', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum,"client_weight_decay": 0.0,  "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": -1, "client_partial": 0.0064, "privacy_clip": 1.0, "privacy_noise": 8.0, "scheduler": scheduler, "lr_min": lr_min}

opt_params = {}
opt_params["sgdm-4e5-n2"] = {'lr': 0.01, 'dataset_name':dataset_name, 'loss': loss_name, 'opt':'federated', 'model_name':model_name, 'momentum':momentum, 'weight_decay':weight_decay, 'batch_size':batch_size, 'epochs':500}
opt_params["adam-4e5-n2"] = {'lr': 0.01, 'dataset_name':dataset_name, 'loss': loss_name, 'opt':'federated', 'model_name':model_name, 'momentum':momentum, 'weight_decay':weight_decay, 'batch_size':batch_size, 'epochs':500}
opt_params["sgdm-no-n2"] = {'lr': 0.01, 'dataset_name':dataset_name, 'loss': loss_name, 'opt':'federated', 'model_name':model_name, 'momentum':momentum, 'weight_decay':weight_decay, 'batch_size':batch_size, 'epochs':500}
opt_params["adam-no-n2"] = {'lr': 0.01, 'dataset_name':dataset_name, 'loss': loss_name, 'opt':'federated', 'model_name':model_name, 'momentum':momentum, 'weight_decay':weight_decay, 'batch_size':batch_size, 'epochs':500}
opt_params["sgdm-4e5-n8"] = opt_params["sgdm-4e5-n6"] = opt_params["sgdm-4e5-n4"] = opt_params["sgdm-4e5-n2"]
opt_params["adam-4e5-n8"] = opt_params["adam-4e5-n6"] = opt_params["adam-4e5-n4"] = opt_params["adam-4e5-n2"]
opt_params["adam-no-n8"] = opt_params["adam-no-n6"] = opt_params["adam-no-n4"] = opt_params["adam-no-n2"]
opt_params["sgdm-no-n8"] = opt_params["sgdm-no-n6"] = opt_params["sgdm-no-n4"] = opt_params["sgdm-no-n2"]

#plot_figures_opts_attrs(["adam-4e5-n2", "adam-no-n2"], model_params, opt_params, attrs=["loss", "accuracy", "test_err"], start=10)
plot_figures_opts_attrs(["adam-4e5-n4"], model_params, opt_params, attrs=["loss", "accuracy", "test_err"], start=10)
plot_figures_opts_attrs(["adam-4e5-n6"], model_params, opt_params, attrs=["loss", "accuracy", "test_err"], start=10)
plot_figures_opts_attrs(["adam-4e5-n8"], model_params, opt_params, attrs=["loss", "accuracy", "test_err"], start=10)
# Out:
# /projects/illinois/eng/cs/arindamb/lucmon/mlopt/results/emnist/CrossEntropyLoss/federated/resnet_gn/depth_101/smooth_0.1/server_opt_adam/client_opt_sgd/client_lr_0.01/client_momentum_0.0/client_weight_decay_0.0/client_num_625/client_epoch_1/sketch_size_4000000/client_partial_0.0064/privacy_clip_1.0/privacy_noise_4.0/scheduler_cosine/lr_min_1e-05/lr_0.01/moment_0.9/wd_0.0001/batch_size_64/epoch_500/
# 1
# 1
# 1
# /projects/illinois/eng/cs/arindamb/lucmon/mlopt/results/emnist/CrossEntropyLoss/federated/resnet_gn/depth_101/smooth_0.1/server_opt_adam/client_opt_sgd/client_lr_0.01/client_momentum_0.0/client_weight_decay_0.0/client_num_625/client_epoch_1/sketch_size_4000000/client_partial_0.0064/privacy_clip_1.0/privacy_noise_6.0/scheduler_cosine/lr_min_1e-05/lr_0.01/moment_0.9/wd_0.0001/batch_size_64/epoch_500/
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ...

# %%
/projects/illinois/eng/cs/arindamb/lucmon/mlopt/results/emnist/CrossEntropyLoss/federated/resnet_gn/depth_101/smooth_0.1/server_opt_sgd/client_opt_sgd/client_lr_0.01/client_momentum_0.0/client_weight_decay_0.0/client_num_625/client_epoch_1/sketch_size_-1/client_partial_0.0064/privacy_clip_1.0/privacy_noise_2.0/scheduler_cosine/lr_min_1e-05/lr_0.01/moment_0.9/wd_0.0001/batch_size_64/epoch_500/

# %%
/projects/illinois/eng/cs/arindamb/lucmon/mlopt/results/emnist/CrossEntropyLoss/federated/resnet_gn/depth_101/smooth_0.1/server_opt_sgd/client_opt_sgd/client_lr_0.01/client_momentum_0.0/client_weight_decay_0.0/client_num_625/client_epoch_1/sketch_size_-1/client_partial_0.0064/privacy_clip_1.0/privacy_noise_2.0/scheduler_cosine/lr_min_1e-05/lr_0.01/moment_0.9/wd_0.0001/batch_size_64/epoch_500/

# %%
/projects/illinois/eng/cs/arindamb/lucmon/mlopt/results/glue/CrossEntropyLoss/federated/google-bert/bert-base-cased/task_name_sst2/seq_length_128/server_opt_sgd/client_opt_sgd/client_lr_0.001/client_momentum_0.0/client_weight_decay_0.0/client_num_625/client_epoch_1/sketch_size_200000/client_partial_0.0064/privacy_clip_1.0/privacy_noise_0.1204/scheduler_cosine/lr_min_0.01/lr_0.1/moment_0.9/wd_0.0001/batch_size_12/epoch_200/run_0/

# %%
from plot_functions import plot_figures_opts, plot_attr_figure, plot_figures_opts_attrs, plot_figures_opts_attr
from main import graphs

lr, dataset_name, loss_name, momentum, weight_decay, batch_size, epochs = 0.1, "glue", 'CrossEntropyLoss', 0.9, 1e-4, 12, 200
model_name, depth, task_name, seq_length = "google-bert/bert-base-cased", 101, "sst2", 128
client_opt, client_lr, client_momentum, client_num, client_epoch, sketch_size, scheduler, lr_min  ="sgd", 0.001, 0.0, 625, 1, 80000, "cosine", 0.01
model_params = {}
model_params["adam-2e5-n4"] = {"task_name": task_name, "seq_length": seq_length, 'server_opt': 'adam', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, "client_weight_decay": 0.0, "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": 200000, "client_partial": 0.0064, "privacy_clip": 1.0, "privacy_noise": 4.0, "scheduler": scheduler, "lr_min": 0.001}
model_params["adam-2e5-n0.8"] = {"task_name": task_name, "seq_length": seq_length, 'server_opt': 'adam', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, "client_weight_decay": 0.0, "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": 200000, "client_partial": 0.0064, "privacy_clip": 1.0, "privacy_noise": 0.8, "scheduler": scheduler, "lr_min": 0.001}
model_params["adam-no-n4"] = {"task_name": task_name, "seq_length": seq_length, 'server_opt': 'adam', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, "client_weight_decay": 0.0, "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": -1, "client_partial": 0.0064, "privacy_clip": 1.0, "privacy_noise": 4.0, "scheduler": scheduler, "lr_min": 0.001}
model_params["adam-no-n0.8"] = {"task_name": task_name, "seq_length": seq_length, 'server_opt': 'adam', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, "client_weight_decay": 0.0, "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": -1, "client_partial": 0.0064, "privacy_clip": 1.0, "privacy_noise": 0.8, "scheduler": scheduler, "lr_min": 0.001}
model_params["adam-2e5-n2"] = {"task_name": task_name, "seq_length": seq_length, 'server_opt': 'adam', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, "client_weight_decay": 0.0, "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": 200000, "client_partial": 0.0064, "privacy_clip": 1.0, "privacy_noise": 2.0, "scheduler": scheduler, "lr_min": 0.001}
model_params["adam-2e5-n1"] = {"task_name": task_name, "seq_length": seq_length, 'server_opt': 'adam', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, "client_weight_decay": 0.0, "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": 200000, "client_partial": 0.0064, "privacy_clip": 1.0, "privacy_noise": 1.0, "scheduler": scheduler, "lr_min": 0.001}
model_params["adam-no-n2"] = {"task_name": task_name, "seq_length": seq_length, 'server_opt': 'adam', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, "client_weight_decay": 0.0, "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": -1, "client_partial": 0.0064, "privacy_clip": 1.0, "privacy_noise": 2.0, "scheduler": scheduler, "lr_min": 0.001}
model_params["adam-no-n1"] = {"task_name": task_name, "seq_length": seq_length, 'server_opt': 'adam', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, "client_weight_decay": 0.0, "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": -1, "client_partial": 0.0064, "privacy_clip": 1.0, "privacy_noise": 1.0, "scheduler": scheduler, "lr_min": 0.001}
model_params["sgdm-2e5-n2"] = {"task_name": task_name, "seq_length": seq_length, 'server_opt': 'sgd', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, "client_weight_decay": 0.0, "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": 200000, "client_partial": 0.0064, "privacy_clip": 1.0, "privacy_noise": 2.0, "scheduler": scheduler, "lr_min": lr_min}
model_params["sgdm-no-n2"] = {"task_name": task_name, "seq_length": seq_length, 'server_opt': 'sgd', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, "client_weight_decay": 0.0, "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": -1, "client_partial": 0.0064, "privacy_clip": 2.0, "privacy_noise": 2.0, "scheduler": scheduler, "lr_min": lr_min}
model_params["sgdm-no-n1"] = {"task_name": task_name, "seq_length": seq_length, 'server_opt': 'sgd', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, "client_weight_decay": 0.0, "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": -1, "client_partial": 0.0064, "privacy_clip": 2.0, "privacy_noise": 1.0, "scheduler": scheduler, "lr_min": lr_min}
model_params["sgdm-2e5-n1"] = {"task_name": task_name, "seq_length": seq_length, 'server_opt': 'sgd', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, "client_weight_decay": 0.0, "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": 200000, "client_partial": 0.0064, "privacy_clip": 1.0, "privacy_noise": 1.0, "scheduler": scheduler, "lr_min": lr_min}
model_params["sgdm-2e5-n4"] = {"task_name": task_name, "seq_length": seq_length, 'server_opt': 'sgd', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, "client_weight_decay": 0.0, "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": 200000, "client_partial": 0.0064, "privacy_clip": 1.0, "privacy_noise": 4.0, "scheduler": scheduler, "lr_min": lr_min}
model_params["sgdm-no-n4"] = {"task_name": task_name, "seq_length": seq_length, 'server_opt': 'sgd', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, "client_weight_decay": 0.0, "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": -1, "client_partial": 0.0064, "privacy_clip": 1.0, "privacy_noise": 4.0, "scheduler": scheduler, "lr_min": lr_min}
model_params["sgdm-no-n0.8"] = {"task_name": task_name, "seq_length": seq_length, 'server_opt': 'sgd', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, "client_weight_decay": 0.0, "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": -1, "client_partial": 0.0064, "privacy_clip": 1.0, "privacy_noise": 0.8, "scheduler": scheduler, "lr_min": lr_min}
model_params["sgdm-2e5-n0.8"] = {"task_name": task_name, "seq_length": seq_length, 'server_opt': 'sgd', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, "client_weight_decay": 0.0, "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": 200000, "client_partial": 0.0064, "privacy_clip": 1.0, "privacy_noise": 0.8, "scheduler": scheduler, "lr_min": lr_min}
model_params["fetch-2e5-n0.8"] = {"task_name": task_name, "seq_length": seq_length, 'server_opt': 'fetchsgd', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, "client_weight_decay": 0.0, "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": 200000, "client_partial": 0.0064, "privacy_clip": 1.0, "privacy_noise": 0.8, "scheduler": scheduler, "lr_min": 0.001}

opt_params = {}
opt_params["fetch-2e5-n0.8"] = {'lr': lr, 'dataset_name':dataset_name, 'loss': loss_name, 'opt':'federated', 'model_name':model_name, 'momentum':momentum, 'weight_decay':weight_decay, 'batch_size':batch_size, 'epochs':epochs}
opt_params["adam-2e5-n2"] = {'lr': 0.001, 'dataset_name':dataset_name, 'loss': loss_name, 'opt':'federated', 'model_name':model_name, 'momentum':momentum, 'weight_decay':weight_decay, 'batch_size':batch_size, 'epochs':epochs}
opt_params["adam-2e5-n1"] = {'lr': 0.001, 'dataset_name':dataset_name, 'loss': loss_name, 'opt':'federated', 'model_name':model_name, 'momentum':momentum, 'weight_decay':weight_decay, 'batch_size':batch_size, 'epochs':epochs}
opt_params["adam-no-n2"] = {'lr': 0.001, 'dataset_name':dataset_name, 'loss': loss_name, 'opt':'federated', 'model_name':model_name, 'momentum':momentum, 'weight_decay':weight_decay, 'batch_size':batch_size, 'epochs':epochs}
opt_params["adam-no-n1"] = {'lr': 0.001, 'dataset_name':dataset_name, 'loss': loss_name, 'opt':'federated', 'model_name':model_name, 'momentum':momentum, 'weight_decay':weight_decay, 'batch_size':batch_size, 'epochs':epochs}
opt_params["sgdm-2e5-n2"] = {'lr': lr, 'dataset_name':dataset_name, 'loss': loss_name, 'opt':'federated', 'model_name':model_name, 'momentum':momentum, 'weight_decay':weight_decay, 'batch_size':batch_size, 'epochs':epochs}
opt_params["sgdm-no-n2"] = {'lr': lr, 'dataset_name':dataset_name, 'loss': loss_name, 'opt':'federated', 'model_name':model_name, 'momentum':momentum, 'weight_decay':weight_decay, 'batch_size':batch_size, 'epochs':epochs}
opt_params["sgdm-no-n1"] = {'lr': lr, 'dataset_name':dataset_name, 'loss': loss_name, 'opt':'federated', 'model_name':model_name, 'momentum':momentum, 'weight_decay':weight_decay, 'batch_size':batch_size, 'epochs':epochs}
opt_params["sgdm-2e5-n1"] = {'lr': lr, 'dataset_name':dataset_name, 'loss': loss_name, 'opt':'federated', 'model_name':model_name, 'momentum':momentum, 'weight_decay':weight_decay, 'batch_size':batch_size, 'epochs':epochs}
opt_params["sgdm-2e5-n4"] = opt_params["sgdm-no-n4"] = opt_params["sgdm-no-n0.8"] = opt_params["sgdm-2e5-n0.8"] = opt_params["sgdm-2e5-n1"]
opt_params["adam-2e5-n4"] = opt_params["adam-no-n4"] = opt_params["adam-no-n0.8"] = opt_params["adam-2e5-n0.8"] = opt_params["adam-2e5-n1"]
#plot_figures_opts_attrs(["adam-4e5-n2", "adam-no-n2"], model_params, opt_params, attrs=["loss", "accuracy", "test_err"], start=10)
#plot_figures_opts_attrs(["adam-2e5-n4", "sgdm-2e5-n4", "adam-no-n4", "sgdm-no-n4"], model_params, opt_params, attrs=["loss", "accuracy", "test_err"], start=10)
#plot_figures_opts_attrs(["adam-2e5-n2", "sgdm-2e5-n2", "adam-no-n2", "sgdm-no-n2"], model_params, opt_params, attrs=["loss", "accuracy", "test_err"], start=10)
#plot_figures_opts_attrs(["adam-2e5-n1", "sgdm-2e5-n1", "adam-no-n1", "sgdm-no-n1"], model_params, opt_params, attrs=["loss", "accuracy", "test_err"], start=10)
#plot_figures_opts_attrs(["adam-2e5-n0.8", "sgdm-2e5-n0.8", "adam-no-n0.8", "sgdm-no-n0.8"], model_params, opt_params, attrs=["loss", "accuracy", "test_err"], start=10)

max_vals = {}
max_vals[4] = plot_figures_opts_attr([["sgdm-2e5-n4", "sgdm-no-n4", "adam-2e5-n4", "adam-no-n4"]], model_params, opt_params, ["test_acc"], start=10, end=None, alpha=1.0, linewidth=1.0, ylabel = "Test Accuracy", titles=[""], legends=[["sgd-4e5", "sgd-no", "adam-4e5", "adam-no"]], save_dir="../plots/uai25/sst_privacy_n4.pdf", return_last=False, return_max=True) #"../plots/iclr25workshop/cifar_client_2.pdf"
max_vals[2] = plot_figures_opts_attr([["sgdm-2e5-n2", "sgdm-no-n2", "adam-2e5-n2", "adam-no-n2"]], model_params, opt_params, ["test_acc"], start=10, end=None, alpha=1.0, linewidth=1.0, ylabel = "Test Accuracy", titles=[""], legends=[["sgd-4e5", "sgd-no", "adam-4e5", "adam-no"]], save_dir="../plots/uai25/sst_privacy_n2.pdf", return_last=False, return_max=True) #"../plots/iclr25workshop/cifar_client_2.pdf"
max_vals[1] = plot_figures_opts_attr([["sgdm-2e5-n1", "sgdm-no-n1", "adam-2e5-n1", "adam-no-n1"]], model_params, opt_params, ["test_acc"], start=10, end=None, alpha=1.0, linewidth=1.0, ylabel = "Test Accuracy", titles=[""], legends=[["sgd-4e5", "sgd-no", "adam-4e5", "adam-no"]], save_dir="../plots/uai25/sst_privacy_n1.pdf", return_last=False, return_max=True) #"../plots/iclr25workshop/cifar_client_2.pdf"
max_vals[0.8] = plot_figures_opts_attr([["sgdm-2e5-n0.8", "sgdm-no-n0.8", "adam-2e5-n0.8", "adam-no-n0.8"]], model_params, opt_params, ["test_acc"], start=10, end=None, alpha=1.0, linewidth=1.0, ylabel = "Test Accuracy", titles=[""], legends=[["sgd-4e5", "sgd-no", "adam-4e5", "adam-no"]], save_dir="../plots/uai25/sst_privacy_n0.8.pdf", return_last=False, return_max=True) #"../plots/iclr25workshop/cifar_client_2.pdf"


#plot_figures_opts_attrs(["adam-2e5-n1", "adam-2e5-n2"], model_params, opt_params, attrs=["loss", "accuracy", "test_err"], start=10)
#plot_figures_opts_attrs(["sgdm-2e5-n0.8", "sgdm-2e5-n1", "sgdm-2e5-n2", "sgdm-2e5-n4"], model_params, opt_params, attrs=["loss", "accuracy", "test_err"], start=10)
# Out:
# /projects/illinois/eng/cs/arindamb/lucmon/mlopt/results/glue/CrossEntropyLoss/federated/google-bert/bert-base-cased/task_name_sst2/seq_length_128/server_opt_sgd/client_opt_sgd/client_lr_0.001/client_momentum_0.0/client_weight_decay_0.0/client_num_625/client_epoch_1/sketch_size_200000/client_partial_0.0064/privacy_clip_1.0/privacy_noise_4.0/scheduler_cosine/lr_min_0.01/lr_0.1/moment_0.9/wd_0.0001/batch_size_12/epoch_200/run_0/
# /projects/illinois/eng/cs/arindamb/lucmon/mlopt/results/glue/CrossEntropyLoss/federated/google-bert/bert-base-cased/task_name_sst2/seq_length_128/server_opt_sgd/client_opt_sgd/client_lr_0.001/client_momentum_0.0/client_weight_decay_0.0/client_num_625/client_epoch_1/sketch_size_-1/client_partial_0.0064/privacy_clip_1.0/privacy_noise_4.0/scheduler_cosine/lr_min_0.01/lr_0.1/moment_0.9/wd_0.0001/batch_size_12/epoch_200/run_0/
# ...

# %%
#nips25
from plot_functions import plot_figures_opts, plot_attr_figure, plot_figures_opts_attrs, plot_figures_opts_attr
from main import graphs

lr, dataset_name, loss_name, momentum, weight_decay, batch_size, epochs = 0.1, "glue", 'CrossEntropyLoss', 0.9, 1e-4, 12, 200
model_name, depth, task_name, seq_length = "google-bert/bert-base-cased", 101, "sst2", 128
client_opt, client_lr, client_momentum, client_num, client_epoch, sketch_size, scheduler, lr_min  ="sgd", 0.001, 0.0, 625, 1, 80000, "cosine", 0.01
model_params = {}
model_params["adam-2e5-n4"] = {"task_name": task_name, "seq_length": seq_length, 'server_opt': 'adam', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, "client_weight_decay": 0.0, "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": 200000, "client_partial": 0.0064, "privacy_clip": 1.0, "privacy_noise": 0.2691, "scheduler": scheduler, "lr_min": 0.001}
model_params["adam-2e5-n2"] = {"task_name": task_name, "seq_length": seq_length, 'server_opt': 'adam', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, "client_weight_decay": 0.0, "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": 200000, "client_partial": 0.0064, "privacy_clip": 1.0, "privacy_noise": 0.1887, "scheduler": scheduler, "lr_min": 0.001}
model_params["adam-2e5-n1"] = {"task_name": task_name, "seq_length": seq_length, 'server_opt': 'adam', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, "client_weight_decay": 0.0, "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": 200000, "client_partial": 0.0064, "privacy_clip": 1.0, "privacy_noise": 0.1204, "scheduler": scheduler, "lr_min": 1e-5}
model_params["adam-2e5-n0.8"] = {"task_name": task_name, "seq_length": seq_length, 'server_opt': 'adam', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, "client_weight_decay": 0.0, "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": 200000, "client_partial": 0.0064, "privacy_clip": 1.0, "privacy_noise": 0.1049, "scheduler": scheduler, "lr_min": 1e-5}
model_params["adam-no-n4"] = {"task_name": task_name, "seq_length": seq_length, 'server_opt': 'adam', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, "client_weight_decay": 0.0, "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": -1, "client_partial": 0.0064, "privacy_clip": 1.0, "privacy_noise": 4.0, "scheduler": scheduler, "lr_min": 0.001}
model_params["adam-no-n0.8"] = {"task_name": task_name, "seq_length": seq_length, 'server_opt': 'adam', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, "client_weight_decay": 0.0, "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": -1, "client_partial": 0.0064, "privacy_clip": 1.0, "privacy_noise": 0.8, "scheduler": scheduler, "lr_min": 0.001}
model_params["adam-no-n2"] = {"task_name": task_name, "seq_length": seq_length, 'server_opt': 'adam', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, "client_weight_decay": 0.0, "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": -1, "client_partial": 0.0064, "privacy_clip": 1.0, "privacy_noise": 2.0, "scheduler": scheduler, "lr_min": 0.001}
model_params["adam-no-n1"] = {"task_name": task_name, "seq_length": seq_length, 'server_opt': 'adam', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, "client_weight_decay": 0.0, "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": -1, "client_partial": 0.0064, "privacy_clip": 1.0, "privacy_noise": 1.0, "scheduler": scheduler, "lr_min": 0.001}
model_params["sgdm-no-n2"] = {"task_name": task_name, "seq_length": seq_length, 'server_opt': 'sgd', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, "client_weight_decay": 0.0, "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": -1, "client_partial": 0.0064, "privacy_clip": 2.0, "privacy_noise": 2.0, "scheduler": scheduler, "lr_min": lr_min}
model_params["sgdm-no-n1"] = {"task_name": task_name, "seq_length": seq_length, 'server_opt': 'sgd', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, "client_weight_decay": 0.0, "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": -1, "client_partial": 0.0064, "privacy_clip": 2.0, "privacy_noise": 1.0, "scheduler": scheduler, "lr_min": lr_min}
model_params["sgdm-2e5-n0.8"] = {"task_name": task_name, "seq_length": seq_length, 'server_opt': 'sgd', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, "client_weight_decay": 0.0, "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": 200000, "client_partial": 0.0064, "privacy_clip": 1.0, "privacy_noise": 0.1049, "scheduler": scheduler, "lr_min": lr_min}
model_params["sgdm-2e5-n1"] = {"task_name": task_name, "seq_length": seq_length, 'server_opt': 'sgd', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, "client_weight_decay": 0.0, "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": 200000, "client_partial": 0.0064, "privacy_clip": 1.0, "privacy_noise": 0.1204, "scheduler": scheduler, "lr_min": lr_min}
model_params["sgdm-2e5-n2"] = {"task_name": task_name, "seq_length": seq_length, 'server_opt': 'sgd', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, "client_weight_decay": 0.0, "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": 200000, "client_partial": 0.0064, "privacy_clip": 1.0, "privacy_noise": 0.1887, "scheduler": scheduler, "lr_min": lr_min}
model_params["sgdm-2e5-n4"] = {"task_name": task_name, "seq_length": seq_length, 'server_opt': 'sgd', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, "client_weight_decay": 0.0, "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": 200000, "client_partial": 0.0064, "privacy_clip": 1.0, "privacy_noise": 0.2691, "scheduler": scheduler, "lr_min": lr_min}
model_params["sgdm-no-n4"] = {"task_name": task_name, "seq_length": seq_length, 'server_opt': 'sgd', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, "client_weight_decay": 0.0, "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": -1, "client_partial": 0.0064, "privacy_clip": 1.0, "privacy_noise": 4.0, "scheduler": scheduler, "lr_min": lr_min}
model_params["sgdm-no-n0.8"] = {"task_name": task_name, "seq_length": seq_length, 'server_opt': 'sgd', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, "client_weight_decay": 0.0, "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": -1, "client_partial": 0.0064, "privacy_clip": 1.0, "privacy_noise": 0.8, "scheduler": scheduler, "lr_min": lr_min}
model_params["fetch-2e5-n0.8"] = {"task_name": task_name, "seq_length": seq_length, 'server_opt': 'fetchsgd', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, "client_weight_decay": 0.0, "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": 200000, "client_partial": 0.0064, "privacy_clip": 1.0, "privacy_noise": 0.1049, "scheduler": scheduler, "lr_min": 0.01}
model_params["fetch-2e5-n1"] = {"task_name": task_name, "seq_length": seq_length, 'server_opt': 'fetchsgd', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, "client_weight_decay": 0.0, "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": 200000, "client_partial": 0.0064, "privacy_clip": 1.0, "privacy_noise": 0.1204, "scheduler": scheduler, "lr_min": 0.01}
model_params["fetch-2e5-n2"] = {"task_name": task_name, "seq_length": seq_length, 'server_opt': 'fetchsgd', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, "client_weight_decay": 0.0, "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": 200000, "client_partial": 0.0064, "privacy_clip": 1.0, "privacy_noise": 0.1887, "scheduler": scheduler, "lr_min": 0.01}
model_params["fetch-2e5-n4"] = {"task_name": task_name, "seq_length": seq_length, 'server_opt': 'fetchsgd', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, "client_weight_decay": 0.0, "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": 200000, "client_partial": 0.0064, "privacy_clip": 1.0, "privacy_noise": 0.2691, "scheduler": scheduler, "lr_min": 0.01}

opt_params = {}
opt_params["fetch-2e5-n0.8"] = {'lr': 0.8, 'dataset_name':dataset_name, 'loss': loss_name, 'opt':'federated', 'model_name':model_name, 'momentum':momentum, 'weight_decay':weight_decay, 'batch_size':batch_size, 'epochs':epochs}
opt_params["adam-2e5-n2"] = {'lr': 0.001, 'dataset_name':dataset_name, 'loss': loss_name, 'opt':'federated', 'model_name':model_name, 'momentum':momentum, 'weight_decay':weight_decay, 'batch_size':batch_size, 'epochs':epochs}
opt_params["adam-2e5-n1"] = {'lr': 0.001, 'dataset_name':dataset_name, 'loss': loss_name, 'opt':'federated', 'model_name':model_name, 'momentum':momentum, 'weight_decay':weight_decay, 'batch_size':batch_size, 'epochs':epochs}
opt_params["adam-no-n2"] = {'lr': 0.001, 'dataset_name':dataset_name, 'loss': loss_name, 'opt':'federated', 'model_name':model_name, 'momentum':momentum, 'weight_decay':weight_decay, 'batch_size':batch_size, 'epochs':epochs}
opt_params["adam-no-n1"] = {'lr': 0.001, 'dataset_name':dataset_name, 'loss': loss_name, 'opt':'federated', 'model_name':model_name, 'momentum':momentum, 'weight_decay':weight_decay, 'batch_size':batch_size, 'epochs':epochs}
opt_params["sgdm-2e5-n2"] = {'lr': lr, 'dataset_name':dataset_name, 'loss': loss_name, 'opt':'federated', 'model_name':model_name, 'momentum':momentum, 'weight_decay':weight_decay, 'batch_size':batch_size, 'epochs':epochs}
opt_params["sgdm-no-n2"] = {'lr': lr, 'dataset_name':dataset_name, 'loss': loss_name, 'opt':'federated', 'model_name':model_name, 'momentum':momentum, 'weight_decay':weight_decay, 'batch_size':batch_size, 'epochs':epochs}
opt_params["sgdm-no-n1"] = {'lr': lr, 'dataset_name':dataset_name, 'loss': loss_name, 'opt':'federated', 'model_name':model_name, 'momentum':momentum, 'weight_decay':weight_decay, 'batch_size':batch_size, 'epochs':epochs}
opt_params["sgdm-2e5-n1"] = {'lr': lr, 'dataset_name':dataset_name, 'loss': loss_name, 'opt':'federated', 'model_name':model_name, 'momentum':momentum, 'weight_decay':weight_decay, 'batch_size':batch_size, 'epochs':epochs}
opt_params["sgdm-2e5-n4"] = opt_params["sgdm-no-n4"] = opt_params["sgdm-no-n0.8"] = opt_params["sgdm-2e5-n0.8"] = opt_params["sgdm-2e5-n1"]
opt_params["adam-2e5-n4"] = opt_params["adam-no-n4"] = opt_params["adam-no-n0.8"] = opt_params["adam-2e5-n0.8"] = opt_params["adam-2e5-n1"]
opt_params["fetch-2e5-n4"] = opt_params["fetch-2e5-n2"] = opt_params["fetch-2e5-n1"] = opt_params["fetch-2e5-n0.8"]
#plot_figures_opts_attrs(["adam-4e5-n2", "adam-no-n2"], model_params, opt_params, attrs=["loss", "accuracy", "test_err"], start=10)
#plot_figures_opts_attrs(["adam-2e5-n4", "sgdm-2e5-n4", "adam-no-n4", "sgdm-no-n4"], model_params, opt_params, attrs=["loss", "accuracy", "test_err"], start=10)
#plot_figures_opts_attrs(["adam-2e5-n2", "sgdm-2e5-n2", "adam-no-n2", "sgdm-no-n2"], model_params, opt_params, attrs=["loss", "accuracy", "test_err"], start=10)
#plot_figures_opts_attrs(["adam-2e5-n1", "sgdm-2e5-n1", "adam-no-n1", "sgdm-no-n1"], model_params, opt_params, attrs=["loss", "accuracy", "test_err"], start=10)
#plot_figures_opts_attrs(["adam-2e5-n0.8", "sgdm-2e5-n0.8", "adam-no-n0.8", "sgdm-no-n0.8"], model_params, opt_params, attrs=["loss", "accuracy", "test_err"], start=10)

max_vals = {}
max_vals[0.8] = plot_figures_opts_attr([["sgdm-2e5-n0.8", "sgdm-no-n0.8", "adam-2e5-n0.8", "adam-no-n0.8", "fetch-2e5-n0.8"]], model_params, opt_params, ["test_acc"], start=0, end=None, alpha=1.0, linewidth=1.0, ylabel = "Test Accuracy", titles=[""], legends=[["sgd-2e5", "sgd-no", "adam-2e5", "adam-no", "DiffSketch"]], save_dir="../plots/nips25privacy/bert_0.8.pdf", return_last=False, return_max=True) #"../plots/iclr25workshop/cifar_client_2.pdf"
max_vals[1] = plot_figures_opts_attr([["sgdm-2e5-n1", "sgdm-no-n1", "adam-2e5-n1", "adam-no-n1", "fetch-2e5-n1"]], model_params, opt_params, ["test_acc"], start=0, end=None, alpha=1.0, linewidth=1.0, ylabel = "Test Accuracy", titles=[""], legends=[["sgd-2e5", "sgd-no", "adam-2e5", "adam-no", "DiffSketch"]], save_dir="../plots/nips25privacy/bert_1.pdf", return_last=False, return_max=True) #"../plots/iclr25workshop/cifar_client_2.pdf"
max_vals[2] = plot_figures_opts_attr([["sgdm-2e5-n2", "sgdm-no-n2", "adam-2e5-n2", "adam-no-n2", "fetch-2e5-n2"]], model_params, opt_params, ["test_acc"], start=0, end=None, alpha=1.0, linewidth=1.0, ylabel = "Test Accuracy", titles=[""], legends=[["sgd-2e5", "sgd-no", "adam-2e5", "adam-no", "DiffSketch"]], save_dir="../plots/nips25privacy/bert_2.pdf", return_last=False, return_max=True) #"../plots/iclr25workshop/cifar_client_2.pdf"
max_vals[4] = plot_figures_opts_attr([["sgdm-2e5-n4", "sgdm-no-n4", "adam-2e5-n4", "adam-no-n4", "fetch-2e5-n4"]], model_params, opt_params, ["test_acc"], start=5, end=None, alpha=1.0, linewidth=1.0, ylabel = "Test Accuracy", titles=[""], legends=[["sgd-2e5", "sgd-no", "adam-2e5", "adam-no", "DiffSketch"]], save_dir="../plots/nips25privacy/bert_4.pdf", return_last=False, return_max=True) #"../plots/iclr25workshop/cifar_client_2.pdf"
max_vals_train = {}
max_vals_train[0.8] = plot_figures_opts_attr([["sgdm-2e5-n0.8", "sgdm-no-n0.8", "adam-2e5-n0.8", "adam-no-n0.8", "fetch-2e5-n0.8"]], model_params, opt_params, ["acc"], start=0, end=None, alpha=1.0, linewidth=1.0, ylabel = "Train Accuracy", titles=[""], legends=[["sgd-2e5", "sgd-no", "adam-2e5", "adam-no", "DiffSketch"]], save_dir="../plots/nips25privacy/bert_0.8_train.pdf", return_last=False, return_max=True) #"../plots/iclr25workshop/cifar_client_2.pdf"
max_vals_train[1] = plot_figures_opts_attr([["sgdm-2e5-n1", "sgdm-no-n1", "adam-2e5-n1", "adam-no-n1", "fetch-2e5-n1"]], model_params, opt_params, ["acc"], start=0, end=None, alpha=1.0, linewidth=1.0, ylabel = "Train Accuracy", titles=[""], legends=[["sgd-2e5", "sgd-no", "adam-2e5", "adam-no", "DiffSketch"]], save_dir="../plots/nips25privacy/bert_1_train.pdf", return_last=False, return_max=True) #"../plots/iclr25workshop/cifar_client_2.pdf"
max_vals_train[2] = plot_figures_opts_attr([["sgdm-2e5-n2", "sgdm-no-n2", "adam-2e5-n2", "adam-no-n2", "fetch-2e5-n2"]], model_params, opt_params, ["acc"], start=0, end=None, alpha=1.0, linewidth=1.0, ylabel = "Train Accuracy", titles=[""], legends=[["sgd-2e5", "sgd-no", "adam-2e5", "adam-no", "DiffSketch"]], save_dir="../plots/nips25privacy/bert_2_train.pdf", return_last=False, return_max=True) #"../plots/iclr25workshop/cifar_client_2.pdf"
max_vals_train[4] = plot_figures_opts_attr([["sgdm-2e5-n4", "sgdm-no-n4", "adam-2e5-n4", "adam-no-n4", "fetch-2e5-n4"]], model_params, opt_params, ["acc"], start=5, end=None, alpha=1.0, linewidth=1.0, ylabel = "Train Accuracy", titles=[""], legends=[["sgd-2e5", "sgd-no", "adam-2e5", "adam-no", "DiffSketch"]], save_dir="../plots/nips25privacy/bert_4_train.pdf", return_last=False, return_max=True) #"../plots/iclr25workshop/cifar_client_2.pdf"
# Out:
# /projects/illinois/eng/cs/arindamb/lucmon/mlopt/results/glue/CrossEntropyLoss/federated/google-bert/bert-base-cased/task_name_sst2/seq_length_128/server_opt_sgd/client_opt_sgd/client_lr_0.001/client_momentum_0.0/client_weight_decay_0.0/client_num_625/client_epoch_1/sketch_size_200000/client_partial_0.0064/privacy_clip_1.0/privacy_noise_0.1049/scheduler_cosine/lr_min_0.01/lr_0.1/moment_0.9/wd_0.0001/batch_size_12/epoch_200/run_0/
# /projects/illinois/eng/cs/arindamb/lucmon/mlopt/results/glue/CrossEntropyLoss/federated/google-bert/bert-base-cased/task_name_sst2/seq_length_128/server_opt_sgd/client_opt_sgd/client_lr_0.001/client_momentum_0.0/client_weight_decay_0.0/client_num_625/client_epoch_1/sketch_size_-1/client_partial_0.0064/privacy_clip_1.0/privacy_noise_0.8/scheduler_cosine/lr_min_0.01/lr_0.1/moment_0.9/wd_0.0001/batch_size_12/epoch_200/run_0/
# ...

# %%
import numpy as np

import matplotlib.pyplot as plt
noise = [0.8, 1, 2,4]
epsilon = [2.76, 1.60, 0.42, 0.18]
legends = ["sgd-4e5","sgd-no","adam-4e5","adam-no", "DiffSketch"]
for i in range(len(legends)):
    array = []
    for n in noise:
        array.append(max_vals[n][0][i])
    plt.plot(epsilon, array)

plt.legend(legends)
plt.ylabel("Test Accuracy")
plt.xlabel(r"$\epsilon$")
plt.savefig("../plots/nips25privacy/sst_test_acc_trend.pdf")

# %%
import numpy as np

import matplotlib.pyplot as plt
noise = [0.8, 1, 2,4]
epsilon = [2.76, 1.60, 0.42, 0.18]
legends = ["sgd-4e5","sgd-no","adam-4e5","adam-no", "DiffSketch"]
for i in range(len(legends)):
    array = []
    for n in noise:
        array.append(max_vals_train[n][0][i])
    plt.plot(epsilon, array)

plt.legend(legends)
plt.ylabel("Test Accuracy")
plt.xlabel(r"$\epsilon$")
plt.savefig("../plots/nips25privacy/sst_train_acc_trend.pdf")

# %%
#nips25
from plot_functions import plot_figures_opts, plot_attr_figure, plot_figures_opts_attrs, plot_figures_opts_attr
from main import graphs

lr, dataset_name, loss_name, momentum, weight_decay, batch_size, epochs = 0.1, "glue", 'CrossEntropyLoss', 0.9, 1e-4, 12, 200
model_name, depth, task_name, seq_length = "google-bert/bert-base-cased", 101, "sst2", 128
client_opt, client_lr, client_momentum, client_num, client_epoch, sketch_size, scheduler, lr_min  ="sgd", 0.001, 0.0, 625, 1, 80000, "cosine", 0.01
model_params = {}
model_params["adam-2e5-n4"] = {"task_name": task_name, "seq_length": seq_length, 'server_opt': 'adam', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, "client_weight_decay": 0.0, "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": 200000, "client_partial": 0.0064, "privacy_clip": 1.0, "privacy_noise": 0.2691, "scheduler": scheduler, "lr_min": 0.001}
model_params["adam-2e5-n2"] = {"task_name": task_name, "seq_length": seq_length, 'server_opt': 'adam', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, "client_weight_decay": 0.0, "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": 200000, "client_partial": 0.0064, "privacy_clip": 1.0, "privacy_noise": 0.1887, "scheduler": scheduler, "lr_min": 0.001}
model_params["adam-2e5-n1"] = {"task_name": task_name, "seq_length": seq_length, 'server_opt': 'adam', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, "client_weight_decay": 0.0, "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": 200000, "client_partial": 0.0064, "privacy_clip": 1.0, "privacy_noise": 0.1204, "scheduler": scheduler, "lr_min": 1e-5}
model_params["adam-2e5-n0.8"] = {"task_name": task_name, "seq_length": seq_length, 'server_opt': 'adam', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, "client_weight_decay": 0.0, "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": 200000, "client_partial": 0.0064, "privacy_clip": 1.0, "privacy_noise": 0.1049, "scheduler": scheduler, "lr_min": 1e-5}
model_params["adam-no-n4"] = {"task_name": task_name, "seq_length": seq_length, 'server_opt': 'adam', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, "client_weight_decay": 0.0, "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": -1, "client_partial": 0.0064, "privacy_clip": 1.0, "privacy_noise": 4.0, "scheduler": scheduler, "lr_min": 0.001}
model_params["adam-no-n0.8"] = {"task_name": task_name, "seq_length": seq_length, 'server_opt': 'adam', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, "client_weight_decay": 0.0, "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": -1, "client_partial": 0.0064, "privacy_clip": 1.0, "privacy_noise": 0.8, "scheduler": scheduler, "lr_min": 0.001}
model_params["adam-no-n2"] = {"task_name": task_name, "seq_length": seq_length, 'server_opt': 'adam', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, "client_weight_decay": 0.0, "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": -1, "client_partial": 0.0064, "privacy_clip": 1.0, "privacy_noise": 2.0, "scheduler": scheduler, "lr_min": 0.001}
model_params["adam-no-n1"] = {"task_name": task_name, "seq_length": seq_length, 'server_opt': 'adam', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, "client_weight_decay": 0.0, "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": -1, "client_partial": 0.0064, "privacy_clip": 1.0, "privacy_noise": 1.0, "scheduler": scheduler, "lr_min": 0.001}
model_params["sgdm-no-n2"] = {"task_name": task_name, "seq_length": seq_length, 'server_opt': 'sgd', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, "client_weight_decay": 0.0, "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": -1, "client_partial": 0.0064, "privacy_clip": 2.0, "privacy_noise": 2.0, "scheduler": scheduler, "lr_min": lr_min}
model_params["sgdm-no-n1"] = {"task_name": task_name, "seq_length": seq_length, 'server_opt': 'sgd', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, "client_weight_decay": 0.0, "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": -1, "client_partial": 0.0064, "privacy_clip": 2.0, "privacy_noise": 1.0, "scheduler": scheduler, "lr_min": lr_min}
model_params["sgdm-2e5-n0.8"] = {"task_name": task_name, "seq_length": seq_length, 'server_opt': 'sgd', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, "client_weight_decay": 0.0, "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": 200000, "client_partial": 0.0064, "privacy_clip": 1.0, "privacy_noise": 0.1049, "scheduler": scheduler, "lr_min": lr_min}
model_params["sgdm-2e5-n1"] = {"task_name": task_name, "seq_length": seq_length, 'server_opt': 'sgd', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, "client_weight_decay": 0.0, "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": 200000, "client_partial": 0.0064, "privacy_clip": 1.0, "privacy_noise": 0.1204, "scheduler": scheduler, "lr_min": lr_min}
model_params["sgdm-2e5-n2"] = {"task_name": task_name, "seq_length": seq_length, 'server_opt': 'sgd', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, "client_weight_decay": 0.0, "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": 200000, "client_partial": 0.0064, "privacy_clip": 1.0, "privacy_noise": 0.1887, "scheduler": scheduler, "lr_min": lr_min}
model_params["sgdm-2e5-n4"] = {"task_name": task_name, "seq_length": seq_length, 'server_opt': 'sgd', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, "client_weight_decay": 0.0, "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": 200000, "client_partial": 0.0064, "privacy_clip": 1.0, "privacy_noise": 0.2691, "scheduler": scheduler, "lr_min": lr_min}
model_params["sgdm-no-n4"] = {"task_name": task_name, "seq_length": seq_length, 'server_opt': 'sgd', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, "client_weight_decay": 0.0, "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": -1, "client_partial": 0.0064, "privacy_clip": 1.0, "privacy_noise": 4.0, "scheduler": scheduler, "lr_min": lr_min}
model_params["sgdm-no-n0.8"] = {"task_name": task_name, "seq_length": seq_length, 'server_opt': 'sgd', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, "client_weight_decay": 0.0, "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": -1, "client_partial": 0.0064, "privacy_clip": 1.0, "privacy_noise": 0.8, "scheduler": scheduler, "lr_min": lr_min}
model_params["fetch-2e5-n0.8"] = {"task_name": task_name, "seq_length": seq_length, 'server_opt': 'fetchsgd', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, "client_weight_decay": 0.0, "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": 200000, "client_partial": 0.0064, "privacy_clip": 1.0, "privacy_noise": 0.1049, "scheduler": scheduler, "lr_min": 0.01}
model_params["fetch-2e5-n1"] = {"task_name": task_name, "seq_length": seq_length, 'server_opt': 'fetchsgd', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, "client_weight_decay": 0.0, "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": 200000, "client_partial": 0.0064, "privacy_clip": 1.0, "privacy_noise": 0.1204, "scheduler": scheduler, "lr_min": 0.01}
model_params["fetch-2e5-n2"] = {"task_name": task_name, "seq_length": seq_length, 'server_opt': 'fetchsgd', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, "client_weight_decay": 0.0, "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": 200000, "client_partial": 0.0064, "privacy_clip": 1.0, "privacy_noise": 0.1887, "scheduler": scheduler, "lr_min": 0.01}
model_params["fetch-2e5-n4"] = {"task_name": task_name, "seq_length": seq_length, 'server_opt': 'fetchsgd', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, "client_weight_decay": 0.0, "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": 200000, "client_partial": 0.0064, "privacy_clip": 1.0, "privacy_noise": 0.2691, "scheduler": scheduler, "lr_min": 0.01}

opt_params = {}
opt_params["fetch-2e5-n0.8"] = {'lr': 0.8, 'dataset_name':dataset_name, 'loss': loss_name, 'opt':'federated', 'model_name':model_name, 'momentum':momentum, 'weight_decay':weight_decay, 'batch_size':batch_size, 'epochs':epochs}
opt_params["adam-2e5-n2"] = {'lr': 0.001, 'dataset_name':dataset_name, 'loss': loss_name, 'opt':'federated', 'model_name':model_name, 'momentum':momentum, 'weight_decay':weight_decay, 'batch_size':batch_size, 'epochs':epochs}
opt_params["adam-2e5-n1"] = {'lr': 0.001, 'dataset_name':dataset_name, 'loss': loss_name, 'opt':'federated', 'model_name':model_name, 'momentum':momentum, 'weight_decay':weight_decay, 'batch_size':batch_size, 'epochs':epochs}
opt_params["adam-no-n2"] = {'lr': 0.001, 'dataset_name':dataset_name, 'loss': loss_name, 'opt':'federated', 'model_name':model_name, 'momentum':momentum, 'weight_decay':weight_decay, 'batch_size':batch_size, 'epochs':epochs}
opt_params["adam-no-n1"] = {'lr': 0.001, 'dataset_name':dataset_name, 'loss': loss_name, 'opt':'federated', 'model_name':model_name, 'momentum':momentum, 'weight_decay':weight_decay, 'batch_size':batch_size, 'epochs':epochs}
opt_params["sgdm-2e5-n2"] = {'lr': lr, 'dataset_name':dataset_name, 'loss': loss_name, 'opt':'federated', 'model_name':model_name, 'momentum':momentum, 'weight_decay':weight_decay, 'batch_size':batch_size, 'epochs':epochs}
opt_params["sgdm-no-n2"] = {'lr': lr, 'dataset_name':dataset_name, 'loss': loss_name, 'opt':'federated', 'model_name':model_name, 'momentum':momentum, 'weight_decay':weight_decay, 'batch_size':batch_size, 'epochs':epochs}
opt_params["sgdm-no-n1"] = {'lr': lr, 'dataset_name':dataset_name, 'loss': loss_name, 'opt':'federated', 'model_name':model_name, 'momentum':momentum, 'weight_decay':weight_decay, 'batch_size':batch_size, 'epochs':epochs}
opt_params["sgdm-2e5-n1"] = {'lr': lr, 'dataset_name':dataset_name, 'loss': loss_name, 'opt':'federated', 'model_name':model_name, 'momentum':momentum, 'weight_decay':weight_decay, 'batch_size':batch_size, 'epochs':epochs}
opt_params["sgdm-2e5-n4"] = opt_params["sgdm-no-n4"] = opt_params["sgdm-no-n0.8"] = opt_params["sgdm-2e5-n0.8"] = opt_params["sgdm-2e5-n1"]
opt_params["adam-2e5-n4"] = opt_params["adam-no-n4"] = opt_params["adam-no-n0.8"] = opt_params["adam-2e5-n0.8"] = opt_params["adam-2e5-n1"]
opt_params["fetch-2e5-n4"] = opt_params["fetch-2e5-n2"] = opt_params["fetch-2e5-n1"] = opt_params["fetch-2e5-n0.8"]
#plot_figures_opts_attrs(["adam-4e5-n2", "adam-no-n2"], model_params, opt_params, attrs=["loss", "accuracy", "test_err"], start=10)
#plot_figures_opts_attrs(["adam-2e5-n4", "sgdm-2e5-n4", "adam-no-n4", "sgdm-no-n4"], model_params, opt_params, attrs=["loss", "accuracy", "test_err"], start=10)
#plot_figures_opts_attrs(["adam-2e5-n2", "sgdm-2e5-n2", "adam-no-n2", "sgdm-no-n2"], model_params, opt_params, attrs=["loss", "accuracy", "test_err"], start=10)
#plot_figures_opts_attrs(["adam-2e5-n1", "sgdm-2e5-n1", "adam-no-n1", "sgdm-no-n1"], model_params, opt_params, attrs=["loss", "accuracy", "test_err"], start=10)
#plot_figures_opts_attrs(["adam-2e5-n0.8", "sgdm-2e5-n0.8", "adam-no-n0.8", "sgdm-no-n0.8"], model_params, opt_params, attrs=["loss", "accuracy", "test_err"], start=10)

max_vals = {}
max_vals[0.8] = plot_figures_opts_attr([["sgdm-2e5-n0.8", "sgdm-no-n0.8", "adam-2e5-n0.8", "adam-no-n0.8",]], model_params, opt_params, ["test_acc"], start=0, end=None, alpha=1.0, linewidth=1.0, ylabel = "Test Accuracy", titles=[""], legends=[["sgd-2e5", "sgd-no", "adam-2e5", "adam-no", "DiffSketch"]], save_dir="../plots/nips25privacy/bert_0.8_nodiff.pdf", return_last=False, return_max=True) #"../plots/iclr25workshop/cifar_client_2.pdf"
max_vals[1] = plot_figures_opts_attr([["sgdm-2e5-n1", "sgdm-no-n1", "adam-2e5-n1", "adam-no-n1", ]], model_params, opt_params, ["test_acc"], start=0, end=None, alpha=1.0, linewidth=1.0, ylabel = "Test Accuracy", titles=[""], legends=[["sgd-2e5", "sgd-no", "adam-2e5", "adam-no", "DiffSketch"]], save_dir="../plots/nips25privacy/bert_1_nodiff.pdf", return_last=False, return_max=True) #"../plots/iclr25workshop/cifar_client_2.pdf"
max_vals[2] = plot_figures_opts_attr([["sgdm-2e5-n2", "sgdm-no-n2", "adam-2e5-n2", "adam-no-n2", ]], model_params, opt_params, ["test_acc"], start=0, end=None, alpha=1.0, linewidth=1.0, ylabel = "Test Accuracy", titles=[""], legends=[["sgd-2e5", "sgd-no", "adam-2e5", "adam-no", "DiffSketch"]], save_dir="../plots/nips25privacy/bert_2_nodiff.pdf", return_last=False, return_max=True) #"../plots/iclr25workshop/cifar_client_2.pdf"
max_vals[4] = plot_figures_opts_attr([["sgdm-2e5-n4", "sgdm-no-n4", "adam-2e5-n4", "adam-no-n4", ]], model_params, opt_params, ["test_acc"], start=5, end=None, alpha=1.0, linewidth=1.0, ylabel = "Test Accuracy", titles=[""], legends=[["sgd-2e5", "sgd-no", "adam-2e5", "adam-no", "DiffSketch"]], save_dir="../plots/nips25privacy/bert_4_nodiff.pdf", return_last=False, return_max=True) #"../plots/iclr25workshop/cifar_client_2.pdf"

max_vals_train = {}
max_vals_train[0.8] = plot_figures_opts_attr([["sgdm-2e5-n0.8", "sgdm-no-n0.8", "adam-2e5-n0.8", "adam-no-n0.8", ]], model_params, opt_params, ["acc"], start=0, end=None, alpha=1.0, linewidth=1.0, ylabel = "Train Accuracy", titles=[""], legends=[["sgd-2e5", "sgd-no", "adam-2e5", "adam-no", "DiffSketch"]], save_dir="../plots/nips25privacy/bert_0.8_train_nodiff.pdf", return_last=False, return_max=True) #"../plots/iclr25workshop/cifar_client_2.pdf"
max_vals_train[1] = plot_figures_opts_attr([["sgdm-2e5-n1", "sgdm-no-n1", "adam-2e5-n1", "adam-no-n1", ]], model_params, opt_params, ["acc"], start=0, end=None, alpha=1.0, linewidth=1.0, ylabel = "Train Accuracy", titles=[""], legends=[["sgd-2e5", "sgd-no", "adam-2e5", "adam-no", "DiffSketch"]], save_dir="../plots/nips25privacy/bert_1_train_nodiff.pdf", return_last=False, return_max=True) #"../plots/iclr25workshop/cifar_client_2.pdf"
max_vals_train[2] = plot_figures_opts_attr([["sgdm-2e5-n2", "sgdm-no-n2", "adam-2e5-n2", "adam-no-n2", ]], model_params, opt_params, ["acc"], start=0, end=None, alpha=1.0, linewidth=1.0, ylabel = "Train Accuracy", titles=[""], legends=[["sgd-2e5", "sgd-no", "adam-2e5", "adam-no", "DiffSketch"]], save_dir="../plots/nips25privacy/bert_2_train_nodiff.pdf", return_last=False, return_max=True) #"../plots/iclr25workshop/cifar_client_2.pdf"
max_vals_train[4] = plot_figures_opts_attr([["sgdm-2e5-n4", "sgdm-no-n4", "adam-2e5-n4", "adam-no-n4", ]], model_params, opt_params, ["acc"], start=5, end=None, alpha=1.0, linewidth=1.0, ylabel = "Train Accuracy", titles=[""], legends=[["sgd-2e5", "sgd-no", "adam-2e5", "adam-no", "DiffSketch"]], save_dir="../plots/nips25privacy/bert_4_train_nodiff.pdf", return_last=False, return_max=True) #"../plots/iclr25workshop/cifar_client_2.pdf"
# Out:
# /projects/illinois/eng/cs/arindamb/lucmon/mlopt/results/glue/CrossEntropyLoss/federated/google-bert/bert-base-cased/task_name_sst2/seq_length_128/server_opt_sgd/client_opt_sgd/client_lr_0.001/client_momentum_0.0/client_weight_decay_0.0/client_num_625/client_epoch_1/sketch_size_200000/client_partial_0.0064/privacy_clip_1.0/privacy_noise_0.1049/scheduler_cosine/lr_min_0.01/lr_0.1/moment_0.9/wd_0.0001/batch_size_12/epoch_200/run_0/
# /projects/illinois/eng/cs/arindamb/lucmon/mlopt/results/glue/CrossEntropyLoss/federated/google-bert/bert-base-cased/task_name_sst2/seq_length_128/server_opt_sgd/client_opt_sgd/client_lr_0.001/client_momentum_0.0/client_weight_decay_0.0/client_num_625/client_epoch_1/sketch_size_-1/client_partial_0.0064/privacy_clip_1.0/privacy_noise_0.8/scheduler_cosine/lr_min_0.01/lr_0.1/moment_0.9/wd_0.0001/batch_size_12/epoch_200/run_0/
# ...

# %%
import numpy as np

import matplotlib.pyplot as plt
noise = [0.8, 1, 2,4]
epsilon = [2.76, 1.60, 0.42, 0.18]
legends = ["sgd-4e5","sgd-no","adam-4e5","adam-no"]
for i in range(len(legends)):
    array = []
    for n in noise:
        array.append(max_vals[n][0][i])
    plt.plot(epsilon, array)

plt.legend(legends)
plt.ylabel("Test Accuracy")
plt.xlabel(r"$\epsilon$")
plt.savefig("../plots/nips25privacy/sst_test_acc_trend_nodiff.pdf")

# %%
import numpy as np

import matplotlib.pyplot as plt
noise = [0.8, 1, 2,4]
epsilon = [2.76, 1.60, 0.42, 0.18]
legends = ["sgd-4e5","sgd-no","adam-4e5","adam-no"]
for i in range(len(legends)):
    array = []
    for n in noise:
        array.append(max_vals_train[n][0][i])
    plt.plot(epsilon, array)

plt.legend(legends)
plt.ylabel("Test Accuracy")
plt.xlabel(r"$\epsilon$")
plt.savefig("../plots/nips25privacy/sst_train_acc_trend_nodiff.pdf")

# %%
max_vals
# Out:
# {}

# %%
/projects/illinois/eng/cs/arindamb/lucmon/mlopt/results/glue/CrossEntropyLoss/federated/google-bert/bert-base-cased/task_name_sst2/seq_length_128/server_opt_fetchsgd/client_opt_sgd/client_lr_0.001/client_momentum_0.0/client_weight_decay_0.0/client_num_625/client_epoch_1/sketch_size_200000/client_partial_0.0064/privacy_clip_1.0/privacy_noise_0.2691/scheduler_cosine/lr_min_0.5/lr_0.8/moment_0.9/wd_0.0001/batch_size_12/epoch_200/run_0/train_graphs.pk

/projects/illinois/eng/cs/arindamb/lucmon/mlopt/results/glue/CrossEntropyLoss/federated/google-bert/bert-base-cased/task_name_sst2/seq_length_128/server_opt_fetchsgd/client_opt_sgd/client_lr_0.001/client_momentum_0.0/client_weight_decay_0.0/client_num_625/client_epoch_1/sketch_size_200000/client_partial_0.0064/privacy_clip_1.0/privacy_noise_0.1049/scheduler_cosine/lr_min_0.01/lr_0.8/moment_0.9/wd_0.0001/batch_size_12/epoch_200/run_0/

# %%
max_vals
# Out:
# {4: [[0.8795871559633027,
#    0.8084862385321101,
#    0.9036697247706422,
#    0.8463302752293578]],
#  2: [[0.8795871559633027,
#    0.8807339449541285,
#    0.908256880733945,
#    0.8738532110091743]],
#  1: [[0.8807339449541285,
#    0.8864678899082569,
#    0.9059633027522935,
#    0.8910550458715596]],
#  0.8: [[0.8818807339449541,
#    0.8864678899082569,
#    0.9105504587155964,
#    0.8956422018348624]]}

# %%
/projects/illinois/eng/cs/arindamb/lucmon/mlopt/results/glue/CrossEntropyLoss/federated/google-bert/bert-base-cased/task_name_sst2/seq_length_128/server_opt_adam/client_opt_sgd/client_lr_0.001/client_momentum_0.0/client_weight_decay_0.0/client_num_625/client_epoch_1/sketch_size_200000/client_partial_0.0064/privacy_clip_1.0/privacy_noise_1.0/scheduler_cosine/lr_min_0.001/lr_0.001/moment_0.9/wd_0.0001/batch_size_12/epoch_200/

/projects/illinois/eng/cs/arindamb/lucmon/mlopt/results/glue/CrossEntropyLoss/federated/google-bert/bert-base-cased/task_name_sst2/seq_length_128/server_opt_adam/client_opt_sgd/client_lr_0.001/client_momentum_0.0/client_weight_decay_0.0/client_num_625/client_epoch_1/sketch_size_-1/client_partial_0.0064/privacy_clip_1.0/privacy_noise_1.0/scheduler_cosine/lr_min_0.001/lr_0.001/moment_0.9/wd_0.0001/batch_size_12/epoch_200/run_0/
