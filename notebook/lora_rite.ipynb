# %%
from plot_functions import plot_figures_opts_attrs
from main import graphs

lr, dataset_name, loss_name, opt_name, momentum, weight_decay, batch_size, epochs = 0.001, "20newsgroups", 'CrossEntropyLoss', "sgd", 0.9, 0.0, 128, 60
model_name= "gpt2"

model_params = {}
model_params["lora"] = {"lora_rank": 16, "lora_alpha": 16}
model_params["lora_adam"] = {"lora_rank": 16, "lora_alpha": 16}
model_params["rite_1e-3"] = {"lora_rank": 16, "lora_alpha": 16}
model_params["rite_1e-2"] = {"lora_rank": 16, "lora_alpha": 16}
model_params["rite_v2"] = {"lora_rank": 16, "lora_alpha": 16}

opt_params = {}
opt_params["lora"] = {'lr': lr, 'dataset_name':dataset_name, 'loss': loss_name, 'opt':"sgd", 'model_name':model_name, 'momentum':momentum, 'weight_decay':weight_decay, 'batch_size':batch_size, 'epochs':epochs}
opt_params["lora_adam"] = {'lr': 0.001, 'dataset_name':dataset_name, 'loss': loss_name, 'opt':"adam", 'model_name':model_name, 'momentum':momentum, 'weight_decay':weight_decay, 'batch_size':batch_size, 'epochs':epochs}
opt_params["rite_1e-3"] = {'lr': 0.01, 'dataset_name':dataset_name, 'loss': loss_name, 'opt':"lora_rite", 'model_name':model_name, 'momentum':momentum, 'weight_decay':weight_decay, 'batch_size':batch_size, 'epochs':epochs}
opt_params["rite_1e-2"] = {'lr': 0.011, 'dataset_name':dataset_name, 'loss': loss_name, 'opt':"lora_rite", 'model_name':model_name, 'momentum':momentum, 'weight_decay':weight_decay, 'batch_size':batch_size, 'epochs':epochs}
opt_params["rite_v2"] = {'lr': 0.01, 'dataset_name':dataset_name, 'loss': loss_name, 'opt':"lora_rite_v2", 'model_name':model_name, 'momentum':momentum, 'weight_decay':weight_decay, 'batch_size':batch_size, 'epochs':epochs}

plot_figures_opts_attrs(["lora", "lora_adam", "rite_1e-3"], model_params, opt_params, attrs=["loss", "accuracy", "test_loss", "test_accuracy"], start=30)
# Out:
# /projects/bdch/lucmon/mlopt/results/20newsgroups/CrossEntropyLoss/sgd/gpt2/lora_rank_16/lora_alpha_16/lr_0.001/moment_0.9/wd_0.0/batch_size_128/epoch_60/
# 1
# 1
# 1
# 1
# /projects/bdch/lucmon/mlopt/results/20newsgroups/CrossEntropyLoss/adam/gpt2/lora_rank_16/lora_alpha_16/lr_0.001/moment_0.9/wd_0.0/batch_size_128/epoch_60/
# 1
# 1
# 1
# 1
# /projects/bdch/lucmon/mlopt/results/20newsgroups/CrossEntropyLoss/lora_rite/gpt2/lora_rank_16/lora_alpha_16/lr_0.01/moment_0.9/wd_0.0/batch_size_128/epoch_60/
# 1
# 1
# 1
# 1

# %%
/projects/bdch/lucmon/mlopt/results/20newsgroups/CrossEntropyLoss/lora_rite/gpt2/lora_rank_16/lora_alpha_16/lr_0.001/moment_0.9/wd_0.0/batch_size_128/epoch_60/

/projects/bdch/lucmon/mlopt/results/20newsgroups/CrossEntropyLoss/lora_rite/gpt2/lora_rank_16/lora_alpha_16/base_opt_sgd/lr_0.001/moment_0.9/wd_0.0/batch_size_128/epoch_60/run_0/

# %%
from plot_functions import get_attr
from main import graphs
ratio_A = get_attr("lora", model_params, opt_params, "ratio_A", eval_graph=False)
# Out:
# /projects/bdch/lucmon/mlopt/results/20newsgroups/CrossEntropyLoss/sgd/gpt2/lora_rank_16/lora_alpha_16/lr_0.001/moment_0.9/wd_0.0/batch_size_128/epoch_60/

# %%
len(ratio_A[0][50][40])
# Out:
# 48

# %%
from plot_functions import plot_figures_opts_attrs
from main import graphs

lr, dataset_name, loss_name, opt_name, momentum, weight_decay, batch_size, epochs = 0.001, "swag", 'CrossEntropyLoss', "sgd", 0.9, 0.0, 128, 60
model_name= "roberta-base"

model_params = {}
model_params["lora"] = {"lora_rank": 16, "lora_alpha": 16}
model_params["rite"] = {"lora_rank": 16, "lora_alpha": 16}

opt_params = {}
opt_params["lora"] = {'lr': lr, 'dataset_name':dataset_name, 'loss': loss_name, 'opt':"sgd", 'model_name':model_name, 'momentum':momentum, 'weight_decay':weight_decay, 'batch_size':batch_size, 'epochs':epochs}
opt_params["lora"] = {'lr': lr, 'dataset_name':dataset_name, 'loss': loss_name, 'opt':"adam", 'model_name':model_name, 'momentum':momentum, 'weight_decay':weight_decay, 'batch_size':batch_size, 'epochs':epochs}

opt_params["rite"] = {'lr': 0.001, 'dataset_name':dataset_name, 'loss': loss_name, 'opt':"lora_rite", 'model_name':model_name, 'momentum':momentum, 'weight_decay':weight_decay, 'batch_size':batch_size, 'epochs':epochs}

plot_figures_opts_attrs(["lora", "rite"], model_params, opt_params, attrs=["loss", "accuracy", "test_loss", "test_accuracy"], start=0)
# Out:
# /projects/bdch/lucmon/mlopt/results/swag/CrossEntropyLoss/adam/roberta-base/lora_rank_16/lora_alpha_16/lr_0.001/moment_0.9/wd_0.0/batch_size_128/epoch_60/
# 1
# 1
# 1
# 1
# /projects/bdch/lucmon/mlopt/results/swag/CrossEntropyLoss/lora_rite/roberta-base/lora_rank_16/lora_alpha_16/lr_0.001/moment_0.9/wd_0.0/batch_size_128/epoch_60/
# 1
# 1
# 1
# 1

# %%
from plot_functions import get_attr
from main import graphs
import matplotlib.pyplot as plt

lr, dataset_name, loss_name, opt_name, momentum, weight_decay, batch_size, epochs = 0.001, "20newsgroups", 'CrossEntropyLoss', "sgd", 0.9, 0.0, 128, 60
model_name= "gpt2"

model_params = {}
model_params["lora"] = {"lora_rank": 16, "lora_alpha": 16}
model_params["lora_adam"] = {"lora_rank": 16, "lora_alpha": 16}
model_params["rite_1e-3"] = {"lora_rank": 16, "lora_alpha": 16}
model_params["rite_1e-2"] = {"lora_rank": 16, "lora_alpha": 16}
model_params["rite_v2"] = {"lora_rank": 16, "lora_alpha": 16}

opt_params = {}
opt_params["lora"] = {'lr': lr, 'dataset_name':dataset_name, 'loss': loss_name, 'opt':"sgd", 'model_name':model_name, 'momentum':momentum, 'weight_decay':weight_decay, 'batch_size':batch_size, 'epochs':epochs}
opt_params["lora_adam"] = {'lr': 0.001, 'dataset_name':dataset_name, 'loss': loss_name, 'opt':"adam", 'model_name':model_name, 'momentum':momentum, 'weight_decay':weight_decay, 'batch_size':batch_size, 'epochs':epochs}
opt_params["rite_1e-3"] = {'lr': 0.001, 'dataset_name':dataset_name, 'loss': loss_name, 'opt':"lora_rite", 'model_name':model_name, 'momentum':momentum, 'weight_decay':weight_decay, 'batch_size':batch_size, 'epochs':epochs}
opt_params["rite_1e-2"] = {'lr': 0.01, 'dataset_name':dataset_name, 'loss': loss_name, 'opt':"lora_rite", 'model_name':model_name, 'momentum':momentum, 'weight_decay':weight_decay, 'batch_size':batch_size, 'epochs':epochs}
opt_params["rite_v2"] = {'lr': 0.01, 'dataset_name':dataset_name, 'loss': loss_name, 'opt':"lora_rite_v2", 'model_name':model_name, 'momentum':momentum, 'weight_decay':weight_decay, 'batch_size':batch_size, 'epochs':epochs}

effective_rank = {}
effective_rank["lora_adam"] = get_attr("lora_adam", model_params, opt_params, "effective_rank", eval_graph=True)
effective_rank["lora_rite"] = get_attr("rite_1e-2", model_params, opt_params, "effective_rank", eval_graph=True)

plt.figure(figsize=(5,5))
plt.plot(effective_rank["lora_adam"][0], marker="^")
plt.plot(effective_rank["lora_rite"][0], marker = "o")
plt.xlabel("layer")
plt.ylabel("effective rank (max: 16)")
plt.legend(["lora_adam", "lora_rite"])
# Out:
# /projects/bdch/lucmon/mlopt/results/20newsgroups/CrossEntropyLoss/adam/gpt2/lora_rank_16/lora_alpha_16/lr_0.001/moment_0.9/wd_0.0/batch_size_128/epoch_60/
# /projects/bdch/lucmon/mlopt/results/20newsgroups/CrossEntropyLoss/lora_rite/gpt2/lora_rank_16/lora_alpha_16/lr_0.01/moment_0.9/wd_0.0/batch_size_128/epoch_60/

# %%
from plot_functions import get_attr
from main import graphs
import matplotlib.pyplot as plt

lr, dataset_name, loss_name, opt_name, momentum, weight_decay, batch_size, epochs = 0.001, "20newsgroups", 'CrossEntropyLoss', "sgd", 0.9, 0.0, 128, 60
model_name= "gpt2"

model_params = {}
model_params["lora"] = {"lora_rank": 16, "lora_alpha": 16}
model_params["lora_adam"] = {"lora_rank": 16, "lora_alpha": 16}
model_params["rite_1e-3"] = {"lora_rank": 16, "lora_alpha": 16}
model_params["rite_1e-2"] = {"lora_rank": 16, "lora_alpha": 16}
model_params["rite_v2"] = {"lora_rank": 16, "lora_alpha": 16}

opt_params = {}
opt_params["lora"] = {'lr': lr, 'dataset_name':dataset_name, 'loss': loss_name, 'opt':"sgd", 'model_name':model_name, 'momentum':momentum, 'weight_decay':weight_decay, 'batch_size':batch_size, 'epochs':epochs}
opt_params["lora_adam"] = {'lr': 0.001, 'dataset_name':dataset_name, 'loss': loss_name, 'opt':"adam", 'model_name':model_name, 'momentum':momentum, 'weight_decay':weight_decay, 'batch_size':batch_size, 'epochs':epochs}
opt_params["rite_1e-3"] = {'lr': 0.001, 'dataset_name':dataset_name, 'loss': loss_name, 'opt':"lora_rite", 'model_name':model_name, 'momentum':momentum, 'weight_decay':weight_decay, 'batch_size':batch_size, 'epochs':epochs}
opt_params["rite_1e-2"] = {'lr': 0.01, 'dataset_name':dataset_name, 'loss': loss_name, 'opt':"lora_rite", 'model_name':model_name, 'momentum':momentum, 'weight_decay':weight_decay, 'batch_size':batch_size, 'epochs':epochs}
opt_params["rite_v2"] = {'lr': 0.01, 'dataset_name':dataset_name, 'loss': loss_name, 'opt':"lora_rite_v2", 'model_name':model_name, 'momentum':momentum, 'weight_decay':weight_decay, 'batch_size':batch_size, 'epochs':epochs}

effective_rank = {}
effective_rank["lora_adam"] = get_attr("lora_adam", model_params, opt_params, "stable_rank", eval_graph=True)
effective_rank["lora_rite"] = get_attr("rite_1e-2", model_params, opt_params, "stable_rank", eval_graph=True)

plt.figure(figsize=(5,5))
plt.plot(effective_rank["lora_adam"][0][49:], marker="^")
plt.plot(effective_rank["lora_rite"][0][98:], marker = "o")
plt.xlabel("layer")
plt.ylabel("stable rank (max: 16)")
plt.legend(["lora_adam", "lora_rite"])
# Out:
# /projects/bdch/lucmon/mlopt/results/20newsgroups/CrossEntropyLoss/adam/gpt2/lora_rank_16/lora_alpha_16/lr_0.001/moment_0.9/wd_0.0/batch_size_128/epoch_60/
# /projects/bdch/lucmon/mlopt/results/20newsgroups/CrossEntropyLoss/lora_rite/gpt2/lora_rank_16/lora_alpha_16/lr_0.01/moment_0.9/wd_0.0/batch_size_128/epoch_60/

# %%
len(effective_rank["lora_adam"][0])
# Out:
# 96

# %%
from plot_functions import get_attr
from main import graphs
import matplotlib.pyplot as plt
lr, dataset_name, loss_name, opt_name, momentum, weight_decay, batch_size, epochs = 0.001, "swag", 'CrossEntropyLoss', "sgd", 0.9, 0.0, 128, 60
model_name= "roberta-base"

model_params = {}
model_params["lora"] = {"lora_rank": 16, "lora_alpha": 16}
model_params["rite"] = {"lora_rank": 16, "lora_alpha": 16}

opt_params = {}
opt_params["lora"] = {'lr': lr, 'dataset_name':dataset_name, 'loss': loss_name, 'opt':"sgd", 'model_name':model_name, 'momentum':momentum, 'weight_decay':weight_decay, 'batch_size':batch_size, 'epochs':epochs}
#opt_params["lora"] = {'lr': lr, 'dataset_name':dataset_name, 'loss': loss_name, 'opt':"adam", 'model_name':model_name, 'momentum':momentum, 'weight_decay':weight_decay, 'batch_size':batch_size, 'epochs':epochs}

opt_params["rite"] = {'lr': 0.001, 'dataset_name':dataset_name, 'loss': loss_name, 'opt':"lora_rite", 'model_name':model_name, 'momentum':momentum, 'weight_decay':weight_decay, 'batch_size':batch_size, 'epochs':epochs}

effective_rank = {}
effective_rank["lora_adam"] = get_attr("lora", model_params, opt_params, "effective_rank", eval_graph=True)
effective_rank["lora_rite"] = get_attr("rite", model_params, opt_params, "effective_rank", eval_graph=True)

plt.figure(figsize=(5,5))
plt.plot(effective_rank["lora_adam"][0], marker="^")
plt.plot(effective_rank["lora_rite"][0], marker = "o")
plt.xlabel("layer")
plt.ylabel("effective rank")
plt.legend(["lora_adam", "lora_rite"])
# Out:
# /projects/bdch/lucmon/mlopt/results/swag/CrossEntropyLoss/sgd/roberta-base/lora_rank_16/lora_alpha_16/lr_0.001/moment_0.9/wd_0.0/batch_size_128/epoch_60/
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /u/lucmon/lucmon/mlopt/notebook/lora_rite.ipynb Cell 7 line 1
#      <a href='vscode-notebook-cell://ssh-remote%2Bdelta/u/lucmon/lucmon/mlopt/notebook/lora_rite.ipynb#W6sdnNjb2RlLXJlbW90ZQ%3D%3D?line=14'>15</a> opt_params["rite"] = {'lr': 0.001, 'dataset_name':dataset_name, 'loss': loss_name, 'opt':"lora_rite", 'model_name':model_name, 'momentum':momentum, 'weight_decay':weight_decay, 'batch_size':batch_size, 'epochs':epochs}
#      <a href='vscode-notebook-cell://ssh-remote%2Bdelta/u/lucmon/lucmon/mlopt/notebook/lora_rite.ipynb#W6sdnNjb2RlLXJlbW90ZQ%3D%3D?line=16'>17</a> effective_rank = {}
# ...
