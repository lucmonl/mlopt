# %%
from plot_functions import plot_figures_opts_attrs
from main import graphs

lr, dataset_name, loss_name, opt_name, momentum, weight_decay, batch_size, epochs = 0.001, "swag", 'CrossEntropyLoss', "federated", 0.9, 0.0001, 32, 1000
model_name = "roberta-base"
client_opt, client_lr, client_momentum, client_weight_decay, client_num, client_epoch, sketch_size ="adam", 0.001, 0.9, 0.0, 100, 1, -1

model_params = {}
model_params["lora_avg"] = {"lora_rank": 16, "lora_alpha": 16,  "fedlora_uba": -1.0,  'server_opt': 'adam', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, "client_weight_decay": client_weight_decay, "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": sketch_size}
model_params["lora_svd"] = {"lora_rank": 16, "lora_alpha": 16,  "fedlora_avg": "svd", "fedlora_uba": 1.0, 'server_opt': 'adam', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, "client_weight_decay": client_weight_decay, "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": sketch_size}
model_params["lora_svd_2.0"] = {"lora_rank": 16, "lora_alpha": 16,  "fedlora_avg": "svd", "fedlora_uba": 2.0, 'server_opt': 'adam', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, "client_weight_decay": client_weight_decay, "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": sketch_size}
model_params["lora_svd_3.0"] = {"lora_rank": 16, "lora_alpha": 16,  "fedlora_avg": "svd", "fedlora_uba": 3.0, 'server_opt': 'adam', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, "client_weight_decay": client_weight_decay, "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": sketch_size}
model_params["lora_svd_3.0"] = {"lora_rank": 16, "lora_alpha": 16,  "fedlora_avg": "svd", "fedlora_uba": 3.0, 'server_opt': 'adam', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, "client_weight_decay": client_weight_decay, "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": sketch_size}
model_params["lora_fedex"] = {"lora_rank": 16, "lora_alpha": 16,  "fedlora_avg": "fedex", 'server_opt': 'sgd', 'client_opt': "adam", 'client_lr': client_lr, 'client_momentum': 0.9, "client_weight_decay": client_weight_decay, "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": sketch_size}
model_params["lora_flora"] = {"lora_rank": 16, "lora_alpha": 16,  "fedlora_avg": "flora", 'server_opt': 'sgd', 'client_opt': "adam", 'client_lr': client_lr, 'client_momentum': 0.9, "client_weight_decay": client_weight_decay, "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": sketch_size}


model_params["lora_svd_ef"] = {"lora_rank": 16, "lora_alpha": 16,  "fedlora_avg": "svd", "fedlora_uba": 1.0, 'use_ef': 1, 'server_opt': 'sgd', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, "client_weight_decay": client_weight_decay, "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": sketch_size}
model_params["lora_svd_60"] = model_params["lora_svd"]

opt_params = {}
opt_params["lora_svd"] = {'lr': 0.001, 'dataset_name':dataset_name, 'loss': loss_name, 'opt':opt_name, 'model_name':model_name, 'momentum':momentum, 'weight_decay':weight_decay, 'batch_size':batch_size, 'epochs':60}
opt_params["lora_avg"] = {'lr': 0.001, 'dataset_name':dataset_name, 'loss': loss_name, 'opt':opt_name, 'model_name':model_name, 'momentum':momentum, 'weight_decay':weight_decay, 'batch_size':batch_size, 'epochs':60}
#opt_params["lora_avg"] = {'lr': 0.01, 'dataset_name':dataset_name, 'loss': loss_name, 'opt':opt_name, 'model_name':model_name, 'momentum':momentum, 'weight_decay':weight_decay, 'batch_size':batch_size, 'epochs':60}
opt_params["lora_svd_2.0"] = {'lr': lr, 'dataset_name':dataset_name, 'loss': loss_name, 'opt':opt_name, 'model_name':model_name, 'momentum':momentum, 'weight_decay':weight_decay, 'batch_size':batch_size, 'epochs':100}
opt_params["lora_fedex"] = {'lr': 2.0, 'dataset_name':dataset_name, 'loss': loss_name, 'opt':opt_name, 'model_name':model_name, 'momentum':momentum, 'weight_decay':weight_decay, 'batch_size':batch_size, 'epochs':60}
opt_params["lora_flora"] = {'lr': 1.0, 'dataset_name':dataset_name, 'loss': loss_name, 'opt':opt_name, 'model_name':model_name, 'momentum':momentum, 'weight_decay':weight_decay, 'batch_size':batch_size, 'epochs':60}

opt_params["lora_svd_60"] = {'lr': lr, 'dataset_name':dataset_name, 'loss': loss_name, 'opt':opt_name, 'model_name':model_name, 'momentum':momentum, 'weight_decay':weight_decay, 'batch_size':batch_size, 'epochs':60}
opt_params["lora_svd_3.0"] = opt_params["lora_svd_60"]

#plot_figures_opts_attrs(["lora_avg", "lora_avg_0.5", "lora_avg_1.0", "lora_avg_2.0", "lora_avg_3.0"], model_params, opt_params, attrs=["loss", "accuracy", "test_loss", "test_accuracy"], start=10)
plot_figures_opts_attrs(["lora_avg", "lora_svd", "lora_fedex", "lora_flora"], model_params, opt_params, attrs=["loss","accuracy", "test_loss", "test_accuracy"], start=10, end=60)
# Out:
# /projects/bdch/lucmon/mlopt/results/swag/CrossEntropyLoss/federated/roberta-base/lora_rank_16/lora_alpha_16/fedlora_uba_-1.0/server_opt_adam/client_opt_adam/client_lr_0.001/client_momentum_0.9/client_weight_decay_0.0/client_num_100/client_epoch_1/sketch_size_-1/lr_0.001/moment_0.9/wd_0.0001/batch_size_32/epoch_60/
# 1
# 1
# 1
# 1
# /projects/bdch/lucmon/mlopt/results/swag/CrossEntropyLoss/federated/roberta-base/lora_rank_16/lora_alpha_16/fedlora_avg_svd/fedlora_uba_1.0/server_opt_adam/client_opt_adam/client_lr_0.001/client_momentum_0.9/client_weight_decay_0.0/client_num_100/client_epoch_1/sketch_size_-1/lr_0.001/moment_0.9/wd_0.0001/batch_size_32/epoch_60/
# 1
# 1
# 1
# 1
# /projects/bdch/lucmon/mlopt/results/swag/CrossEntropyLoss/federated/roberta-base/lora_rank_16/lora_alpha_16/fedlora_avg_fedex/server_opt_sgd/client_opt_adam/client_lr_0.001/client_momentum_0.9/client_weight_decay_0.0/client_num_100/client_epoch_1/sketch_size_-1/lr_2.0/moment_0.9/wd_0.0001/batch_size_32/epoch_60/
# ...

# %%
#effect of client num
from plot_functions import plot_figures_opts_attrs
from main import graphs

lr, dataset_name, loss_name, opt_name, momentum, weight_decay, batch_size, epochs = 0.001, "swag", 'CrossEntropyLoss', "federated", 0.9, 0.0001, 32, 60
model_name = "roberta-base"
client_opt, client_lr, client_momentum, client_weight_decay, client_num, client_epoch, sketch_size ="adam", 0.001, 0.9, 0.0, 100, 1, -1

model_params, opt_params = {}, {}
client_num, batch_size = 100, 32
model_params["lora_avg_100"] = {"lora_rank": 16, "lora_alpha": 16,  "fedlora_uba": -1.0,  'server_opt': 'adam', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, "client_weight_decay": client_weight_decay, "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": sketch_size}
model_params["lora_svd_100"] = {"lora_rank": 16, "lora_alpha": 16,  "fedlora_avg": "svd", "fedlora_uba": 1.0, 'server_opt': 'adam', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, "client_weight_decay": client_weight_decay, "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": sketch_size}
opt_params["lora_svd_100"] = {'lr': 0.001, 'dataset_name':dataset_name, 'loss': loss_name, 'opt':opt_name, 'model_name':model_name, 'momentum':momentum, 'weight_decay':weight_decay, 'batch_size':batch_size, 'epochs':epochs}
opt_params["lora_avg_100"] = {'lr': 0.001, 'dataset_name':dataset_name, 'loss': loss_name, 'opt':opt_name, 'model_name':model_name, 'momentum':momentum, 'weight_decay':weight_decay, 'batch_size':batch_size, 'epochs':epochs}
client_num, batch_size = 400, 8
model_params["lora_avg_400"] = {"lora_rank": 16, "lora_alpha": 16,  "fedlora_uba": -1.0,  'server_opt': 'adam', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, "client_weight_decay": client_weight_decay, "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": sketch_size}
model_params["lora_svd_400"] = {"lora_rank": 16, "lora_alpha": 16,  "fedlora_avg": "svd", "fedlora_uba": 1.0, 'server_opt': 'adam', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, "client_weight_decay": client_weight_decay, "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": sketch_size}
opt_params["lora_svd_400"] = {'lr': 0.001, 'dataset_name':dataset_name, 'loss': loss_name, 'opt':opt_name, 'model_name':model_name, 'momentum':momentum, 'weight_decay':weight_decay, 'batch_size':batch_size, 'epochs':epochs}
opt_params["lora_avg_400"] = {'lr': 0.001, 'dataset_name':dataset_name, 'loss': loss_name, 'opt':opt_name, 'model_name':model_name, 'momentum':momentum, 'weight_decay':weight_decay, 'batch_size':batch_size, 'epochs':epochs}
client_num, batch_size = 25, 128
model_params["lora_avg_25"] = {"lora_rank": 16, "lora_alpha": 16,  "fedlora_uba": -1.0,  'server_opt': 'adam', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, "client_weight_decay": client_weight_decay, "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": sketch_size}
model_params["lora_svd_25"] = {"lora_rank": 16, "lora_alpha": 16,  "fedlora_avg": "svd", "fedlora_uba": 1.0, 'server_opt': 'adam', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, "client_weight_decay": client_weight_decay, "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": sketch_size}
opt_params["lora_svd_25"] = {'lr': 0.001, 'dataset_name':dataset_name, 'loss': loss_name, 'opt':opt_name, 'model_name':model_name, 'momentum':momentum, 'weight_decay':weight_decay, 'batch_size':batch_size, 'epochs':epochs}
opt_params["lora_avg_25"] = {'lr': 0.001, 'dataset_name':dataset_name, 'loss': loss_name, 'opt':opt_name, 'model_name':model_name, 'momentum':momentum, 'weight_decay':weight_decay, 'batch_size':batch_size, 'epochs':epochs}

plot_figures_opts_attrs(["lora_avg_25", "lora_avg_100", "lora_avg_400", "lora_svd_25", "lora_svd_100", "lora_svd_400"], model_params, opt_params, attrs=["loss","accuracy", "test_loss", "test_accuracy"], start=1, end=60)
# Out:
# /projects/bdch/lucmon/mlopt/results/swag/CrossEntropyLoss/federated/roberta-base/lora_rank_16/lora_alpha_16/fedlora_uba_-1.0/server_opt_adam/client_opt_adam/client_lr_0.001/client_momentum_0.9/client_weight_decay_0.0/client_num_25/client_epoch_1/sketch_size_-1/lr_0.001/moment_0.9/wd_0.0001/batch_size_128/epoch_60/
# 1
# 1
# 1
# 1
# /projects/bdch/lucmon/mlopt/results/swag/CrossEntropyLoss/federated/roberta-base/lora_rank_16/lora_alpha_16/fedlora_uba_-1.0/server_opt_adam/client_opt_adam/client_lr_0.001/client_momentum_0.9/client_weight_decay_0.0/client_num_100/client_epoch_1/sketch_size_-1/lr_0.001/moment_0.9/wd_0.0001/batch_size_32/epoch_60/
# 1
# 1
# 1
# 1
# /projects/bdch/lucmon/mlopt/results/swag/CrossEntropyLoss/federated/roberta-base/lora_rank_16/lora_alpha_16/fedlora_uba_-1.0/server_opt_adam/client_opt_adam/client_lr_0.001/client_momentum_0.9/client_weight_decay_0.0/client_num_400/client_epoch_1/sketch_size_-1/lr_0.001/moment_0.9/wd_0.0001/batch_size_8/epoch_60/
# 1
# 1
# 1
# ...

# %%
#swag dataset baselines
# client adamw
from plot_functions import plot_figures_opts_attrs
from main import graphs

lr, dataset_name, loss_name, opt_name, momentum, weight_decay, batch_size, epochs = 0.001, "20newsgroups", 'CrossEntropyLoss', "federated", 0.9, 0.01, 12, 200
model_name= "gpt2"
client_opt, client_lr, client_momentum, client_weight_decay, client_num, client_epoch, sketch_size, non_iid_alpha  ="adamw", 0.001, 0.9, 0.0, 100, 1, -1, 0.01

model_params = {}
model_params["lora_avg"] = {"non_iid": non_iid_alpha, "lora_rank": 16, "lora_alpha": 16,"fedlora_uba": "-1.0", 'server_opt': 'adamw', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, "client_weight_decay": client_weight_decay, "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": sketch_size}
model_params["lora_svd"] = {"non_iid": non_iid_alpha, "lora_rank": 16, "lora_alpha": 16, "fedlora_avg": "svd", "fedlora_uba": "1.0", 'server_opt': 'adamw', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, "client_weight_decay": client_weight_decay, "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": sketch_size}
model_params["lora_fedex"] = {"non_iid": non_iid_alpha, "lora_rank": 16, "lora_alpha": 16, "fedlora_avg": "fedex",  'server_opt': 'adamw', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, "client_weight_decay": client_weight_decay, "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": sketch_size}
model_params["lora_flora"] = {"non_iid": non_iid_alpha, "lora_rank": 16, "lora_alpha": 16, "fedlora_avg": "flora",  'server_opt': 'adamw', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, "client_weight_decay": client_weight_decay, "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": sketch_size}


opt_params = {}
opt_params["lora_avg"] = {'lr': lr, 'dataset_name':dataset_name, 'loss': loss_name, 'opt':opt_name, 'model_name':model_name, 'momentum':0.9, 'weight_decay':weight_decay, 'batch_size':batch_size, 'epochs':epochs}
opt_params["lora_svd"] = {'lr': lr, 'dataset_name':dataset_name, 'loss': loss_name, 'opt':opt_name, 'model_name':model_name, 'momentum':0.9, 'weight_decay':weight_decay, 'batch_size':batch_size, 'epochs':epochs}
opt_params["lora_fedex"] = {'lr': 1.0, 'dataset_name':dataset_name, 'loss': loss_name, 'opt':opt_name, 'model_name':model_name, 'momentum':0.9, 'weight_decay':weight_decay, 'batch_size':batch_size, 'epochs':epochs}
opt_params["lora_flora"] = {'lr': 1.0, 'dataset_name':dataset_name, 'loss': loss_name, 'opt':opt_name, 'model_name':model_name, 'momentum':0.9, 'weight_decay':weight_decay, 'batch_size':batch_size, 'epochs':epochs}

plot_figures_opts_attrs(["lora_avg", "lora_svd", "lora_fedex", "lora_flora"], model_params, opt_params, attrs=["loss", "accuracy", "test_loss", "test_accuracy"], start=0, end=-1)
# Out:
# /projects/bdch/lucmon/mlopt/results/20newsgroups/CrossEntropyLoss/federated/gpt2/non_iid_0.01/lora_rank_16/lora_alpha_16/fedlora_uba_-1.0/server_opt_adamw/client_opt_adamw/client_lr_0.001/client_momentum_0.9/client_weight_decay_0.0/client_num_100/client_epoch_1/sketch_size_-1/lr_0.001/moment_0.9/wd_0.01/batch_size_12/epoch_200/
# 1
# 1
# 1
# 1
# /projects/bdch/lucmon/mlopt/results/20newsgroups/CrossEntropyLoss/federated/gpt2/non_iid_0.01/lora_rank_16/lora_alpha_16/fedlora_avg_svd/fedlora_uba_1.0/server_opt_adamw/client_opt_adamw/client_lr_0.001/client_momentum_0.9/client_weight_decay_0.0/client_num_100/client_epoch_1/sketch_size_-1/lr_0.001/moment_0.9/wd_0.01/batch_size_12/epoch_200/
# 1
# 1
# 1
# 1
# ...

# %%
# non_iid_alpha
from plot_functions import plot_figures_opts_attrs
from main import graphs

lr, dataset_name, loss_name, opt_name, momentum, weight_decay, batch_size, epochs = 0.001, "20newsgroups", 'CrossEntropyLoss', "federated", 0.9, 0.01, 12, 200
model_name= "gpt2"
client_opt, client_lr, client_momentum, client_weight_decay, client_num, client_epoch, sketch_size, non_iid_alpha  ="adamw", 0.001, 0.9, 0.0, 100, 1, -1, 0.1

model_params = {}
non_iid_alpha = 0.1
model_params["lora_avg_0.1"] = {"non_iid": non_iid_alpha, "lora_rank": 16, "lora_alpha": 16,"fedlora_uba": "-1.0", 'server_opt': 'adamw', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, "client_weight_decay": client_weight_decay, "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": sketch_size}
model_params["lora_svd_0.1"] = {"non_iid": non_iid_alpha, "lora_rank": 16, "lora_alpha": 16, "fedlora_avg": "svd", "fedlora_uba": "1.0", 'server_opt': 'adamw', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, "client_weight_decay": client_weight_decay, "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": sketch_size}
non_iid_alpha = 0.01
model_params["lora_avg_0.01"] = {"non_iid": non_iid_alpha, "lora_rank": 16, "lora_alpha": 16,"fedlora_uba": "-1.0", 'server_opt': 'adamw', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, "client_weight_decay": client_weight_decay, "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": sketch_size}
model_params["lora_svd_0.01"] = {"non_iid": non_iid_alpha, "lora_rank": 16, "lora_alpha": 16, "fedlora_avg": "svd", "fedlora_uba": "1.0", 'server_opt': 'adamw', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, "client_weight_decay": client_weight_decay, "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": sketch_size}


opt_params = {}
opt_params["lora_avg_0.1"] = {'lr': lr, 'dataset_name':dataset_name, 'loss': loss_name, 'opt':opt_name, 'model_name':model_name, 'momentum':0.9, 'weight_decay':weight_decay, 'batch_size':batch_size, 'epochs':epochs}
opt_params["lora_svd_0.1"] = {'lr': lr, 'dataset_name':dataset_name, 'loss': loss_name, 'opt':opt_name, 'model_name':model_name, 'momentum':0.9, 'weight_decay':weight_decay, 'batch_size':batch_size, 'epochs':epochs}
opt_params["lora_avg_0.01"] = opt_params["lora_svd_0.01"] = opt_params["lora_svd_0.1"]
plot_figures_opts_attrs(["lora_avg_0.1", "lora_avg_0.01", "lora_svd_0.1", "lora_svd_0.01"], model_params, opt_params, attrs=["loss", "accuracy", "test_loss", "test_accuracy"], start=0, end=-1)
# Out:
# /projects/bdch/lucmon/mlopt/results/20newsgroups/CrossEntropyLoss/federated/gpt2/non_iid_0.1/lora_rank_16/lora_alpha_16/fedlora_uba_-1.0/server_opt_adamw/client_opt_adamw/client_lr_0.001/client_momentum_0.9/client_weight_decay_0.0/client_num_100/client_epoch_1/sketch_size_-1/lr_0.001/moment_0.9/wd_0.01/batch_size_12/epoch_200/
# 1
# 1
# 1
# 1
# /projects/bdch/lucmon/mlopt/results/20newsgroups/CrossEntropyLoss/federated/gpt2/non_iid_0.01/lora_rank_16/lora_alpha_16/fedlora_uba_-1.0/server_opt_adamw/client_opt_adamw/client_lr_0.001/client_momentum_0.9/client_weight_decay_0.0/client_num_100/client_epoch_1/sketch_size_-1/lr_0.001/moment_0.9/wd_0.01/batch_size_12/epoch_200/
# 1
# 1
# 1
# 1
# ...

# %% [markdown]
# #### CIFAR100

# %%
from plot_functions import plot_figures_opts_attrs
from main import graphs

lr, dataset_name, loss_name, opt_name, momentum, weight_decay, batch_size, epochs = 1.0, "cifar100", 'CrossEntropyLoss', "federated", 0.9, 0.0001, 128, 100
model_name= "google/vit-base-patch16-224-in21k"
client_opt, client_lr, client_momentum, client_weight_decay, client_num, client_epoch, sketch_size, non_iid_alpha  ="sgd", 0.1, 0.0, 0.0, 10, 1, -1, 0.1

model_params = {}
model_params["lora_avg"] = {"non_iid": non_iid_alpha, "lora_rank": 16, "lora_alpha": 16,  "fedlora_uba": -1.0,  'server_opt': 'sgd', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, "client_weight_decay": client_weight_decay, "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": sketch_size}
model_params["lora_avg_1.0"] = {"non_iid": non_iid_alpha, "lora_rank": 16, "lora_alpha": 16,  "fedlora_uba": 1.0,  'server_opt': 'sgd', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, "client_weight_decay": client_weight_decay, "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": sketch_size}
model_params["lora_svd"] = {"non_iid": non_iid_alpha, "lora_rank": 16, "lora_alpha": 16, "fedlora_avg": "svd",  "fedlora_uba": 1.0,  'server_opt': 'sgd', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, "client_weight_decay": client_weight_decay, "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": sketch_size}
model_params["lora_svd_ef"] = {"non_iid": non_iid_alpha, "lora_rank": 16, "lora_alpha": 16, "fedlora_avg": "svd",  "fedlora_uba": 1.0,  'use_ef': 1, 'server_opt': 'sgd', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, "client_weight_decay": client_weight_decay, "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": sketch_size}
model_params["lora_svd_5.0"] = {"non_iid": non_iid_alpha, "lora_rank": 16, "lora_alpha": 16, "fedlora_avg": "svd",  "fedlora_uba": 5.0,  'server_opt': 'sgd', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, "client_weight_decay": client_weight_decay, "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": sketch_size}
model_params["lora_svd_2.0"] = {"non_iid": non_iid_alpha, "lora_rank": 16, "lora_alpha": 16, "fedlora_avg": "svd",  "fedlora_uba": 2.0,  'server_opt': 'sgd', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, "client_weight_decay": client_weight_decay, "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": sketch_size}


opt_params = {}
opt_params["lora_avg"] = {'lr': lr, 'dataset_name':dataset_name, 'loss': loss_name, 'opt':opt_name, 'model_name':model_name, 'momentum':momentum, 'weight_decay':weight_decay, 'batch_size':batch_size, 'epochs':500}
opt_params["lora_svd_5.0"] = {'lr': lr, 'dataset_name':dataset_name, 'loss': loss_name, 'opt':opt_name, 'model_name':model_name, 'momentum':momentum, 'weight_decay':weight_decay, 'batch_size':batch_size, 'epochs':epochs}
opt_params["lora_avg_0.5"] = opt_params["lora_avg_2.0"] = opt_params["lora_avg_3.0"] = opt_params["lora_avg_5.0"] = opt_params["lora_avg_1.0"] = opt_params["lora_svd"] = opt_params["lora_svd_ef"] =opt_params["lora_svd_2.0"] = opt_params["lora_svd_0.5"] = opt_params["lora_svd_3.0"] = opt_params["lora_svd_5.0"]
plot_figures_opts_attrs(["lora_avg", "lora_svd", "lora_svd_ef"], model_params, opt_params, attrs=["loss", "accuracy", "test_loss", "test_accuracy"], start=10, end=20)
# Out:
# /projects/bdch/lucmon/mlopt/results/cifar100/CrossEntropyLoss/federated/google/vit-base-patch16-224-in21k/non_iid_0.1/lora_rank_16/lora_alpha_16/fedlora_uba_-1.0/server_opt_sgd/client_opt_sgd/client_lr_0.1/client_momentum_0.0/client_weight_decay_0.0/client_num_10/client_epoch_1/sketch_size_-1/lr_1.0/moment_0.9/wd_0.0001/batch_size_128/epoch_500/
# 1
# 1
# 1
# 1
# /projects/bdch/lucmon/mlopt/results/cifar100/CrossEntropyLoss/federated/google/vit-base-patch16-224-in21k/non_iid_0.1/lora_rank_16/lora_alpha_16/fedlora_avg_svd/fedlora_uba_1.0/server_opt_sgd/client_opt_sgd/client_lr_0.1/client_momentum_0.0/client_weight_decay_0.0/client_num_10/client_epoch_1/sketch_size_-1/lr_1.0/moment_0.9/wd_0.0001/batch_size_128/epoch_100/
# 1
# 1
# 1
# 1
# ...

# %%
from plot_functions import plot_figures_opts_attrs
from main import graphs

lr, dataset_name, loss_name, opt_name, momentum, weight_decay, batch_size, epochs = 0.001, "cifar100", 'CrossEntropyLoss', "federated", 0.9, 0.01, 12, 200
model_name= "google/vit-base-patch16-224-in21k"
client_opt, client_lr, client_momentum, client_weight_decay, client_num, client_epoch, sketch_size, non_iid_alpha  ="sgd", 0.001, 0.0, 0.0, 100, 1, -1, 0.1

model_params = {}
model_params["lora_avg"] = {"non_iid": non_iid_alpha, "lora_rank": 16, "lora_alpha": 16,  'server_opt': 'adamw', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, "client_weight_decay": client_weight_decay, "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": sketch_size}
model_params["lora_svd"] = {"non_iid": non_iid_alpha, "lora_rank": 16, "lora_alpha": 16,  "fedlora_avg": "svd", 'server_opt': 'adamw', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, "client_weight_decay": client_weight_decay, "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": sketch_size}

opt_params = {}
opt_params["lora_avg"] = {'lr': lr, 'dataset_name':dataset_name, 'loss': loss_name, 'opt':opt_name, 'model_name':model_name, 'momentum':momentum, 'weight_decay':weight_decay, 'batch_size':batch_size, 'epochs':1000}
opt_params["lora_svd"] = {'lr': lr, 'dataset_name':dataset_name, 'loss': loss_name, 'opt':opt_name, 'model_name':model_name, 'momentum':momentum, 'weight_decay':weight_decay, 'batch_size':batch_size, 'epochs':1000}

plot_figures_opts_attrs(["lora_svd"], model_params, opt_params, attrs=["loss", "accuracy", "test_loss", "test_accuracy"], start=10)
# Out:
# /projects/bdch/lucmon/mlopt/results/cifar100/CrossEntropyLoss/federated/google/vit-base-patch16-224-in21k/non_iid_0.1/lora_rank_16/lora_alpha_16/fedlora_avg_svd/server_opt_adamw/client_opt_sgd/client_lr_0.001/client_momentum_0.0/client_weight_decay_0.0/client_num_100/client_epoch_1/sketch_size_-1/lr_0.001/moment_0.9/wd_0.01/batch_size_12/epoch_1000/
# 1
# 1
# 1
# 1

# %%
from plot_functions import plot_figures_opts_attrs
from main import graphs

lr, dataset_name, loss_name, opt_name, momentum, weight_decay, batch_size, epochs = 0.001, "cifar100", 'CrossEntropyLoss', "federated", 0.9, 0.01, 16, 300
model_name= "google/vit-base-patch16-224-in21k"
client_opt, client_lr, client_momentum, client_weight_decay, client_num, client_epoch, sketch_size, non_iid_alpha  ="sgd", 0.001, 0.0, 0.0, 100, 1, -1, 0.01

model_params = {}
model_params["lora_svd"] = {"non_iid": non_iid_alpha, "lora_rank": 16, "lora_alpha": 16,  "fedlora_avg": "svd", "fedlora_uba": -1.0, 'server_opt': 'adamw', 'client_opt': client_opt, 'client_lr': client_lr, 'client_momentum': client_momentum, "client_weight_decay": client_weight_decay, "client_num": client_num, 'client_epoch': client_epoch, "sketch_size": sketch_size}

opt_params = {}
opt_params["lora_svd"] = {'lr': lr, 'dataset_name':dataset_name, 'loss': loss_name, 'opt':opt_name, 'model_name':model_name, 'momentum':momentum, 'weight_decay':weight_decay, 'batch_size':batch_size, 'epochs':epochs}

plot_figures_opts_attrs(["lora_svd"], model_params, opt_params, attrs=["loss", "accuracy", "test_loss", "test_accuracy"], start=10)
# Out:
# /projects/bdch/lucmon/mlopt/results/cifar100/CrossEntropyLoss/federated/google/vit-base-patch16-224-in21k/non_iid_0.01/lora_rank_16/lora_alpha_16/fedlora_avg_svd/fedlora_uba_-1.0/server_opt_adamw/client_opt_sgd/client_lr_0.001/client_momentum_0.0/client_weight_decay_0.0/client_num_100/client_epoch_1/sketch_size_-1/lr_0.001/moment_0.9/wd_0.01/batch_size_16/epoch_300/
# 1
# 1
# 1
# 1

# %%
results/cifar100/CrossEntropyLoss/federated/google/vit-base-patch16-224-in21k/non_iid_0.1/lora_rank_16/lora_alpha_16/fedlora_avg_svd/server_opt_adamw/client_opt_sgd/client_lr_0.001/client_momentum_0.0/client_weight_decay_0.0/client_num_100/client_epoch_1/sketch_size_-1/lr_0.001/moment_0.9/wd_0.01/batch_size_12/epoch_1000/

results/cifar100/CrossEntropyLoss/federated/google/vit-base-patch16-224-in21k/non_iid_0.01/lora_rank_16/lora_alpha_16/fedlora_avg_svd/fedlora_uba_-1.0/server_opt_adamw/client_opt_sgd/client_lr_0.001/client_momentum_0.0/client_weight_decay_0.0/client_num_100/client_epoch_1/sketch_size_-1/lr_0.001/moment_0.9/wd_0.01/batch_size_16/epoch_300
